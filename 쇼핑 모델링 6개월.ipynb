# %% [markdown]
# # 쇼핑 모델링 6개월

# %% [markdown]
# ## 라이브러리 호출

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#한글폰트 가져오기
from matplotlib import rc
rc('font', family='NanumGothic')

# Warning 메세지를 뜨지 않게 해줌
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler, StandardScaler

#평가
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score

# %% [markdown]
# ## 데이터 불러오기

# %%
train = pd.read_csv('./Online Retail_2009.csv')
test = pd.read_csv('./2010_final.csv')

# %%
# test 2011년 5월 30일 이전까지 사용
test = test[test['InvoiceDate'] <= '2011-05-30']

# %%
test = test.drop(columns='Unnamed: 0')

# %%
train.info()
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 391893 entries, 0 to 391892
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    391893 non-null  int64
#  1   StockCode    391893 non-null  object
#  2   Description  391893 non-null  object
#  3   Quantity     391893 non-null  int64
#  4   InvoiceDate  391893 non-null  object
#  5   UnitPrice    391893 non-null  float64
#  6   CustomerID   391893 non-null  int64
#  7   Country      391893 non-null  object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 23.9+ MB
# <class 'pandas.core.frame.DataFrame'>
# Index: 143971 entries, 0 to 143970
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    143971 non-null  int64
#  1   StockCode    143971 non-null  object
#  2   Description  143971 non-null  object
#  3   Quantity     143971 non-null  int64
#  4   InvoiceDate  143971 non-null  object
#  5   UnitPrice    143971 non-null  float64
#  6   CustomerID   143971 non-null  int64
#  7   Country      143971 non-null  object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 9.9+ MB

# %% [markdown]
# ## 디폴트 데이터
# value: 구매여부
# - pivot_CS: 구매여부를 추출하기 위한 데이터프레임
# - pivot_test: 평가를 위한 데이터프레임
# - pairs_CI: InvoiceNo_to_CustomerID함수 적용을 위한 데이터프레임
# - pairs_SD: StockCode에 따른 Description을 출력하기 위한 데이터프레임

# %%
#pivot_CS
df_CS = pd.DataFrame(train.loc[:,['CustomerID','StockCode']].groupby('CustomerID').value_counts())
df_CS['count'] = 1
pivot_CS = df_CS.pivot_table('count', index='CustomerID',columns='StockCode')
pivot_CS.fillna(0,inplace=True)

#pivot_test
df_CS_test = pd.DataFrame(test.loc[:,['CustomerID','StockCode']].groupby('CustomerID').value_counts())
df_CS_test['count'] = 1
pivot_test = df_CS_test.pivot_table('count', index='CustomerID',columns='StockCode')
pivot_test.fillna(0,inplace=True)

#paris_CI 생성
pairs_CI = train[['CustomerID','InvoiceNo']].groupby('CustomerID')['InvoiceNo'].apply(lambda x: x.unique())

#paris_SD 생성
pairs_SD = train.loc[:,['StockCode','Description']].groupby('StockCode')['Description'].apply(lambda x: x.unique())

# %% [markdown]
# ### 겹치는 StockCode 확인

# %%
print(len(train['StockCode'].unique()))
print(len(set(train['StockCode'].unique())))
print(len(test['StockCode'].unique()))
print(len(set(test['StockCode'].unique())))
print(len(set(train['StockCode'].unique()).intersection(set(test['StockCode'].unique()))))
# Out:
# 4000
# 4000
# 3106
# 3106
# 2881

# %% [markdown]
# ### 겹치는 CusomerID 확인

# %%
print(len(train['CustomerID'].unique()))
print(len(set(train['CustomerID'].unique())))
print(len(test['CustomerID'].unique()))
print(len(set(test['CustomerID'].unique())))
print(len(set(train['CustomerID'].unique()).intersection(set(test['CustomerID'].unique()))))
# Out:
# 4239
# 4239
# 2706
# 2706
# 2040

# %% [markdown]
# ## 함수생성

# %% [markdown]
# ### InvoiceNo_to_CustomerID
# InvoiceNo - StockCode 형태를 CustomerID - StockCode형태로 변환

# %%
def InvoiceNo_to_CustomerID(Pred_IS, pairs_CI = pairs_CI):
    #빈객체 생성
    merged_data = []
    CustomerID_list = []
    #CustomerID와 InvoiceNo를 각각 저장해 루프 생성
    for CustomerID, invoice_list in pairs_CI.items():
        #같은 CutomerID 예측 값만 추출해 저장
        customer_data = Pred_IS[Pred_IS.index.isin(invoice_list)] 
        merged_data.append(customer_data.mean(axis=0)) #값들을 모두 합해 새로운 객체에 저장
        CustomerID_list.append(CustomerID)
    merged_data = pd.DataFrame(merged_data,index=CustomerID_list,columns=Pred_IS.columns)
    return merged_data

# %% [markdown]
# ### get_topsim
# top_n개의 유사도 외에는 다 0으로 만들어 가중치가 없도록 변환

# %%
def get_topsim(sim_df, top_n=20):
    sim_topn = sim_df.copy()
    for col in range(sim_df.shape[1]):
        col_sim = sim_df.iloc[:,col]
        top_n_items = [np.argsort(col_sim)[:-top_n]]
        sim_topn.iloc[top_n_items,col] = 0
    return sim_topn

# %% [markdown]
# ### predict_count
# 행렬곱을 통해 데이터 프레임 형태로 반환

# %%
def predict_count(pivot, sim_df, IS = False):
    count_pred = pivot.T.values.dot(sim_df.values) / np.array([np.abs(sim_df.values).sum(axis=1)])
    count_pred = pd.DataFrame(count_pred, index=pivot.columns, columns=pivot.index)
    count_pred = count_pred.T
    if IS:
        count_pred = InvoiceNo_to_CustomerID(count_pred)
    return count_pred

# %% [markdown]
# ### recomm_model
# 구매하지 않은 상품기준
# - 고객별 구매하지 않은 상품 리스트
# - 고객별 추천 상품(StockCode)
# - 혼동행렬
# - 정밀도

# %% [markdown]
# ##### 평가도 같이

# %%
def recomm_model(pred_df, recomm_n = 10, pivot_CS = pivot_CS):
    unbought_df = []
    recomm_prod_df = []
    total_conf_matrix = np.matrix([[0,0],[0,0]])
    shared_customers = set(train['CustomerID'].unique()).intersection(set(test['CustomerID'].unique())) 
    for CustomerID in shared_customers:
        #구매하지 않은 상품 추출
        Customer_info = pivot_CS.loc[CustomerID,]
        unbought_list = Customer_info[Customer_info==0].index
        unbought_df.append({'CustomerID': CustomerID, 'Unbought_Items': unbought_list})

        #pred_df를 기반, 구매하지 않은 상품 중 상위 10개 추천
        recomm_prod = pred_df.loc[CustomerID, unbought_list].sort_values(ascending=False)[:recomm_n].index
        recomm_prod_df.append({'CustomerID': CustomerID, 'recommend_products': recomm_prod})

        #평가
        y_test = pd.Series(np.zeros(len(recomm_prod)))
        for index, value in enumerate(recomm_prod):
            if value in pivot_test.columns:
                y_test[index] = pivot_test.loc[CustomerID, value]
        y_pred = pd.Series(np.ones(len(recomm_prod)))
        conf_matrix = confusion_matrix(y_test, y_pred) # 혼동 행렬 계산
        if (conf_matrix[0,0] != 0):
            print('<전부 구매함>', f'\nCustomerID: {CustomerID}', f'\nprodcuct: {recomm_prod}')
            total_conf_matrix = total_conf_matrix + [[0,0],[0,conf_matrix[0,0]]]
        else:
            total_conf_matrix = total_conf_matrix + conf_matrix
    unbought_df = pd.DataFrame(unbought_df)
    recomm_prod_df = pd.DataFrame(recomm_prod_df)

    TN = total_conf_matrix[0,0]
    FP = total_conf_matrix[0,1]
    FN = total_conf_matrix[1,0]
    TP = total_conf_matrix[1,1]

    precision = np.round(TP / (TP + FP), 4) # 정밀도 계산

    evaluation = {'정밀도': precision}    
    return unbought_df, recomm_prod_df, total_conf_matrix, evaluation

# %% [markdown]
# ##### 추천만

# %%
def recomm(pred_df, recomm_n = 10, pivot_CS = pivot_CS, pivot_test = pivot_test):
    unbought_df = []
    recomm_prod_df = []
    total_conf_matrix = np.matrix([[0,0],[0,0]])
    shared_customers = set(train['CustomerID'].unique()).intersection(set(test['CustomerID'].unique())) 
    
    for CustomerID in shared_customers:
        #구매하지 않은 상품 추출
        Customer_info = pivot_CS.loc[CustomerID,]
        unbought_list = Customer_info[Customer_info==0].index
        unbought_df.append({'CustomerID': CustomerID, 'Unbought_Items': unbought_list})

        #pred_df를 기반, 구매하지 않은 상품 중 상위 10개 추천
        recomm_prod = pred_df.loc[CustomerID, unbought_list].sort_values(ascending=False)[:recomm_n].index
        recomm_prod_df.append({'CustomerID': CustomerID, 'StockCode': recomm_prod})
        
    unbought_df = pd.DataFrame(unbought_df)
    recomm_prod_df = pd.DataFrame(recomm_prod_df)
    recomm_prod_df.head(1)
    
    return unbought_df, recomm_prod_df

# %% [markdown]
# ## 주문기반 추천시스템
# 함께 주문한 상품 종류 기반
# - value: 주문여부
# - 유사도: 코사인
# - top: 20명
# - recomm: 10개

# %%
#주문별 상품 종류 데이터 프레임 생성
df_IS = pd.DataFrame(train[['InvoiceNo','StockCode']].value_counts())
df_IS['count'] = 1

#피봇형태로 변환
pivot_IS = df_IS.pivot_table('count', index='InvoiceNo',columns='StockCode')
pivot_IS.fillna(0, inplace=True) # 상품의 구매여부 1: 구매 0: 구매 x

#유사도 계산
sim_Inv = pd.DataFrame(cosine_similarity(pivot_IS),index=pivot_IS.index, columns=pivot_IS.index) # 코사인 유사도를 이용한 유사도

# %%
# 주문 번호와 상품 코드별 구매 빈도수 계산 및 DataFrame으로 변환
df_ISN = train[['InvoiceNo', 'StockCode']].value_counts().reset_index(name='count')

# 피벗 테이블 생성: 인보이스별로 각 상품의 구매 횟수를 나타냄
pivot_ISN = df_ISN.pivot_table(index='InvoiceNo', columns='StockCode', values='count', fill_value=0)

# 코사인 유사도 계산
sim_Inv = pd.DataFrame(cosine_similarity(pivot_ISN), index=pivot_ISN.index, columns=pivot_ISN.index)

# %%
pred_IS = predict_count(pivot_IS, sim_Inv, IS = True)
result_IS = recomm_model(pred_IS, recomm_n=8)
display(result_IS[2:])
# Out:
# (matrix([[    0, 14992],
#          [    0,  1328]]),
#  {'정밀도': 0.0814})

# %%
pred_IS = predict_count(pivot_IS, sim_Inv, IS = True)
result_IS = recomm_model(pred_IS, recomm_n=10)
display(result_IS[2:])
# Out:
# (matrix([[    0, 18786],
#          [    0,  1614]]),
#  {'정밀도': 0.0791})

# %%
pred_IS = predict_count(pivot_IS, sim_Inv, IS = True)
result_IS = recomm_model(pred_IS, recomm_n=12)
display(result_IS[2:])
# Out:
# (matrix([[    0, 22654],
#          [    0,  1826]]),
#  {'정밀도': 0.0746})

# %%
recomm_n = 10
Inv_param_200 = []

print(recomm_n,'개 추천')
for i in range(50,18151,200):
    pred = predict_count(pivot_IS, get_topsim(sim_Inv, top_n=i), IS = True)
    result = recomm_model(pred, recomm_n=recomm_n)
    Inv_param_200.append([i,'개의 유사도를 반영할 때',result[3]])

print('최대 정밀도',max(Inv_param_200, key=lambda x: x[2]['정밀도']))
Inv_param_200

# %%
Inv_param_200
# Out:
# [[50, '개의 유사도를 반영할 때', {'정밀도': 0.0829}],
#  [250, '개의 유사도를 반영할 때', {'정밀도': 0.0892}],
#  [450, '개의 유사도를 반영할 때', {'정밀도': 0.0898}],
#  [650, '개의 유사도를 반영할 때', {'정밀도': 0.0888}],
#  [850, '개의 유사도를 반영할 때', {'정밀도': 0.0884}],
#  [1050, '개의 유사도를 반영할 때', {'정밀도': 0.0875}],
#  [1250, '개의 유사도를 반영할 때', {'정밀도': 0.0864}],
#  [1450, '개의 유사도를 반영할 때', {'정밀도': 0.0858}],
#  [1650, '개의 유사도를 반영할 때', {'정밀도': 0.0856}],
#  [1850, '개의 유사도를 반영할 때', {'정밀도': 0.0846}],
#  [2050, '개의 유사도를 반영할 때', {'정밀도': 0.0839}],
#  [2250, '개의 유사도를 반영할 때', {'정밀도': 0.084}],
#  [2450, '개의 유사도를 반영할 때', {'정밀도': 0.0838}],
#  [2650, '개의 유사도를 반영할 때', {'정밀도': 0.0835}],
#  [2850, '개의 유사도를 반영할 때', {'정밀도': 0.0828}],
#  [3050, '개의 유사도를 반영할 때', {'정밀도': 0.0826}],
#  [3250, '개의 유사도를 반영할 때', {'정밀도': 0.0825}],
#  [3450, '개의 유사도를 반영할 때', {'정밀도': 0.0821}],
#  [3650, '개의 유사도를 반영할 때', {'정밀도': 0.0817}],
#  [3850, '개의 유사도를 반영할 때', {'정밀도': 0.0812}],
#  [4050, '개의 유사도를 반영할 때', {'정밀도': 0.0808}],
#  [4250, '개의 유사도를 반영할 때', {'정밀도': 0.0804}],
#  [4450, '개의 유사도를 반영할 때', {'정밀도': 0.0802}],
#  [4650, '개의 유사도를 반영할 때', {'정밀도': 0.0799}],
#  [4850, '개의 유사도를 반영할 때', {'정밀도': 0.08}],
#  [5050, '개의 유사도를 반영할 때', {'정밀도': 0.0798}],
#  [5250, '개의 유사도를 반영할 때', {'정밀도': 0.0798}],
#  [5450, '개의 유사도를 반영할 때', {'정밀도': 0.0797}],
#  [5650, '개의 유사도를 반영할 때', {'정밀도': 0.0795}],
#  [5850, '개의 유사도를 반영할 때', {'정밀도': 0.0797}],
#  [6050, '개의 유사도를 반영할 때', {'정밀도': 0.0797}],
#  [6250, '개의 유사도를 반영할 때', {'정밀도': 0.0797}],
#  [6450, '개의 유사도를 반영할 때', {'정밀도': 0.0796}],
#  [6650, '개의 유사도를 반영할 때', {'정밀도': 0.0793}],
#  [6850, '개의 유사도를 반영할 때', {'정밀도': 0.0793}],
#  [7050, '개의 유사도를 반영할 때', {'정밀도': 0.0794}],
#  [7250, '개의 유사도를 반영할 때', {'정밀도': 0.0792}],
#  [7450, '개의 유사도를 반영할 때', {'정밀도': 0.0793}],
#  [7650, '개의 유사도를 반영할 때', {'정밀도': 0.0793}],
#  [7850, '개의 유사도를 반영할 때', {'정밀도': 0.0791}],
#  [8050, '개의 유사도를 반영할 때', {'정밀도': 0.0792}],
#  [8250, '개의 유사도를 반영할 때', {'정밀도': 0.0792}],
#  [8450, '개의 유사도를 반영할 때', {'정밀도': 0.0792}],
#  [8650, '개의 유사도를 반영할 때', {'정밀도': 0.0793}],
#  [8850, '개의 유사도를 반영할 때', {'정밀도': 0.0792}],
#  [9050, '개의 유사도를 반영할 때', {'정밀도': 0.0792}],
#  [9250, '개의 유사도를 반영할 때', {'정밀도': 0.0792}],
#  [9450, '개의 유사도를 반영할 때', {'정밀도': 0.0792}],
#  [9650, '개의 유사도를 반영할 때', {'정밀도': 0.0792}],
#  [9850, '개의 유사도를 반영할 때', {'정밀도': 0.0792}],
#  [10050, '개의 유사도를 반영할 때', {'정밀도': 0.0792}]]

# %%
x = [entry[0] for entry in Inv_param_200]
y = [entry[2]['정밀도'] for entry in Inv_param_200]

# 꺾은선 그래프 그리기
plt.plot(x, y, marker='o')

plt.title('200 step')
plt.xlabel('Count')
plt.ylabel('accuracy')

# 그래프 표시
plt.grid(True)
plt.show()

print('based on Order')
print(x[np.argsort(y)[-1]],'accuracy:',max(y))
# Out:
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# based on Order
# 450 accuracy: 0.0898

# %%
Inv_param = []

print(recomm_n,'개 추천')
for i in range(400,500):
    pred = predict_count(pivot_IS, get_topsim(sim_Inv, top_n=i), IS = True)
    result = recomm_model(pred, recomm_n=recomm_n)
    Inv_param.append([i,'개의 유사도를 반영할 때',result[3]])

print('최대 정밀도', max(Inv_param, key=lambda x: x[2]['정밀도']))
Inv_param
# Out:
# 10 개 추천
# 최대 정밀도 [437, '개의 유사도를 반영할 때', {'정밀도': 0.0901}]
# [[400, '개의 유사도를 반영할 때', {'정밀도': 0.0896}],
#  [401, '개의 유사도를 반영할 때', {'정밀도': 0.0898}],
#  [402, '개의 유사도를 반영할 때', {'정밀도': 0.0899}],
#  [403, '개의 유사도를 반영할 때', {'정밀도': 0.0897}],
#  [404, '개의 유사도를 반영할 때', {'정밀도': 0.0897}],
#  [405, '개의 유사도를 반영할 때', {'정밀도': 0.0896}],
#  [406, '개의 유사도를 반영할 때', {'정밀도': 0.0894}],
#  [407, '개의 유사도를 반영할 때', {'정밀도': 0.0894}],
#  [408, '개의 유사도를 반영할 때', {'정밀도': 0.0895}],
#  [409, '개의 유사도를 반영할 때', {'정밀도': 0.0895}],
#  [410, '개의 유사도를 반영할 때', {'정밀도': 0.0898}],
#  [411, '개의 유사도를 반영할 때', {'정밀도': 0.0898}],
#  [412, '개의 유사도를 반영할 때', {'정밀도': 0.0897}],
#  [413, '개의 유사도를 반영할 때', {'정밀도': 0.0898}],
#  [414, '개의 유사도를 반영할 때', {'정밀도': 0.0897}],
#  [415, '개의 유사도를 반영할 때', {'정밀도': 0.0896}],
#  [416, '개의 유사도를 반영할 때', {'정밀도': 0.0894}],
#  [417, '개의 유사도를 반영할 때', {'정밀도': 0.0895}],
#  [418, '개의 유사도를 반영할 때', {'정밀도': 0.0893}],
#  [419, '개의 유사도를 반영할 때', {'정밀도': 0.0895}],
#  [420, '개의 유사도를 반영할 때', {'정밀도': 0.0897}],
#  [421, '개의 유사도를 반영할 때', {'정밀도': 0.0898}],
#  [422, '개의 유사도를 반영할 때', {'정밀도': 0.0899}],
#  [423, '개의 유사도를 반영할 때', {'정밀도': 0.0898}],
#  [424, '개의 유사도를 반영할 때', {'정밀도': 0.0896}],
#  [425, '개의 유사도를 반영할 때', {'정밀도': 0.0895}],
#  [426, '개의 유사도를 반영할 때', {'정밀도': 0.0896}],
#  [427, '개의 유사도를 반영할 때', {'정밀도': 0.0897}],
#  [428, '개의 유사도를 반영할 때', {'정밀도': 0.09}],
#  [429, '개의 유사도를 반영할 때', {'정밀도': 0.0897}],
#  [430, '개의 유사도를 반영할 때', {'정밀도': 0.0898}],
#  [431, '개의 유사도를 반영할 때', {'정밀도': 0.0899}],
#  [432, '개의 유사도를 반영할 때', {'정밀도': 0.0897}],
#  [433, '개의 유사도를 반영할 때', {'정밀도': 0.0899}],
#  [434, '개의 유사도를 반영할 때', {'정밀도': 0.09}],
#  [435, '개의 유사도를 반영할 때', {'정밀도': 0.0897}],
#  [436, '개의 유사도를 반영할 때', {'정밀도': 0.0899}],
#  [437, '개의 유사도를 반영할 때', {'정밀도': 0.0901}],
#  [438, '개의 유사도를 반영할 때', {'정밀도': 0.09}],
#  [439, '개의 유사도를 반영할 때', {'정밀도': 0.09}],
#  [440, '개의 유사도를 반영할 때', {'정밀도': 0.0897}],
#  [441, '개의 유사도를 반영할 때', {'정밀도': 0.0897}],
#  [442, '개의 유사도를 반영할 때', {'정밀도': 0.0898}],
#  [443, '개의 유사도를 반영할 때', {'정밀도': 0.0897}],
#  [444, '개의 유사도를 반영할 때', {'정밀도': 0.0895}],
#  [445, '개의 유사도를 반영할 때', {'정밀도': 0.0897}],
#  [446, '개의 유사도를 반영할 때', {'정밀도': 0.0898}],
#  [447, '개의 유사도를 반영할 때', {'정밀도': 0.0897}],
#  [448, '개의 유사도를 반영할 때', {'정밀도': 0.0898}],
#  [449, '개의 유사도를 반영할 때', {'정밀도': 0.0897}],
#  [450, '개의 유사도를 반영할 때', {'정밀도': 0.0898}],
#  [451, '개의 유사도를 반영할 때', {'정밀도': 0.09}],
#  [452, '개의 유사도를 반영할 때', {'정밀도': 0.09}],
#  [453, '개의 유사도를 반영할 때', {'정밀도': 0.0898}],
#  [454, '개의 유사도를 반영할 때', {'정밀도': 0.0899}],
#  [455, '개의 유사도를 반영할 때', {'정밀도': 0.0896}],
#  [456, '개의 유사도를 반영할 때', {'정밀도': 0.0894}],
#  [457, '개의 유사도를 반영할 때', {'정밀도': 0.0896}],
#  [458, '개의 유사도를 반영할 때', {'정밀도': 0.0895}],
#  [459, '개의 유사도를 반영할 때', {'정밀도': 0.0893}],
#  [460, '개의 유사도를 반영할 때', {'정밀도': 0.0893}],
#  [461, '개의 유사도를 반영할 때', {'정밀도': 0.0894}],
#  [462, '개의 유사도를 반영할 때', {'정밀도': 0.0893}],
#  [463, '개의 유사도를 반영할 때', {'정밀도': 0.0896}],
#  [464, '개의 유사도를 반영할 때', {'정밀도': 0.0894}],
#  [465, '개의 유사도를 반영할 때', {'정밀도': 0.0891}],
#  [466, '개의 유사도를 반영할 때', {'정밀도': 0.089}],
#  [467, '개의 유사도를 반영할 때', {'정밀도': 0.0891}],
#  [468, '개의 유사도를 반영할 때', {'정밀도': 0.0893}],
#  [469, '개의 유사도를 반영할 때', {'정밀도': 0.0892}],
#  [470, '개의 유사도를 반영할 때', {'정밀도': 0.0894}],
#  [471, '개의 유사도를 반영할 때', {'정밀도': 0.0896}],
#  [472, '개의 유사도를 반영할 때', {'정밀도': 0.0896}],
#  [473, '개의 유사도를 반영할 때', {'정밀도': 0.0898}],
#  [474, '개의 유사도를 반영할 때', {'정밀도': 0.0897}],
#  [475, '개의 유사도를 반영할 때', {'정밀도': 0.0899}],
#  [476, '개의 유사도를 반영할 때', {'정밀도': 0.0899}],
#  [477, '개의 유사도를 반영할 때', {'정밀도': 0.09}],
#  [478, '개의 유사도를 반영할 때', {'정밀도': 0.0899}],
#  [479, '개의 유사도를 반영할 때', {'정밀도': 0.0897}],
#  [480, '개의 유사도를 반영할 때', {'정밀도': 0.0898}],
#  [481, '개의 유사도를 반영할 때', {'정밀도': 0.0898}],
#  [482, '개의 유사도를 반영할 때', {'정밀도': 0.09}],
#  [483, '개의 유사도를 반영할 때', {'정밀도': 0.0897}],
#  [484, '개의 유사도를 반영할 때', {'정밀도': 0.0898}],
#  [485, '개의 유사도를 반영할 때', {'정밀도': 0.0895}],
#  [486, '개의 유사도를 반영할 때', {'정밀도': 0.0898}],
#  [487, '개의 유사도를 반영할 때', {'정밀도': 0.0897}],
#  [488, '개의 유사도를 반영할 때', {'정밀도': 0.0897}],
#  [489, '개의 유사도를 반영할 때', {'정밀도': 0.0894}],
#  [490, '개의 유사도를 반영할 때', {'정밀도': 0.0894}],
#  [491, '개의 유사도를 반영할 때', {'정밀도': 0.0893}],
#  [492, '개의 유사도를 반영할 때', {'정밀도': 0.0894}],
#  [493, '개의 유사도를 반영할 때', {'정밀도': 0.0894}],
#  [494, '개의 유사도를 반영할 때', {'정밀도': 0.0894}],
#  [495, '개의 유사도를 반영할 때', {'정밀도': 0.0892}],
#  [496, '개의 유사도를 반영할 때', {'정밀도': 0.0893}],
#  [497, '개의 유사도를 반영할 때', {'정밀도': 0.0894}],
#  [498, '개의 유사도를 반영할 때', {'정밀도': 0.0896}],
#  [499, '개의 유사도를 반영할 때', {'정밀도': 0.0896}]]

# %%
x = [entry[0] for entry in Inv_param]
y = [entry[2]['정밀도'] for entry in Inv_param]

# 꺾은선 그래프 그리기
plt.plot(x, y, marker='o')

plt.title('350~450')
plt.xlabel('Count')
plt.ylabel('accuracy')

# 그래프 표시
plt.grid(True)
plt.show()

print('based on Order')
print(x[np.argsort(y)[-1]],'accuracy:',max(y))
# Out:
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# based on Order
# 437 accuracy: 0.0901

# %% [markdown]
# ## 고객기반 추천시스템
# - 고객의 RFM기반
# - value: 구매여부

# %% [markdown]
# ### RFM 계산, scaling

# %%
RFM = train.copy()
RFM['InvoiceDate'] = pd.to_datetime(RFM['InvoiceDate']) #datetime 형식으로 변환
RFM['TotalPrice'] = RFM['Quantity'] * RFM['UnitPrice']

current_date = pd.Timestamp(RFM['InvoiceDate'].max()) + pd.Timedelta(days=1)
df_RFM = RFM.groupby('CustomerID').agg({
    'InvoiceDate' : (lambda x: (current_date - x.max()).days), # R
    'InvoiceNo' : 'count', # F
    'TotalPrice' : 'sum' # M
}) 

RFM_Scaler = MinMaxScaler()
df_RFM_scaled = RFM_Scaler.fit_transform(df_RFM)
df_RFM_scaled = pd.DataFrame(df_RFM_scaled, index =df_RFM.index, columns=df_RFM.columns )

# %%
df_RFM_scaled
# Out:
#             InvoiceDate  InvoiceNo  TotalPrice
# CustomerID
# 12346          0.425824   0.004318    0.000522
# 12347          0.082418   0.007323    0.001898
# 12348          0.175824   0.003380    0.000683
# 12349          0.090659   0.018588    0.006908
# 12351          0.002747   0.003755    0.000932
# ...                 ...        ...         ...
# 18283          0.021978   0.042997    0.001992
# 18284          0.156593   0.004882    0.001276
# 18285          0.785714   0.001878    0.001168
# 18286          0.280220   0.012204    0.003874
# 18287          0.021978   0.015584    0.007140
#
# [4239 rows x 3 columns]

# %%
df_CS = pd.DataFrame(train.loc[:,['CustomerID','StockCode']].groupby('CustomerID').value_counts())
df_CS['count'] = 1

pivot_CS = df_CS.pivot_table('count', index='CustomerID',columns='StockCode')
pivot_CS.fillna(0,inplace=True)

sim_Cust = pd.DataFrame(cosine_similarity(df_RFM_scaled),index=df_RFM_scaled.index, columns=df_RFM_scaled.index)

# %%
pred_CS = predict_count(pivot_CS, sim_Cust)
result_CS = recomm_model(pred_CS, recomm_n=10)
display(result_CS[2:])
# Out:
# (matrix([[    0, 19289],
#          [    0,  1111]]),
#  {'정밀도': 0.0545})

# %%
pred_CS_top = predict_count(pivot_CS, get_topsim(sim_Cust, top_n=20))
result_CS_top = recomm_model(pred_CS_top, recomm_n=10)
display(result_CS_top[2:])
# Out:
# (matrix([[    0, 19542],
#          [    0,   858]]),
#  {'정밀도': 0.0421})

# %%
Cust_param_100 = []

print(recomm_n,'개 추천')
for i in range(50,3000,100):
    pred = predict_count(pivot_CS, get_topsim(sim_Cust, top_n=i))
    result = recomm_model(pred, recomm_n=recomm_n)
    Cust_param_100.append([i,'개의 유사도를 반영할 때',result[3]])

print('최대 정밀도', max(Cust_param_100, key=lambda x: x[2]['정밀도']))
Cust_param_100
# Out:
# 10 개 추천
# 최대 정밀도 [1050, '개의 유사도를 반영할 때', {'정밀도': 0.0544}]
# [[50, '개의 유사도를 반영할 때', {'정밀도': 0.0492}],
#  [150, '개의 유사도를 반영할 때', {'정밀도': 0.0529}],
#  [250, '개의 유사도를 반영할 때', {'정밀도': 0.0543}],
#  [350, '개의 유사도를 반영할 때', {'정밀도': 0.0538}],
#  [450, '개의 유사도를 반영할 때', {'정밀도': 0.0543}],
#  [550, '개의 유사도를 반영할 때', {'정밀도': 0.0532}],
#  [650, '개의 유사도를 반영할 때', {'정밀도': 0.0526}],
#  [750, '개의 유사도를 반영할 때', {'정밀도': 0.0533}],
#  [850, '개의 유사도를 반영할 때', {'정밀도': 0.0539}],
#  [950, '개의 유사도를 반영할 때', {'정밀도': 0.0537}],
#  [1050, '개의 유사도를 반영할 때', {'정밀도': 0.0544}],
#  [1150, '개의 유사도를 반영할 때', {'정밀도': 0.0538}],
#  [1250, '개의 유사도를 반영할 때', {'정밀도': 0.0539}],
#  [1350, '개의 유사도를 반영할 때', {'정밀도': 0.0535}],
#  [1450, '개의 유사도를 반영할 때', {'정밀도': 0.0534}],
#  [1550, '개의 유사도를 반영할 때', {'정밀도': 0.0534}],
#  [1650, '개의 유사도를 반영할 때', {'정밀도': 0.0535}],
#  [1750, '개의 유사도를 반영할 때', {'정밀도': 0.0535}],
#  [1850, '개의 유사도를 반영할 때', {'정밀도': 0.0529}],
#  [1950, '개의 유사도를 반영할 때', {'정밀도': 0.0534}],
#  [2050, '개의 유사도를 반영할 때', {'정밀도': 0.0528}],
#  [2150, '개의 유사도를 반영할 때', {'정밀도': 0.0529}],
#  [2250, '개의 유사도를 반영할 때', {'정밀도': 0.0531}],
#  [2350, '개의 유사도를 반영할 때', {'정밀도': 0.0532}],
#  [2450, '개의 유사도를 반영할 때', {'정밀도': 0.0536}],
#  [2550, '개의 유사도를 반영할 때', {'정밀도': 0.0532}],
#  [2650, '개의 유사도를 반영할 때', {'정밀도': 0.0533}],
#  [2750, '개의 유사도를 반영할 때', {'정밀도': 0.0535}],
#  [2850, '개의 유사도를 반영할 때', {'정밀도': 0.0535}],
#  [2950, '개의 유사도를 반영할 때', {'정밀도': 0.0534}]]

# %%
x = [entry[0] for entry in Cust_param_100]
y = [entry[2]['정밀도'] for entry in Cust_param_100]

# 꺾은선 그래프 그리기
plt.plot(x, y, marker='o')

plt.title('100 steps')
plt.xlabel('count')
plt.ylabel('accuracy')

# 그래프 표시
plt.grid(True)
plt.show()

print('based on Customer')
print(x[np.argsort(y)[-1]],'accuracy:',max(y))
# Out:
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# based on Customer
# 1050 accuracy: 0.0544

# %%
Cust_param = []

print(recomm_n,'개 추천')
for i in range(1000,1100):
    pred = predict_count(pivot_CS, get_topsim(sim_Cust, top_n=i))
    result = recomm_model(pred, recomm_n=recomm_n)
    Cust_param.append([i,'개의 유사도를 반영할 때',result[3]])

print('최대 정밀도', max(Cust_param, key=lambda x: x[2]['정밀도']))
Cust_param
# Out:
# 10 개 추천
# 최대 정밀도 [1046, '개의 유사도를 반영할 때', {'정밀도': 0.0547}]
# [[1000, '개의 유사도를 반영할 때', {'정밀도': 0.054}],
#  [1001, '개의 유사도를 반영할 때', {'정밀도': 0.054}],
#  [1002, '개의 유사도를 반영할 때', {'정밀도': 0.0542}],
#  [1003, '개의 유사도를 반영할 때', {'정밀도': 0.0542}],
#  [1004, '개의 유사도를 반영할 때', {'정밀도': 0.0543}],
#  [1005, '개의 유사도를 반영할 때', {'정밀도': 0.0543}],
#  [1006, '개의 유사도를 반영할 때', {'정밀도': 0.0542}],
#  [1007, '개의 유사도를 반영할 때', {'정밀도': 0.0541}],
#  [1008, '개의 유사도를 반영할 때', {'정밀도': 0.0539}],
#  [1009, '개의 유사도를 반영할 때', {'정밀도': 0.0539}],
#  [1010, '개의 유사도를 반영할 때', {'정밀도': 0.0538}],
#  [1011, '개의 유사도를 반영할 때', {'정밀도': 0.0539}],
#  [1012, '개의 유사도를 반영할 때', {'정밀도': 0.0539}],
#  [1013, '개의 유사도를 반영할 때', {'정밀도': 0.0539}],
#  [1014, '개의 유사도를 반영할 때', {'정밀도': 0.054}],
#  [1015, '개의 유사도를 반영할 때', {'정밀도': 0.0541}],
#  [1016, '개의 유사도를 반영할 때', {'정밀도': 0.0542}],
#  [1017, '개의 유사도를 반영할 때', {'정밀도': 0.0543}],
#  [1018, '개의 유사도를 반영할 때', {'정밀도': 0.0542}],
#  [1019, '개의 유사도를 반영할 때', {'정밀도': 0.0539}],
#  [1020, '개의 유사도를 반영할 때', {'정밀도': 0.0539}],
#  [1021, '개의 유사도를 반영할 때', {'정밀도': 0.0537}],
#  [1022, '개의 유사도를 반영할 때', {'정밀도': 0.0538}],
#  [1023, '개의 유사도를 반영할 때', {'정밀도': 0.0538}],
#  [1024, '개의 유사도를 반영할 때', {'정밀도': 0.0537}],
#  [1025, '개의 유사도를 반영할 때', {'정밀도': 0.0538}],
#  [1026, '개의 유사도를 반영할 때', {'정밀도': 0.0539}],
#  [1027, '개의 유사도를 반영할 때', {'정밀도': 0.0541}],
#  [1028, '개의 유사도를 반영할 때', {'정밀도': 0.054}],
#  [1029, '개의 유사도를 반영할 때', {'정밀도': 0.054}],
#  [1030, '개의 유사도를 반영할 때', {'정밀도': 0.054}],
#  [1031, '개의 유사도를 반영할 때', {'정밀도': 0.0542}],
#  [1032, '개의 유사도를 반영할 때', {'정밀도': 0.0542}],
#  [1033, '개의 유사도를 반영할 때', {'정밀도': 0.0542}],
#  [1034, '개의 유사도를 반영할 때', {'정밀도': 0.054}],
#  [1035, '개의 유사도를 반영할 때', {'정밀도': 0.054}],
#  [1036, '개의 유사도를 반영할 때', {'정밀도': 0.0541}],
#  [1037, '개의 유사도를 반영할 때', {'정밀도': 0.0542}],
#  [1038, '개의 유사도를 반영할 때', {'정밀도': 0.0542}],
#  [1039, '개의 유사도를 반영할 때', {'정밀도': 0.0544}],
#  [1040, '개의 유사도를 반영할 때', {'정밀도': 0.0542}],
#  [1041, '개의 유사도를 반영할 때', {'정밀도': 0.0543}],
#  [1042, '개의 유사도를 반영할 때', {'정밀도': 0.0543}],
#  [1043, '개의 유사도를 반영할 때', {'정밀도': 0.0544}],
#  [1044, '개의 유사도를 반영할 때', {'정밀도': 0.0545}],
#  [1045, '개의 유사도를 반영할 때', {'정밀도': 0.0545}],
#  [1046, '개의 유사도를 반영할 때', {'정밀도': 0.0547}],
#  [1047, '개의 유사도를 반영할 때', {'정밀도': 0.0545}],
#  [1048, '개의 유사도를 반영할 때', {'정밀도': 0.0542}],
#  [1049, '개의 유사도를 반영할 때', {'정밀도': 0.0542}],
#  [1050, '개의 유사도를 반영할 때', {'정밀도': 0.0544}],
#  [1051, '개의 유사도를 반영할 때', {'정밀도': 0.0544}],
#  [1052, '개의 유사도를 반영할 때', {'정밀도': 0.0543}],
#  [1053, '개의 유사도를 반영할 때', {'정밀도': 0.0542}],
#  [1054, '개의 유사도를 반영할 때', {'정밀도': 0.0543}],
#  [1055, '개의 유사도를 반영할 때', {'정밀도': 0.0542}],
#  [1056, '개의 유사도를 반영할 때', {'정밀도': 0.054}],
#  [1057, '개의 유사도를 반영할 때', {'정밀도': 0.0539}],
#  [1058, '개의 유사도를 반영할 때', {'정밀도': 0.054}],
#  [1059, '개의 유사도를 반영할 때', {'정밀도': 0.0542}],
#  [1060, '개의 유사도를 반영할 때', {'정밀도': 0.0542}],
#  [1061, '개의 유사도를 반영할 때', {'정밀도': 0.054}],
#  [1062, '개의 유사도를 반영할 때', {'정밀도': 0.054}],
#  [1063, '개의 유사도를 반영할 때', {'정밀도': 0.0541}],
#  [1064, '개의 유사도를 반영할 때', {'정밀도': 0.0541}],
#  [1065, '개의 유사도를 반영할 때', {'정밀도': 0.0542}],
#  [1066, '개의 유사도를 반영할 때', {'정밀도': 0.0541}],
#  [1067, '개의 유사도를 반영할 때', {'정밀도': 0.054}],
#  [1068, '개의 유사도를 반영할 때', {'정밀도': 0.054}],
#  [1069, '개의 유사도를 반영할 때', {'정밀도': 0.0538}],
#  [1070, '개의 유사도를 반영할 때', {'정밀도': 0.0539}],
#  [1071, '개의 유사도를 반영할 때', {'정밀도': 0.0538}],
#  [1072, '개의 유사도를 반영할 때', {'정밀도': 0.0537}],
#  [1073, '개의 유사도를 반영할 때', {'정밀도': 0.0534}],
#  [1074, '개의 유사도를 반영할 때', {'정밀도': 0.0537}],
#  [1075, '개의 유사도를 반영할 때', {'정밀도': 0.0539}],
#  [1076, '개의 유사도를 반영할 때', {'정밀도': 0.054}],
#  [1077, '개의 유사도를 반영할 때', {'정밀도': 0.0542}],
#  [1078, '개의 유사도를 반영할 때', {'정밀도': 0.054}],
#  [1079, '개의 유사도를 반영할 때', {'정밀도': 0.0539}],
#  [1080, '개의 유사도를 반영할 때', {'정밀도': 0.0538}],
#  [1081, '개의 유사도를 반영할 때', {'정밀도': 0.0539}],
#  [1082, '개의 유사도를 반영할 때', {'정밀도': 0.0538}],
#  [1083, '개의 유사도를 반영할 때', {'정밀도': 0.0538}],
#  [1084, '개의 유사도를 반영할 때', {'정밀도': 0.0539}],
#  [1085, '개의 유사도를 반영할 때', {'정밀도': 0.0538}],
#  [1086, '개의 유사도를 반영할 때', {'정밀도': 0.0538}],
#  [1087, '개의 유사도를 반영할 때', {'정밀도': 0.0539}],
#  [1088, '개의 유사도를 반영할 때', {'정밀도': 0.0539}],
#  [1089, '개의 유사도를 반영할 때', {'정밀도': 0.0538}],
#  [1090, '개의 유사도를 반영할 때', {'정밀도': 0.0538}],
#  [1091, '개의 유사도를 반영할 때', {'정밀도': 0.0537}],
#  [1092, '개의 유사도를 반영할 때', {'정밀도': 0.0537}],
#  [1093, '개의 유사도를 반영할 때', {'정밀도': 0.0537}],
#  [1094, '개의 유사도를 반영할 때', {'정밀도': 0.0536}],
#  [1095, '개의 유사도를 반영할 때', {'정밀도': 0.0536}],
#  [1096, '개의 유사도를 반영할 때', {'정밀도': 0.0538}],
#  [1097, '개의 유사도를 반영할 때', {'정밀도': 0.054}],
#  [1098, '개의 유사도를 반영할 때', {'정밀도': 0.0539}],
#  [1099, '개의 유사도를 반영할 때', {'정밀도': 0.054}]]

# %%
import re
import nltk
from nltk.corpus import stopwords

# %%
SD_pairs = train[['StockCode','Description']].groupby('StockCode')['Description'].apply(lambda x: list(set(x))).to_dict()
for stockcode, descriptions in SD_pairs.items(): #리스트형태의 데이터를 문자형으로 변환
    SD_pairs[stockcode] = ' '.join(descriptions)

# %% [markdown]
# ## 아이템 유사도 기반

# %%
SD_pairs = train[['StockCode','Description']].groupby('StockCode')['Description'].apply(lambda x: list(set(x))).to_dict()
for stockcode, descriptions in SD_pairs.items(): #리스트형태의 데이터를 문자형으로 변환
    SD_pairs[stockcode] = ' '.join(descriptions)

Des_uniq = pd.Series(SD_pairs)
Des_uniq = Des_uniq.str.strip()
def replace_slash_with_space(text): #/를 공백으로 치환하는 함수
    return text.replace('/', ' ')
def remove_extra_spaces(text): #공백을 한칸으로 통일
    return re.sub(r'\s+', ' ', text)
Des_uniq = Des_uniq.apply(replace_slash_with_space)
Des_uniq = Des_uniq.apply(remove_extra_spaces)

# %%
Des_uniq_split = pd.Series(Des_uniq.str.split(" "))
Des_words = [word for sublist in Des_uniq_split for word in sublist]
uniq_words = set(Des_words)

# %%
print('삭제 전 단어 수:',len(uniq_words))

# 영어 불용어 목록
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

def remove_special_characters(text): # 문자, 숫자, 공백을 제외한 모든 문자 삭제
    return re.sub(r'[^a-zA-Z0-9\s]', '', text)

uniq_words = {remove_special_characters(word) for word in uniq_words} # 특수 기호 삭제
uniq_words = {word for word in uniq_words if word.strip()} # 공백 또는 빈 문자열 삭제
uniq_words = {word for word in uniq_words if not word.isdigit()} #숫자 삭제
uniq_words -= stop_words # 불용어 삭제

print('삭제 후 단어 수:',len(uniq_words))
# Out:
# 삭제 전 단어 수: 2265
# 삭제 후 단어 수: 2154
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/kimminji/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df_Des = pd.DataFrame()
for word in uniq_words:
    pattern = r'(\b{}\b|^\w+ {}\b|\b{} \w+$)'.format(word, word, word) # 공백이나 문장부호와 함께 등장하는 단어를 포함하는 정규표현식

    # 정규표현식을 사용하여 해당 단어가 Description에 포함되어 있는지 여부를 확인
    df_Des[word] = Des_uniq.str.contains(pattern, regex=True).astype(int)

sim_Des = pd.DataFrame(cosine_similarity(df_Des),index=df_Des.index, columns=df_Des.index)

# %%
Item_param_100 = []

print(recomm_n,'개 추천')
for i in range(50,4001,100):
    sim = get_topsim(sim_Des, top_n= i)
    pred = pivot_CS.values.dot(sim.values) / np.array([np.abs(sim.values).sum(axis=1)])
    pred = pd.DataFrame(pred, index=pivot_CS.index, columns=pivot_CS.columns)
    result = recomm_model(pred, recomm_n=recomm_n)
    Item_param_100.append([i,'개의 유사도를 반영할 때',result[3]])

print('최대 정밀도',max(Item_param_100, key=lambda x: x[2]['정밀도']))
Item_param_100
# Out:
# 10 개 추천
# 최대 정밀도 [450, '개의 유사도를 반영할 때', {'정밀도': 0.0347}]
# [[50, '개의 유사도를 반영할 때', {'정밀도': 0.0272}],
#  [150, '개의 유사도를 반영할 때', {'정밀도': 0.0238}],
#  [250, '개의 유사도를 반영할 때', {'정밀도': 0.0272}],
#  [350, '개의 유사도를 반영할 때', {'정밀도': 0.0326}],
#  [450, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [550, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [650, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [750, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [850, '개의 유사도를 반영할 때', {'정밀도': 0.0342}],
#  [950, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [1050, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [1150, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [1250, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [1350, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [1450, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [1550, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [1650, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [1750, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [1850, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [1950, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [2050, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [2150, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [2250, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [2350, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [2450, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [2550, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [2650, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [2750, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [2850, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [2950, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [3050, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [3150, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [3250, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [3350, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [3450, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [3550, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [3650, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [3750, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [3850, '개의 유사도를 반영할 때', {'정밀도': 0.0343}],
#  [3950, '개의 유사도를 반영할 때', {'정밀도': 0.0343}]]

# %%
x = [entry[0] for entry in Item_param_100]
y = [entry[2]['정밀도'] for entry in Item_param_100]

# 꺾은선 그래프 그리기
plt.plot(x, y, marker='o')

plt.title('100 steps')
plt.xlabel('count')
plt.ylabel('accuracy')

# 그래프 표시
plt.grid(True)
plt.show()

print('based on Items')
print(x[np.argsort(y)[-1]],'accuracy:',max(y))
# Out:
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# based on Items
# 450 accuracy: 0.0347

# %%
Item_param = []

print(recomm_n,'개 추천')
for i in range(400,501):
    sim = get_topsim(sim_Des, top_n= i)
    pred = pivot_CS.values.dot(sim.values) / np.array([np.abs(sim.values).sum(axis=1)])
    pred = pd.DataFrame(pred, index=pivot_CS.index, columns=pivot_CS.columns)
    result = recomm_model(pred, recomm_n=recomm_n)
    Item_param.append([i,'개의 유사도를 반영할 때',result[3]])
    
print('최대 유사도',max(Item_param, key=lambda x: x[2]['정밀도']))
Item_param
# Out:
# 10 개 추천
# 최대 유사도 [439, '개의 유사도를 반영할 때', {'정밀도': 0.0349}]
# [[400, '개의 유사도를 반영할 때', {'정밀도': 0.0345}],
#  [401, '개의 유사도를 반영할 때', {'정밀도': 0.0345}],
#  [402, '개의 유사도를 반영할 때', {'정밀도': 0.0345}],
#  [403, '개의 유사도를 반영할 때', {'정밀도': 0.0345}],
#  [404, '개의 유사도를 반영할 때', {'정밀도': 0.0345}],
#  [405, '개의 유사도를 반영할 때', {'정밀도': 0.0346}],
#  [406, '개의 유사도를 반영할 때', {'정밀도': 0.0345}],
#  [407, '개의 유사도를 반영할 때', {'정밀도': 0.0345}],
#  [408, '개의 유사도를 반영할 때', {'정밀도': 0.0345}],
#  [409, '개의 유사도를 반영할 때', {'정밀도': 0.0345}],
#  [410, '개의 유사도를 반영할 때', {'정밀도': 0.0345}],
#  [411, '개의 유사도를 반영할 때', {'정밀도': 0.0346}],
#  [412, '개의 유사도를 반영할 때', {'정밀도': 0.0345}],
#  [413, '개의 유사도를 반영할 때', {'정밀도': 0.0346}],
#  [414, '개의 유사도를 반영할 때', {'정밀도': 0.0345}],
#  [415, '개의 유사도를 반영할 때', {'정밀도': 0.0345}],
#  [416, '개의 유사도를 반영할 때', {'정밀도': 0.0345}],
#  [417, '개의 유사도를 반영할 때', {'정밀도': 0.0345}],
#  [418, '개의 유사도를 반영할 때', {'정밀도': 0.0346}],
#  [419, '개의 유사도를 반영할 때', {'정밀도': 0.0345}],
#  [420, '개의 유사도를 반영할 때', {'정밀도': 0.0345}],
#  [421, '개의 유사도를 반영할 때', {'정밀도': 0.0345}],
#  [422, '개의 유사도를 반영할 때', {'정밀도': 0.0346}],
#  [423, '개의 유사도를 반영할 때', {'정밀도': 0.0345}],
#  [424, '개의 유사도를 반영할 때', {'정밀도': 0.0346}],
#  [425, '개의 유사도를 반영할 때', {'정밀도': 0.0345}],
#  [426, '개의 유사도를 반영할 때', {'정밀도': 0.0345}],
#  [427, '개의 유사도를 반영할 때', {'정밀도': 0.0345}],
#  [428, '개의 유사도를 반영할 때', {'정밀도': 0.0345}],
#  [429, '개의 유사도를 반영할 때', {'정밀도': 0.0345}],
#  [430, '개의 유사도를 반영할 때', {'정밀도': 0.0344}],
#  [431, '개의 유사도를 반영할 때', {'정밀도': 0.0344}],
#  [432, '개의 유사도를 반영할 때', {'정밀도': 0.0345}],
#  [433, '개의 유사도를 반영할 때', {'정밀도': 0.0346}],
#  [434, '개의 유사도를 반영할 때', {'정밀도': 0.0346}],
#  [435, '개의 유사도를 반영할 때', {'정밀도': 0.0345}],
#  [436, '개의 유사도를 반영할 때', {'정밀도': 0.0346}],
#  [437, '개의 유사도를 반영할 때', {'정밀도': 0.0346}],
#  [438, '개의 유사도를 반영할 때', {'정밀도': 0.0346}],
#  [439, '개의 유사도를 반영할 때', {'정밀도': 0.0349}],
#  [440, '개의 유사도를 반영할 때', {'정밀도': 0.0348}],
#  [441, '개의 유사도를 반영할 때', {'정밀도': 0.0348}],
#  [442, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [443, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [444, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [445, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [446, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [447, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [448, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [449, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [450, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [451, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [452, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [453, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [454, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [455, '개의 유사도를 반영할 때', {'정밀도': 0.0346}],
#  [456, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [457, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [458, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [459, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [460, '개의 유사도를 반영할 때', {'정밀도': 0.0346}],
#  [461, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [462, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [463, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [464, '개의 유사도를 반영할 때', {'정밀도': 0.0346}],
#  [465, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [466, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [467, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [468, '개의 유사도를 반영할 때', {'정밀도': 0.0346}],
#  [469, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [470, '개의 유사도를 반영할 때', {'정밀도': 0.0346}],
#  [471, '개의 유사도를 반영할 때', {'정밀도': 0.0346}],
#  [472, '개의 유사도를 반영할 때', {'정밀도': 0.0345}],
#  [473, '개의 유사도를 반영할 때', {'정밀도': 0.0346}],
#  [474, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [475, '개의 유사도를 반영할 때', {'정밀도': 0.0346}],
#  [476, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [477, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [478, '개의 유사도를 반영할 때', {'정밀도': 0.0348}],
#  [479, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [480, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [481, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [482, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [483, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [484, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [485, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [486, '개의 유사도를 반영할 때', {'정밀도': 0.0346}],
#  [487, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [488, '개의 유사도를 반영할 때', {'정밀도': 0.0346}],
#  [489, '개의 유사도를 반영할 때', {'정밀도': 0.0346}],
#  [490, '개의 유사도를 반영할 때', {'정밀도': 0.0346}],
#  [491, '개의 유사도를 반영할 때', {'정밀도': 0.0346}],
#  [492, '개의 유사도를 반영할 때', {'정밀도': 0.0346}],
#  [493, '개의 유사도를 반영할 때', {'정밀도': 0.0346}],
#  [494, '개의 유사도를 반영할 때', {'정밀도': 0.0346}],
#  [495, '개의 유사도를 반영할 때', {'정밀도': 0.0346}],
#  [496, '개의 유사도를 반영할 때', {'정밀도': 0.0345}],
#  [497, '개의 유사도를 반영할 때', {'정밀도': 0.0345}],
#  [498, '개의 유사도를 반영할 때', {'정밀도': 0.0346}],
#  [499, '개의 유사도를 반영할 때', {'정밀도': 0.0345}],
#  [500, '개의 유사도를 반영할 때', {'정밀도': 0.0345}]]

# %% [markdown]
# ## 종합모델

# %%
pred_IS = predict_count(pivot_IS, get_topsim(sim_Inv, top_n = 437), IS = True)
pred_CS = predict_count(pivot_CS, get_topsim(sim_Cust, top_n = 1050))

topsim_Des = get_topsim(sim_Des, top_n= 439)
pred_Des = pivot_CS.values.dot(topsim_Des.values) / np.array([np.abs(topsim_Des.values).sum(axis=1)])
pred_Des = pd.DataFrame(pred_Des, index=pivot_CS.index, columns=pivot_CS.columns)

# %%
print(recomm_model(pred_IS, recomm_n = recomm_n)[3])
print(recomm_model(pred_CS, recomm_n = recomm_n)[3])
print(recomm_model(pred_Des, recomm_n = recomm_n)[3])
# Out:
# {'정밀도': 0.0901}
# {'정밀도': 0.0544}
# {'정밀도': 0.0349}

# %%
total_param = [] 

# 첫 번째 숫자 선택
for num1 in range(101): #2601번 실행
    # 두 번째 숫자 선택
    for num2 in range(num1 + 1):
        # 세 번째 숫자는 첫 번째와 두 번째 숫자를 뺀 나머지
        num3 = 100 - num1 - num2
        # 세 번째 숫자가 음수가 되면 다음 순서로 넘어감
        if num3 < 0:
            continue

        num_1 = num1/100
        num_2 = num2/100
        num_3 = num3/100

        precision = recomm_model((num_1*pred_IS + num_2*pred_CS + num_3*pred_Des), recomm_n = recomm_n)[3]
        total_param.append(['가중치 비율',[num_1, num_2, num_3], precision])

        print('가중치 비율',[num_1, num_2, num_3], precision)
        
print('\n 최대 정밀도:', max(total_param, key=lambda x: x[2]['정밀도']))
# Out:
# 가중치 비율 [0.0, 0.0, 1.0] {'정밀도': 0.0349}
# 가중치 비율 [0.01, 0.0, 0.99] {'정밀도': 0.0352}
# 가중치 비율 [0.01, 0.01, 0.98] {'정밀도': 0.0355}
# 가중치 비율 [0.02, 0.0, 0.98] {'정밀도': 0.0355}
# 가중치 비율 [0.02, 0.01, 0.97] {'정밀도': 0.0358}
# 가중치 비율 [0.02, 0.02, 0.96] {'정밀도': 0.0363}
# 가중치 비율 [0.03, 0.0, 0.97] {'정밀도': 0.0362}
# 가중치 비율 [0.03, 0.01, 0.96] {'정밀도': 0.0365}
# 가중치 비율 [0.03, 0.02, 0.95] {'정밀도': 0.0369}
# 가중치 비율 [0.03, 0.03, 0.94] {'정밀도': 0.0373}
# 가중치 비율 [0.04, 0.0, 0.96] {'정밀도': 0.0365}
# 가중치 비율 [0.04, 0.01, 0.95] {'정밀도': 0.0368}
# 가중치 비율 [0.04, 0.02, 0.94] {'정밀도': 0.0374}
# 가중치 비율 [0.04, 0.03, 0.93] {'정밀도': 0.0376}
# 가중치 비율 [0.04, 0.04, 0.92] {'정밀도': 0.0379}
# 가중치 비율 [0.05, 0.0, 0.95] {'정밀도': 0.0371}
# 가중치 비율 [0.05, 0.01, 0.94] {'정밀도': 0.0375}
# 가중치 비율 [0.05, 0.02, 0.93] {'정밀도': 0.0379}
# 가중치 비율 [0.05, 0.03, 0.92] {'정밀도': 0.0379}
# 가중치 비율 [0.05, 0.04, 0.91] {'정밀도': 0.0382}
# 가중치 비율 [0.05, 0.05, 0.9] {'정밀도': 0.0387}
# 가중치 비율 [0.06, 0.0, 0.94] {'정밀도': 0.0375}
# 가중치 비율 [0.06, 0.01, 0.93] {'정밀도': 0.0377}
# 가중치 비율 [0.06, 0.02, 0.92] {'정밀도': 0.038}
# 가중치 비율 [0.06, 0.03, 0.91] {'정밀도': 0.0383}
# 가중치 비율 [0.06, 0.04, 0.9] {'정밀도': 0.0387}
# 가중치 비율 [0.06, 0.05, 0.89] {'정밀도': 0.0392}
# 가중치 비율 [0.06, 0.06, 0.88] {'정밀도': 0.0397}
# 가중치 비율 [0.07, 0.0, 0.93] {'정밀도': 0.0379}
# 가중치 비율 [0.07, 0.01, 0.92] {'정밀도': 0.0382}
# 가중치 비율 [0.07, 0.02, 0.91] {'정밀도': 0.0385}
# 가중치 비율 [0.07, 0.03, 0.9] {'정밀도': 0.0389}
# 가중치 비율 [0.07, 0.04, 0.89] {'정밀도': 0.0393}
# 가중치 비율 [0.07, 0.05, 0.88] {'정밀도': 0.04}
# 가중치 비율 [0.07, 0.06, 0.87] {'정밀도': 0.0407}
# 가중치 비율 [0.07, 0.07, 0.86] {'정밀도': 0.0408}
# 가중치 비율 [0.08, 0.0, 0.92] {'정밀도': 0.0382}
# 가중치 비율 [0.08, 0.01, 0.91] {'정밀도': 0.0387}
# 가중치 비율 [0.08, 0.02, 0.9] {'정밀도': 0.039}
# 가중치 비율 [0.08, 0.03, 0.89] {'정밀도': 0.0395}
# 가중치 비율 [0.08, 0.04, 0.88] {'정밀도': 0.0401}
# 가중치 비율 [0.08, 0.05, 0.87] {'정밀도': 0.0407}
# 가중치 비율 [0.08, 0.06, 0.86] {'정밀도': 0.0412}
# 가중치 비율 [0.08, 0.07, 0.85] {'정밀도': 0.0413}
# 가중치 비율 [0.08, 0.08, 0.84] {'정밀도': 0.0418}
# 가중치 비율 [0.09, 0.0, 0.91] {'정밀도': 0.0387}
# 가중치 비율 [0.09, 0.01, 0.9] {'정밀도': 0.039}
# 가중치 비율 [0.09, 0.02, 0.89] {'정밀도': 0.0396}
# 가중치 비율 [0.09, 0.03, 0.88] {'정밀도': 0.0402}
# 가중치 비율 [0.09, 0.04, 0.87] {'정밀도': 0.0405}
# 가중치 비율 [0.09, 0.05, 0.86] {'정밀도': 0.041}
# 가중치 비율 [0.09, 0.06, 0.85] {'정밀도': 0.0416}
# 가중치 비율 [0.09, 0.07, 0.84] {'정밀도': 0.0416}
# 가중치 비율 [0.09, 0.08, 0.83] {'정밀도': 0.0423}
# 가중치 비율 [0.09, 0.09, 0.82] {'정밀도': 0.0425}
# 가중치 비율 [0.1, 0.0, 0.9] {'정밀도': 0.0392}
# 가중치 비율 [0.1, 0.01, 0.89] {'정밀도': 0.0395}
# 가중치 비율 [0.1, 0.02, 0.88] {'정밀도': 0.0401}
# 가중치 비율 [0.1, 0.03, 0.87] {'정밀도': 0.0407}
# 가중치 비율 [0.1, 0.04, 0.86] {'정밀도': 0.0409}
# 가중치 비율 [0.1, 0.05, 0.85] {'정밀도': 0.0417}
# 가중치 비율 [0.1, 0.06, 0.84] {'정밀도': 0.042}
# 가중치 비율 [0.1, 0.07, 0.83] {'정밀도': 0.0422}
# 가중치 비율 [0.1, 0.08, 0.82] {'정밀도': 0.0429}
# 가중치 비율 [0.1, 0.09, 0.81] {'정밀도': 0.0431}
# 가중치 비율 [0.1, 0.1, 0.8] {'정밀도': 0.0434}
# 가중치 비율 [0.11, 0.0, 0.89] {'정밀도': 0.0395}
# 가중치 비율 [0.11, 0.01, 0.88] {'정밀도': 0.0401}
# 가중치 비율 [0.11, 0.02, 0.87] {'정밀도': 0.0406}
# 가중치 비율 [0.11, 0.03, 0.86] {'정밀도': 0.041}
# 가중치 비율 [0.11, 0.04, 0.85] {'정밀도': 0.0415}
# 가중치 비율 [0.11, 0.05, 0.84] {'정밀도': 0.0421}
# 가중치 비율 [0.11, 0.06, 0.83] {'정밀도': 0.0421}
# 가중치 비율 [0.11, 0.07, 0.82] {'정밀도': 0.0429}
# 가중치 비율 [0.11, 0.08, 0.81] {'정밀도': 0.043}
# 가중치 비율 [0.11, 0.09, 0.8] {'정밀도': 0.0433}
# 가중치 비율 [0.11, 0.1, 0.79] {'정밀도': 0.0437}
# 가중치 비율 [0.11, 0.11, 0.78] {'정밀도': 0.044}
# 가중치 비율 [0.12, 0.0, 0.88] {'정밀도': 0.04}
# 가중치 비율 [0.12, 0.01, 0.87] {'정밀도': 0.0405}
# 가중치 비율 [0.12, 0.02, 0.86] {'정밀도': 0.0411}
# 가중치 비율 [0.12, 0.03, 0.85] {'정밀도': 0.0416}
# 가중치 비율 [0.12, 0.04, 0.84] {'정밀도': 0.0419}
# 가중치 비율 [0.12, 0.05, 0.83] {'정밀도': 0.0423}
# 가중치 비율 [0.12, 0.06, 0.82] {'정밀도': 0.0427}
# 가중치 비율 [0.12, 0.07, 0.81] {'정밀도': 0.0431}
# 가중치 비율 [0.12, 0.08, 0.8] {'정밀도': 0.0433}
# 가중치 비율 [0.12, 0.09, 0.79] {'정밀도': 0.0436}
# 가중치 비율 [0.12, 0.1, 0.78] {'정밀도': 0.0443}
# 가중치 비율 [0.12, 0.11, 0.77] {'정밀도': 0.0451}
# 가중치 비율 [0.12, 0.12, 0.76] {'정밀도': 0.0459}
# 가중치 비율 [0.13, 0.0, 0.87] {'정밀도': 0.0402}
# 가중치 비율 [0.13, 0.01, 0.86] {'정밀도': 0.041}
# 가중치 비율 [0.13, 0.02, 0.85] {'정밀도': 0.0416}
# 가중치 비율 [0.13, 0.03, 0.84] {'정밀도': 0.042}
# 가중치 비율 [0.13, 0.04, 0.83] {'정밀도': 0.0425}
# 가중치 비율 [0.13, 0.05, 0.82] {'정밀도': 0.0426}
# 가중치 비율 [0.13, 0.06, 0.81] {'정밀도': 0.0431}
# 가중치 비율 [0.13, 0.07, 0.8] {'정밀도': 0.0437}
# 가중치 비율 [0.13, 0.08, 0.79] {'정밀도': 0.0441}
# 가중치 비율 [0.13, 0.09, 0.78] {'정밀도': 0.0448}
# 가중치 비율 [0.13, 0.1, 0.77] {'정밀도': 0.0452}
# 가중치 비율 [0.13, 0.11, 0.76] {'정밀도': 0.0458}
# 가중치 비율 [0.13, 0.12, 0.75] {'정밀도': 0.0465}
# 가중치 비율 [0.13, 0.13, 0.74] {'정밀도': 0.0467}
# 가중치 비율 [0.14, 0.0, 0.86] {'정밀도': 0.041}
# 가중치 비율 [0.14, 0.01, 0.85] {'정밀도': 0.0415}
# 가중치 비율 [0.14, 0.02, 0.84] {'정밀도': 0.042}
# 가중치 비율 [0.14, 0.03, 0.83] {'정밀도': 0.0425}
# 가중치 비율 [0.14, 0.04, 0.82] {'정밀도': 0.0429}
# 가중치 비율 [0.14, 0.05, 0.81] {'정밀도': 0.0435}
# 가중치 비율 [0.14, 0.06, 0.8] {'정밀도': 0.0437}
# 가중치 비율 [0.14, 0.07, 0.79] {'정밀도': 0.0444}
# 가중치 비율 [0.14, 0.08, 0.78] {'정밀도': 0.0447}
# 가중치 비율 [0.14, 0.09, 0.77] {'정밀도': 0.0458}
# 가중치 비율 [0.14, 0.1, 0.76] {'정밀도': 0.0459}
# 가중치 비율 [0.14, 0.11, 0.75] {'정밀도': 0.0465}
# 가중치 비율 [0.14, 0.12, 0.74] {'정밀도': 0.0467}
# 가중치 비율 [0.14, 0.13, 0.73] {'정밀도': 0.0474}
# 가중치 비율 [0.14, 0.14, 0.72] {'정밀도': 0.0481}
# 가중치 비율 [0.15, 0.0, 0.85] {'정밀도': 0.0419}
# 가중치 비율 [0.15, 0.01, 0.84] {'정밀도': 0.0422}
# 가중치 비율 [0.15, 0.02, 0.83] {'정밀도': 0.0426}
# 가중치 비율 [0.15, 0.03, 0.82] {'정밀도': 0.0431}
# 가중치 비율 [0.15, 0.04, 0.81] {'정밀도': 0.0434}
# 가중치 비율 [0.15, 0.05, 0.8] {'정밀도': 0.044}
# 가중치 비율 [0.15, 0.06, 0.79] {'정밀도': 0.0445}
# 가중치 비율 [0.15, 0.07, 0.78] {'정밀도': 0.045}
# 가중치 비율 [0.15, 0.08, 0.77] {'정밀도': 0.0457}
# 가중치 비율 [0.15, 0.09, 0.76] {'정밀도': 0.0465}
# 가중치 비율 [0.15, 0.1, 0.75] {'정밀도': 0.0466}
# 가중치 비율 [0.15, 0.11, 0.74] {'정밀도': 0.0472}
# 가중치 비율 [0.15, 0.12, 0.73] {'정밀도': 0.0475}
# 가중치 비율 [0.15, 0.13, 0.72] {'정밀도': 0.0483}
# 가중치 비율 [0.15, 0.14, 0.71] {'정밀도': 0.0492}
# 가중치 비율 [0.15, 0.15, 0.7] {'정밀도': 0.05}
# 가중치 비율 [0.16, 0.0, 0.84] {'정밀도': 0.0423}
# 가중치 비율 [0.16, 0.01, 0.83] {'정밀도': 0.0428}
# 가중치 비율 [0.16, 0.02, 0.82] {'정밀도': 0.0431}
# 가중치 비율 [0.16, 0.03, 0.81] {'정밀도': 0.0434}
# 가중치 비율 [0.16, 0.04, 0.8] {'정밀도': 0.0442}
# 가중치 비율 [0.16, 0.05, 0.79] {'정밀도': 0.0445}
# 가중치 비율 [0.16, 0.06, 0.78] {'정밀도': 0.045}
# 가중치 비율 [0.16, 0.07, 0.77] {'정밀도': 0.0456}
# 가중치 비율 [0.16, 0.08, 0.76] {'정밀도': 0.0464}
# 가중치 비율 [0.16, 0.09, 0.75] {'정밀도': 0.0469}
# 가중치 비율 [0.16, 0.1, 0.74] {'정밀도': 0.0474}
# 가중치 비율 [0.16, 0.11, 0.73] {'정밀도': 0.0479}
# 가중치 비율 [0.16, 0.12, 0.72] {'정밀도': 0.0488}
# 가중치 비율 [0.16, 0.13, 0.71] {'정밀도': 0.0495}
# 가중치 비율 [0.16, 0.14, 0.7] {'정밀도': 0.05}
# 가중치 비율 [0.16, 0.15, 0.69] {'정밀도': 0.0515}
# 가중치 비율 [0.16, 0.16, 0.68] {'정밀도': 0.0521}
# 가중치 비율 [0.17, 0.0, 0.83] {'정밀도': 0.0426}
# 가중치 비율 [0.17, 0.01, 0.82] {'정밀도': 0.0431}
# 가중치 비율 [0.17, 0.02, 0.81] {'정밀도': 0.0435}
# 가중치 비율 [0.17, 0.03, 0.8] {'정밀도': 0.044}
# 가중치 비율 [0.17, 0.04, 0.79] {'정밀도': 0.0447}
# 가중치 비율 [0.17, 0.05, 0.78] {'정밀도': 0.0451}
# 가중치 비율 [0.17, 0.06, 0.77] {'정밀도': 0.0457}
# 가중치 비율 [0.17, 0.07, 0.76] {'정밀도': 0.0465}
# 가중치 비율 [0.17, 0.08, 0.75] {'정밀도': 0.0471}
# 가중치 비율 [0.17, 0.09, 0.74] {'정밀도': 0.0475}
# 가중치 비율 [0.17, 0.1, 0.73] {'정밀도': 0.0485}
# 가중치 비율 [0.17, 0.11, 0.72] {'정밀도': 0.0492}
# 가중치 비율 [0.17, 0.12, 0.71] {'정밀도': 0.05}
# 가중치 비율 [0.17, 0.13, 0.7] {'정밀도': 0.0506}
# 가중치 비율 [0.17, 0.14, 0.69] {'정밀도': 0.0518}
# 가중치 비율 [0.17, 0.15, 0.68] {'정밀도': 0.0522}
# 가중치 비율 [0.17, 0.16, 0.67] {'정밀도': 0.0524}
# 가중치 비율 [0.17, 0.17, 0.66] {'정밀도': 0.0536}
# 가중치 비율 [0.18, 0.0, 0.82] {'정밀도': 0.0428}
# 가중치 비율 [0.18, 0.01, 0.81] {'정밀도': 0.0439}
# 가중치 비율 [0.18, 0.02, 0.8] {'정밀도': 0.0445}
# 가중치 비율 [0.18, 0.03, 0.79] {'정밀도': 0.0448}
# 가중치 비율 [0.18, 0.04, 0.78] {'정밀도': 0.0453}
# 가중치 비율 [0.18, 0.05, 0.77] {'정밀도': 0.0457}
# 가중치 비율 [0.18, 0.06, 0.76] {'정밀도': 0.0465}
# 가중치 비율 [0.18, 0.07, 0.75] {'정밀도': 0.0471}
# 가중치 비율 [0.18, 0.08, 0.74] {'정밀도': 0.048}
# 가중치 비율 [0.18, 0.09, 0.73] {'정밀도': 0.049}
# 가중치 비율 [0.18, 0.1, 0.72] {'정밀도': 0.0497}
# 가중치 비율 [0.18, 0.11, 0.71] {'정밀도': 0.0506}
# 가중치 비율 [0.18, 0.12, 0.7] {'정밀도': 0.051}
# 가중치 비율 [0.18, 0.13, 0.69] {'정밀도': 0.0514}
# 가중치 비율 [0.18, 0.14, 0.68] {'정밀도': 0.0522}
# 가중치 비율 [0.18, 0.15, 0.67] {'정밀도': 0.0531}
# 가중치 비율 [0.18, 0.16, 0.66] {'정밀도': 0.0536}
# 가중치 비율 [0.18, 0.17, 0.65] {'정밀도': 0.0545}
# 가중치 비율 [0.18, 0.18, 0.64] {'정밀도': 0.0555}
# 가중치 비율 [0.19, 0.0, 0.81] {'정밀도': 0.0439}
# 가중치 비율 [0.19, 0.01, 0.8] {'정밀도': 0.0445}
# 가중치 비율 [0.19, 0.02, 0.79] {'정밀도': 0.0449}
# 가중치 비율 [0.19, 0.03, 0.78] {'정밀도': 0.0452}
# 가중치 비율 [0.19, 0.04, 0.77] {'정밀도': 0.0457}
# 가중치 비율 [0.19, 0.05, 0.76] {'정밀도': 0.0467}
# 가중치 비율 [0.19, 0.06, 0.75] {'정밀도': 0.0474}
# 가중치 비율 [0.19, 0.07, 0.74] {'정밀도': 0.0483}
# 가중치 비율 [0.19, 0.08, 0.73] {'정밀도': 0.0491}
# 가중치 비율 [0.19, 0.09, 0.72] {'정밀도': 0.0501}
# 가중치 비율 [0.19, 0.1, 0.71] {'정밀도': 0.0505}
# 가중치 비율 [0.19, 0.11, 0.7] {'정밀도': 0.051}
# 가중치 비율 [0.19, 0.12, 0.69] {'정밀도': 0.0519}
# 가중치 비율 [0.19, 0.13, 0.68] {'정밀도': 0.0524}
# 가중치 비율 [0.19, 0.14, 0.67] {'정밀도': 0.0531}
# 가중치 비율 [0.19, 0.15, 0.66] {'정밀도': 0.0536}
# 가중치 비율 [0.19, 0.16, 0.65] {'정밀도': 0.0543}
# 가중치 비율 [0.19, 0.17, 0.64] {'정밀도': 0.0555}
# 가중치 비율 [0.19, 0.18, 0.63] {'정밀도': 0.0565}
# 가중치 비율 [0.19, 0.19, 0.62] {'정밀도': 0.0577}
# 가중치 비율 [0.2, 0.0, 0.8] {'정밀도': 0.0443}
# 가중치 비율 [0.2, 0.01, 0.79] {'정밀도': 0.0449}
# 가중치 비율 [0.2, 0.02, 0.78] {'정밀도': 0.0454}
# 가중치 비율 [0.2, 0.03, 0.77] {'정밀도': 0.046}
# 가중치 비율 [0.2, 0.04, 0.76] {'정밀도': 0.0469}
# 가중치 비율 [0.2, 0.05, 0.75] {'정밀도': 0.0476}
# 가중치 비율 [0.2, 0.06, 0.74] {'정밀도': 0.0483}
# 가중치 비율 [0.2, 0.07, 0.73] {'정밀도': 0.0492}
# 가중치 비율 [0.2, 0.08, 0.72] {'정밀도': 0.0497}
# 가중치 비율 [0.2, 0.09, 0.71] {'정밀도': 0.0508}
# 가중치 비율 [0.2, 0.1, 0.7] {'정밀도': 0.0515}
# 가중치 비율 [0.2, 0.11, 0.69] {'정밀도': 0.0518}
# 가중치 비율 [0.2, 0.12, 0.68] {'정밀도': 0.0525}
# 가중치 비율 [0.2, 0.13, 0.67] {'정밀도': 0.0537}
# 가중치 비율 [0.2, 0.14, 0.66] {'정밀도': 0.0539}
# 가중치 비율 [0.2, 0.15, 0.65] {'정밀도': 0.0548}
# 가중치 비율 [0.2, 0.16, 0.64] {'정밀도': 0.0552}
# 가중치 비율 [0.2, 0.17, 0.63] {'정밀도': 0.0564}
# 가중치 비율 [0.2, 0.18, 0.62] {'정밀도': 0.0574}
# 가중치 비율 [0.2, 0.19, 0.61] {'정밀도': 0.0587}
# 가중치 비율 [0.2, 0.2, 0.6] {'정밀도': 0.0594}
# 가중치 비율 [0.21, 0.0, 0.79] {'정밀도': 0.0451}
# 가중치 비율 [0.21, 0.01, 0.78] {'정밀도': 0.0459}
# 가중치 비율 [0.21, 0.02, 0.77] {'정밀도': 0.0464}
# 가중치 비율 [0.21, 0.03, 0.76] {'정밀도': 0.0467}
# 가중치 비율 [0.21, 0.04, 0.75] {'정밀도': 0.0478}
# 가중치 비율 [0.21, 0.05, 0.74] {'정밀도': 0.0484}
# 가중치 비율 [0.21, 0.06, 0.73] {'정밀도': 0.0494}
# 가중치 비율 [0.21, 0.07, 0.72] {'정밀도': 0.0499}
# 가중치 비율 [0.21, 0.08, 0.71] {'정밀도': 0.0507}
# 가중치 비율 [0.21, 0.09, 0.7] {'정밀도': 0.0517}
# 가중치 비율 [0.21, 0.1, 0.69] {'정밀도': 0.0524}
# 가중치 비율 [0.21, 0.11, 0.68] {'정밀도': 0.053}
# 가중치 비율 [0.21, 0.12, 0.67] {'정밀도': 0.0534}
# 가중치 비율 [0.21, 0.13, 0.66] {'정밀도': 0.0543}
# 가중치 비율 [0.21, 0.14, 0.65] {'정밀도': 0.0548}
# 가중치 비율 [0.21, 0.15, 0.64] {'정밀도': 0.0554}
# 가중치 비율 [0.21, 0.16, 0.63] {'정밀도': 0.0565}
# 가중치 비율 [0.21, 0.17, 0.62] {'정밀도': 0.0576}
# 가중치 비율 [0.21, 0.18, 0.61] {'정밀도': 0.0589}
# 가중치 비율 [0.21, 0.19, 0.6] {'정밀도': 0.0596}
# 가중치 비율 [0.21, 0.2, 0.59] {'정밀도': 0.0606}
# 가중치 비율 [0.21, 0.21, 0.58] {'정밀도': 0.0616}
# 가중치 비율 [0.22, 0.0, 0.78] {'정밀도': 0.046}
# 가중치 비율 [0.22, 0.01, 0.77] {'정밀도': 0.0469}
# 가중치 비율 [0.22, 0.02, 0.76] {'정밀도': 0.0472}
# 가중치 비율 [0.22, 0.03, 0.75] {'정밀도': 0.0479}
# 가중치 비율 [0.22, 0.04, 0.74] {'정밀도': 0.0485}
# 가중치 비율 [0.22, 0.05, 0.73] {'정밀도': 0.0494}
# 가중치 비율 [0.22, 0.06, 0.72] {'정밀도': 0.0503}
# 가중치 비율 [0.22, 0.07, 0.71] {'정밀도': 0.0509}
# 가중치 비율 [0.22, 0.08, 0.7] {'정밀도': 0.0518}
# 가중치 비율 [0.22, 0.09, 0.69] {'정밀도': 0.0524}
# 가중치 비율 [0.22, 0.1, 0.68] {'정밀도': 0.0529}
# 가중치 비율 [0.22, 0.11, 0.67] {'정밀도': 0.0536}
# 가중치 비율 [0.22, 0.12, 0.66] {'정밀도': 0.0547}
# 가중치 비율 [0.22, 0.13, 0.65] {'정밀도': 0.0551}
# 가중치 비율 [0.22, 0.14, 0.64] {'정밀도': 0.0557}
# 가중치 비율 [0.22, 0.15, 0.63] {'정밀도': 0.0568}
# 가중치 비율 [0.22, 0.16, 0.62] {'정밀도': 0.0575}
# 가중치 비율 [0.22, 0.17, 0.61] {'정밀도': 0.0588}
# 가중치 비율 [0.22, 0.18, 0.6] {'정밀도': 0.0598}
# 가중치 비율 [0.22, 0.19, 0.59] {'정밀도': 0.0609}
# 가중치 비율 [0.22, 0.2, 0.58] {'정밀도': 0.0618}
# 가중치 비율 [0.22, 0.21, 0.57] {'정밀도': 0.0627}
# 가중치 비율 [0.22, 0.22, 0.56] {'정밀도': 0.064}
# 가중치 비율 [0.23, 0.0, 0.77] {'정밀도': 0.0469}
# 가중치 비율 [0.23, 0.01, 0.76] {'정밀도': 0.0474}
# 가중치 비율 [0.23, 0.02, 0.75] {'정밀도': 0.0479}
# 가중치 비율 [0.23, 0.03, 0.74] {'정밀도': 0.0487}
# 가중치 비율 [0.23, 0.04, 0.73] {'정밀도': 0.0496}
# 가중치 비율 [0.23, 0.05, 0.72] {'정밀도': 0.0502}
# 가중치 비율 [0.23, 0.06, 0.71] {'정밀도': 0.0509}
# 가중치 비율 [0.23, 0.07, 0.7] {'정밀도': 0.0518}
# 가중치 비율 [0.23, 0.08, 0.69] {'정밀도': 0.0529}
# 가중치 비율 [0.23, 0.09, 0.68] {'정밀도': 0.0531}
# 가중치 비율 [0.23, 0.1, 0.67] {'정밀도': 0.0539}
# 가중치 비율 [0.23, 0.11, 0.66] {'정밀도': 0.0543}
# 가중치 비율 [0.23, 0.12, 0.65] {'정밀도': 0.0552}
# 가중치 비율 [0.23, 0.13, 0.64] {'정밀도': 0.056}
# 가중치 비율 [0.23, 0.14, 0.63] {'정밀도': 0.0568}
# 가중치 비율 [0.23, 0.15, 0.62] {'정밀도': 0.0579}
# 가중치 비율 [0.23, 0.16, 0.61] {'정밀도': 0.059}
# 가중치 비율 [0.23, 0.17, 0.6] {'정밀도': 0.0597}
# 가중치 비율 [0.23, 0.18, 0.59] {'정밀도': 0.0608}
# 가중치 비율 [0.23, 0.19, 0.58] {'정밀도': 0.0616}
# 가중치 비율 [0.23, 0.2, 0.57] {'정밀도': 0.0628}
# 가중치 비율 [0.23, 0.21, 0.56] {'정밀도': 0.0638}
# 가중치 비율 [0.23, 0.22, 0.55] {'정밀도': 0.0654}
# 가중치 비율 [0.23, 0.23, 0.54] {'정밀도': 0.0668}
# 가중치 비율 [0.24, 0.0, 0.76] {'정밀도': 0.0476}
# 가중치 비율 [0.24, 0.01, 0.75] {'정밀도': 0.0481}
# 가중치 비율 [0.24, 0.02, 0.74] {'정밀도': 0.0488}
# 가중치 비율 [0.24, 0.03, 0.73] {'정밀도': 0.0496}
# 가중치 비율 [0.24, 0.04, 0.72] {'정밀도': 0.0505}
# 가중치 비율 [0.24, 0.05, 0.71] {'정밀도': 0.051}
# 가중치 비율 [0.24, 0.06, 0.7] {'정밀도': 0.0519}
# 가중치 비율 [0.24, 0.07, 0.69] {'정밀도': 0.0525}
# 가중치 비율 [0.24, 0.08, 0.68] {'정밀도': 0.0534}
# 가중치 비율 [0.24, 0.09, 0.67] {'정밀도': 0.0537}
# 가중치 비율 [0.24, 0.1, 0.66] {'정밀도': 0.0545}
# 가중치 비율 [0.24, 0.11, 0.65] {'정밀도': 0.0554}
# 가중치 비율 [0.24, 0.12, 0.64] {'정밀도': 0.0563}
# 가중치 비율 [0.24, 0.13, 0.63] {'정밀도': 0.0569}
# 가중치 비율 [0.24, 0.14, 0.62] {'정밀도': 0.0577}
# 가중치 비율 [0.24, 0.15, 0.61] {'정밀도': 0.0587}
# 가중치 비율 [0.24, 0.16, 0.6] {'정밀도': 0.0597}
# 가중치 비율 [0.24, 0.17, 0.59] {'정밀도': 0.0609}
# 가중치 비율 [0.24, 0.18, 0.58] {'정밀도': 0.0619}
# 가중치 비율 [0.24, 0.19, 0.57] {'정밀도': 0.0628}
# 가중치 비율 [0.24, 0.2, 0.56] {'정밀도': 0.0642}
# 가중치 비율 [0.24, 0.21, 0.55] {'정밀도': 0.065}
# 가중치 비율 [0.24, 0.22, 0.54] {'정밀도': 0.0662}
# 가중치 비율 [0.24, 0.23, 0.53] {'정밀도': 0.0676}
# 가중치 비율 [0.24, 0.24, 0.52] {'정밀도': 0.0688}
# 가중치 비율 [0.25, 0.0, 0.75] {'정밀도': 0.0484}
# 가중치 비율 [0.25, 0.01, 0.74] {'정밀도': 0.0492}
# 가중치 비율 [0.25, 0.02, 0.73] {'정밀도': 0.0497}
# 가중치 비율 [0.25, 0.03, 0.72] {'정밀도': 0.0504}
# 가중치 비율 [0.25, 0.04, 0.71] {'정밀도': 0.051}
# 가중치 비율 [0.25, 0.05, 0.7] {'정밀도': 0.0517}
# 가중치 비율 [0.25, 0.06, 0.69] {'정밀도': 0.0527}
# 가중치 비율 [0.25, 0.07, 0.68] {'정밀도': 0.0533}
# 가중치 비율 [0.25, 0.08, 0.67] {'정밀도': 0.0538}
# 가중치 비율 [0.25, 0.09, 0.66] {'정밀도': 0.0549}
# 가중치 비율 [0.25, 0.1, 0.65] {'정밀도': 0.0554}
# 가중치 비율 [0.25, 0.11, 0.64] {'정밀도': 0.0559}
# 가중치 비율 [0.25, 0.12, 0.63] {'정밀도': 0.0568}
# 가중치 비율 [0.25, 0.13, 0.62] {'정밀도': 0.0578}
# 가중치 비율 [0.25, 0.14, 0.61] {'정밀도': 0.0588}
# 가중치 비율 [0.25, 0.15, 0.6] {'정밀도': 0.0596}
# 가중치 비율 [0.25, 0.16, 0.59] {'정밀도': 0.0608}
# 가중치 비율 [0.25, 0.17, 0.58] {'정밀도': 0.0619}
# 가중치 비율 [0.25, 0.18, 0.57] {'정밀도': 0.0625}
# 가중치 비율 [0.25, 0.19, 0.56] {'정밀도': 0.0639}
# 가중치 비율 [0.25, 0.2, 0.55] {'정밀도': 0.0647}
# 가중치 비율 [0.25, 0.21, 0.54] {'정밀도': 0.0658}
# 가중치 비율 [0.25, 0.22, 0.53] {'정밀도': 0.0671}
# 가중치 비율 [0.25, 0.23, 0.52] {'정밀도': 0.0687}
# 가중치 비율 [0.25, 0.24, 0.51] {'정밀도': 0.0696}
# 가중치 비율 [0.25, 0.25, 0.5] {'정밀도': 0.0706}
# 가중치 비율 [0.26, 0.0, 0.74] {'정밀도': 0.0494}
# 가중치 비율 [0.26, 0.01, 0.73] {'정밀도': 0.0498}
# 가중치 비율 [0.26, 0.02, 0.72] {'정밀도': 0.0503}
# 가중치 비율 [0.26, 0.03, 0.71] {'정밀도': 0.0507}
# 가중치 비율 [0.26, 0.04, 0.7] {'정밀도': 0.0517}
# 가중치 비율 [0.26, 0.05, 0.69] {'정밀도': 0.0526}
# 가중치 비율 [0.26, 0.06, 0.68] {'정밀도': 0.0536}
# 가중치 비율 [0.26, 0.07, 0.67] {'정밀도': 0.054}
# 가중치 비율 [0.26, 0.08, 0.66] {'정밀도': 0.0547}
# 가중치 비율 [0.26, 0.09, 0.65] {'정밀도': 0.0555}
# 가중치 비율 [0.26, 0.1, 0.64] {'정밀도': 0.0561}
# 가중치 비율 [0.26, 0.11, 0.63] {'정밀도': 0.0572}
# 가중치 비율 [0.26, 0.12, 0.62] {'정밀도': 0.0581}
# 가중치 비율 [0.26, 0.13, 0.61] {'정밀도': 0.0588}
# 가중치 비율 [0.26, 0.14, 0.6] {'정밀도': 0.0597}
# 가중치 비율 [0.26, 0.15, 0.59] {'정밀도': 0.0605}
# 가중치 비율 [0.26, 0.16, 0.58] {'정밀도': 0.0617}
# 가중치 비율 [0.26, 0.17, 0.57] {'정밀도': 0.0625}
# 가중치 비율 [0.26, 0.18, 0.56] {'정밀도': 0.0633}
# 가중치 비율 [0.26, 0.19, 0.55] {'정밀도': 0.065}
# 가중치 비율 [0.26, 0.2, 0.54] {'정밀도': 0.0655}
# 가중치 비율 [0.26, 0.21, 0.53] {'정밀도': 0.0669}
# 가중치 비율 [0.26, 0.22, 0.52] {'정밀도': 0.0685}
# 가중치 비율 [0.26, 0.23, 0.51] {'정밀도': 0.0698}
# 가중치 비율 [0.26, 0.24, 0.5] {'정밀도': 0.071}
# 가중치 비율 [0.26, 0.25, 0.49] {'정밀도': 0.0719}
# 가중치 비율 [0.26, 0.26, 0.48] {'정밀도': 0.0724}
# 가중치 비율 [0.27, 0.0, 0.73] {'정밀도': 0.0499}
# 가중치 비율 [0.27, 0.01, 0.72] {'정밀도': 0.0504}
# 가중치 비율 [0.27, 0.02, 0.71] {'정밀도': 0.0505}
# 가중치 비율 [0.27, 0.03, 0.7] {'정밀도': 0.0515}
# 가중치 비율 [0.27, 0.04, 0.69] {'정밀도': 0.0526}
# 가중치 비율 [0.27, 0.05, 0.68] {'정밀도': 0.0534}
# 가중치 비율 [0.27, 0.06, 0.67] {'정밀도': 0.0539}
# 가중치 비율 [0.27, 0.07, 0.66] {'정밀도': 0.0549}
# 가중치 비율 [0.27, 0.08, 0.65] {'정밀도': 0.0556}
# 가중치 비율 [0.27, 0.09, 0.64] {'정밀도': 0.0562}
# 가중치 비율 [0.27, 0.1, 0.63] {'정밀도': 0.0571}
# 가중치 비율 [0.27, 0.11, 0.62] {'정밀도': 0.0579}
# 가중치 비율 [0.27, 0.12, 0.61] {'정밀도': 0.0593}
# 가중치 비율 [0.27, 0.13, 0.6] {'정밀도': 0.0597}
# 가중치 비율 [0.27, 0.14, 0.59] {'정밀도': 0.0605}
# 가중치 비율 [0.27, 0.15, 0.58] {'정밀도': 0.0614}
# 가중치 비율 [0.27, 0.16, 0.57] {'정밀도': 0.0624}
# 가중치 비율 [0.27, 0.17, 0.56] {'정밀도': 0.0635}
# 가중치 비율 [0.27, 0.18, 0.55] {'정밀도': 0.065}
# 가중치 비율 [0.27, 0.19, 0.54] {'정밀도': 0.0657}
# 가중치 비율 [0.27, 0.2, 0.53] {'정밀도': 0.0668}
# 가중치 비율 [0.27, 0.21, 0.52] {'정밀도': 0.0683}
# 가중치 비율 [0.27, 0.22, 0.51] {'정밀도': 0.0696}
# 가중치 비율 [0.27, 0.23, 0.5] {'정밀도': 0.071}
# 가중치 비율 [0.27, 0.24, 0.49] {'정밀도': 0.0719}
# 가중치 비율 [0.27, 0.25, 0.48] {'정밀도': 0.0724}
# 가중치 비율 [0.27, 0.26, 0.47] {'정밀도': 0.0732}
# 가중치 비율 [0.27, 0.27, 0.46] {'정밀도': 0.0738}
# 가중치 비율 [0.28, 0.0, 0.72] {'정밀도': 0.0504}
# 가중치 비율 [0.28, 0.01, 0.71] {'정밀도': 0.0507}
# 가중치 비율 [0.28, 0.02, 0.7] {'정밀도': 0.0514}
# 가중치 비율 [0.28, 0.03, 0.69] {'정밀도': 0.0523}
# 가중치 비율 [0.28, 0.04, 0.68] {'정밀도': 0.0535}
# 가중치 비율 [0.28, 0.05, 0.67] {'정밀도': 0.0537}
# 가중치 비율 [0.28, 0.06, 0.66] {'정밀도': 0.0547}
# 가중치 비율 [0.28, 0.07, 0.65] {'정밀도': 0.0557}
# 가중치 비율 [0.28, 0.08, 0.64] {'정밀도': 0.0565}
# 가중치 비율 [0.28, 0.09, 0.63] {'정밀도': 0.0574}
# 가중치 비율 [0.28, 0.1, 0.62] {'정밀도': 0.0581}
# 가중치 비율 [0.28, 0.11, 0.61] {'정밀도': 0.0591}
# 가중치 비율 [0.28, 0.12, 0.6] {'정밀도': 0.0593}
# 가중치 비율 [0.28, 0.13, 0.59] {'정밀도': 0.0604}
# 가중치 비율 [0.28, 0.14, 0.58] {'정밀도': 0.0611}
# 가중치 비율 [0.28, 0.15, 0.57] {'정밀도': 0.0625}
# 가중치 비율 [0.28, 0.16, 0.56] {'정밀도': 0.0636}
# 가중치 비율 [0.28, 0.17, 0.55] {'정밀도': 0.0647}
# 가중치 비율 [0.28, 0.18, 0.54] {'정밀도': 0.0658}
# 가중치 비율 [0.28, 0.19, 0.53] {'정밀도': 0.0673}
# 가중치 비율 [0.28, 0.2, 0.52] {'정밀도': 0.0684}
# 가중치 비율 [0.28, 0.21, 0.51] {'정밀도': 0.0699}
# 가중치 비율 [0.28, 0.22, 0.5] {'정밀도': 0.0711}
# 가중치 비율 [0.28, 0.23, 0.49] {'정밀도': 0.072}
# 가중치 비율 [0.28, 0.24, 0.48] {'정밀도': 0.0731}
# 가중치 비율 [0.28, 0.25, 0.47] {'정밀도': 0.0737}
# 가중치 비율 [0.28, 0.26, 0.46] {'정밀도': 0.0743}
# 가중치 비율 [0.28, 0.27, 0.45] {'정밀도': 0.0749}
# 가중치 비율 [0.28, 0.28, 0.44] {'정밀도': 0.0761}
# 가중치 비율 [0.29, 0.0, 0.71] {'정밀도': 0.0509}
# 가중치 비율 [0.29, 0.01, 0.7] {'정밀도': 0.0513}
# 가중치 비율 [0.29, 0.02, 0.69] {'정밀도': 0.0523}
# 가중치 비율 [0.29, 0.03, 0.68] {'정밀도': 0.0536}
# 가중치 비율 [0.29, 0.04, 0.67] {'정밀도': 0.054}
# 가중치 비율 [0.29, 0.05, 0.66] {'정밀도': 0.0546}
# 가중치 비율 [0.29, 0.06, 0.65] {'정밀도': 0.0553}
# 가중치 비율 [0.29, 0.07, 0.64] {'정밀도': 0.0567}
# 가중치 비율 [0.29, 0.08, 0.63] {'정밀도': 0.0575}
# 가중치 비율 [0.29, 0.09, 0.62] {'정밀도': 0.0579}
# 가중치 비율 [0.29, 0.1, 0.61] {'정밀도': 0.0588}
# 가중치 비율 [0.29, 0.11, 0.6] {'정밀도': 0.0594}
# 가중치 비율 [0.29, 0.12, 0.59] {'정밀도': 0.0601}
# 가중치 비율 [0.29, 0.13, 0.58] {'정밀도': 0.0612}
# 가중치 비율 [0.29, 0.14, 0.57] {'정밀도': 0.0623}
# 가중치 비율 [0.29, 0.15, 0.56] {'정밀도': 0.0633}
# 가중치 비율 [0.29, 0.16, 0.55] {'정밀도': 0.0643}
# 가중치 비율 [0.29, 0.17, 0.54] {'정밀도': 0.0653}
# 가중치 비율 [0.29, 0.18, 0.53] {'정밀도': 0.0674}
# 가중치 비율 [0.29, 0.19, 0.52] {'정밀도': 0.0685}
# 가중치 비율 [0.29, 0.2, 0.51] {'정밀도': 0.07}
# 가중치 비율 [0.29, 0.21, 0.5] {'정밀도': 0.071}
# 가중치 비율 [0.29, 0.22, 0.49] {'정밀도': 0.072}
# 가중치 비율 [0.29, 0.23, 0.48] {'정밀도': 0.073}
# 가중치 비율 [0.29, 0.24, 0.47] {'정밀도': 0.074}
# 가중치 비율 [0.29, 0.25, 0.46] {'정밀도': 0.0748}
# 가중치 비율 [0.29, 0.26, 0.45] {'정밀도': 0.0753}
# 가중치 비율 [0.29, 0.27, 0.44] {'정밀도': 0.0759}
# 가중치 비율 [0.29, 0.28, 0.43] {'정밀도': 0.0765}
# 가중치 비율 [0.29, 0.29, 0.42] {'정밀도': 0.0768}
# 가중치 비율 [0.3, 0.0, 0.7] {'정밀도': 0.0516}
# 가중치 비율 [0.3, 0.01, 0.69] {'정밀도': 0.0524}
# 가중치 비율 [0.3, 0.02, 0.68] {'정밀도': 0.0535}
# 가중치 비율 [0.3, 0.03, 0.67] {'정밀도': 0.0542}
# 가중치 비율 [0.3, 0.04, 0.66] {'정밀도': 0.0547}
# 가중치 비율 [0.3, 0.05, 0.65] {'정밀도': 0.0559}
# 가중치 비율 [0.3, 0.06, 0.64] {'정밀도': 0.0567}
# 가중치 비율 [0.3, 0.07, 0.63] {'정밀도': 0.0574}
# 가중치 비율 [0.3, 0.08, 0.62] {'정밀도': 0.058}
# 가중치 비율 [0.3, 0.09, 0.61] {'정밀도': 0.0584}
# 가중치 비율 [0.3, 0.1, 0.6] {'정밀도': 0.0594}
# 가중치 비율 [0.3, 0.11, 0.59] {'정밀도': 0.0597}
# 가중치 비율 [0.3, 0.12, 0.58] {'정밀도': 0.0611}
# 가중치 비율 [0.3, 0.13, 0.57] {'정밀도': 0.0622}
# 가중치 비율 [0.3, 0.14, 0.56] {'정밀도': 0.0632}
# 가중치 비율 [0.3, 0.15, 0.55] {'정밀도': 0.0645}
# 가중치 비율 [0.3, 0.16, 0.54] {'정밀도': 0.0656}
# 가중치 비율 [0.3, 0.17, 0.53] {'정밀도': 0.0674}
# 가중치 비율 [0.3, 0.18, 0.52] {'정밀도': 0.0683}
# 가중치 비율 [0.3, 0.19, 0.51] {'정밀도': 0.07}
# 가중치 비율 [0.3, 0.2, 0.5] {'정밀도': 0.0708}
# 가중치 비율 [0.3, 0.21, 0.49] {'정밀도': 0.072}
# 가중치 비율 [0.3, 0.22, 0.48] {'정밀도': 0.0727}
# 가중치 비율 [0.3, 0.23, 0.47] {'정밀도': 0.0741}
# 가중치 비율 [0.3, 0.24, 0.46] {'정밀도': 0.0746}
# 가중치 비율 [0.3, 0.25, 0.45] {'정밀도': 0.0754}
# 가중치 비율 [0.3, 0.26, 0.44] {'정밀도': 0.0763}
# 가중치 비율 [0.3, 0.27, 0.43] {'정밀도': 0.0766}
# 가중치 비율 [0.3, 0.28, 0.42] {'정밀도': 0.0769}
# 가중치 비율 [0.3, 0.29, 0.41] {'정밀도': 0.0777}
# 가중치 비율 [0.3, 0.3, 0.4] {'정밀도': 0.0778}
# 가중치 비율 [0.31, 0.0, 0.69] {'정밀도': 0.0527}
# 가중치 비율 [0.31, 0.01, 0.68] {'정밀도': 0.0533}
# 가중치 비율 [0.31, 0.02, 0.67] {'정밀도': 0.0543}
# 가중치 비율 [0.31, 0.03, 0.66] {'정밀도': 0.0546}
# 가중치 비율 [0.31, 0.04, 0.65] {'정밀도': 0.0555}
# 가중치 비율 [0.31, 0.05, 0.64] {'정밀도': 0.0565}
# 가중치 비율 [0.31, 0.06, 0.63] {'정밀도': 0.0571}
# 가중치 비율 [0.31, 0.07, 0.62] {'정밀도': 0.058}
# 가중치 비율 [0.31, 0.08, 0.61] {'정밀도': 0.0587}
# 가중치 비율 [0.31, 0.09, 0.6] {'정밀도': 0.0594}
# 가중치 비율 [0.31, 0.1, 0.59] {'정밀도': 0.0599}
# 가중치 비율 [0.31, 0.11, 0.58] {'정밀도': 0.0607}
# 가중치 비율 [0.31, 0.12, 0.57] {'정밀도': 0.0626}
# 가중치 비율 [0.31, 0.13, 0.56] {'정밀도': 0.0629}
# 가중치 비율 [0.31, 0.14, 0.55] {'정밀도': 0.0641}
# 가중치 비율 [0.31, 0.15, 0.54] {'정밀도': 0.0653}
# 가중치 비율 [0.31, 0.16, 0.53] {'정밀도': 0.067}
# 가중치 비율 [0.31, 0.17, 0.52] {'정밀도': 0.0686}
# 가중치 비율 [0.31, 0.18, 0.51] {'정밀도': 0.0701}
# 가중치 비율 [0.31, 0.19, 0.5] {'정밀도': 0.0709}
# 가중치 비율 [0.31, 0.2, 0.49] {'정밀도': 0.0717}
# 가중치 비율 [0.31, 0.21, 0.48] {'정밀도': 0.0729}
# 가중치 비율 [0.31, 0.22, 0.47] {'정밀도': 0.074}
# 가중치 비율 [0.31, 0.23, 0.46] {'정밀도': 0.0744}
# 가중치 비율 [0.31, 0.24, 0.45] {'정밀도': 0.0753}
# 가중치 비율 [0.31, 0.25, 0.44] {'정밀도': 0.0761}
# 가중치 비율 [0.31, 0.26, 0.43] {'정밀도': 0.0767}
# 가중치 비율 [0.31, 0.27, 0.42] {'정밀도': 0.0771}
# 가중치 비율 [0.31, 0.28, 0.41] {'정밀도': 0.0774}
# 가중치 비율 [0.31, 0.29, 0.4] {'정밀도': 0.0782}
# 가중치 비율 [0.31, 0.3, 0.39] {'정밀도': 0.0785}
# 가중치 비율 [0.31, 0.31, 0.38] {'정밀도': 0.0795}
# 가중치 비율 [0.32, 0.0, 0.68] {'정밀도': 0.0534}
# 가중치 비율 [0.32, 0.01, 0.67] {'정밀도': 0.0539}
# 가중치 비율 [0.32, 0.02, 0.66] {'정밀도': 0.0547}
# 가중치 비율 [0.32, 0.03, 0.65] {'정밀도': 0.0553}
# 가중치 비율 [0.32, 0.04, 0.64] {'정밀도': 0.0562}
# 가중치 비율 [0.32, 0.05, 0.63] {'정밀도': 0.0569}
# 가중치 비율 [0.32, 0.06, 0.62] {'정밀도': 0.0584}
# 가중치 비율 [0.32, 0.07, 0.61] {'정밀도': 0.0589}
# 가중치 비율 [0.32, 0.08, 0.6] {'정밀도': 0.0596}
# 가중치 비율 [0.32, 0.09, 0.59] {'정밀도': 0.0599}
# 가중치 비율 [0.32, 0.1, 0.58] {'정밀도': 0.0608}
# 가중치 비율 [0.32, 0.11, 0.57] {'정밀도': 0.0622}
# 가중치 비율 [0.32, 0.12, 0.56] {'정밀도': 0.0634}
# 가중치 비율 [0.32, 0.13, 0.55] {'정밀도': 0.0642}
# 가중치 비율 [0.32, 0.14, 0.54] {'정밀도': 0.0653}
# 가중치 비율 [0.32, 0.15, 0.53] {'정밀도': 0.067}
# 가중치 비율 [0.32, 0.16, 0.52] {'정밀도': 0.0688}
# 가중치 비율 [0.32, 0.17, 0.51] {'정밀도': 0.0697}
# 가중치 비율 [0.32, 0.18, 0.5] {'정밀도': 0.0707}
# 가중치 비율 [0.32, 0.19, 0.49] {'정밀도': 0.0716}
# 가중치 비율 [0.32, 0.2, 0.48] {'정밀도': 0.0729}
# 가중치 비율 [0.32, 0.21, 0.47] {'정밀도': 0.0737}
# 가중치 비율 [0.32, 0.22, 0.46] {'정밀도': 0.0747}
# 가중치 비율 [0.32, 0.23, 0.45] {'정밀도': 0.0755}
# 가중치 비율 [0.32, 0.24, 0.44] {'정밀도': 0.0762}
# 가중치 비율 [0.32, 0.25, 0.43] {'정밀도': 0.0766}
# 가중치 비율 [0.32, 0.26, 0.42] {'정밀도': 0.0773}
# 가중치 비율 [0.32, 0.27, 0.41] {'정밀도': 0.0776}
# 가중치 비율 [0.32, 0.28, 0.4] {'정밀도': 0.0784}
# 가중치 비율 [0.32, 0.29, 0.39] {'정밀도': 0.0787}
# 가중치 비율 [0.32, 0.3, 0.38] {'정밀도': 0.0795}
# 가중치 비율 [0.32, 0.31, 0.37] {'정밀도': 0.08}
# 가중치 비율 [0.32, 0.32, 0.36] {'정밀도': 0.0805}
# 가중치 비율 [0.33, 0.0, 0.67] {'정밀도': 0.054}
# 가중치 비율 [0.33, 0.01, 0.66] {'정밀도': 0.0547}
# 가중치 비율 [0.33, 0.02, 0.65] {'정밀도': 0.0553}
# 가중치 비율 [0.33, 0.03, 0.64] {'정밀도': 0.056}
# 가중치 비율 [0.33, 0.04, 0.63] {'정밀도': 0.057}
# 가중치 비율 [0.33, 0.05, 0.62] {'정밀도': 0.0579}
# 가중치 비율 [0.33, 0.06, 0.61] {'정밀도': 0.0587}
# 가중치 비율 [0.33, 0.07, 0.6] {'정밀도': 0.0594}
# 가중치 비율 [0.33, 0.08, 0.59] {'정밀도': 0.06}
# 가중치 비율 [0.33, 0.09, 0.58] {'정밀도': 0.061}
# 가중치 비율 [0.33, 0.1, 0.57] {'정밀도': 0.062}
# 가중치 비율 [0.33, 0.11, 0.56] {'정밀도': 0.0633}
# 가중치 비율 [0.33, 0.12, 0.55] {'정밀도': 0.0644}
# 가중치 비율 [0.33, 0.13, 0.54] {'정밀도': 0.0654}
# 가중치 비율 [0.33, 0.14, 0.53] {'정밀도': 0.0666}
# 가중치 비율 [0.33, 0.15, 0.52] {'정밀도': 0.0683}
# 가중치 비율 [0.33, 0.16, 0.51] {'정밀도': 0.0699}
# 가중치 비율 [0.33, 0.17, 0.5] {'정밀도': 0.071}
# 가중치 비율 [0.33, 0.18, 0.49] {'정밀도': 0.0718}
# 가중치 비율 [0.33, 0.19, 0.48] {'정밀도': 0.073}
# 가중치 비율 [0.33, 0.2, 0.47] {'정밀도': 0.074}
# 가중치 비율 [0.33, 0.21, 0.46] {'정밀도': 0.0748}
# 가중치 비율 [0.33, 0.22, 0.45] {'정밀도': 0.0754}
# 가중치 비율 [0.33, 0.23, 0.44] {'정밀도': 0.0762}
# 가중치 비율 [0.33, 0.24, 0.43] {'정밀도': 0.0766}
# 가중치 비율 [0.33, 0.25, 0.42] {'정밀도': 0.0775}
# 가중치 비율 [0.33, 0.26, 0.41] {'정밀도': 0.0779}
# 가중치 비율 [0.33, 0.27, 0.4] {'정밀도': 0.0783}
# 가중치 비율 [0.33, 0.28, 0.39] {'정밀도': 0.0789}
# 가중치 비율 [0.33, 0.29, 0.38] {'정밀도': 0.0794}
# 가중치 비율 [0.33, 0.3, 0.37] {'정밀도': 0.0803}
# 가중치 비율 [0.33, 0.31, 0.36] {'정밀도': 0.0807}
# 가중치 비율 [0.33, 0.32, 0.35] {'정밀도': 0.0812}
# 가중치 비율 [0.33, 0.33, 0.34] {'정밀도': 0.0811}
# 가중치 비율 [0.34, 0.0, 0.66] {'정밀도': 0.0547}
# 가중치 비율 [0.34, 0.01, 0.65] {'정밀도': 0.055}
# 가중치 비율 [0.34, 0.02, 0.64] {'정밀도': 0.0564}
# 가중치 비율 [0.34, 0.03, 0.63] {'정밀도': 0.057}
# 가중치 비율 [0.34, 0.04, 0.62] {'정밀도': 0.0579}
# 가중치 비율 [0.34, 0.05, 0.61] {'정밀도': 0.0586}
# 가중치 비율 [0.34, 0.06, 0.6] {'정밀도': 0.0595}
# 가중치 비율 [0.34, 0.07, 0.59] {'정밀도': 0.06}
# 가중치 비율 [0.34, 0.08, 0.58] {'정밀도': 0.0609}
# 가중치 비율 [0.34, 0.09, 0.57] {'정밀도': 0.0622}
# 가중치 비율 [0.34, 0.1, 0.56] {'정밀도': 0.0626}
# 가중치 비율 [0.34, 0.11, 0.55] {'정밀도': 0.0644}
# 가중치 비율 [0.34, 0.12, 0.54] {'정밀도': 0.0654}
# 가중치 비율 [0.34, 0.13, 0.53] {'정밀도': 0.0661}
# 가중치 비율 [0.34, 0.14, 0.52] {'정밀도': 0.0682}
# 가중치 비율 [0.34, 0.15, 0.51] {'정밀도': 0.0701}
# 가중치 비율 [0.34, 0.16, 0.5] {'정밀도': 0.0709}
# 가중치 비율 [0.34, 0.17, 0.49] {'정밀도': 0.072}
# 가중치 비율 [0.34, 0.18, 0.48] {'정밀도': 0.0725}
# 가중치 비율 [0.34, 0.19, 0.47] {'정밀도': 0.0742}
# 가중치 비율 [0.34, 0.2, 0.46] {'정밀도': 0.0748}
# 가중치 비율 [0.34, 0.21, 0.45] {'정밀도': 0.0755}
# 가중치 비율 [0.34, 0.22, 0.44] {'정밀도': 0.0762}
# 가중치 비율 [0.34, 0.23, 0.43] {'정밀도': 0.077}
# 가중치 비율 [0.34, 0.24, 0.42] {'정밀도': 0.0778}
# 가중치 비율 [0.34, 0.25, 0.41] {'정밀도': 0.0778}
# 가중치 비율 [0.34, 0.26, 0.4] {'정밀도': 0.0784}
# 가중치 비율 [0.34, 0.27, 0.39] {'정밀도': 0.0791}
# 가중치 비율 [0.34, 0.28, 0.38] {'정밀도': 0.0798}
# 가중치 비율 [0.34, 0.29, 0.37] {'정밀도': 0.0806}
# 가중치 비율 [0.34, 0.3, 0.36] {'정밀도': 0.0809}
# 가중치 비율 [0.34, 0.31, 0.35] {'정밀도': 0.0816}
# 가중치 비율 [0.34, 0.32, 0.34] {'정밀도': 0.0816}
# 가중치 비율 [0.34, 0.33, 0.33] {'정밀도': 0.0815}
# 가중치 비율 [0.34, 0.34, 0.32] {'정밀도': 0.0812}
# 가중치 비율 [0.35, 0.0, 0.65] {'정밀도': 0.0551}
# 가중치 비율 [0.35, 0.01, 0.64] {'정밀도': 0.0561}
# 가중치 비율 [0.35, 0.02, 0.63] {'정밀도': 0.0568}
# 가중치 비율 [0.35, 0.03, 0.62] {'정밀도': 0.0581}
# 가중치 비율 [0.35, 0.04, 0.61] {'정밀도': 0.0587}
# 가중치 비율 [0.35, 0.05, 0.6] {'정밀도': 0.0595}
# 가중치 비율 [0.35, 0.06, 0.59] {'정밀도': 0.0601}
# 가중치 비율 [0.35, 0.07, 0.58] {'정밀도': 0.0608}
# 가중치 비율 [0.35, 0.08, 0.57] {'정밀도': 0.062}
# 가중치 비율 [0.35, 0.09, 0.56] {'정밀도': 0.063}
# 가중치 비율 [0.35, 0.1, 0.55] {'정밀도': 0.0645}
# 가중치 비율 [0.35, 0.11, 0.54] {'정밀도': 0.0656}
# 가중치 비율 [0.35, 0.12, 0.53] {'정밀도': 0.0665}
# 가중치 비율 [0.35, 0.13, 0.52] {'정밀도': 0.0681}
# 가중치 비율 [0.35, 0.14, 0.51] {'정밀도': 0.0699}
# 가중치 비율 [0.35, 0.15, 0.5] {'정밀도': 0.0708}
# 가중치 비율 [0.35, 0.16, 0.49] {'정밀도': 0.0716}
# 가중치 비율 [0.35, 0.17, 0.48] {'정밀도': 0.0726}
# 가중치 비율 [0.35, 0.18, 0.47] {'정밀도': 0.0742}
# 가중치 비율 [0.35, 0.19, 0.46] {'정밀도': 0.075}
# 가중치 비율 [0.35, 0.2, 0.45] {'정밀도': 0.0761}
# 가중치 비율 [0.35, 0.21, 0.44] {'정밀도': 0.0764}
# 가중치 비율 [0.35, 0.22, 0.43] {'정밀도': 0.0771}
# 가중치 비율 [0.35, 0.23, 0.42] {'정밀도': 0.078}
# 가중치 비율 [0.35, 0.24, 0.41] {'정밀도': 0.0783}
# 가중치 비율 [0.35, 0.25, 0.4] {'정밀도': 0.0786}
# 가중치 비율 [0.35, 0.26, 0.39] {'정밀도': 0.0792}
# 가중치 비율 [0.35, 0.27, 0.38] {'정밀도': 0.0798}
# 가중치 비율 [0.35, 0.28, 0.37] {'정밀도': 0.0804}
# 가중치 비율 [0.35, 0.29, 0.36] {'정밀도': 0.0814}
# 가중치 비율 [0.35, 0.3, 0.35] {'정밀도': 0.0815}
# 가중치 비율 [0.35, 0.31, 0.34] {'정밀도': 0.0821}
# 가중치 비율 [0.35, 0.32, 0.33] {'정밀도': 0.0816}
# 가중치 비율 [0.35, 0.33, 0.32] {'정밀도': 0.082}
# 가중치 비율 [0.35, 0.34, 0.31] {'정밀도': 0.0822}
# 가중치 비율 [0.35, 0.35, 0.3] {'정밀도': 0.0817}
# 가중치 비율 [0.36, 0.0, 0.64] {'정밀도': 0.0558}
# 가중치 비율 [0.36, 0.01, 0.63] {'정밀도': 0.057}
# 가중치 비율 [0.36, 0.02, 0.62] {'정밀도': 0.0579}
# 가중치 비율 [0.36, 0.03, 0.61] {'정밀도': 0.0589}
# 가중치 비율 [0.36, 0.04, 0.6] {'정밀도': 0.0593}
# 가중치 비율 [0.36, 0.05, 0.59] {'정밀도': 0.0602}
# 가중치 비율 [0.36, 0.06, 0.58] {'정밀도': 0.0608}
# 가중치 비율 [0.36, 0.07, 0.57] {'정밀도': 0.0618}
# 가중치 비율 [0.36, 0.08, 0.56] {'정밀도': 0.063}
# 가중치 비율 [0.36, 0.09, 0.55] {'정밀도': 0.0644}
# 가중치 비율 [0.36, 0.1, 0.54] {'정밀도': 0.0654}
# 가중치 비율 [0.36, 0.11, 0.53] {'정밀도': 0.0665}
# 가중치 비율 [0.36, 0.12, 0.52] {'정밀도': 0.0678}
# 가중치 비율 [0.36, 0.13, 0.51] {'정밀도': 0.0694}
# 가중치 비율 [0.36, 0.14, 0.5] {'정밀도': 0.071}
# 가중치 비율 [0.36, 0.15, 0.49] {'정밀도': 0.0716}
# 가중치 비율 [0.36, 0.16, 0.48] {'정밀도': 0.0729}
# 가중치 비율 [0.36, 0.17, 0.47] {'정밀도': 0.0737}
# 가중치 비율 [0.36, 0.18, 0.46] {'정밀도': 0.0749}
# 가중치 비율 [0.36, 0.19, 0.45] {'정밀도': 0.0757}
# 가중치 비율 [0.36, 0.2, 0.44] {'정밀도': 0.0764}
# 가중치 비율 [0.36, 0.21, 0.43] {'정밀도': 0.0774}
# 가중치 비율 [0.36, 0.22, 0.42] {'정밀도': 0.0778}
# 가중치 비율 [0.36, 0.23, 0.41] {'정밀도': 0.0786}
# 가중치 비율 [0.36, 0.24, 0.4] {'정밀도': 0.0783}
# 가중치 비율 [0.36, 0.25, 0.39] {'정밀도': 0.0791}
# 가중치 비율 [0.36, 0.26, 0.38] {'정밀도': 0.0803}
# 가중치 비율 [0.36, 0.27, 0.37] {'정밀도': 0.0801}
# 가중치 비율 [0.36, 0.28, 0.36] {'정밀도': 0.0817}
# 가중치 비율 [0.36, 0.29, 0.35] {'정밀도': 0.0819}
# 가중치 비율 [0.36, 0.3, 0.34] {'정밀도': 0.0823}
# 가중치 비율 [0.36, 0.31, 0.33] {'정밀도': 0.0822}
# 가중치 비율 [0.36, 0.32, 0.32] {'정밀도': 0.0822}
# 가중치 비율 [0.36, 0.33, 0.31] {'정밀도': 0.0825}
# 가중치 비율 [0.36, 0.34, 0.3] {'정밀도': 0.0824}
# 가중치 비율 [0.36, 0.35, 0.29] {'정밀도': 0.0818}
# 가중치 비율 [0.36, 0.36, 0.28] {'정밀도': 0.081}
# 가중치 비율 [0.37, 0.0, 0.63] {'정밀도': 0.0569}
# 가중치 비율 [0.37, 0.01, 0.62] {'정밀도': 0.0578}
# 가중치 비율 [0.37, 0.02, 0.61] {'정밀도': 0.0587}
# 가중치 비율 [0.37, 0.03, 0.6] {'정밀도': 0.0597}
# 가중치 비율 [0.37, 0.04, 0.59] {'정밀도': 0.0602}
# 가중치 비율 [0.37, 0.05, 0.58] {'정밀도': 0.061}
# 가중치 비율 [0.37, 0.06, 0.57] {'정밀도': 0.0621}
# 가중치 비율 [0.37, 0.07, 0.56] {'정밀도': 0.0632}
# 가중치 비율 [0.37, 0.08, 0.55] {'정밀도': 0.0644}
# 가중치 비율 [0.37, 0.09, 0.54] {'정밀도': 0.0657}
# 가중치 비율 [0.37, 0.1, 0.53] {'정밀도': 0.0664}
# 가중치 비율 [0.37, 0.11, 0.52] {'정밀도': 0.0676}
# 가중치 비율 [0.37, 0.12, 0.51] {'정밀도': 0.0689}
# 가중치 비율 [0.37, 0.13, 0.5] {'정밀도': 0.0703}
# 가중치 비율 [0.37, 0.14, 0.49] {'정밀도': 0.0715}
# 가중치 비율 [0.37, 0.15, 0.48] {'정밀도': 0.0725}
# 가중치 비율 [0.37, 0.16, 0.47] {'정밀도': 0.0739}
# 가중치 비율 [0.37, 0.17, 0.46] {'정밀도': 0.075}
# 가중치 비율 [0.37, 0.18, 0.45] {'정밀도': 0.0756}
# 가중치 비율 [0.37, 0.19, 0.44] {'정밀도': 0.0765}
# 가중치 비율 [0.37, 0.2, 0.43] {'정밀도': 0.0774}
# 가중치 비율 [0.37, 0.21, 0.42] {'정밀도': 0.078}
# 가중치 비율 [0.37, 0.22, 0.41] {'정밀도': 0.0787}
# 가중치 비율 [0.37, 0.23, 0.4] {'정밀도': 0.0792}
# 가중치 비율 [0.37, 0.24, 0.39] {'정밀도': 0.0793}
# 가중치 비율 [0.37, 0.25, 0.38] {'정밀도': 0.08}
# 가중치 비율 [0.37, 0.26, 0.37] {'정밀도': 0.0808}
# 가중치 비율 [0.37, 0.27, 0.36] {'정밀도': 0.0814}
# 가중치 비율 [0.37, 0.28, 0.35] {'정밀도': 0.0822}
# 가중치 비율 [0.37, 0.29, 0.34] {'정밀도': 0.0828}
# 가중치 비율 [0.37, 0.3, 0.33] {'정밀도': 0.0825}
# 가중치 비율 [0.37, 0.31, 0.32] {'정밀도': 0.0826}
# 가중치 비율 [0.37, 0.32, 0.31] {'정밀도': 0.0828}
# 가중치 비율 [0.37, 0.33, 0.3] {'정밀도': 0.0823}
# 가중치 비율 [0.37, 0.34, 0.29] {'정밀도': 0.0821}
# 가중치 비율 [0.37, 0.35, 0.28] {'정밀도': 0.0818}
# 가중치 비율 [0.37, 0.36, 0.27] {'정밀도': 0.0812}
# 가중치 비율 [0.37, 0.37, 0.26] {'정밀도': 0.081}
# 가중치 비율 [0.38, 0.0, 0.62] {'정밀도': 0.0577}
# 가중치 비율 [0.38, 0.01, 0.61] {'정밀도': 0.0588}
# 가중치 비율 [0.38, 0.02, 0.6] {'정밀도': 0.0595}
# 가중치 비율 [0.38, 0.03, 0.59] {'정밀도': 0.0601}
# 가중치 비율 [0.38, 0.04, 0.58] {'정밀도': 0.061}
# 가중치 비율 [0.38, 0.05, 0.57] {'정밀도': 0.0623}
# 가중치 비율 [0.38, 0.06, 0.56] {'정밀도': 0.0629}
# 가중치 비율 [0.38, 0.07, 0.55] {'정밀도': 0.0644}
# 가중치 비율 [0.38, 0.08, 0.54] {'정밀도': 0.0655}
# 가중치 비율 [0.38, 0.09, 0.53] {'정밀도': 0.0665}
# 가중치 비율 [0.38, 0.1, 0.52] {'정밀도': 0.0678}
# 가중치 비율 [0.38, 0.11, 0.51] {'정밀도': 0.0689}
# 가중치 비율 [0.38, 0.12, 0.5] {'정밀도': 0.0703}
# 가중치 비율 [0.38, 0.13, 0.49] {'정밀도': 0.0712}
# 가중치 비율 [0.38, 0.14, 0.48] {'정밀도': 0.0724}
# 가중치 비율 [0.38, 0.15, 0.47] {'정밀도': 0.0737}
# 가중치 비율 [0.38, 0.16, 0.46] {'정밀도': 0.0746}
# 가중치 비율 [0.38, 0.17, 0.45] {'정밀도': 0.0753}
# 가중치 비율 [0.38, 0.18, 0.44] {'정밀도': 0.0765}
# 가중치 비율 [0.38, 0.19, 0.43] {'정밀도': 0.0772}
# 가중치 비율 [0.38, 0.2, 0.42] {'정밀도': 0.0784}
# 가중치 비율 [0.38, 0.21, 0.41] {'정밀도': 0.0789}
# 가중치 비율 [0.38, 0.22, 0.4] {'정밀도': 0.0798}
# 가중치 비율 [0.38, 0.23, 0.39] {'정밀도': 0.0799}
# 가중치 비율 [0.38, 0.24, 0.38] {'정밀도': 0.0799}
# 가중치 비율 [0.38, 0.25, 0.37] {'정밀도': 0.0804}
# 가중치 비율 [0.38, 0.26, 0.36] {'정밀도': 0.0815}
# 가중치 비율 [0.38, 0.27, 0.35] {'정밀도': 0.0824}
# 가중치 비율 [0.38, 0.28, 0.34] {'정밀도': 0.0828}
# 가중치 비율 [0.38, 0.29, 0.33] {'정밀도': 0.0829}
# 가중치 비율 [0.38, 0.3, 0.32] {'정밀도': 0.0825}
# 가중치 비율 [0.38, 0.31, 0.31] {'정밀도': 0.0828}
# 가중치 비율 [0.38, 0.32, 0.3] {'정밀도': 0.0829}
# 가중치 비율 [0.38, 0.33, 0.29] {'정밀도': 0.0823}
# 가중치 비율 [0.38, 0.34, 0.28] {'정밀도': 0.082}
# 가중치 비율 [0.38, 0.35, 0.27] {'정밀도': 0.0819}
# 가중치 비율 [0.38, 0.36, 0.26] {'정밀도': 0.0814}
# 가중치 비율 [0.38, 0.37, 0.25] {'정밀도': 0.0809}
# 가중치 비율 [0.38, 0.38, 0.24] {'정밀도': 0.0804}
# 가중치 비율 [0.39, 0.0, 0.61] {'정밀도': 0.0586}
# 가중치 비율 [0.39, 0.01, 0.6] {'정밀도': 0.0595}
# 가중치 비율 [0.39, 0.02, 0.59] {'정밀도': 0.0602}
# 가중치 비율 [0.39, 0.03, 0.58] {'정밀도': 0.0611}
# 가중치 비율 [0.39, 0.04, 0.57] {'정밀도': 0.0621}
# 가중치 비율 [0.39, 0.05, 0.56] {'정밀도': 0.0631}
# 가중치 비율 [0.39, 0.06, 0.55] {'정밀도': 0.0646}
# 가중치 비율 [0.39, 0.07, 0.54] {'정밀도': 0.0653}
# 가중치 비율 [0.39, 0.08, 0.53] {'정밀도': 0.0666}
# 가중치 비율 [0.39, 0.09, 0.52] {'정밀도': 0.0675}
# 가중치 비율 [0.39, 0.1, 0.51] {'정밀도': 0.0688}
# 가중치 비율 [0.39, 0.11, 0.5] {'정밀도': 0.0704}
# 가중치 비율 [0.39, 0.12, 0.49] {'정밀도': 0.0707}
# 가중치 비율 [0.39, 0.13, 0.48] {'정밀도': 0.0722}
# 가중치 비율 [0.39, 0.14, 0.47] {'정밀도': 0.073}
# 가중치 비율 [0.39, 0.15, 0.46] {'정밀도': 0.075}
# 가중치 비율 [0.39, 0.16, 0.45] {'정밀도': 0.0751}
# 가중치 비율 [0.39, 0.17, 0.44] {'정밀도': 0.0764}
# 가중치 비율 [0.39, 0.18, 0.43] {'정밀도': 0.0775}
# 가중치 비율 [0.39, 0.19, 0.42] {'정밀도': 0.0778}
# 가중치 비율 [0.39, 0.2, 0.41] {'정밀도': 0.0788}
# 가중치 비율 [0.39, 0.21, 0.4] {'정밀도': 0.0799}
# 가중치 비율 [0.39, 0.22, 0.39] {'정밀도': 0.0806}
# 가중치 비율 [0.39, 0.23, 0.38] {'정밀도': 0.0805}
# 가중치 비율 [0.39, 0.24, 0.37] {'정밀도': 0.0808}
# 가중치 비율 [0.39, 0.25, 0.36] {'정밀도': 0.0814}
# 가중치 비율 [0.39, 0.26, 0.35] {'정밀도': 0.0823}
# 가중치 비율 [0.39, 0.27, 0.34] {'정밀도': 0.083}
# 가중치 비율 [0.39, 0.28, 0.33] {'정밀도': 0.0837}
# 가중치 비율 [0.39, 0.29, 0.32] {'정밀도': 0.0831}
# 가중치 비율 [0.39, 0.3, 0.31] {'정밀도': 0.0833}
# 가중치 비율 [0.39, 0.31, 0.3] {'정밀도': 0.0832}
# 가중치 비율 [0.39, 0.32, 0.29] {'정밀도': 0.0825}
# 가중치 비율 [0.39, 0.33, 0.28] {'정밀도': 0.0824}
# 가중치 비율 [0.39, 0.34, 0.27] {'정밀도': 0.0819}
# 가중치 비율 [0.39, 0.35, 0.26] {'정밀도': 0.0816}
# 가중치 비율 [0.39, 0.36, 0.25] {'정밀도': 0.0816}
# 가중치 비율 [0.39, 0.37, 0.24] {'정밀도': 0.0807}
# 가중치 비율 [0.39, 0.38, 0.23] {'정밀도': 0.0807}
# 가중치 비율 [0.39, 0.39, 0.22] {'정밀도': 0.0801}
# 가중치 비율 [0.4, 0.0, 0.6] {'정밀도': 0.0589}
# 가중치 비율 [0.4, 0.01, 0.59] {'정밀도': 0.0601}
# 가중치 비율 [0.4, 0.02, 0.58] {'정밀도': 0.0608}
# 가중치 비율 [0.4, 0.03, 0.57] {'정밀도': 0.0619}
# 가중치 비율 [0.4, 0.04, 0.56] {'정밀도': 0.0632}
# 가중치 비율 [0.4, 0.05, 0.55] {'정밀도': 0.0642}
# 가중치 비율 [0.4, 0.06, 0.54] {'정밀도': 0.0654}
# 가중치 비율 [0.4, 0.07, 0.53] {'정밀도': 0.067}
# 가중치 비율 [0.4, 0.08, 0.52] {'정밀도': 0.0675}
# 가중치 비율 [0.4, 0.09, 0.51] {'정밀도': 0.0687}
# 가중치 비율 [0.4, 0.1, 0.5] {'정밀도': 0.0701}
# 가중치 비율 [0.4, 0.11, 0.49] {'정밀도': 0.071}
# 가중치 비율 [0.4, 0.12, 0.48] {'정밀도': 0.0714}
# 가중치 비율 [0.4, 0.13, 0.47] {'정밀도': 0.0731}
# 가중치 비율 [0.4, 0.14, 0.46] {'정밀도': 0.0742}
# 가중치 비율 [0.4, 0.15, 0.45] {'정밀도': 0.0754}
# 가중치 비율 [0.4, 0.16, 0.44] {'정밀도': 0.0764}
# 가중치 비율 [0.4, 0.17, 0.43] {'정밀도': 0.0775}
# 가중치 비율 [0.4, 0.18, 0.42] {'정밀도': 0.0783}
# 가중치 비율 [0.4, 0.19, 0.41] {'정밀도': 0.0792}
# 가중치 비율 [0.4, 0.2, 0.4] {'정밀도': 0.0802}
# 가중치 비율 [0.4, 0.21, 0.39] {'정밀도': 0.0811}
# 가중치 비율 [0.4, 0.22, 0.38] {'정밀도': 0.0808}
# 가중치 비율 [0.4, 0.23, 0.37] {'정밀도': 0.0814}
# 가중치 비율 [0.4, 0.24, 0.36] {'정밀도': 0.0815}
# 가중치 비율 [0.4, 0.25, 0.35] {'정밀도': 0.0824}
# 가중치 비율 [0.4, 0.26, 0.34] {'정밀도': 0.0834}
# 가중치 비율 [0.4, 0.27, 0.33] {'정밀도': 0.0834}
# 가중치 비율 [0.4, 0.28, 0.32] {'정밀도': 0.0838}
# 가중치 비율 [0.4, 0.29, 0.31] {'정밀도': 0.0836}
# 가중치 비율 [0.4, 0.3, 0.3] {'정밀도': 0.0836}
# 가중치 비율 [0.4, 0.31, 0.29] {'정밀도': 0.0832}
# 가중치 비율 [0.4, 0.32, 0.28] {'정밀도': 0.0827}
# 가중치 비율 [0.4, 0.33, 0.27] {'정밀도': 0.0825}
# 가중치 비율 [0.4, 0.34, 0.26] {'정밀도': 0.0816}
# 가중치 비율 [0.4, 0.35, 0.25] {'정밀도': 0.0816}
# 가중치 비율 [0.4, 0.36, 0.24] {'정밀도': 0.0815}
# 가중치 비율 [0.4, 0.37, 0.23] {'정밀도': 0.0811}
# 가중치 비율 [0.4, 0.38, 0.22] {'정밀도': 0.0808}
# 가중치 비율 [0.4, 0.39, 0.21] {'정밀도': 0.0804}
# 가중치 비율 [0.4, 0.4, 0.2] {'정밀도': 0.08}
# 가중치 비율 [0.41, 0.0, 0.59] {'정밀도': 0.0597}
# 가중치 비율 [0.41, 0.01, 0.58] {'정밀도': 0.0607}
# 가중치 비율 [0.41, 0.02, 0.57] {'정밀도': 0.0616}
# 가중치 비율 [0.41, 0.03, 0.56] {'정밀도': 0.0629}
# 가중치 비율 [0.41, 0.04, 0.55] {'정밀도': 0.0639}
# 가중치 비율 [0.41, 0.05, 0.54] {'정밀도': 0.0652}
# 가중치 비율 [0.41, 0.06, 0.53] {'정밀도': 0.0671}
# 가중치 비율 [0.41, 0.07, 0.52] {'정밀도': 0.0672}
# 가중치 비율 [0.41, 0.08, 0.51] {'정밀도': 0.0681}
# 가중치 비율 [0.41, 0.09, 0.5] {'정밀도': 0.0701}
# 가중치 비율 [0.41, 0.1, 0.49] {'정밀도': 0.0709}
# 가중치 비율 [0.41, 0.11, 0.48] {'정밀도': 0.0718}
# 가중치 비율 [0.41, 0.12, 0.47] {'정밀도': 0.0727}
# 가중치 비율 [0.41, 0.13, 0.46] {'정밀도': 0.0739}
# 가중치 비율 [0.41, 0.14, 0.45] {'정밀도': 0.075}
# 가중치 비율 [0.41, 0.15, 0.44] {'정밀도': 0.0761}
# 가중치 비율 [0.41, 0.16, 0.43] {'정밀도': 0.0774}
# 가중치 비율 [0.41, 0.17, 0.42] {'정밀도': 0.0782}
# 가중치 비율 [0.41, 0.18, 0.41] {'정밀도': 0.0793}
# 가중치 비율 [0.41, 0.19, 0.4] {'정밀도': 0.0802}
# 가중치 비율 [0.41, 0.2, 0.39] {'정밀도': 0.0813}
# 가중치 비율 [0.41, 0.21, 0.38] {'정밀도': 0.0815}
# 가중치 비율 [0.41, 0.22, 0.37] {'정밀도': 0.0814}
# 가중치 비율 [0.41, 0.23, 0.36] {'정밀도': 0.0822}
# 가중치 비율 [0.41, 0.24, 0.35] {'정밀도': 0.0823}
# 가중치 비율 [0.41, 0.25, 0.34] {'정밀도': 0.0831}
# 가중치 비율 [0.41, 0.26, 0.33] {'정밀도': 0.0837}
# 가중치 비율 [0.41, 0.27, 0.32] {'정밀도': 0.0838}
# 가중치 비율 [0.41, 0.28, 0.31] {'정밀도': 0.0842}
# 가중치 비율 [0.41, 0.29, 0.3] {'정밀도': 0.0843}
# 가중치 비율 [0.41, 0.3, 0.29] {'정밀도': 0.0838}
# 가중치 비율 [0.41, 0.31, 0.28] {'정밀도': 0.0835}
# 가중치 비율 [0.41, 0.32, 0.27] {'정밀도': 0.0829}
# 가중치 비율 [0.41, 0.33, 0.26] {'정밀도': 0.0821}
# 가중치 비율 [0.41, 0.34, 0.25] {'정밀도': 0.0819}
# 가중치 비율 [0.41, 0.35, 0.24] {'정밀도': 0.0818}
# 가중치 비율 [0.41, 0.36, 0.23] {'정밀도': 0.0816}
# 가중치 비율 [0.41, 0.37, 0.22] {'정밀도': 0.0808}
# 가중치 비율 [0.41, 0.38, 0.21] {'정밀도': 0.0801}
# 가중치 비율 [0.41, 0.39, 0.2] {'정밀도': 0.0802}
# 가중치 비율 [0.41, 0.4, 0.19] {'정밀도': 0.0794}
# 가중치 비율 [0.41, 0.41, 0.18] {'정밀도': 0.0791}
# 가중치 비율 [0.42, 0.0, 0.58] {'정밀도': 0.0606}
# 가중치 비율 [0.42, 0.01, 0.57] {'정밀도': 0.0615}
# 가중치 비율 [0.42, 0.02, 0.56] {'정밀도': 0.0626}
# 가중치 비율 [0.42, 0.03, 0.55] {'정밀도': 0.0641}
# 가중치 비율 [0.42, 0.04, 0.54] {'정밀도': 0.0654}
# 가중치 비율 [0.42, 0.05, 0.53] {'정밀도': 0.0667}
# 가중치 비율 [0.42, 0.06, 0.52] {'정밀도': 0.0676}
# 가중치 비율 [0.42, 0.07, 0.51] {'정밀도': 0.0682}
# 가중치 비율 [0.42, 0.08, 0.5] {'정밀도': 0.0698}
# 가중치 비율 [0.42, 0.09, 0.49] {'정밀도': 0.0708}
# 가중치 비율 [0.42, 0.1, 0.48] {'정밀도': 0.072}
# 가중치 비율 [0.42, 0.11, 0.47] {'정밀도': 0.0725}
# 가중치 비율 [0.42, 0.12, 0.46] {'정밀도': 0.0734}
# 가중치 비율 [0.42, 0.13, 0.45] {'정밀도': 0.0744}
# 가중치 비율 [0.42, 0.14, 0.44] {'정밀도': 0.0763}
# 가중치 비율 [0.42, 0.15, 0.43] {'정밀도': 0.0775}
# 가중치 비율 [0.42, 0.16, 0.42] {'정밀도': 0.0786}
# 가중치 비율 [0.42, 0.17, 0.41] {'정밀도': 0.0797}
# 가중치 비율 [0.42, 0.18, 0.4] {'정밀도': 0.0803}
# 가중치 비율 [0.42, 0.19, 0.39] {'정밀도': 0.081}
# 가중치 비율 [0.42, 0.2, 0.38] {'정밀도': 0.0816}
# 가중치 비율 [0.42, 0.21, 0.37] {'정밀도': 0.0821}
# 가중치 비율 [0.42, 0.22, 0.36] {'정밀도': 0.0828}
# 가중치 비율 [0.42, 0.23, 0.35] {'정밀도': 0.0828}
# 가중치 비율 [0.42, 0.24, 0.34] {'정밀도': 0.0836}
# 가중치 비율 [0.42, 0.25, 0.33] {'정밀도': 0.0843}
# 가중치 비율 [0.42, 0.26, 0.32] {'정밀도': 0.0842}
# 가중치 비율 [0.42, 0.27, 0.31] {'정밀도': 0.0845}
# 가중치 비율 [0.42, 0.28, 0.3] {'정밀도': 0.0843}
# 가중치 비율 [0.42, 0.29, 0.29] {'정밀도': 0.0843}
# 가중치 비율 [0.42, 0.3, 0.28] {'정밀도': 0.0839}
# 가중치 비율 [0.42, 0.31, 0.27] {'정밀도': 0.0835}
# 가중치 비율 [0.42, 0.32, 0.26] {'정밀도': 0.0826}
# 가중치 비율 [0.42, 0.33, 0.25] {'정밀도': 0.0821}
# 가중치 비율 [0.42, 0.34, 0.24] {'정밀도': 0.0817}
# 가중치 비율 [0.42, 0.35, 0.23] {'정밀도': 0.0817}
# 가중치 비율 [0.42, 0.36, 0.22] {'정밀도': 0.0812}
# 가중치 비율 [0.42, 0.37, 0.21] {'정밀도': 0.0806}
# 가중치 비율 [0.42, 0.38, 0.2] {'정밀도': 0.0801}
# 가중치 비율 [0.42, 0.39, 0.19] {'정밀도': 0.0799}
# 가중치 비율 [0.42, 0.4, 0.18] {'정밀도': 0.0794}
# 가중치 비율 [0.42, 0.41, 0.17] {'정밀도': 0.0785}
# 가중치 비율 [0.42, 0.42, 0.16] {'정밀도': 0.0783}
# 가중치 비율 [0.43, 0.0, 0.57] {'정밀도': 0.0613}
# 가중치 비율 [0.43, 0.01, 0.56] {'정밀도': 0.0624}
# 가중치 비율 [0.43, 0.02, 0.55] {'정밀도': 0.0639}
# 가중치 비율 [0.43, 0.03, 0.54] {'정밀도': 0.0652}
# 가중치 비율 [0.43, 0.04, 0.53] {'정밀도': 0.0665}
# 가중치 비율 [0.43, 0.05, 0.52] {'정밀도': 0.0676}
# 가중치 비율 [0.43, 0.06, 0.51] {'정밀도': 0.0681}
# 가중치 비율 [0.43, 0.07, 0.5] {'정밀도': 0.0692}
# 가중치 비율 [0.43, 0.08, 0.49] {'정밀도': 0.0705}
# 가중치 비율 [0.43, 0.09, 0.48] {'정밀도': 0.0717}
# 가중치 비율 [0.43, 0.1, 0.47] {'정밀도': 0.0725}
# 가중치 비율 [0.43, 0.11, 0.46] {'정밀도': 0.0736}
# 가중치 비율 [0.43, 0.12, 0.45] {'정밀도': 0.0745}
# 가중치 비율 [0.43, 0.13, 0.44] {'정밀도': 0.0759}
# 가중치 비율 [0.43, 0.14, 0.43] {'정밀도': 0.0775}
# 가중치 비율 [0.43, 0.15, 0.42] {'정밀도': 0.0787}
# 가중치 비율 [0.43, 0.16, 0.41] {'정밀도': 0.0796}
# 가중치 비율 [0.43, 0.17, 0.4] {'정밀도': 0.0806}
# 가중치 비율 [0.43, 0.18, 0.39] {'정밀도': 0.081}
# 가중치 비율 [0.43, 0.19, 0.38] {'정밀도': 0.0817}
# 가중치 비율 [0.43, 0.2, 0.37] {'정밀도': 0.0824}
# 가중치 비율 [0.43, 0.21, 0.36] {'정밀도': 0.0826}
# 가중치 비율 [0.43, 0.22, 0.35] {'정밀도': 0.0834}
# 가중치 비율 [0.43, 0.23, 0.34] {'정밀도': 0.0839}
# 가중치 비율 [0.43, 0.24, 0.33] {'정밀도': 0.0845}
# 가중치 비율 [0.43, 0.25, 0.32] {'정밀도': 0.0848}
# 가중치 비율 [0.43, 0.26, 0.31] {'정밀도': 0.085}
# 가중치 비율 [0.43, 0.27, 0.3] {'정밀도': 0.0848}
# 가중치 비율 [0.43, 0.28, 0.29] {'정밀도': 0.0843}
# 가중치 비율 [0.43, 0.29, 0.28] {'정밀도': 0.085}
# 가중치 비율 [0.43, 0.3, 0.27] {'정밀도': 0.0839}
# 가중치 비율 [0.43, 0.31, 0.26] {'정밀도': 0.0833}
# 가중치 비율 [0.43, 0.32, 0.25] {'정밀도': 0.0829}
# 가중치 비율 [0.43, 0.33, 0.24] {'정밀도': 0.0821}
# 가중치 비율 [0.43, 0.34, 0.23] {'정밀도': 0.0822}
# 가중치 비율 [0.43, 0.35, 0.22] {'정밀도': 0.0815}
# 가중치 비율 [0.43, 0.36, 0.21] {'정밀도': 0.0809}
# 가중치 비율 [0.43, 0.37, 0.2] {'정밀도': 0.0806}
# 가중치 비율 [0.43, 0.38, 0.19] {'정밀도': 0.0802}
# 가중치 비율 [0.43, 0.39, 0.18] {'정밀도': 0.0799}
# 가중치 비율 [0.43, 0.4, 0.17] {'정밀도': 0.079}
# 가중치 비율 [0.43, 0.41, 0.16] {'정밀도': 0.0786}
# 가중치 비율 [0.43, 0.42, 0.15] {'정밀도': 0.0783}
# 가중치 비율 [0.43, 0.43, 0.14] {'정밀도': 0.0779}
# 가중치 비율 [0.44, 0.0, 0.56] {'정밀도': 0.0623}
# 가중치 비율 [0.44, 0.01, 0.55] {'정밀도': 0.0634}
# 가중치 비율 [0.44, 0.02, 0.54] {'정밀도': 0.0651}
# 가중치 비율 [0.44, 0.03, 0.53] {'정밀도': 0.0663}
# 가중치 비율 [0.44, 0.04, 0.52] {'정밀도': 0.0672}
# 가중치 비율 [0.44, 0.05, 0.51] {'정밀도': 0.0685}
# 가중치 비율 [0.44, 0.06, 0.5] {'정밀도': 0.069}
# 가중치 비율 [0.44, 0.07, 0.49] {'정밀도': 0.0707}
# 가중치 비율 [0.44, 0.08, 0.48] {'정밀도': 0.072}
# 가중치 비율 [0.44, 0.09, 0.47] {'정밀도': 0.0727}
# 가중치 비율 [0.44, 0.1, 0.46] {'정밀도': 0.0737}
# 가중치 비율 [0.44, 0.11, 0.45] {'정밀도': 0.0743}
# 가중치 비율 [0.44, 0.12, 0.44] {'정밀도': 0.0759}
# 가중치 비율 [0.44, 0.13, 0.43] {'정밀도': 0.0776}
# 가중치 비율 [0.44, 0.14, 0.42] {'정밀도': 0.0789}
# 가중치 비율 [0.44, 0.15, 0.41] {'정밀도': 0.0797}
# 가중치 비율 [0.44, 0.16, 0.4] {'정밀도': 0.0805}
# 가중치 비율 [0.44, 0.17, 0.39] {'정밀도': 0.0812}
# 가중치 비율 [0.44, 0.18, 0.38] {'정밀도': 0.0819}
# 가중치 비율 [0.44, 0.19, 0.37] {'정밀도': 0.0823}
# 가중치 비율 [0.44, 0.2, 0.36] {'정밀도': 0.083}
# 가중치 비율 [0.44, 0.21, 0.35] {'정밀도': 0.0836}
# 가중치 비율 [0.44, 0.22, 0.34] {'정밀도': 0.0841}
# 가중치 비율 [0.44, 0.23, 0.33] {'정밀도': 0.0845}
# 가중치 비율 [0.44, 0.24, 0.32] {'정밀도': 0.0849}
# 가중치 비율 [0.44, 0.25, 0.31] {'정밀도': 0.0852}
# 가중치 비율 [0.44, 0.26, 0.3] {'정밀도': 0.0849}
# 가중치 비율 [0.44, 0.27, 0.29] {'정밀도': 0.085}
# 가중치 비율 [0.44, 0.28, 0.28] {'정밀도': 0.0848}
# 가중치 비율 [0.44, 0.29, 0.27] {'정밀도': 0.0847}
# 가중치 비율 [0.44, 0.3, 0.26] {'정밀도': 0.0845}
# 가중치 비율 [0.44, 0.31, 0.25] {'정밀도': 0.0834}
# 가중치 비율 [0.44, 0.32, 0.24] {'정밀도': 0.0825}
# 가중치 비율 [0.44, 0.33, 0.23] {'정밀도': 0.0823}
# 가중치 비율 [0.44, 0.34, 0.22] {'정밀도': 0.0823}
# 가중치 비율 [0.44, 0.35, 0.21] {'정밀도': 0.0814}
# 가중치 비율 [0.44, 0.36, 0.2] {'정밀도': 0.0811}
# 가중치 비율 [0.44, 0.37, 0.19] {'정밀도': 0.081}
# 가중치 비율 [0.44, 0.38, 0.18] {'정밀도': 0.0805}
# 가중치 비율 [0.44, 0.39, 0.17] {'정밀도': 0.0793}
# 가중치 비율 [0.44, 0.4, 0.16] {'정밀도': 0.079}
# 가중치 비율 [0.44, 0.41, 0.15] {'정밀도': 0.0786}
# 가중치 비율 [0.44, 0.42, 0.14] {'정밀도': 0.0783}
# 가중치 비율 [0.44, 0.43, 0.13] {'정밀도': 0.0778}
# 가중치 비율 [0.44, 0.44, 0.12] {'정밀도': 0.0771}
# 가중치 비율 [0.45, 0.0, 0.55] {'정밀도': 0.064}
# 가중치 비율 [0.45, 0.01, 0.54] {'정밀도': 0.065}
# 가중치 비율 [0.45, 0.02, 0.53] {'정밀도': 0.0662}
# 가중치 비율 [0.45, 0.03, 0.52] {'정밀도': 0.0671}
# 가중치 비율 [0.45, 0.04, 0.51] {'정밀도': 0.0688}
# 가중치 비율 [0.45, 0.05, 0.5] {'정밀도': 0.0693}
# 가중치 비율 [0.45, 0.06, 0.49] {'정밀도': 0.0704}
# 가중치 비율 [0.45, 0.07, 0.48] {'정밀도': 0.0724}
# 가중치 비율 [0.45, 0.08, 0.47] {'정밀도': 0.0728}
# 가중치 비율 [0.45, 0.09, 0.46] {'정밀도': 0.0736}
# 가중치 비율 [0.45, 0.1, 0.45] {'정밀도': 0.0744}
# 가중치 비율 [0.45, 0.11, 0.44] {'정밀도': 0.0754}
# 가중치 비율 [0.45, 0.12, 0.43] {'정밀도': 0.0772}
# 가중치 비율 [0.45, 0.13, 0.42] {'정밀도': 0.0783}
# 가중치 비율 [0.45, 0.14, 0.41] {'정밀도': 0.0795}
# 가중치 비율 [0.45, 0.15, 0.4] {'정밀도': 0.0803}
# 가중치 비율 [0.45, 0.16, 0.39] {'정밀도': 0.0812}
# 가중치 비율 [0.45, 0.17, 0.38] {'정밀도': 0.0822}
# 가중치 비율 [0.45, 0.18, 0.37] {'정밀도': 0.0827}
# 가중치 비율 [0.45, 0.19, 0.36] {'정밀도': 0.0834}
# 가중치 비율 [0.45, 0.2, 0.35] {'정밀도': 0.0841}
# 가중치 비율 [0.45, 0.21, 0.34] {'정밀도': 0.0841}
# 가중치 비율 [0.45, 0.22, 0.33] {'정밀도': 0.0852}
# 가중치 비율 [0.45, 0.23, 0.32] {'정밀도': 0.085}
# 가중치 비율 [0.45, 0.24, 0.31] {'정밀도': 0.0855}
# 가중치 비율 [0.45, 0.25, 0.3] {'정밀도': 0.0849}
# 가중치 비율 [0.45, 0.26, 0.29] {'정밀도': 0.085}
# 가중치 비율 [0.45, 0.27, 0.28] {'정밀도': 0.0851}
# 가중치 비율 [0.45, 0.28, 0.27] {'정밀도': 0.0854}
# 가중치 비율 [0.45, 0.29, 0.26] {'정밀도': 0.085}
# 가중치 비율 [0.45, 0.3, 0.25] {'정밀도': 0.0846}
# 가중치 비율 [0.45, 0.31, 0.24] {'정밀도': 0.0836}
# 가중치 비율 [0.45, 0.32, 0.23] {'정밀도': 0.0827}
# 가중치 비율 [0.45, 0.33, 0.22] {'정밀도': 0.0827}
# 가중치 비율 [0.45, 0.34, 0.21] {'정밀도': 0.0818}
# 가중치 비율 [0.45, 0.35, 0.2] {'정밀도': 0.081}
# 가중치 비율 [0.45, 0.36, 0.19] {'정밀도': 0.0809}
# 가중치 비율 [0.45, 0.37, 0.18] {'정밀도': 0.0808}
# 가중치 비율 [0.45, 0.38, 0.17] {'정밀도': 0.0803}
# 가중치 비율 [0.45, 0.39, 0.16] {'정밀도': 0.0796}
# 가중치 비율 [0.45, 0.4, 0.15] {'정밀도': 0.0793}
# 가중치 비율 [0.45, 0.41, 0.14] {'정밀도': 0.0788}
# 가중치 비율 [0.45, 0.42, 0.13] {'정밀도': 0.0782}
# 가중치 비율 [0.45, 0.43, 0.12] {'정밀도': 0.0776}
# 가중치 비율 [0.45, 0.44, 0.11] {'정밀도': 0.0767}
# 가중치 비율 [0.45, 0.45, 0.1] {'정밀도': 0.0763}
# 가중치 비율 [0.46, 0.0, 0.54] {'정밀도': 0.065}
# 가중치 비율 [0.46, 0.01, 0.53] {'정밀도': 0.0657}
# 가중치 비율 [0.46, 0.02, 0.52] {'정밀도': 0.067}
# 가중치 비율 [0.46, 0.03, 0.51] {'정밀도': 0.0681}
# 가중치 비율 [0.46, 0.04, 0.5] {'정밀도': 0.0695}
# 가중치 비율 [0.46, 0.05, 0.49] {'정밀도': 0.0705}
# 가중치 비율 [0.46, 0.06, 0.48] {'정밀도': 0.0726}
# 가중치 비율 [0.46, 0.07, 0.47] {'정밀도': 0.0733}
# 가중치 비율 [0.46, 0.08, 0.46] {'정밀도': 0.0736}
# 가중치 비율 [0.46, 0.09, 0.45] {'정밀도': 0.0744}
# 가중치 비율 [0.46, 0.1, 0.44] {'정밀도': 0.0756}
# 가중치 비율 [0.46, 0.11, 0.43] {'정밀도': 0.0773}
# 가중치 비율 [0.46, 0.12, 0.42] {'정밀도': 0.0786}
# 가중치 비율 [0.46, 0.13, 0.41] {'정밀도': 0.0796}
# 가중치 비율 [0.46, 0.14, 0.4] {'정밀도': 0.0806}
# 가중치 비율 [0.46, 0.15, 0.39] {'정밀도': 0.0816}
# 가중치 비율 [0.46, 0.16, 0.38] {'정밀도': 0.0826}
# 가중치 비율 [0.46, 0.17, 0.37] {'정밀도': 0.0828}
# 가중치 비율 [0.46, 0.18, 0.36] {'정밀도': 0.0831}
# 가중치 비율 [0.46, 0.19, 0.35] {'정밀도': 0.0842}
# 가중치 비율 [0.46, 0.2, 0.34] {'정밀도': 0.0843}
# 가중치 비율 [0.46, 0.21, 0.33] {'정밀도': 0.0851}
# 가중치 비율 [0.46, 0.22, 0.32] {'정밀도': 0.0857}
# 가중치 비율 [0.46, 0.23, 0.31] {'정밀도': 0.0864}
# 가중치 비율 [0.46, 0.24, 0.3] {'정밀도': 0.0852}
# 가중치 비율 [0.46, 0.25, 0.29] {'정밀도': 0.0852}
# 가중치 비율 [0.46, 0.26, 0.28] {'정밀도': 0.0853}
# 가중치 비율 [0.46, 0.27, 0.27] {'정밀도': 0.085}
# 가중치 비율 [0.46, 0.28, 0.26] {'정밀도': 0.0853}
# 가중치 비율 [0.46, 0.29, 0.25] {'정밀도': 0.0849}
# 가중치 비율 [0.46, 0.3, 0.24] {'정밀도': 0.0849}
# 가중치 비율 [0.46, 0.31, 0.23] {'정밀도': 0.0835}
# 가중치 비율 [0.46, 0.32, 0.22] {'정밀도': 0.0828}
# 가중치 비율 [0.46, 0.33, 0.21] {'정밀도': 0.0826}
# 가중치 비율 [0.46, 0.34, 0.2] {'정밀도': 0.0819}
# 가중치 비율 [0.46, 0.35, 0.19] {'정밀도': 0.0809}
# 가중치 비율 [0.46, 0.36, 0.18] {'정밀도': 0.0811}
# 가중치 비율 [0.46, 0.37, 0.17] {'정밀도': 0.0808}
# 가중치 비율 [0.46, 0.38, 0.16] {'정밀도': 0.0804}
# 가중치 비율 [0.46, 0.39, 0.15] {'정밀도': 0.0798}
# 가중치 비율 [0.46, 0.4, 0.14] {'정밀도': 0.0791}
# 가중치 비율 [0.46, 0.41, 0.13] {'정밀도': 0.0787}
# 가중치 비율 [0.46, 0.42, 0.12] {'정밀도': 0.0786}
# 가중치 비율 [0.46, 0.43, 0.11] {'정밀도': 0.0776}
# 가중치 비율 [0.46, 0.44, 0.1] {'정밀도': 0.0768}
# 가중치 비율 [0.46, 0.45, 0.09] {'정밀도': 0.0761}
# 가중치 비율 [0.46, 0.46, 0.08] {'정밀도': 0.0763}
# 가중치 비율 [0.47, 0.0, 0.53] {'정밀도': 0.0658}
# 가중치 비율 [0.47, 0.01, 0.52] {'정밀도': 0.0665}
# 가중치 비율 [0.47, 0.02, 0.51] {'정밀도': 0.068}
# 가중치 비율 [0.47, 0.03, 0.5] {'정밀도': 0.069}
# 가중치 비율 [0.47, 0.04, 0.49] {'정밀도': 0.0705}
# 가중치 비율 [0.47, 0.05, 0.48] {'정밀도': 0.0722}
# 가중치 비율 [0.47, 0.06, 0.47] {'정밀도': 0.0733}
# 가중치 비율 [0.47, 0.07, 0.46] {'정밀도': 0.0736}
# 가중치 비율 [0.47, 0.08, 0.45] {'정밀도': 0.0745}
# 가중치 비율 [0.47, 0.09, 0.44] {'정밀도': 0.0756}
# 가중치 비율 [0.47, 0.1, 0.43] {'정밀도': 0.0764}
# 가중치 비율 [0.47, 0.11, 0.42] {'정밀도': 0.0781}
# 가중치 비율 [0.47, 0.12, 0.41] {'정밀도': 0.0791}
# 가중치 비율 [0.47, 0.13, 0.4] {'정밀도': 0.0805}
# 가중치 비율 [0.47, 0.14, 0.39] {'정밀도': 0.0816}
# 가중치 비율 [0.47, 0.15, 0.38] {'정밀도': 0.0825}
# 가중치 비율 [0.47, 0.16, 0.37] {'정밀도': 0.0832}
# 가중치 비율 [0.47, 0.17, 0.36] {'정밀도': 0.0836}
# 가중치 비율 [0.47, 0.18, 0.35] {'정밀도': 0.0839}
# 가중치 비율 [0.47, 0.19, 0.34] {'정밀도': 0.085}
# 가중치 비율 [0.47, 0.2, 0.33] {'정밀도': 0.0854}
# 가중치 비율 [0.47, 0.21, 0.32] {'정밀도': 0.086}
# 가중치 비율 [0.47, 0.22, 0.31] {'정밀도': 0.0863}
# 가중치 비율 [0.47, 0.23, 0.3] {'정밀도': 0.086}
# 가중치 비율 [0.47, 0.24, 0.29] {'정밀도': 0.0852}
# 가중치 비율 [0.47, 0.25, 0.28] {'정밀도': 0.0857}
# ...
# 가중치 비율 [0.73, 0.22, 0.05] {'정밀도': 0.0854}
# 가중치 비율 [0.73, 0.23, 0.04] {'정밀도': 0.085}
# 가중치 비율 [0.73, 0.24, 0.03] {'정밀도': 0.085}
# 가중치 비율 [0.73, 0.25, 0.02] {'정밀도': 0.0845}
# 가중치 비율 [0.73, 0.26, 0.01] {'정밀도': 0.0845}
# 가중치 비율 [0.73, 0.27, 0.0] {'정밀도': 0.0835}
# 가중치 비율 [0.74, 0.0, 0.26] {'정밀도': 0.0863}
# 가중치 비율 [0.74, 0.01, 0.25] {'정밀도': 0.087}
# 가중치 비율 [0.74, 0.02, 0.24] {'정밀도': 0.088}
# 가중치 비율 [0.74, 0.03, 0.23] {'정밀도': 0.0884}
# 가중치 비율 [0.74, 0.04, 0.22] {'정밀도': 0.0887}
# 가중치 비율 [0.74, 0.05, 0.21] {'정밀도': 0.0893}
# 가중치 비율 [0.74, 0.06, 0.2] {'정밀도': 0.09}
# 가중치 비율 [0.74, 0.07, 0.19] {'정밀도': 0.0905}
# 가중치 비율 [0.74, 0.08, 0.18] {'정밀도': 0.0902}
# 가중치 비율 [0.74, 0.09, 0.17] {'정밀도': 0.0903}
# 가중치 비율 [0.74, 0.1, 0.16] {'정밀도': 0.0902}
# 가중치 비율 [0.74, 0.11, 0.15] {'정밀도': 0.0902}
# 가중치 비율 [0.74, 0.12, 0.14] {'정밀도': 0.0902}
# 가중치 비율 [0.74, 0.13, 0.13] {'정밀도': 0.0896}
# 가중치 비율 [0.74, 0.14, 0.12] {'정밀도': 0.0899}
# 가중치 비율 [0.74, 0.15, 0.11] {'정밀도': 0.0893}
# 가중치 비율 [0.74, 0.16, 0.1] {'정밀도': 0.0886}
# 가중치 비율 [0.74, 0.17, 0.09] {'정밀도': 0.088}
# 가중치 비율 [0.74, 0.18, 0.08] {'정밀도': 0.0879}
# 가중치 비율 [0.74, 0.19, 0.07] {'정밀도': 0.0874}
# 가중치 비율 [0.74, 0.2, 0.06] {'정밀도': 0.0868}
# 가중치 비율 [0.74, 0.21, 0.05] {'정밀도': 0.0859}
# 가중치 비율 [0.74, 0.22, 0.04] {'정밀도': 0.0855}
# 가중치 비율 [0.74, 0.23, 0.03] {'정밀도': 0.085}
# 가중치 비율 [0.74, 0.24, 0.02] {'정밀도': 0.0847}
# 가중치 비율 [0.74, 0.25, 0.01] {'정밀도': 0.0848}
# 가중치 비율 [0.74, 0.26, 0.0] {'정밀도': 0.0843}
# 가중치 비율 [0.75, 0.0, 0.25] {'정밀도': 0.0871}
# 가중치 비율 [0.75, 0.01, 0.24] {'정밀도': 0.0877}
# 가중치 비율 [0.75, 0.02, 0.23] {'정밀도': 0.0884}
# 가중치 비율 [0.75, 0.03, 0.22] {'정밀도': 0.089}
# 가중치 비율 [0.75, 0.04, 0.21] {'정밀도': 0.0892}
# 가중치 비율 [0.75, 0.05, 0.2] {'정밀도': 0.0902}
# 가중치 비율 [0.75, 0.06, 0.19] {'정밀도': 0.0905}
# 가중치 비율 [0.75, 0.07, 0.18] {'정밀도': 0.0905}
# 가중치 비율 [0.75, 0.08, 0.17] {'정밀도': 0.0901}
# 가중치 비율 [0.75, 0.09, 0.16] {'정밀도': 0.09}
# 가중치 비율 [0.75, 0.1, 0.15] {'정밀도': 0.0904}
# 가중치 비율 [0.75, 0.11, 0.14] {'정밀도': 0.0905}
# 가중치 비율 [0.75, 0.12, 0.13] {'정밀도': 0.0899}
# 가중치 비율 [0.75, 0.13, 0.12] {'정밀도': 0.0895}
# 가중치 비율 [0.75, 0.14, 0.11] {'정밀도': 0.0896}
# 가중치 비율 [0.75, 0.15, 0.1] {'정밀도': 0.0888}
# 가중치 비율 [0.75, 0.16, 0.09] {'정밀도': 0.0883}
# 가중치 비율 [0.75, 0.17, 0.08] {'정밀도': 0.0882}
# 가중치 비율 [0.75, 0.18, 0.07] {'정밀도': 0.0876}
# 가중치 비율 [0.75, 0.19, 0.06] {'정밀도': 0.0869}
# 가중치 비율 [0.75, 0.2, 0.05] {'정밀도': 0.0864}
# 가중치 비율 [0.75, 0.21, 0.04] {'정밀도': 0.0858}
# 가중치 비율 [0.75, 0.22, 0.03] {'정밀도': 0.0854}
# 가중치 비율 [0.75, 0.23, 0.02] {'정밀도': 0.0851}
# 가중치 비율 [0.75, 0.24, 0.01] {'정밀도': 0.0849}
# 가중치 비율 [0.75, 0.25, 0.0] {'정밀도': 0.0847}
# 가중치 비율 [0.76, 0.0, 0.24] {'정밀도': 0.0871}
# 가중치 비율 [0.76, 0.01, 0.23] {'정밀도': 0.0883}
# 가중치 비율 [0.76, 0.02, 0.22] {'정밀도': 0.0887}
# 가중치 비율 [0.76, 0.03, 0.21] {'정밀도': 0.0892}
# 가중치 비율 [0.76, 0.04, 0.2] {'정밀도': 0.0901}
# 가중치 비율 [0.76, 0.05, 0.19] {'정밀도': 0.0906}
# 가중치 비율 [0.76, 0.06, 0.18] {'정밀도': 0.0908}
# 가중치 비율 [0.76, 0.07, 0.17] {'정밀도': 0.0907}
# 가중치 비율 [0.76, 0.08, 0.16] {'정밀도': 0.0901}
# 가중치 비율 [0.76, 0.09, 0.15] {'정밀도': 0.0905}
# 가중치 비율 [0.76, 0.1, 0.14] {'정밀도': 0.0908}
# 가중치 비율 [0.76, 0.11, 0.13] {'정밀도': 0.0903}
# 가중치 비율 [0.76, 0.12, 0.12] {'정밀도': 0.0895}
# 가중치 비율 [0.76, 0.13, 0.11] {'정밀도': 0.0894}
# 가중치 비율 [0.76, 0.14, 0.1] {'정밀도': 0.0892}
# 가중치 비율 [0.76, 0.15, 0.09] {'정밀도': 0.0886}
# 가중치 비율 [0.76, 0.16, 0.08] {'정밀도': 0.0884}
# 가중치 비율 [0.76, 0.17, 0.07] {'정밀도': 0.0878}
# 가중치 비율 [0.76, 0.18, 0.06] {'정밀도': 0.0873}
# 가중치 비율 [0.76, 0.19, 0.05] {'정밀도': 0.0866}
# 가중치 비율 [0.76, 0.2, 0.04] {'정밀도': 0.0861}
# 가중치 비율 [0.76, 0.21, 0.03] {'정밀도': 0.0856}
# 가중치 비율 [0.76, 0.22, 0.02] {'정밀도': 0.0853}
# 가중치 비율 [0.76, 0.23, 0.01] {'정밀도': 0.085}
# 가중치 비율 [0.76, 0.24, 0.0] {'정밀도': 0.0848}
# 가중치 비율 [0.77, 0.0, 0.23] {'정밀도': 0.0879}
# 가중치 비율 [0.77, 0.01, 0.22] {'정밀도': 0.0885}
# 가중치 비율 [0.77, 0.02, 0.21] {'정밀도': 0.0894}
# 가중치 비율 [0.77, 0.03, 0.2] {'정밀도': 0.0895}
# 가중치 비율 [0.77, 0.04, 0.19] {'정밀도': 0.0905}
# 가중치 비율 [0.77, 0.05, 0.18] {'정밀도': 0.0908}
# 가중치 비율 [0.77, 0.06, 0.17] {'정밀도': 0.0905}
# 가중치 비율 [0.77, 0.07, 0.16] {'정밀도': 0.0903}
# 가중치 비율 [0.77, 0.08, 0.15] {'정밀도': 0.0904}
# 가중치 비율 [0.77, 0.09, 0.14] {'정밀도': 0.0908}
# 가중치 비율 [0.77, 0.1, 0.13] {'정밀도': 0.0904}
# 가중치 비율 [0.77, 0.11, 0.12] {'정밀도': 0.0903}
# 가중치 비율 [0.77, 0.12, 0.11] {'정밀도': 0.0897}
# 가중치 비율 [0.77, 0.13, 0.1] {'정밀도': 0.0892}
# 가중치 비율 [0.77, 0.14, 0.09] {'정밀도': 0.0888}
# 가중치 비율 [0.77, 0.15, 0.08] {'정밀도': 0.0885}
# 가중치 비율 [0.77, 0.16, 0.07] {'정밀도': 0.0878}
# 가중치 비율 [0.77, 0.17, 0.06] {'정밀도': 0.0876}
# 가중치 비율 [0.77, 0.18, 0.05] {'정밀도': 0.0872}
# 가중치 비율 [0.77, 0.19, 0.04] {'정밀도': 0.0863}
# 가중치 비율 [0.77, 0.2, 0.03] {'정밀도': 0.0859}
# 가중치 비율 [0.77, 0.21, 0.02] {'정밀도': 0.0856}
# 가중치 비율 [0.77, 0.22, 0.01] {'정밀도': 0.0852}
# 가중치 비율 [0.77, 0.23, 0.0] {'정밀도': 0.0849}
# 가중치 비율 [0.78, 0.0, 0.22] {'정밀도': 0.0884}
# 가중치 비율 [0.78, 0.01, 0.21] {'정밀도': 0.0891}
# 가중치 비율 [0.78, 0.02, 0.2] {'정밀도': 0.0896}
# 가중치 비율 [0.78, 0.03, 0.19] {'정밀도': 0.0901}
# 가중치 비율 [0.78, 0.04, 0.18] {'정밀도': 0.091}
# 가중치 비율 [0.78, 0.05, 0.17] {'정밀도': 0.0906}
# 가중치 비율 [0.78, 0.06, 0.16] {'정밀도': 0.0906}
# 가중치 비율 [0.78, 0.07, 0.15] {'정밀도': 0.0902}
# 가중치 비율 [0.78, 0.08, 0.14] {'정밀도': 0.0907}
# 가중치 비율 [0.78, 0.09, 0.13] {'정밀도': 0.0903}
# 가중치 비율 [0.78, 0.1, 0.12] {'정밀도': 0.0904}
# 가중치 비율 [0.78, 0.11, 0.11] {'정밀도': 0.09}
# 가중치 비율 [0.78, 0.12, 0.1] {'정밀도': 0.0898}
# 가중치 비율 [0.78, 0.13, 0.09] {'정밀도': 0.0887}
# 가중치 비율 [0.78, 0.14, 0.08] {'정밀도': 0.0883}
# 가중치 비율 [0.78, 0.15, 0.07] {'정밀도': 0.0885}
# 가중치 비율 [0.78, 0.16, 0.06] {'정밀도': 0.0878}
# 가중치 비율 [0.78, 0.17, 0.05] {'정밀도': 0.0874}
# 가중치 비율 [0.78, 0.18, 0.04] {'정밀도': 0.0867}
# 가중치 비율 [0.78, 0.19, 0.03] {'정밀도': 0.086}
# 가중치 비율 [0.78, 0.2, 0.02] {'정밀도': 0.0858}
# 가중치 비율 [0.78, 0.21, 0.01] {'정밀도': 0.0857}
# 가중치 비율 [0.78, 0.22, 0.0] {'정밀도': 0.085}
# 가중치 비율 [0.79, 0.0, 0.21] {'정밀도': 0.0889}
# 가중치 비율 [0.79, 0.01, 0.2] {'정밀도': 0.0891}
# 가중치 비율 [0.79, 0.02, 0.19] {'정밀도': 0.0898}
# 가중치 비율 [0.79, 0.03, 0.18] {'정밀도': 0.0904}
# 가중치 비율 [0.79, 0.04, 0.17] {'정밀도': 0.0905}
# 가중치 비율 [0.79, 0.05, 0.16] {'정밀도': 0.0903}
# 가중치 비율 [0.79, 0.06, 0.15] {'정밀도': 0.0902}
# 가중치 비율 [0.79, 0.07, 0.14] {'정밀도': 0.09}
# 가중치 비율 [0.79, 0.08, 0.13] {'정밀도': 0.0908}
# 가중치 비율 [0.79, 0.09, 0.12] {'정밀도': 0.0905}
# 가중치 비율 [0.79, 0.1, 0.11] {'정밀도': 0.0899}
# 가중치 비율 [0.79, 0.11, 0.1] {'정밀도': 0.0901}
# 가중치 비율 [0.79, 0.12, 0.09] {'정밀도': 0.0894}
# 가중치 비율 [0.79, 0.13, 0.08] {'정밀도': 0.0888}
# 가중치 비율 [0.79, 0.14, 0.07] {'정밀도': 0.0885}
# 가중치 비율 [0.79, 0.15, 0.06] {'정밀도': 0.0885}
# 가중치 비율 [0.79, 0.16, 0.05] {'정밀도': 0.0876}
# 가중치 비율 [0.79, 0.17, 0.04] {'정밀도': 0.0872}
# 가중치 비율 [0.79, 0.18, 0.03] {'정밀도': 0.0863}
# 가중치 비율 [0.79, 0.19, 0.02] {'정밀도': 0.0862}
# 가중치 비율 [0.79, 0.2, 0.01] {'정밀도': 0.0856}
# 가중치 비율 [0.79, 0.21, 0.0] {'정밀도': 0.0856}
# 가중치 비율 [0.8, 0.0, 0.2] {'정밀도': 0.089}
# 가중치 비율 [0.8, 0.01, 0.19] {'정밀도': 0.0894}
# 가중치 비율 [0.8, 0.02, 0.18] {'정밀도': 0.09}
# 가중치 비율 [0.8, 0.03, 0.17] {'정밀도': 0.0907}
# 가중치 비율 [0.8, 0.04, 0.16] {'정밀도': 0.0903}
# 가중치 비율 [0.8, 0.05, 0.15] {'정밀도': 0.0902}
# 가중치 비율 [0.8, 0.06, 0.14] {'정밀도': 0.0902}
# 가중치 비율 [0.8, 0.07, 0.13] {'정밀도': 0.0906}
# 가중치 비율 [0.8, 0.08, 0.12] {'정밀도': 0.0906}
# 가중치 비율 [0.8, 0.09, 0.11] {'정밀도': 0.09}
# 가중치 비율 [0.8, 0.1, 0.1] {'정밀도': 0.0901}
# 가중치 비율 [0.8, 0.11, 0.09] {'정밀도': 0.0901}
# 가중치 비율 [0.8, 0.12, 0.08] {'정밀도': 0.0895}
# 가중치 비율 [0.8, 0.13, 0.07] {'정밀도': 0.0887}
# 가중치 비율 [0.8, 0.14, 0.06] {'정밀도': 0.0888}
# 가중치 비율 [0.8, 0.15, 0.05] {'정밀도': 0.0884}
# 가중치 비율 [0.8, 0.16, 0.04] {'정밀도': 0.0872}
# 가중치 비율 [0.8, 0.17, 0.03] {'정밀도': 0.0869}
# 가중치 비율 [0.8, 0.18, 0.02] {'정밀도': 0.0863}
# 가중치 비율 [0.8, 0.19, 0.01] {'정밀도': 0.086}
# 가중치 비율 [0.8, 0.2, 0.0] {'정밀도': 0.0857}
# 가중치 비율 [0.81, 0.0, 0.19] {'정밀도': 0.0893}
# 가중치 비율 [0.81, 0.01, 0.18] {'정밀도': 0.09}
# 가중치 비율 [0.81, 0.02, 0.17] {'정밀도': 0.0908}
# 가중치 비율 [0.81, 0.03, 0.16] {'정밀도': 0.0906}
# 가중치 비율 [0.81, 0.04, 0.15] {'정밀도': 0.0905}
# 가중치 비율 [0.81, 0.05, 0.14] {'정밀도': 0.0902}
# 가중치 비율 [0.81, 0.06, 0.13] {'정밀도': 0.0907}
# 가중치 비율 [0.81, 0.07, 0.12] {'정밀도': 0.0903}
# 가중치 비율 [0.81, 0.08, 0.11] {'정밀도': 0.0902}
# 가중치 비율 [0.81, 0.09, 0.1] {'정밀도': 0.0897}
# 가중치 비율 [0.81, 0.1, 0.09] {'정밀도': 0.09}
# 가중치 비율 [0.81, 0.11, 0.08] {'정밀도': 0.0898}
# 가중치 비율 [0.81, 0.12, 0.07] {'정밀도': 0.0892}
# 가중치 비율 [0.81, 0.13, 0.06] {'정밀도': 0.0888}
# 가중치 비율 [0.81, 0.14, 0.05] {'정밀도': 0.0884}
# 가중치 비율 [0.81, 0.15, 0.04] {'정밀도': 0.088}
# 가중치 비율 [0.81, 0.16, 0.03] {'정밀도': 0.0872}
# 가중치 비율 [0.81, 0.17, 0.02] {'정밀도': 0.0864}
# 가중치 비율 [0.81, 0.18, 0.01] {'정밀도': 0.0863}
# 가중치 비율 [0.81, 0.19, 0.0] {'정밀도': 0.0856}
# 가중치 비율 [0.82, 0.0, 0.18] {'정밀도': 0.0899}
# 가중치 비율 [0.82, 0.01, 0.17] {'정밀도': 0.0908}
# 가중치 비율 [0.82, 0.02, 0.16] {'정밀도': 0.0909}
# 가중치 비율 [0.82, 0.03, 0.15] {'정밀도': 0.0906}
# 가중치 비율 [0.82, 0.04, 0.14] {'정밀도': 0.0906}
# 가중치 비율 [0.82, 0.05, 0.13] {'정밀도': 0.0907}
# 가중치 비율 [0.82, 0.06, 0.12] {'정밀도': 0.0909}
# 가중치 비율 [0.82, 0.07, 0.11] {'정밀도': 0.0898}
# 가중치 비율 [0.82, 0.08, 0.1] {'정밀도': 0.09}
# 가중치 비율 [0.82, 0.09, 0.09] {'정밀도': 0.0902}
# 가중치 비율 [0.82, 0.1, 0.08] {'정밀도': 0.0898}
# 가중치 비율 [0.82, 0.11, 0.07] {'정밀도': 0.0898}
# 가중치 비율 [0.82, 0.12, 0.06] {'정밀도': 0.0892}
# 가중치 비율 [0.82, 0.13, 0.05] {'정밀도': 0.0888}
# 가중치 비율 [0.82, 0.14, 0.04] {'정밀도': 0.0881}
# 가중치 비율 [0.82, 0.15, 0.03] {'정밀도': 0.0875}
# 가중치 비율 [0.82, 0.16, 0.02] {'정밀도': 0.0868}
# 가중치 비율 [0.82, 0.17, 0.01] {'정밀도': 0.0863}
# 가중치 비율 [0.82, 0.18, 0.0] {'정밀도': 0.0857}
# 가중치 비율 [0.83, 0.0, 0.17] {'정밀도': 0.0907}
# 가중치 비율 [0.83, 0.01, 0.16] {'정밀도': 0.0909}
# 가중치 비율 [0.83, 0.02, 0.15] {'정밀도': 0.0904}
# 가중치 비율 [0.83, 0.03, 0.14] {'정밀도': 0.0908}
# 가중치 비율 [0.83, 0.04, 0.13] {'정밀도': 0.0906}
# 가중치 비율 [0.83, 0.05, 0.12] {'정밀도': 0.091}
# 가중치 비율 [0.83, 0.06, 0.11] {'정밀도': 0.0903}
# 가중치 비율 [0.83, 0.07, 0.1] {'정밀도': 0.09}
# 가중치 비율 [0.83, 0.08, 0.09] {'정밀도': 0.0901}
# 가중치 비율 [0.83, 0.09, 0.08] {'정밀도': 0.0898}
# 가중치 비율 [0.83, 0.1, 0.07] {'정밀도': 0.0899}
# 가중치 비율 [0.83, 0.11, 0.06] {'정밀도': 0.0897}
# 가중치 비율 [0.83, 0.12, 0.05] {'정밀도': 0.0893}
# 가중치 비율 [0.83, 0.13, 0.04] {'정밀도': 0.0887}
# 가중치 비율 [0.83, 0.14, 0.03] {'정밀도': 0.0881}
# 가중치 비율 [0.83, 0.15, 0.02] {'정밀도': 0.0873}
# 가중치 비율 [0.83, 0.16, 0.01] {'정밀도': 0.0865}
# 가중치 비율 [0.83, 0.17, 0.0] {'정밀도': 0.086}
# 가중치 비율 [0.84, 0.0, 0.16] {'정밀도': 0.091}
# 가중치 비율 [0.84, 0.01, 0.15] {'정밀도': 0.0908}
# 가중치 비율 [0.84, 0.02, 0.14] {'정밀도': 0.0904}
# 가중치 비율 [0.84, 0.03, 0.13] {'정밀도': 0.0903}
# 가중치 비율 [0.84, 0.04, 0.12] {'정밀도': 0.0906}
# 가중치 비율 [0.84, 0.05, 0.11] {'정밀도': 0.0908}
# 가중치 비율 [0.84, 0.06, 0.1] {'정밀도': 0.0901}
# 가중치 비율 [0.84, 0.07, 0.09] {'정밀도': 0.0897}
# 가중치 비율 [0.84, 0.08, 0.08] {'정밀도': 0.09}
# 가중치 비율 [0.84, 0.09, 0.07] {'정밀도': 0.0896}
# 가중치 비율 [0.84, 0.1, 0.06] {'정밀도': 0.0898}
# 가중치 비율 [0.84, 0.11, 0.05] {'정밀도': 0.0896}
# 가중치 비율 [0.84, 0.12, 0.04] {'정밀도': 0.089}
# 가중치 비율 [0.84, 0.13, 0.03] {'정밀도': 0.0884}
# 가중치 비율 [0.84, 0.14, 0.02] {'정밀도': 0.0878}
# 가중치 비율 [0.84, 0.15, 0.01] {'정밀도': 0.0871}
# 가중치 비율 [0.84, 0.16, 0.0] {'정밀도': 0.0865}
# 가중치 비율 [0.85, 0.0, 0.15] {'정밀도': 0.0909}
# 가중치 비율 [0.85, 0.01, 0.14] {'정밀도': 0.0906}
# 가중치 비율 [0.85, 0.02, 0.13] {'정밀도': 0.09}
# 가중치 비율 [0.85, 0.03, 0.12] {'정밀도': 0.0909}
# 가중치 비율 [0.85, 0.04, 0.11] {'정밀도': 0.0907}
# 가중치 비율 [0.85, 0.05, 0.1] {'정밀도': 0.0904}
# 가중치 비율 [0.85, 0.06, 0.09] {'정밀도': 0.09}
# 가중치 비율 [0.85, 0.07, 0.08] {'정밀도': 0.0895}
# 가중치 비율 [0.85, 0.08, 0.07] {'정밀도': 0.0899}
# 가중치 비율 [0.85, 0.09, 0.06] {'정밀도': 0.0894}
# 가중치 비율 [0.85, 0.1, 0.05] {'정밀도': 0.0895}
# 가중치 비율 [0.85, 0.11, 0.04] {'정밀도': 0.0894}
# 가중치 비율 [0.85, 0.12, 0.03] {'정밀도': 0.0887}
# 가중치 비율 [0.85, 0.13, 0.02] {'정밀도': 0.088}
# 가중치 비율 [0.85, 0.14, 0.01] {'정밀도': 0.0875}
# 가중치 비율 [0.85, 0.15, 0.0] {'정밀도': 0.0867}
# 가중치 비율 [0.86, 0.0, 0.14] {'정밀도': 0.091}
# 가중치 비율 [0.86, 0.01, 0.13] {'정밀도': 0.0902}
# 가중치 비율 [0.86, 0.02, 0.12] {'정밀도': 0.0909}
# 가중치 비율 [0.86, 0.03, 0.11] {'정밀도': 0.0907}
# 가중치 비율 [0.86, 0.04, 0.1] {'정밀도': 0.0903}
# 가중치 비율 [0.86, 0.05, 0.09] {'정밀도': 0.0906}
# 가중치 비율 [0.86, 0.06, 0.08] {'정밀도': 0.0901}
# 가중치 비율 [0.86, 0.07, 0.07] {'정밀도': 0.0895}
# 가중치 비율 [0.86, 0.08, 0.06] {'정밀도': 0.0895}
# 가중치 비율 [0.86, 0.09, 0.05] {'정밀도': 0.0894}
# 가중치 비율 [0.86, 0.1, 0.04] {'정밀도': 0.0894}
# 가중치 비율 [0.86, 0.11, 0.03] {'정밀도': 0.0893}
# 가중치 비율 [0.86, 0.12, 0.02] {'정밀도': 0.0885}
# 가중치 비율 [0.86, 0.13, 0.01] {'정밀도': 0.0878}
# 가중치 비율 [0.86, 0.14, 0.0] {'정밀도': 0.0874}
# 가중치 비율 [0.87, 0.0, 0.13] {'정밀도': 0.0905}
# 가중치 비율 [0.87, 0.01, 0.12] {'정밀도': 0.0908}
# 가중치 비율 [0.87, 0.02, 0.11] {'정밀도': 0.0907}
# 가중치 비율 [0.87, 0.03, 0.1] {'정밀도': 0.0905}
# 가중치 비율 [0.87, 0.04, 0.09] {'정밀도': 0.0905}
# 가중치 비율 [0.87, 0.05, 0.08] {'정밀도': 0.0905}
# 가중치 비율 [0.87, 0.06, 0.07] {'정밀도': 0.09}
# 가중치 비율 [0.87, 0.07, 0.06] {'정밀도': 0.0895}
# 가중치 비율 [0.87, 0.08, 0.05] {'정밀도': 0.0892}
# 가중치 비율 [0.87, 0.09, 0.04] {'정밀도': 0.0894}
# 가중치 비율 [0.87, 0.1, 0.03] {'정밀도': 0.0893}
# 가중치 비율 [0.87, 0.11, 0.02] {'정밀도': 0.0888}
# 가중치 비율 [0.87, 0.12, 0.01] {'정밀도': 0.0883}
# 가중치 비율 [0.87, 0.13, 0.0] {'정밀도': 0.0879}
# 가중치 비율 [0.88, 0.0, 0.12] {'정밀도': 0.0906}
# 가중치 비율 [0.88, 0.01, 0.11] {'정밀도': 0.0904}
# 가중치 비율 [0.88, 0.02, 0.1] {'정밀도': 0.0908}
# 가중치 비율 [0.88, 0.03, 0.09] {'정밀도': 0.0907}
# 가중치 비율 [0.88, 0.04, 0.08] {'정밀도': 0.0904}
# 가중치 비율 [0.88, 0.05, 0.07] {'정밀도': 0.0905}
# 가중치 비율 [0.88, 0.06, 0.06] {'정밀도': 0.09}
# 가중치 비율 [0.88, 0.07, 0.05] {'정밀도': 0.0897}
# 가중치 비율 [0.88, 0.08, 0.04] {'정밀도': 0.0891}
# 가중치 비율 [0.88, 0.09, 0.03] {'정밀도': 0.0892}
# 가중치 비율 [0.88, 0.1, 0.02] {'정밀도': 0.0891}
# 가중치 비율 [0.88, 0.11, 0.01] {'정밀도': 0.0884}
# 가중치 비율 [0.88, 0.12, 0.0] {'정밀도': 0.0885}
# 가중치 비율 [0.89, 0.0, 0.11] {'정밀도': 0.0908}
# 가중치 비율 [0.89, 0.01, 0.1] {'정밀도': 0.0906}
# 가중치 비율 [0.89, 0.02, 0.09] {'정밀도': 0.0906}
# 가중치 비율 [0.89, 0.03, 0.08] {'정밀도': 0.0909}
# 가중치 비율 [0.89, 0.04, 0.07] {'정밀도': 0.0904}
# 가중치 비율 [0.89, 0.05, 0.06] {'정밀도': 0.0904}
# 가중치 비율 [0.89, 0.06, 0.05] {'정밀도': 0.0897}
# 가중치 비율 [0.89, 0.07, 0.04] {'정밀도': 0.0892}
# 가중치 비율 [0.89, 0.08, 0.03] {'정밀도': 0.0889}
# 가중치 비율 [0.89, 0.09, 0.02] {'정밀도': 0.0891}
# 가중치 비율 [0.89, 0.1, 0.01] {'정밀도': 0.0886}
# 가중치 비율 [0.89, 0.11, 0.0] {'정밀도': 0.0883}
# 가중치 비율 [0.9, 0.0, 0.1] {'정밀도': 0.0906}
# 가중치 비율 [0.9, 0.01, 0.09] {'정밀도': 0.0906}
# 가중치 비율 [0.9, 0.02, 0.08] {'정밀도': 0.0907}
# 가중치 비율 [0.9, 0.03, 0.07] {'정밀도': 0.0907}
# 가중치 비율 [0.9, 0.04, 0.06] {'정밀도': 0.0904}
# 가중치 비율 [0.9, 0.05, 0.05] {'정밀도': 0.0901}
# 가중치 비율 [0.9, 0.06, 0.04] {'정밀도': 0.0896}
# 가중치 비율 [0.9, 0.07, 0.03] {'정밀도': 0.089}
# 가중치 비율 [0.9, 0.08, 0.02] {'정밀도': 0.0888}
# 가중치 비율 [0.9, 0.09, 0.01] {'정밀도': 0.089}
# 가중치 비율 [0.9, 0.1, 0.0] {'정밀도': 0.0886}
# 가중치 비율 [0.91, 0.0, 0.09] {'정밀도': 0.0906}
# 가중치 비율 [0.91, 0.01, 0.08] {'정밀도': 0.0907}
# 가중치 비율 [0.91, 0.02, 0.07] {'정밀도': 0.0904}
# 가중치 비율 [0.91, 0.03, 0.06] {'정밀도': 0.0906}
# 가중치 비율 [0.91, 0.04, 0.05] {'정밀도': 0.0903}
# 가중치 비율 [0.91, 0.05, 0.04] {'정밀도': 0.0897}
# 가중치 비율 [0.91, 0.06, 0.03] {'정밀도': 0.0895}
# 가중치 비율 [0.91, 0.07, 0.02] {'정밀도': 0.0886}
# 가중치 비율 [0.91, 0.08, 0.01] {'정밀도': 0.0885}
# 가중치 비율 [0.91, 0.09, 0.0] {'정밀도': 0.0886}
# 가중치 비율 [0.92, 0.0, 0.08] {'정밀도': 0.0906}
# 가중치 비율 [0.92, 0.01, 0.07] {'정밀도': 0.0908}
# 가중치 비율 [0.92, 0.02, 0.06] {'정밀도': 0.0906}
# 가중치 비율 [0.92, 0.03, 0.05] {'정밀도': 0.0905}
# 가중치 비율 [0.92, 0.04, 0.04] {'정밀도': 0.0901}
# 가중치 비율 [0.92, 0.05, 0.03] {'정밀도': 0.0896}
# 가중치 비율 [0.92, 0.06, 0.02] {'정밀도': 0.0893}
# 가중치 비율 [0.92, 0.07, 0.01] {'정밀도': 0.0888}
# 가중치 비율 [0.92, 0.08, 0.0] {'정밀도': 0.0884}
# 가중치 비율 [0.93, 0.0, 0.07] {'정밀도': 0.0911}
# 가중치 비율 [0.93, 0.01, 0.06] {'정밀도': 0.0904}
# 가중치 비율 [0.93, 0.02, 0.05] {'정밀도': 0.0905}
# 가중치 비율 [0.93, 0.03, 0.04] {'정밀도': 0.0903}
# 가중치 비율 [0.93, 0.04, 0.03] {'정밀도': 0.0899}
# 가중치 비율 [0.93, 0.05, 0.02] {'정밀도': 0.0895}
# 가중치 비율 [0.93, 0.06, 0.01] {'정밀도': 0.089}
# 가중치 비율 [0.93, 0.07, 0.0] {'정밀도': 0.0889}
# 가중치 비율 [0.94, 0.0, 0.06] {'정밀도': 0.0911}
# 가중치 비율 [0.94, 0.01, 0.05] {'정밀도': 0.0908}
# 가중치 비율 [0.94, 0.02, 0.04] {'정밀도': 0.0903}
# 가중치 비율 [0.94, 0.03, 0.03] {'정밀도': 0.0901}
# 가중치 비율 [0.94, 0.04, 0.02] {'정밀도': 0.0896}
# 가중치 비율 [0.94, 0.05, 0.01] {'정밀도': 0.0889}
# 가중치 비율 [0.94, 0.06, 0.0] {'정밀도': 0.0888}
# 가중치 비율 [0.95, 0.0, 0.05] {'정밀도': 0.091}
# 가중치 비율 [0.95, 0.01, 0.04] {'정밀도': 0.0906}
# 가중치 비율 [0.95, 0.02, 0.03] {'정밀도': 0.0902}
# 가중치 비율 [0.95, 0.03, 0.02] {'정밀도': 0.09}
# 가중치 비율 [0.95, 0.04, 0.01] {'정밀도': 0.0894}
# 가중치 비율 [0.95, 0.05, 0.0] {'정밀도': 0.089}
# 가중치 비율 [0.96, 0.0, 0.04] {'정밀도': 0.0908}
# 가중치 비율 [0.96, 0.01, 0.03] {'정밀도': 0.0902}
# 가중치 비율 [0.96, 0.02, 0.02] {'정밀도': 0.0902}
# 가중치 비율 [0.96, 0.03, 0.01] {'정밀도': 0.0895}
# 가중치 비율 [0.96, 0.04, 0.0] {'정밀도': 0.0892}
# 가중치 비율 [0.97, 0.0, 0.03] {'정밀도': 0.0904}
# 가중치 비율 [0.97, 0.01, 0.02] {'정밀도': 0.0901}
# 가중치 비율 [0.97, 0.02, 0.01] {'정밀도': 0.0898}
# 가중치 비율 [0.97, 0.03, 0.0] {'정밀도': 0.0894}
# 가중치 비율 [0.98, 0.0, 0.02] {'정밀도': 0.0903}
# 가중치 비율 [0.98, 0.01, 0.01] {'정밀도': 0.0898}
# 가중치 비율 [0.98, 0.02, 0.0] {'정밀도': 0.0899}
# 가중치 비율 [0.99, 0.0, 0.01] {'정밀도': 0.0901}
# 가중치 비율 [0.99, 0.01, 0.0] {'정밀도': 0.0897}
# 가중치 비율 [1.0, 0.0, 0.0] {'정밀도': 0.0901}
#
#  최대 정밀도: ['가중치 비율', [0.93, 0.0, 0.07], {'정밀도': 0.0911}]

# %%
x = range(len(total_param))
y = [entry[2]['정밀도'] for entry in total_param]

# 꺾은선 그래프 그리기
plt.plot(x, y, marker='o')

plt.title('Final model')
plt.xlabel('')
plt.ylabel('accuracy')

# 그래프 표시
plt.grid(True)
plt.show()

print('최대 정밀도',max(y))
# Out:
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# 최대 정밀도 0.0911

# %% [markdown]
# ## 모델 검증

# %%
#구매 수량 순, 구매 횟수 순 정렬
top_Quant_prod = train[['StockCode','Quantity']].groupby('StockCode').sum().sort_values(by='Quantity',ascending=False)
top_buy_prod = pd.DataFrame(train['StockCode'].value_counts())

# %%
def popular_prod_eval(recomm_n = 10, popular_df = top_Quant_prod):
    total_conf_matrix = np.matrix([[0,0],[0,0]])
    shared_customers = set(train['CustomerID'].unique()).intersection(set(test['CustomerID'].unique())) 
    for CustomerID in shared_customers:
        #구매하지 않은 상품 추출
        Customer_info = pivot_CS.loc[CustomerID,]
        unbought_list = Customer_info[Customer_info==0].index

        #구매하지 않은 상품 중 상위 인기 recomm_n개 추천
        unbought_pop_df = popular_df[popular_df.index.isin(unbought_list)]
        recomm_prod = unbought_pop_df[:recomm_n].index

        #평가
        y_test = pd.Series(np.zeros(recomm_n))
        for index, value in enumerate(recomm_prod):
            if value in pivot_test.columns:
                y_test[index] = pivot_test.loc[CustomerID, value]
        y_pred = pd.Series(np.ones(len(recomm_prod)))
        conf_matrix = confusion_matrix(y_test, y_pred) # 혼동 행렬 계산
        if (conf_matrix[0,0] != 0):
            print('<전부 구매함>', f'\nCustomerID: {CustomerID}', f'\nprodcuct: {recomm_prod}')
            total_conf_matrix = total_conf_matrix + [[0,0],[0,conf_matrix[0,0]]]
        else:
            total_conf_matrix = total_conf_matrix + conf_matrix

    FP = total_conf_matrix[0,1]
    TP = total_conf_matrix[1,1]

    precision = np.round(TP / (TP + FP), 4) # 정밀도 계산

    evaluation = {'정밀도': precision}    
    return total_conf_matrix, evaluation

# %% [markdown]
# ### 인기순 정밀도

# %%
recomm_n = 10

print(popular_prod_eval(recomm_n=recomm_n,popular_df=top_Quant_prod))
popular_prod_eval(recomm_n=recomm_n,popular_df=top_buy_prod)
# Out:
# (matrix([[    0, 19651],
#         [    0,   749]]), {'정밀도': 0.0367})
# (matrix([[    0, 19376],
#          [    0,  1024]]),
#  {'정밀도': 0.0502})

# %%
pred_final = recomm_model((0.93*pred_IS + 0*pred_CS + 0.07*pred_Des), recomm_n = recomm_n)
recomm_final = pred_final[1]

# %%
def recomm_test(CustomerID):
    recomm_SC = recomm_final[recomm_final['CustomerID'] == CustomerID[0]]['recommend_products'].explode().tolist()
    recomm_Des = pairs_SD[pairs_SD.index.isin(recomm_SC)]
    recomm_Des.name = 'recomm_prod'
    
    bought_SC = train[train['CustomerID'] == CustomerID[0]]['StockCode'].unique()
    bought_Des = pairs_SD[pairs_SD.index.isin(bought_SC)]
    bought_Des.name = 'bought_prod'

    new_bought_SC = test[test['CustomerID'] == CustomerID[0]]['StockCode'].unique()
    new_bought_Des = pairs_SD[pairs_SD.index.isin(new_bought_SC)]
    new_bought_Des.name = 'new_bought_prod'

    bought_from_recomm = recomm_Des[recomm_Des.isin(new_bought_Des)]
    bought_from_recomm.name = 'bought_from_recomm'
    return recomm_Des, bought_Des, new_bought_Des, bought_from_recomm

# %% [markdown]
# ## 추천 내역 예시

# %%
import random

# random.seed(1004)
test_ID = random.sample(recomm_final['CustomerID'].tolist(), 1)
print('CustomerID:',test_ID,'\n')

model_test = recomm_test(test_ID) 

print(model_test[0],'\n') #추천제품
print(model_test[1],'\n') #기존 구매 제품
print(model_test[2],'\n') #최근 구매 제품
print(model_test[3]) #추천한 제품 중 구매한 제품
# Out:
# CustomerID: [17968]
#
# StockCode
# 20725                   [LUNCH BAG RED SPOTTY]
# 21094          [SET/6 RED SPOTTY PAPER PLATES]
# 21122       [SET/10 PINK SPOTTY PARTY CANDLES]
# 21124       [SET/10 BLUE SPOTTY PARTY CANDLES]
# 21212       [PACK OF 72 RETRO SPOT CAKE CASES]
# 22383                 [LUNCHBAG SUKI  DESIGN ]
# 22384                [LUNCHBAG PINK RETROSPOT]
# 22952        [72 CAKE CASES VINTAGE CHRISTMAS]
# 85099B           [JUMBO BAG RED WHITE SPOTTY ]
# 85123A    [WHITE HANGING HEART T-LIGHT HOLDER]
# Name: recomm_prod, dtype: object
#
# StockCode
# 10123G                [ARMY CAMO WRAPPING TAPE]
# 20727                 [LUNCH BAG  BLACK SKULL.]
# 20931                  [BLUE POT PLANT CANDLE ]
# 21080        [SET/20 RED SPOTTY PAPER NAPKINS ]
# 21086             [SET/6 RED SPOTTY PAPER CUPS]
# 21121         [SET/10 RED SPOTTY PARTY CANDLES]
# 21425                [SKULLS STORAGE BOX LARGE]
# 21562                   [HAWAIIAN GRASS SKIRT ]
# 21609     [SET 12 LAVENDER  BOTANICAL T-LIGHTS]
# 21610          [SET 12 PEAR BOTANICAL T-LIGHTS]
# 21833                    [CAMOUFLAGE LED TORCH]
# 22035          [VINTAGE CARAVAN GREETING CARD ]
# 22078                [RIBBON REEL LACE DESIGN ]
# 22099               [CARAVAN SQUARE TISSUE BOX]
# 22197                 [POPCORN HOLDER , SMALL ]
# 22198                  [POPCORN HOLDER , LARGE]
# 22332          [SKULLS PARTY BAG + STICKER SET]
# 22333     [RETRO SPORT PARTY BAG + STICKER SET]
# 22379                [RECYCLING BAG RETROSPOT ]
# 22381               [TOY TIDY PINK RETROSPOT  ]
# 22382               [LUNCHBAG SPACEBOY DESIGN ]
# 22386         [JUMBO BAG PINK WITH WHITE SPOTS]
# 22441       [GROW YOUR OWN BASIL IN ENAMEL MUG]
# 22556          [PLASTERS IN TIN CIRCUS PARADE ]
# 22584          [PACK OF 6 PANNETONE GIFT BOXES]
# 22585               [PACK OF 6 BIRDY GIFT TAGS]
# 22586        [FELTCRAFT HAIRBAND PINK AND BLUE]
# 22587       [FELTCRAFT HAIRBAND, S/2, RED/BLUE]
# 22663             [JUMBO BAG DOLLY GIRL DESIGN]
# 22780          [LIGHT GARLAND BUTTERFILES PINK]
# 22812        [PACK 3 BOXES CHRISTMAS PANNETONE]
# 22813            [PACK 3 BOXES BIRD PANNETONE ]
# 22910       [PAPER CHAIN KIT VINTAGE CHRISTMAS]
# 22955                [36 FOIL STAR CAKE CASES ]
# 72741                   [GRAND CHOCOLATECANDLE]
# 84006               [MAGIC TREE -PAPER FLOWERS]
# 84012     [MAGIC SHEEP WOOL GROWING FROM PAPER]
# 84508A                 [CAMOFLAGE DESIGN TEDDY]
# 85036B     [CHOCOLATE 1 WICK MORRIS BOX CANDLE]
# 85038         [6 CHOCOLATE LOVE HEART T-LIGHTS]
# 85172           [HYACINTH BULB T-LIGHT CANDLES]
# 85227             [SET/6 3D KIT CARDS FOR KIDS]
# 85231G          [ORANGE SCENTED SET/9 T-LIGHTS]
# Name: bought_prod, dtype: object
#
# StockCode
# 10125               [MINI FUNKY DESIGN TAPES]
# 16258A       [SWIRLY CIRCULAR RUBBERS IN BAG]
# 20866               [BLUE ROSE FABRIC MIRROR]
# 20878     [SET/9 CHRISTMAS T-LIGHTS SCENTED ]
# 21121       [SET/10 RED SPOTTY PARTY CANDLES]
#                          ...
# 90185C       [BLACK DIAMANTE EXPANDABLE RING]
# 90200A           [PURPLE SWEETHEART BRACELET]
# 90200B            [BLACK SWEETHEART BRACELET]
# 90200C             [BLUE SWEETHEART BRACELET]
# 90200D             [PINK SWEETHEART BRACELET]
# Name: new_bought_prod, Length: 74, dtype: object
#
# StockCode
# 21122     [SET/10 PINK SPOTTY PARTY CANDLES]
# 21124     [SET/10 BLUE SPOTTY PARTY CANDLES]
# 21212     [PACK OF 72 RETRO SPOT CAKE CASES]
# 22952      [72 CAKE CASES VINTAGE CHRISTMAS]
# 85099B         [JUMBO BAG RED WHITE SPOTTY ]
# Name: bought_from_recomm, dtype: object

# %%
print(model_test[3]) #추천한 제품 중 구매한 제품
# Out:
# StockCode
# 21122     [SET/10 PINK SPOTTY PARTY CANDLES]
# 21124     [SET/10 BLUE SPOTTY PARTY CANDLES]
# 21212     [PACK OF 72 RETRO SPOT CAKE CASES]
# 22952      [72 CAKE CASES VINTAGE CHRISTMAS]
# 85099B         [JUMBO BAG RED WHITE SPOTTY ]
# Name: bought_from_recomm, dtype: object
