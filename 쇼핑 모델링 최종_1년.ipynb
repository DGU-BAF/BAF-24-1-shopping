# %% [markdown]
# # 쇼핑 모델링 최종(1년)

# %% [markdown]
# ## 라이브러리 호출

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json

#한글폰트 가져오기
from matplotlib import rc
rc('font', family='NanumGothic')

# Warning 메세지를 뜨지 않게 해줌
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler

#평가
from sklearn.metrics import confusion_matrix, jaccard_score
from itertools import combinations

#NLP
import nltk
from nltk.corpus import stopwords
import re

# %% [markdown]
# ## train 데이터 불러오기

# %%
train = pd.read_csv('./data/Online Retail_2009.csv')

#pivot_CS
df_CS = pd.DataFrame(train.loc[:,['CustomerID','StockCode']].value_counts())
df_CS[0] = 1
pivot_CS = df_CS.pivot_table(0, index='CustomerID',columns='StockCode')
pivot_CS.fillna(0,inplace=True)

#paris_CI 생성
pairs_CI = train[['CustomerID','InvoiceNo']].groupby('CustomerID')['InvoiceNo'].apply(lambda x: x.unique())

#paris_SD 생성
pairs_SD = train.loc[:,['StockCode','Description']].groupby('StockCode')['Description'].apply(lambda x: x.unique())

# %% [markdown]
# ## test 데이터 불러오기

# %%
test = pd.read_csv('./data/Online Retail_df.csv')
test['InvoiceDate'] = pd.to_datetime(test['InvoiceDate'])

# 'InvoiceDate' 열이 '2011-11-30' 이전인 데이터만 선택
test = test[test['InvoiceDate'] < '2011-12-01']

#pivot_test
df_CS_test = pd.DataFrame(test.loc[:,['CustomerID','StockCode']].value_counts())
df_CS_test['count'] = 1
pivot_test = df_CS_test.pivot_table('count', index='CustomerID',columns='StockCode')
pivot_test.fillna(0,inplace=True)

# %% [markdown]
# ## 함수생성

# %% [markdown]
# ### InvoiceNo_to_CustomerID
# InvoiceNo - StockCode 형태를 CustomerID - StockCode형태로 변환

# %%
def InvoiceNo_to_CustomerID(Pred_IS, pairs_CI = pairs_CI):
    #빈객체 생성
    merged_data = []
    CustomerID_list = []
    #CustomerID와 InvoiceNo를 각각 저장해 루프 생성
    for CustomerID, invoice_list in pairs_CI.items():
        #같은 CutomerID 예측 값만 추출해 저장
        customer_data = Pred_IS[Pred_IS.index.isin(invoice_list)] 
        merged_data.append(customer_data.mean(axis=0)) #값들을 모두 합해 새로운 객체에 저장
        CustomerID_list.append(CustomerID)
    merged_data = pd.DataFrame(merged_data,index=CustomerID_list,columns=Pred_IS.columns)
    return merged_data

# %% [markdown]
# ### get_topsim
# top_n개의 유사도 외에는 다 0으로 만들어 가중치가 없도록 변환

# %%
def get_topsim(sim_df, top_n=20):
    sim_topn = sim_df.copy()
    for col in range(sim_df.shape[1]):
        col_sim = sim_df.iloc[:,col]
        top_n_items = [np.argsort(col_sim)[:-top_n]]
        sim_topn.iloc[top_n_items,col] = 0
    return sim_topn

# %% [markdown]
# ### predict_count
# 행렬곱을 통해 데이터 프레임 형태로 반환

# %%
def predict_count(pivot, sim_df, IS = False):
    count_pred = pivot.T.values.dot(sim_df.values) / np.array([np.abs(sim_df.values).sum(axis=1)])
    count_pred = pd.DataFrame(count_pred, index=pivot.columns, columns=pivot.index)
    count_pred = count_pred.T
    if IS:
        count_pred = InvoiceNo_to_CustomerID(count_pred)
    return count_pred

# %% [markdown]
# ### recomm_model
# 구매하지 않은 상품기준
# - 고객별 구매하지 않은 상품 리스트
# - 고객별 추천 상품(StockCode)
# - 혼동행렬
# - 정밀도

# %%
def recomm_model(pred_df, recomm_n = 10, pivot_CS = pivot_CS):
    unbought_df = []
    recomm_prod_df = []
    total_conf_matrix = np.matrix([[0,0],[0,0]])
    shared_customers = set(train['CustomerID'].unique()).intersection(set(test['CustomerID'].unique())) 
    for CustomerID in shared_customers:
        #구매하지 않은 상품 추출
        Customer_info = pivot_CS.loc[CustomerID,]
        unbought_list = Customer_info[Customer_info==0].index
        unbought_df.append({'CustomerID': CustomerID, 'Unbought_Items': unbought_list})

        #pred_df를 기반, 구매하지 않은 상품 중 상위 10개 추천
        recomm_prod = pred_df.loc[CustomerID, unbought_list].sort_values(ascending=False)[:recomm_n].index
        recomm_prod_df.append({'CustomerID': CustomerID, 'recommend_products': recomm_prod})

        #평가
        y_test = pd.Series(np.zeros(len(recomm_prod)))
        for index, value in enumerate(recomm_prod):
            if value in pivot_test.columns:
                y_test[index] = pivot_test.loc[CustomerID, value]
        y_pred = pd.Series(np.ones(len(recomm_prod)))
        conf_matrix = confusion_matrix(y_test, y_pred) # 혼동 행렬 계산
        if (conf_matrix[0,0] != 0):
            print('<전부 구매함>', f'\nCustomerID: {CustomerID}', f'\nprodcuct: {recomm_prod}')
            total_conf_matrix = total_conf_matrix + [[0,0],[0,conf_matrix[0,0]]]
        else:
            total_conf_matrix = total_conf_matrix + conf_matrix
    unbought_df = pd.DataFrame(unbought_df)
    recomm_prod_df = pd.DataFrame(recomm_prod_df)

    TN = total_conf_matrix[0,0]
    FP = total_conf_matrix[0,1]
    FN = total_conf_matrix[1,0]
    TP = total_conf_matrix[1,1]

    precision = np.round(TP / (TP + FP), 4) # 정밀도 계산

    evaluation = {'정밀도': precision}    
    return unbought_df, recomm_prod_df, total_conf_matrix, evaluation

# %% [markdown]
# ## 추천 수 설정

# %%
recomm_n = 12

# %% [markdown]
# ## 주문유사도 기반 추천

# %%
#주문별 상품 종류 데이터 프레임 생성
df_IS = pd.DataFrame(train[['InvoiceNo','StockCode']].value_counts())
df_IS['count'] = 1

#피봇형태로 변환
pivot_IS = df_IS.pivot_table('count', index='InvoiceNo',columns='StockCode')
pivot_IS.fillna(0, inplace=True)

#유사도 계산
sim_Inv = pd.DataFrame(cosine_similarity(pivot_IS),index=pivot_IS.index, columns=pivot_IS.index)

# %% [markdown]
# ### 50개 단위

# %%
Inv_param_50 = []

print(recomm_n,'개 추천')
for i in range(50,18151,50):
    pred = predict_count(pivot_IS, get_topsim(sim_Inv, top_n=i), IS = True)
    result = recomm_model(pred, recomm_n=recomm_n)
    Inv_param_50.append([i,'개의 유사도를 반영할 때',result[3]])

print('최대 정밀도',max(Inv_param_50, key=lambda x: x[2]['정밀도']))
Inv_param_50
# Out:
# 12 개 추천
# 최대 정밀도 [400, '개의 유사도를 반영할 때', {'정밀도': 0.1175}]
# [[50, '개의 유사도를 반영할 때', {'정밀도': 0.1068}],
#  [100, '개의 유사도를 반영할 때', {'정밀도': 0.1127}],
#  [150, '개의 유사도를 반영할 때', {'정밀도': 0.1143}],
#  [200, '개의 유사도를 반영할 때', {'정밀도': 0.1152}],
#  [250, '개의 유사도를 반영할 때', {'정밀도': 0.116}],
#  [300, '개의 유사도를 반영할 때', {'정밀도': 0.1167}],
#  [350, '개의 유사도를 반영할 때', {'정밀도': 0.1166}],
#  [400, '개의 유사도를 반영할 때', {'정밀도': 0.1175}],
#  [450, '개의 유사도를 반영할 때', {'정밀도': 0.1165}],
#  [500, '개의 유사도를 반영할 때', {'정밀도': 0.1161}],
#  [550, '개의 유사도를 반영할 때', {'정밀도': 0.1167}],
#  [600, '개의 유사도를 반영할 때', {'정밀도': 0.1162}],
#  [650, '개의 유사도를 반영할 때', {'정밀도': 0.1161}],
#  [700, '개의 유사도를 반영할 때', {'정밀도': 0.1158}],
#  [750, '개의 유사도를 반영할 때', {'정밀도': 0.1157}],
#  [800, '개의 유사도를 반영할 때', {'정밀도': 0.1157}],
#  [850, '개의 유사도를 반영할 때', {'정밀도': 0.115}],
#  [900, '개의 유사도를 반영할 때', {'정밀도': 0.1152}],
#  [950, '개의 유사도를 반영할 때', {'정밀도': 0.1148}],
#  [1000, '개의 유사도를 반영할 때', {'정밀도': 0.1144}],
#  [1050, '개의 유사도를 반영할 때', {'정밀도': 0.1143}],
#  [1100, '개의 유사도를 반영할 때', {'정밀도': 0.1142}],
#  [1150, '개의 유사도를 반영할 때', {'정밀도': 0.1135}],
#  [1200, '개의 유사도를 반영할 때', {'정밀도': 0.1136}],
#  [1250, '개의 유사도를 반영할 때', {'정밀도': 0.1132}],
#  [1300, '개의 유사도를 반영할 때', {'정밀도': 0.113}],
#  [1350, '개의 유사도를 반영할 때', {'정밀도': 0.1125}],
#  [1400, '개의 유사도를 반영할 때', {'정밀도': 0.1122}],
#  [1450, '개의 유사도를 반영할 때', {'정밀도': 0.112}],
#  [1500, '개의 유사도를 반영할 때', {'정밀도': 0.1113}],
#  [1550, '개의 유사도를 반영할 때', {'정밀도': 0.1112}],
#  [1600, '개의 유사도를 반영할 때', {'정밀도': 0.1111}],
#  [1650, '개의 유사도를 반영할 때', {'정밀도': 0.1108}],
#  [1700, '개의 유사도를 반영할 때', {'정밀도': 0.1108}],
#  [1750, '개의 유사도를 반영할 때', {'정밀도': 0.1108}],
#  [1800, '개의 유사도를 반영할 때', {'정밀도': 0.1104}],
#  [1850, '개의 유사도를 반영할 때', {'정밀도': 0.11}],
#  [1900, '개의 유사도를 반영할 때', {'정밀도': 0.1099}],
#  [1950, '개의 유사도를 반영할 때', {'정밀도': 0.1099}],
#  [2000, '개의 유사도를 반영할 때', {'정밀도': 0.1096}],
#  [2050, '개의 유사도를 반영할 때', {'정밀도': 0.1095}],
#  [2100, '개의 유사도를 반영할 때', {'정밀도': 0.1093}],
#  [2150, '개의 유사도를 반영할 때', {'정밀도': 0.109}],
#  [2200, '개의 유사도를 반영할 때', {'정밀도': 0.109}],
#  [2250, '개의 유사도를 반영할 때', {'정밀도': 0.1089}],
#  [2300, '개의 유사도를 반영할 때', {'정밀도': 0.1088}],
#  [2350, '개의 유사도를 반영할 때', {'정밀도': 0.1086}],
#  [2400, '개의 유사도를 반영할 때', {'정밀도': 0.1086}],
#  [2450, '개의 유사도를 반영할 때', {'정밀도': 0.1085}],
#  [2500, '개의 유사도를 반영할 때', {'정밀도': 0.1082}],
#  [2550, '개의 유사도를 반영할 때', {'정밀도': 0.1083}],
#  [2600, '개의 유사도를 반영할 때', {'정밀도': 0.1081}],
#  [2650, '개의 유사도를 반영할 때', {'정밀도': 0.1081}],
#  [2700, '개의 유사도를 반영할 때', {'정밀도': 0.1078}],
#  [2750, '개의 유사도를 반영할 때', {'정밀도': 0.108}],
#  [2800, '개의 유사도를 반영할 때', {'정밀도': 0.1079}],
#  [2850, '개의 유사도를 반영할 때', {'정밀도': 0.1076}],
#  [2900, '개의 유사도를 반영할 때', {'정밀도': 0.1074}],
#  [2950, '개의 유사도를 반영할 때', {'정밀도': 0.1074}],
#  [3000, '개의 유사도를 반영할 때', {'정밀도': 0.1072}],
#  [3050, '개의 유사도를 반영할 때', {'정밀도': 0.107}],
#  [3100, '개의 유사도를 반영할 때', {'정밀도': 0.1069}],
#  [3150, '개의 유사도를 반영할 때', {'정밀도': 0.1069}],
#  [3200, '개의 유사도를 반영할 때', {'정밀도': 0.1069}],
#  [3250, '개의 유사도를 반영할 때', {'정밀도': 0.1068}],
#  [3300, '개의 유사도를 반영할 때', {'정밀도': 0.107}],
#  [3350, '개의 유사도를 반영할 때', {'정밀도': 0.1069}],
#  [3400, '개의 유사도를 반영할 때', {'정밀도': 0.1069}],
#  [3450, '개의 유사도를 반영할 때', {'정밀도': 0.1068}],
#  [3500, '개의 유사도를 반영할 때', {'정밀도': 0.1066}],
#  [3550, '개의 유사도를 반영할 때', {'정밀도': 0.1064}],
#  [3600, '개의 유사도를 반영할 때', {'정밀도': 0.1063}],
#  [3650, '개의 유사도를 반영할 때', {'정밀도': 0.1059}],
#  [3700, '개의 유사도를 반영할 때', {'정밀도': 0.1057}],
#  [3750, '개의 유사도를 반영할 때', {'정밀도': 0.1056}],
#  [3800, '개의 유사도를 반영할 때', {'정밀도': 0.1056}],
#  [3850, '개의 유사도를 반영할 때', {'정밀도': 0.1053}],
#  [3900, '개의 유사도를 반영할 때', {'정밀도': 0.1052}],
#  [3950, '개의 유사도를 반영할 때', {'정밀도': 0.1051}],
#  [4000, '개의 유사도를 반영할 때', {'정밀도': 0.1051}],
#  [4050, '개의 유사도를 반영할 때', {'정밀도': 0.1051}],
#  [4100, '개의 유사도를 반영할 때', {'정밀도': 0.105}],
#  [4150, '개의 유사도를 반영할 때', {'정밀도': 0.1051}],
#  [4200, '개의 유사도를 반영할 때', {'정밀도': 0.1051}],
#  [4250, '개의 유사도를 반영할 때', {'정밀도': 0.105}],
#  [4300, '개의 유사도를 반영할 때', {'정밀도': 0.1049}],
#  [4350, '개의 유사도를 반영할 때', {'정밀도': 0.105}],
#  [4400, '개의 유사도를 반영할 때', {'정밀도': 0.1049}],
#  [4450, '개의 유사도를 반영할 때', {'정밀도': 0.1049}],
#  [4500, '개의 유사도를 반영할 때', {'정밀도': 0.1048}],
#  [4550, '개의 유사도를 반영할 때', {'정밀도': 0.1048}],
#  [4600, '개의 유사도를 반영할 때', {'정밀도': 0.1047}],
#  [4650, '개의 유사도를 반영할 때', {'정밀도': 0.1045}],
#  [4700, '개의 유사도를 반영할 때', {'정밀도': 0.1045}],
#  [4750, '개의 유사도를 반영할 때', {'정밀도': 0.1047}],
#  [4800, '개의 유사도를 반영할 때', {'정밀도': 0.1045}],
#  [4850, '개의 유사도를 반영할 때', {'정밀도': 0.1044}],
#  [4900, '개의 유사도를 반영할 때', {'정밀도': 0.1044}],
#  [4950, '개의 유사도를 반영할 때', {'정밀도': 0.104}],
#  [5000, '개의 유사도를 반영할 때', {'정밀도': 0.1041}],
#  [5050, '개의 유사도를 반영할 때', {'정밀도': 0.1041}],
#  [5100, '개의 유사도를 반영할 때', {'정밀도': 0.104}],
#  [5150, '개의 유사도를 반영할 때', {'정밀도': 0.1039}],
#  [5200, '개의 유사도를 반영할 때', {'정밀도': 0.104}],
#  [5250, '개의 유사도를 반영할 때', {'정밀도': 0.104}],
#  [5300, '개의 유사도를 반영할 때', {'정밀도': 0.1039}],
#  [5350, '개의 유사도를 반영할 때', {'정밀도': 0.1039}],
#  [5400, '개의 유사도를 반영할 때', {'정밀도': 0.1037}],
#  [5450, '개의 유사도를 반영할 때', {'정밀도': 0.1038}],
#  [5500, '개의 유사도를 반영할 때', {'정밀도': 0.1038}],
#  [5550, '개의 유사도를 반영할 때', {'정밀도': 0.1038}],
#  [5600, '개의 유사도를 반영할 때', {'정밀도': 0.1037}],
#  [5650, '개의 유사도를 반영할 때', {'정밀도': 0.1037}],
#  [5700, '개의 유사도를 반영할 때', {'정밀도': 0.1037}],
#  [5750, '개의 유사도를 반영할 때', {'정밀도': 0.1036}],
#  [5800, '개의 유사도를 반영할 때', {'정밀도': 0.1036}],
#  [5850, '개의 유사도를 반영할 때', {'정밀도': 0.1036}],
#  [5900, '개의 유사도를 반영할 때', {'정밀도': 0.1034}],
#  [5950, '개의 유사도를 반영할 때', {'정밀도': 0.1033}],
#  [6000, '개의 유사도를 반영할 때', {'정밀도': 0.1031}],
#  [6050, '개의 유사도를 반영할 때', {'정밀도': 0.1033}],
#  [6100, '개의 유사도를 반영할 때', {'정밀도': 0.1032}],
#  [6150, '개의 유사도를 반영할 때', {'정밀도': 0.1031}],
#  [6200, '개의 유사도를 반영할 때', {'정밀도': 0.103}],
#  [6250, '개의 유사도를 반영할 때', {'정밀도': 0.1029}],
#  [6300, '개의 유사도를 반영할 때', {'정밀도': 0.1028}],
#  [6350, '개의 유사도를 반영할 때', {'정밀도': 0.1028}],
#  [6400, '개의 유사도를 반영할 때', {'정밀도': 0.1027}],
#  [6450, '개의 유사도를 반영할 때', {'정밀도': 0.1027}],
#  [6500, '개의 유사도를 반영할 때', {'정밀도': 0.1026}],
#  [6550, '개의 유사도를 반영할 때', {'정밀도': 0.1027}],
#  [6600, '개의 유사도를 반영할 때', {'정밀도': 0.1027}],
#  [6650, '개의 유사도를 반영할 때', {'정밀도': 0.1027}],
#  [6700, '개의 유사도를 반영할 때', {'정밀도': 0.1027}],
#  [6750, '개의 유사도를 반영할 때', {'정밀도': 0.1027}],
#  [6800, '개의 유사도를 반영할 때', {'정밀도': 0.1027}],
#  [6850, '개의 유사도를 반영할 때', {'정밀도': 0.1027}],
#  [6900, '개의 유사도를 반영할 때', {'정밀도': 0.1025}],
#  [6950, '개의 유사도를 반영할 때', {'정밀도': 0.1025}],
#  [7000, '개의 유사도를 반영할 때', {'정밀도': 0.1024}],
#  [7050, '개의 유사도를 반영할 때', {'정밀도': 0.1025}],
#  [7100, '개의 유사도를 반영할 때', {'정밀도': 0.1024}],
#  [7150, '개의 유사도를 반영할 때', {'정밀도': 0.1024}],
#  [7200, '개의 유사도를 반영할 때', {'정밀도': 0.1024}],
#  [7250, '개의 유사도를 반영할 때', {'정밀도': 0.1024}],
#  [7300, '개의 유사도를 반영할 때', {'정밀도': 0.1025}],
#  [7350, '개의 유사도를 반영할 때', {'정밀도': 0.1025}],
#  [7400, '개의 유사도를 반영할 때', {'정밀도': 0.1025}],
#  [7450, '개의 유사도를 반영할 때', {'정밀도': 0.1024}],
#  [7500, '개의 유사도를 반영할 때', {'정밀도': 0.1024}],
#  [7550, '개의 유사도를 반영할 때', {'정밀도': 0.1024}],
#  [7600, '개의 유사도를 반영할 때', {'정밀도': 0.1023}],
#  [7650, '개의 유사도를 반영할 때', {'정밀도': 0.1023}],
#  [7700, '개의 유사도를 반영할 때', {'정밀도': 0.1022}],
#  [7750, '개의 유사도를 반영할 때', {'정밀도': 0.1023}],
#  [7800, '개의 유사도를 반영할 때', {'정밀도': 0.1023}],
#  [7850, '개의 유사도를 반영할 때', {'정밀도': 0.1023}],
#  [7900, '개의 유사도를 반영할 때', {'정밀도': 0.1023}],
#  [7950, '개의 유사도를 반영할 때', {'정밀도': 0.1023}],
#  [8000, '개의 유사도를 반영할 때', {'정밀도': 0.1022}],
#  [8050, '개의 유사도를 반영할 때', {'정밀도': 0.1022}],
#  [8100, '개의 유사도를 반영할 때', {'정밀도': 0.1023}],
#  [8150, '개의 유사도를 반영할 때', {'정밀도': 0.1023}],
#  [8200, '개의 유사도를 반영할 때', {'정밀도': 0.1021}],
#  [8250, '개의 유사도를 반영할 때', {'정밀도': 0.1021}],
#  [8300, '개의 유사도를 반영할 때', {'정밀도': 0.1021}],
#  [8350, '개의 유사도를 반영할 때', {'정밀도': 0.1021}],
#  [8400, '개의 유사도를 반영할 때', {'정밀도': 0.1021}],
#  [8450, '개의 유사도를 반영할 때', {'정밀도': 0.1021}],
#  [8500, '개의 유사도를 반영할 때', {'정밀도': 0.1021}],
#  [8550, '개의 유사도를 반영할 때', {'정밀도': 0.1021}],
#  [8600, '개의 유사도를 반영할 때', {'정밀도': 0.1021}],
#  [8650, '개의 유사도를 반영할 때', {'정밀도': 0.1021}],
#  [8700, '개의 유사도를 반영할 때', {'정밀도': 0.1021}],
#  [8750, '개의 유사도를 반영할 때', {'정밀도': 0.1021}],
#  [8800, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [8850, '개의 유사도를 반영할 때', {'정밀도': 0.1021}],
#  [8900, '개의 유사도를 반영할 때', {'정밀도': 0.1022}],
#  [8950, '개의 유사도를 반영할 때', {'정밀도': 0.1022}],
#  [9000, '개의 유사도를 반영할 때', {'정밀도': 0.1022}],
#  [9050, '개의 유사도를 반영할 때', {'정밀도': 0.1021}],
#  [9100, '개의 유사도를 반영할 때', {'정밀도': 0.1021}],
#  [9150, '개의 유사도를 반영할 때', {'정밀도': 0.1021}],
#  [9200, '개의 유사도를 반영할 때', {'정밀도': 0.1021}],
#  [9250, '개의 유사도를 반영할 때', {'정밀도': 0.1021}],
#  [9300, '개의 유사도를 반영할 때', {'정밀도': 0.1021}],
#  [9350, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [9400, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [9450, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [9500, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [9550, '개의 유사도를 반영할 때', {'정밀도': 0.1019}],
#  [9600, '개의 유사도를 반영할 때', {'정밀도': 0.1019}],
#  [9650, '개의 유사도를 반영할 때', {'정밀도': 0.1019}],
#  [9700, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [9750, '개의 유사도를 반영할 때', {'정밀도': 0.1019}],
#  [9800, '개의 유사도를 반영할 때', {'정밀도': 0.1019}],
#  [9850, '개의 유사도를 반영할 때', {'정밀도': 0.1019}],
#  [9900, '개의 유사도를 반영할 때', {'정밀도': 0.1019}],
#  [9950, '개의 유사도를 반영할 때', {'정밀도': 0.1019}],
#  [10000, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [10050, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [10100, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [10150, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [10200, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [10250, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [10300, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [10350, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [10400, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [10450, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [10500, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [10550, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [10600, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [10650, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [10700, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [10750, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [10800, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [10850, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [10900, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [10950, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [11000, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [11050, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [11100, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [11150, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [11200, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [11250, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [11300, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [11350, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [11400, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [11450, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [11500, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [11550, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [11600, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [11650, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [11700, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [11750, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [11800, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [11850, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [11900, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [11950, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [12000, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [12050, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [12100, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [12150, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [12200, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [12250, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [12300, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [12350, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [12400, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [12450, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [12500, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [12550, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [12600, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [12650, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [12700, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [12750, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [12800, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [12850, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [12900, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [12950, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [13000, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [13050, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [13100, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [13150, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [13200, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [13250, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [13300, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [13350, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [13400, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [13450, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [13500, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [13550, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [13600, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [13650, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [13700, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [13750, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [13800, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [13850, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [13900, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [13950, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [14000, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [14050, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [14100, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [14150, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [14200, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [14250, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [14300, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [14350, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [14400, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [14450, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [14500, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [14550, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [14600, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [14650, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [14700, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [14750, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [14800, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [14850, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [14900, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [14950, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [15000, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [15050, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [15100, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [15150, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [15200, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [15250, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [15300, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [15350, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [15400, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [15450, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [15500, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [15550, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [15600, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [15650, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [15700, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [15750, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [15800, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [15850, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [15900, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [15950, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [16000, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [16050, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [16100, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [16150, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [16200, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [16250, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [16300, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [16350, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [16400, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [16450, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [16500, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [16550, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [16600, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [16650, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [16700, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [16750, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [16800, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [16850, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [16900, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [16950, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [17000, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [17050, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [17100, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [17150, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [17200, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [17250, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [17300, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [17350, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [17400, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [17450, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [17500, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [17550, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [17600, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [17650, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [17700, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [17750, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [17800, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [17850, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [17900, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [17950, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [18000, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [18050, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [18100, '개의 유사도를 반영할 때', {'정밀도': 0.102}],
#  [18150, '개의 유사도를 반영할 때', {'정밀도': 0.102}]]

# %%
x = [entry[0] for entry in Inv_param_50]
y = [entry[2]['정밀도'] for entry in Inv_param_50]

# 꺾은선 그래프 그리기
plt.plot(x, y, marker='o')

plt.title('50씩 증가시킬 때 정밀도 변화(주문기반)')
plt.xlabel('유사도 수')
plt.ylabel('정밀도')

# 그래프 표시
plt.grid(True)
plt.show()

print('주문기반 최대 정밀도')
print(x[np.argsort(y)[-1]],'개의 유사도를 반영할 때 정밀도:',max(y))
# Out:
# 주문기반 최대 정밀도
# 400 개의 유사도를 반영할 때 정밀도: 0.1175

# %% [markdown]
# ### 350~450개

# %%
Inv_param = []

print(recomm_n,'개 추천')
for i in range(350,451):
    pred = predict_count(pivot_IS, get_topsim(sim_Inv, top_n=i), IS = True)
    result = recomm_model(pred, recomm_n=recomm_n)
    Inv_param.append([i,'개의 유사도를 반영할 때',result[3]])

print('최대 정밀도', max(Inv_param, key=lambda x: x[2]['정밀도']))
Inv_param
# Out:
# 12 개 추천
# 최대 정밀도 [417, '개의 유사도를 반영할 때', {'정밀도': 0.1179}]
# [[350, '개의 유사도를 반영할 때', {'정밀도': 0.1166}],
#  [351, '개의 유사도를 반영할 때', {'정밀도': 0.1164}],
#  [352, '개의 유사도를 반영할 때', {'정밀도': 0.1163}],
#  [353, '개의 유사도를 반영할 때', {'정밀도': 0.1165}],
#  [354, '개의 유사도를 반영할 때', {'정밀도': 0.1165}],
#  [355, '개의 유사도를 반영할 때', {'정밀도': 0.1165}],
#  [356, '개의 유사도를 반영할 때', {'정밀도': 0.1167}],
#  [357, '개의 유사도를 반영할 때', {'정밀도': 0.1167}],
#  [358, '개의 유사도를 반영할 때', {'정밀도': 0.1168}],
#  [359, '개의 유사도를 반영할 때', {'정밀도': 0.1168}],
#  [360, '개의 유사도를 반영할 때', {'정밀도': 0.1169}],
#  [361, '개의 유사도를 반영할 때', {'정밀도': 0.1168}],
#  [362, '개의 유사도를 반영할 때', {'정밀도': 0.1171}],
#  [363, '개의 유사도를 반영할 때', {'정밀도': 0.1169}],
#  [364, '개의 유사도를 반영할 때', {'정밀도': 0.1168}],
#  [365, '개의 유사도를 반영할 때', {'정밀도': 0.1173}],
#  [366, '개의 유사도를 반영할 때', {'정밀도': 0.1168}],
#  [367, '개의 유사도를 반영할 때', {'정밀도': 0.1166}],
#  [368, '개의 유사도를 반영할 때', {'정밀도': 0.1168}],
#  [369, '개의 유사도를 반영할 때', {'정밀도': 0.1169}],
#  [370, '개의 유사도를 반영할 때', {'정밀도': 0.1171}],
#  [371, '개의 유사도를 반영할 때', {'정밀도': 0.1168}],
#  [372, '개의 유사도를 반영할 때', {'정밀도': 0.1167}],
#  [373, '개의 유사도를 반영할 때', {'정밀도': 0.1166}],
#  [374, '개의 유사도를 반영할 때', {'정밀도': 0.1166}],
#  [375, '개의 유사도를 반영할 때', {'정밀도': 0.1166}],
#  [376, '개의 유사도를 반영할 때', {'정밀도': 0.1165}],
#  [377, '개의 유사도를 반영할 때', {'정밀도': 0.1164}],
#  [378, '개의 유사도를 반영할 때', {'정밀도': 0.1168}],
#  [379, '개의 유사도를 반영할 때', {'정밀도': 0.1167}],
#  [380, '개의 유사도를 반영할 때', {'정밀도': 0.1167}],
#  [381, '개의 유사도를 반영할 때', {'정밀도': 0.1167}],
#  [382, '개의 유사도를 반영할 때', {'정밀도': 0.1168}],
#  [383, '개의 유사도를 반영할 때', {'정밀도': 0.1172}],
#  [384, '개의 유사도를 반영할 때', {'정밀도': 0.1171}],
#  [385, '개의 유사도를 반영할 때', {'정밀도': 0.117}],
#  [386, '개의 유사도를 반영할 때', {'정밀도': 0.1171}],
#  [387, '개의 유사도를 반영할 때', {'정밀도': 0.1172}],
#  [388, '개의 유사도를 반영할 때', {'정밀도': 0.117}],
#  [389, '개의 유사도를 반영할 때', {'정밀도': 0.1171}],
#  [390, '개의 유사도를 반영할 때', {'정밀도': 0.1174}],
#  [391, '개의 유사도를 반영할 때', {'정밀도': 0.1172}],
#  [392, '개의 유사도를 반영할 때', {'정밀도': 0.1171}],
#  [393, '개의 유사도를 반영할 때', {'정밀도': 0.1172}],
#  [394, '개의 유사도를 반영할 때', {'정밀도': 0.1169}],
#  [395, '개의 유사도를 반영할 때', {'정밀도': 0.1172}],
#  [396, '개의 유사도를 반영할 때', {'정밀도': 0.117}],
#  [397, '개의 유사도를 반영할 때', {'정밀도': 0.1172}],
#  [398, '개의 유사도를 반영할 때', {'정밀도': 0.1173}],
#  [399, '개의 유사도를 반영할 때', {'정밀도': 0.1175}],
#  [400, '개의 유사도를 반영할 때', {'정밀도': 0.1175}],
#  [401, '개의 유사도를 반영할 때', {'정밀도': 0.1176}],
#  [402, '개의 유사도를 반영할 때', {'정밀도': 0.1173}],
#  [403, '개의 유사도를 반영할 때', {'정밀도': 0.1175}],
#  [404, '개의 유사도를 반영할 때', {'정밀도': 0.1173}],
#  [405, '개의 유사도를 반영할 때', {'정밀도': 0.1171}],
#  [406, '개의 유사도를 반영할 때', {'정밀도': 0.1171}],
#  [407, '개의 유사도를 반영할 때', {'정밀도': 0.1171}],
#  [408, '개의 유사도를 반영할 때', {'정밀도': 0.1169}],
#  [409, '개의 유사도를 반영할 때', {'정밀도': 0.117}],
#  [410, '개의 유사도를 반영할 때', {'정밀도': 0.1172}],
#  [411, '개의 유사도를 반영할 때', {'정밀도': 0.1174}],
#  [412, '개의 유사도를 반영할 때', {'정밀도': 0.1173}],
#  [413, '개의 유사도를 반영할 때', {'정밀도': 0.1174}],
#  [414, '개의 유사도를 반영할 때', {'정밀도': 0.1176}],
#  [415, '개의 유사도를 반영할 때', {'정밀도': 0.1176}],
#  [416, '개의 유사도를 반영할 때', {'정밀도': 0.1176}],
#  [417, '개의 유사도를 반영할 때', {'정밀도': 0.1179}],
#  [418, '개의 유사도를 반영할 때', {'정밀도': 0.1178}],
#  [419, '개의 유사도를 반영할 때', {'정밀도': 0.1176}],
#  [420, '개의 유사도를 반영할 때', {'정밀도': 0.1177}],
#  [421, '개의 유사도를 반영할 때', {'정밀도': 0.1177}],
#  [422, '개의 유사도를 반영할 때', {'정밀도': 0.1177}],
#  [423, '개의 유사도를 반영할 때', {'정밀도': 0.1177}],
#  [424, '개의 유사도를 반영할 때', {'정밀도': 0.1174}],
#  [425, '개의 유사도를 반영할 때', {'정밀도': 0.1175}],
#  [426, '개의 유사도를 반영할 때', {'정밀도': 0.1172}],
#  [427, '개의 유사도를 반영할 때', {'정밀도': 0.1173}],
#  [428, '개의 유사도를 반영할 때', {'정밀도': 0.1172}],
#  [429, '개의 유사도를 반영할 때', {'정밀도': 0.1171}],
#  [430, '개의 유사도를 반영할 때', {'정밀도': 0.1171}],
#  [431, '개의 유사도를 반영할 때', {'정밀도': 0.1173}],
#  [432, '개의 유사도를 반영할 때', {'정밀도': 0.1173}],
#  [433, '개의 유사도를 반영할 때', {'정밀도': 0.1172}],
#  [434, '개의 유사도를 반영할 때', {'정밀도': 0.1173}],
#  [435, '개의 유사도를 반영할 때', {'정밀도': 0.1171}],
#  [436, '개의 유사도를 반영할 때', {'정밀도': 0.1169}],
#  [437, '개의 유사도를 반영할 때', {'정밀도': 0.1169}],
#  [438, '개의 유사도를 반영할 때', {'정밀도': 0.117}],
#  [439, '개의 유사도를 반영할 때', {'정밀도': 0.1168}],
#  [440, '개의 유사도를 반영할 때', {'정밀도': 0.1168}],
#  [441, '개의 유사도를 반영할 때', {'정밀도': 0.1168}],
#  [442, '개의 유사도를 반영할 때', {'정밀도': 0.1167}],
#  [443, '개의 유사도를 반영할 때', {'정밀도': 0.1168}],
#  [444, '개의 유사도를 반영할 때', {'정밀도': 0.1169}],
#  [445, '개의 유사도를 반영할 때', {'정밀도': 0.1169}],
#  [446, '개의 유사도를 반영할 때', {'정밀도': 0.1168}],
#  [447, '개의 유사도를 반영할 때', {'정밀도': 0.1167}],
#  [448, '개의 유사도를 반영할 때', {'정밀도': 0.1165}],
#  [449, '개의 유사도를 반영할 때', {'정밀도': 0.1165}],
#  [450, '개의 유사도를 반영할 때', {'정밀도': 0.1165}]]

# %%
x = [entry[0] for entry in Inv_param]
y = [entry[2]['정밀도'] for entry in Inv_param]

# 꺾은선 그래프 그리기
plt.plot(x, y, marker='o')

plt.title('350~450개의 유사도 반영시 정밀도 변화(주문기반)')
plt.xlabel('유사도 수')
plt.ylabel('정밀도')

# 그래프 표시
plt.grid(True)
plt.show()

print('주문기반 최대 정밀도')
print(x[np.argsort(y)[-1]],'개의 유사도를 반영할 때 정밀도:',max(y))
# Out:
# 주문기반 최대 정밀도
# 417 개의 유사도를 반영할 때 정밀도: 0.1179

# %% [markdown]
# ## 고객유사도 기반 추천

# %% [markdown]
# ### RFM 계산, scaling

# %%
RFM = train.copy()
RFM['InvoiceDate'] = pd.to_datetime(RFM['InvoiceDate']) #datetime 형식으로 변환
RFM['TotalPrice'] = RFM['Quantity'] * RFM['UnitPrice']

current_date = pd.Timestamp(RFM['InvoiceDate'].max()) + pd.Timedelta(days=1)
df_RFM = RFM.groupby('CustomerID').agg({
    'InvoiceDate' : (lambda x: (current_date - x.max()).days), # R
    'InvoiceNo' : 'count', # F
    'TotalPrice' : 'sum' # M
}) 

RFM_Scaler = MinMaxScaler()
df_RFM_scaled = RFM_Scaler.fit_transform(df_RFM)
df_RFM_scaled = pd.DataFrame(df_RFM_scaled, index =df_RFM.index, columns=df_RFM.columns )

# %%
df_CS = pd.DataFrame(train.loc[:,['CustomerID','StockCode']].value_counts())
df_CS['count'] = 1

pivot_CS = df_CS.pivot_table('count', index='CustomerID',columns='StockCode')
pivot_CS.fillna(0,inplace=True)

sim_Cust = pd.DataFrame(cosine_similarity(df_RFM_scaled),index=df_RFM_scaled.index, columns=df_RFM_scaled.index)

# %% [markdown]
# ### 50개 단위

# %%
Cust_param_50 = []

print(recomm_n,'개 추천')
for i in range(50,4201,50):
    pred = predict_count(pivot_CS, get_topsim(sim_Cust, top_n=i))
    result = recomm_model(pred, recomm_n=recomm_n)
    Cust_param_50.append([i,'개의 유사도를 반영할 때',result[3]])

print('최대 정밀도', max(Cust_param_50, key=lambda x: x[2]['정밀도']))
Cust_param_50
# Out:
# 12 개 추천
# 최대 정밀도 [400, '개의 유사도를 반영할 때', {'정밀도': 0.0762}]
# [[50, '개의 유사도를 반영할 때', {'정밀도': 0.0684}],
#  [100, '개의 유사도를 반영할 때', {'정밀도': 0.071}],
#  [150, '개의 유사도를 반영할 때', {'정밀도': 0.0736}],
#  [200, '개의 유사도를 반영할 때', {'정밀도': 0.0744}],
#  [250, '개의 유사도를 반영할 때', {'정밀도': 0.0755}],
#  [300, '개의 유사도를 반영할 때', {'정밀도': 0.0754}],
#  [350, '개의 유사도를 반영할 때', {'정밀도': 0.0761}],
#  [400, '개의 유사도를 반영할 때', {'정밀도': 0.0762}],
#  [450, '개의 유사도를 반영할 때', {'정밀도': 0.076}],
#  [500, '개의 유사도를 반영할 때', {'정밀도': 0.0756}],
#  [550, '개의 유사도를 반영할 때', {'정밀도': 0.0747}],
#  [600, '개의 유사도를 반영할 때', {'정밀도': 0.075}],
#  [650, '개의 유사도를 반영할 때', {'정밀도': 0.0749}],
#  [700, '개의 유사도를 반영할 때', {'정밀도': 0.076}],
#  [750, '개의 유사도를 반영할 때', {'정밀도': 0.0757}],
#  [800, '개의 유사도를 반영할 때', {'정밀도': 0.0751}],
#  [850, '개의 유사도를 반영할 때', {'정밀도': 0.0749}],
#  [900, '개의 유사도를 반영할 때', {'정밀도': 0.0748}],
#  [950, '개의 유사도를 반영할 때', {'정밀도': 0.075}],
#  [1000, '개의 유사도를 반영할 때', {'정밀도': 0.0748}],
#  [1050, '개의 유사도를 반영할 때', {'정밀도': 0.0752}],
#  [1100, '개의 유사도를 반영할 때', {'정밀도': 0.0753}],
#  [1150, '개의 유사도를 반영할 때', {'정밀도': 0.0751}],
#  [1200, '개의 유사도를 반영할 때', {'정밀도': 0.0753}],
#  [1250, '개의 유사도를 반영할 때', {'정밀도': 0.0751}],
#  [1300, '개의 유사도를 반영할 때', {'정밀도': 0.0749}],
#  [1350, '개의 유사도를 반영할 때', {'정밀도': 0.0747}],
#  [1400, '개의 유사도를 반영할 때', {'정밀도': 0.075}],
#  [1450, '개의 유사도를 반영할 때', {'정밀도': 0.0751}],
#  [1500, '개의 유사도를 반영할 때', {'정밀도': 0.0751}],
#  [1550, '개의 유사도를 반영할 때', {'정밀도': 0.0754}],
#  [1600, '개의 유사도를 반영할 때', {'정밀도': 0.0757}],
#  [1650, '개의 유사도를 반영할 때', {'정밀도': 0.0757}],
#  [1700, '개의 유사도를 반영할 때', {'정밀도': 0.0754}],
#  [1750, '개의 유사도를 반영할 때', {'정밀도': 0.0754}],
#  [1800, '개의 유사도를 반영할 때', {'정밀도': 0.0752}],
#  [1850, '개의 유사도를 반영할 때', {'정밀도': 0.0744}],
#  [1900, '개의 유사도를 반영할 때', {'정밀도': 0.0745}],
#  [1950, '개의 유사도를 반영할 때', {'정밀도': 0.0746}],
#  [2000, '개의 유사도를 반영할 때', {'정밀도': 0.0745}],
#  [2050, '개의 유사도를 반영할 때', {'정밀도': 0.0738}],
#  [2100, '개의 유사도를 반영할 때', {'정밀도': 0.0739}],
#  [2150, '개의 유사도를 반영할 때', {'정밀도': 0.0733}],
#  [2200, '개의 유사도를 반영할 때', {'정밀도': 0.0735}],
#  [2250, '개의 유사도를 반영할 때', {'정밀도': 0.0736}],
#  [2300, '개의 유사도를 반영할 때', {'정밀도': 0.0736}],
#  [2350, '개의 유사도를 반영할 때', {'정밀도': 0.0738}],
#  [2400, '개의 유사도를 반영할 때', {'정밀도': 0.0738}],
#  [2450, '개의 유사도를 반영할 때', {'정밀도': 0.0735}],
#  [2500, '개의 유사도를 반영할 때', {'정밀도': 0.0732}],
#  [2550, '개의 유사도를 반영할 때', {'정밀도': 0.0735}],
#  [2600, '개의 유사도를 반영할 때', {'정밀도': 0.0732}],
#  [2650, '개의 유사도를 반영할 때', {'정밀도': 0.0736}],
#  [2700, '개의 유사도를 반영할 때', {'정밀도': 0.0732}],
#  [2750, '개의 유사도를 반영할 때', {'정밀도': 0.0735}],
#  [2800, '개의 유사도를 반영할 때', {'정밀도': 0.0736}],
#  [2850, '개의 유사도를 반영할 때', {'정밀도': 0.0738}],
#  [2900, '개의 유사도를 반영할 때', {'정밀도': 0.0738}],
#  [2950, '개의 유사도를 반영할 때', {'정밀도': 0.0736}],
#  [3000, '개의 유사도를 반영할 때', {'정밀도': 0.0735}],
#  [3050, '개의 유사도를 반영할 때', {'정밀도': 0.0734}],
#  [3100, '개의 유사도를 반영할 때', {'정밀도': 0.0739}],
#  [3150, '개의 유사도를 반영할 때', {'정밀도': 0.0735}],
#  [3200, '개의 유사도를 반영할 때', {'정밀도': 0.0737}],
#  [3250, '개의 유사도를 반영할 때', {'정밀도': 0.0738}],
#  [3300, '개의 유사도를 반영할 때', {'정밀도': 0.0738}],
#  [3350, '개의 유사도를 반영할 때', {'정밀도': 0.0735}],
#  [3400, '개의 유사도를 반영할 때', {'정밀도': 0.0739}],
#  [3450, '개의 유사도를 반영할 때', {'정밀도': 0.0739}],
#  [3500, '개의 유사도를 반영할 때', {'정밀도': 0.0738}],
#  [3550, '개의 유사도를 반영할 때', {'정밀도': 0.0739}],
#  [3600, '개의 유사도를 반영할 때', {'정밀도': 0.0735}],
#  [3650, '개의 유사도를 반영할 때', {'정밀도': 0.0734}],
#  [3700, '개의 유사도를 반영할 때', {'정밀도': 0.0735}],
#  [3750, '개의 유사도를 반영할 때', {'정밀도': 0.0731}],
#  [3800, '개의 유사도를 반영할 때', {'정밀도': 0.0734}],
#  [3850, '개의 유사도를 반영할 때', {'정밀도': 0.0734}],
#  [3900, '개의 유사도를 반영할 때', {'정밀도': 0.0734}],
#  [3950, '개의 유사도를 반영할 때', {'정밀도': 0.0732}],
#  [4000, '개의 유사도를 반영할 때', {'정밀도': 0.0732}],
#  [4050, '개의 유사도를 반영할 때', {'정밀도': 0.0733}],
#  [4100, '개의 유사도를 반영할 때', {'정밀도': 0.0734}],
#  [4150, '개의 유사도를 반영할 때', {'정밀도': 0.0736}],
#  [4200, '개의 유사도를 반영할 때', {'정밀도': 0.0734}]]

# %%
x = [entry[0] for entry in Cust_param_50]
y = [entry[2]['정밀도'] for entry in Cust_param_50]

# 꺾은선 그래프 그리기
plt.plot(x, y, marker='o')

plt.title('50씩 증가시킬 때 정밀도 변화(고객기반)')
plt.xlabel('유사도 수')
plt.ylabel('정밀도')

# 그래프 표시
plt.grid(True)
plt.show()

print('고객기반 최대 정밀도')
print(x[np.argsort(y)[-1]],'개의 유사도를 반영할 때 정밀도:',max(y))
# Out:
# 고객기반 최대 정밀도
# 400 개의 유사도를 반영할 때 정밀도: 0.0762

# %% [markdown]
# ### 350~450개

# %%
Cust_param = []

print(recomm_n,'개 추천')
for i in range(350,451):
    pred = predict_count(pivot_CS, get_topsim(sim_Cust, top_n=i))
    result = recomm_model(pred, recomm_n=recomm_n)
    Cust_param.append([i,'개의 유사도를 반영할 때',result[3]])

print('최대 정밀도', max(Cust_param, key=lambda x: x[2]['정밀도']))
Cust_param
# Out:
# 12 개 추천
# 최대 정밀도 [396, '개의 유사도를 반영할 때', {'정밀도': 0.0764}]
# [[350, '개의 유사도를 반영할 때', {'정밀도': 0.0761}],
#  [351, '개의 유사도를 반영할 때', {'정밀도': 0.0759}],
#  [352, '개의 유사도를 반영할 때', {'정밀도': 0.076}],
#  [353, '개의 유사도를 반영할 때', {'정밀도': 0.0758}],
#  [354, '개의 유사도를 반영할 때', {'정밀도': 0.0757}],
#  [355, '개의 유사도를 반영할 때', {'정밀도': 0.0754}],
#  [356, '개의 유사도를 반영할 때', {'정밀도': 0.0757}],
#  [357, '개의 유사도를 반영할 때', {'정밀도': 0.0759}],
#  [358, '개의 유사도를 반영할 때', {'정밀도': 0.0763}],
#  [359, '개의 유사도를 반영할 때', {'정밀도': 0.0763}],
#  [360, '개의 유사도를 반영할 때', {'정밀도': 0.0762}],
#  [361, '개의 유사도를 반영할 때', {'정밀도': 0.0759}],
#  [362, '개의 유사도를 반영할 때', {'정밀도': 0.0758}],
#  [363, '개의 유사도를 반영할 때', {'정밀도': 0.0758}],
#  [364, '개의 유사도를 반영할 때', {'정밀도': 0.0755}],
#  [365, '개의 유사도를 반영할 때', {'정밀도': 0.0759}],
#  [366, '개의 유사도를 반영할 때', {'정밀도': 0.0758}],
#  [367, '개의 유사도를 반영할 때', {'정밀도': 0.0757}],
#  [368, '개의 유사도를 반영할 때', {'정밀도': 0.0756}],
#  [369, '개의 유사도를 반영할 때', {'정밀도': 0.0755}],
#  [370, '개의 유사도를 반영할 때', {'정밀도': 0.0755}],
#  [371, '개의 유사도를 반영할 때', {'정밀도': 0.0757}],
#  [372, '개의 유사도를 반영할 때', {'정밀도': 0.0758}],
#  [373, '개의 유사도를 반영할 때', {'정밀도': 0.0758}],
#  [374, '개의 유사도를 반영할 때', {'정밀도': 0.0759}],
#  [375, '개의 유사도를 반영할 때', {'정밀도': 0.0759}],
#  [376, '개의 유사도를 반영할 때', {'정밀도': 0.0757}],
#  [377, '개의 유사도를 반영할 때', {'정밀도': 0.0757}],
#  [378, '개의 유사도를 반영할 때', {'정밀도': 0.0758}],
#  [379, '개의 유사도를 반영할 때', {'정밀도': 0.0757}],
#  [380, '개의 유사도를 반영할 때', {'정밀도': 0.0755}],
#  [381, '개의 유사도를 반영할 때', {'정밀도': 0.0758}],
#  [382, '개의 유사도를 반영할 때', {'정밀도': 0.0755}],
#  [383, '개의 유사도를 반영할 때', {'정밀도': 0.0756}],
#  [384, '개의 유사도를 반영할 때', {'정밀도': 0.0753}],
#  [385, '개의 유사도를 반영할 때', {'정밀도': 0.0753}],
#  [386, '개의 유사도를 반영할 때', {'정밀도': 0.0754}],
#  [387, '개의 유사도를 반영할 때', {'정밀도': 0.0755}],
#  [388, '개의 유사도를 반영할 때', {'정밀도': 0.0757}],
#  [389, '개의 유사도를 반영할 때', {'정밀도': 0.076}],
#  [390, '개의 유사도를 반영할 때', {'정밀도': 0.0762}],
#  [391, '개의 유사도를 반영할 때', {'정밀도': 0.0762}],
#  [392, '개의 유사도를 반영할 때', {'정밀도': 0.0762}],
#  [393, '개의 유사도를 반영할 때', {'정밀도': 0.0761}],
#  [394, '개의 유사도를 반영할 때', {'정밀도': 0.0761}],
#  [395, '개의 유사도를 반영할 때', {'정밀도': 0.0761}],
#  [396, '개의 유사도를 반영할 때', {'정밀도': 0.0764}],
#  [397, '개의 유사도를 반영할 때', {'정밀도': 0.0763}],
#  [398, '개의 유사도를 반영할 때', {'정밀도': 0.0762}],
#  [399, '개의 유사도를 반영할 때', {'정밀도': 0.076}],
#  [400, '개의 유사도를 반영할 때', {'정밀도': 0.0762}],
#  [401, '개의 유사도를 반영할 때', {'정밀도': 0.0761}],
#  [402, '개의 유사도를 반영할 때', {'정밀도': 0.0761}],
#  [403, '개의 유사도를 반영할 때', {'정밀도': 0.0759}],
#  [404, '개의 유사도를 반영할 때', {'정밀도': 0.0759}],
#  [405, '개의 유사도를 반영할 때', {'정밀도': 0.0757}],
#  [406, '개의 유사도를 반영할 때', {'정밀도': 0.0757}],
#  [407, '개의 유사도를 반영할 때', {'정밀도': 0.0761}],
#  [408, '개의 유사도를 반영할 때', {'정밀도': 0.0761}],
#  [409, '개의 유사도를 반영할 때', {'정밀도': 0.0761}],
#  [410, '개의 유사도를 반영할 때', {'정밀도': 0.0763}],
#  [411, '개의 유사도를 반영할 때', {'정밀도': 0.0762}],
#  [412, '개의 유사도를 반영할 때', {'정밀도': 0.0758}],
#  [413, '개의 유사도를 반영할 때', {'정밀도': 0.0758}],
#  [414, '개의 유사도를 반영할 때', {'정밀도': 0.0759}],
#  [415, '개의 유사도를 반영할 때', {'정밀도': 0.0757}],
#  [416, '개의 유사도를 반영할 때', {'정밀도': 0.0756}],
#  [417, '개의 유사도를 반영할 때', {'정밀도': 0.076}],
#  [418, '개의 유사도를 반영할 때', {'정밀도': 0.0758}],
#  [419, '개의 유사도를 반영할 때', {'정밀도': 0.0756}],
#  [420, '개의 유사도를 반영할 때', {'정밀도': 0.0756}],
#  [421, '개의 유사도를 반영할 때', {'정밀도': 0.0757}],
#  [422, '개의 유사도를 반영할 때', {'정밀도': 0.0756}],
#  [423, '개의 유사도를 반영할 때', {'정밀도': 0.0757}],
#  [424, '개의 유사도를 반영할 때', {'정밀도': 0.0756}],
#  [425, '개의 유사도를 반영할 때', {'정밀도': 0.0755}],
#  [426, '개의 유사도를 반영할 때', {'정밀도': 0.0756}],
#  [427, '개의 유사도를 반영할 때', {'정밀도': 0.0758}],
#  [428, '개의 유사도를 반영할 때', {'정밀도': 0.0756}],
#  [429, '개의 유사도를 반영할 때', {'정밀도': 0.0759}],
#  [430, '개의 유사도를 반영할 때', {'정밀도': 0.0759}],
#  [431, '개의 유사도를 반영할 때', {'정밀도': 0.0755}],
#  [432, '개의 유사도를 반영할 때', {'정밀도': 0.0757}],
#  [433, '개의 유사도를 반영할 때', {'정밀도': 0.0756}],
#  [434, '개의 유사도를 반영할 때', {'정밀도': 0.0757}],
#  [435, '개의 유사도를 반영할 때', {'정밀도': 0.0757}],
#  [436, '개의 유사도를 반영할 때', {'정밀도': 0.0756}],
#  [437, '개의 유사도를 반영할 때', {'정밀도': 0.0759}],
#  [438, '개의 유사도를 반영할 때', {'정밀도': 0.0762}],
#  [439, '개의 유사도를 반영할 때', {'정밀도': 0.0764}],
#  [440, '개의 유사도를 반영할 때', {'정밀도': 0.0762}],
#  [441, '개의 유사도를 반영할 때', {'정밀도': 0.0762}],
#  [442, '개의 유사도를 반영할 때', {'정밀도': 0.0759}],
#  [443, '개의 유사도를 반영할 때', {'정밀도': 0.0759}],
#  [444, '개의 유사도를 반영할 때', {'정밀도': 0.0762}],
#  [445, '개의 유사도를 반영할 때', {'정밀도': 0.0763}],
#  [446, '개의 유사도를 반영할 때', {'정밀도': 0.0763}],
#  [447, '개의 유사도를 반영할 때', {'정밀도': 0.0763}],
#  [448, '개의 유사도를 반영할 때', {'정밀도': 0.0761}],
#  [449, '개의 유사도를 반영할 때', {'정밀도': 0.0759}],
#  [450, '개의 유사도를 반영할 때', {'정밀도': 0.076}]]

# %%
x = [entry[0] for entry in Cust_param]
y = [entry[2]['정밀도'] for entry in Cust_param]

# 꺾은선 그래프 그리기
plt.plot(x, y, marker='o')

plt.title('350~450개의 유사도 반영시 정밀도 변화(고객기반)')
plt.xlabel('유사도 수')
plt.ylabel('정밀도')

# 그래프 표시
plt.grid(True)
plt.show()

print('고객기반 최대 정밀도')
print(x[np.argsort(y)[-1]],'개의 유사도를 반영할 때 정밀도:',max(y))
# Out:
# 고객기반 최대 정밀도
# 396 개의 유사도를 반영할 때 정밀도: 0.0764

# %% [markdown]
# ## 아이템 유사도 기반

# %%
SD_pairs = train[['StockCode','Description']].groupby('StockCode')['Description'].apply(lambda x: list(set(x))).to_dict()
for stockcode, descriptions in SD_pairs.items(): #리스트형태의 데이터를 문자형으로 변환
    SD_pairs[stockcode] = ' '.join(descriptions)

Des_uniq = pd.Series(SD_pairs)
Des_uniq = Des_uniq.str.strip()
def replace_slash_with_space(text): #/를 공백으로 치환하는 함수
    return text.replace('/', ' ')
def remove_extra_spaces(text): #공백을 한칸으로 통일
    return re.sub(r'\s+', ' ', text)
Des_uniq = Des_uniq.apply(replace_slash_with_space)
Des_uniq = Des_uniq.apply(remove_extra_spaces)

# %%
Des_uniq_split = pd.Series(Des_uniq.str.split(" "))
Des_words = [word for sublist in Des_uniq_split for word in sublist]
uniq_words = set(Des_words)

# %%
print('삭제 전 단어 수:',len(uniq_words))

# 영어 불용어 목록
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

def remove_special_characters(text): # 문자, 숫자, 공백을 제외한 모든 문자 삭제
    return re.sub(r'[^a-zA-Z0-9\s]', '', text)

uniq_words = {remove_special_characters(word) for word in uniq_words} # 특수 기호 삭제
uniq_words = {word for word in uniq_words if word.strip()} # 공백 또는 빈 문자열 삭제
uniq_words = {word for word in uniq_words if not word.isdigit()} #숫자 삭제
uniq_words -= stop_words # 불용어 삭제

print('삭제 후 단어 수:',len(uniq_words))
# Out:
# 삭제 전 단어 수: 2265
# 삭제 후 단어 수: 2154
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\oky40\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df_Des = pd.DataFrame()
for word in uniq_words:
    pattern = r'(\b{}\b|^\w+ {}\b|\b{} \w+$)'.format(word, word, word) # 공백이나 문장부호와 함께 등장하는 단어를 포함하는 정규표현식

    # 정규표현식을 사용하여 해당 단어가 Description에 포함되어 있는지 여부를 확인
    df_Des[word] = Des_uniq.str.contains(pattern, regex=True).astype(int)

sim_Des = pd.DataFrame(cosine_similarity(df_Des),index=df_Des.index, columns=df_Des.index)

# %% [markdown]
# ### 50개 단위

# %%
Item_param_50 = []

print(recomm_n,'개 추천')
for i in range(50,4001,50):
    sim = get_topsim(sim_Des, top_n= i)
    pred = pivot_CS.values.dot(sim.values) / np.array([np.abs(sim.values).sum(axis=1)])
    pred = pd.DataFrame(pred, index=pivot_CS.index, columns=pivot_CS.columns)
    result = recomm_model(pred, recomm_n=recomm_n)
    Item_param_50.append([i,'개의 유사도를 반영할 때',result[3]])

print('최대 정밀도',max(Item_param_50, key=lambda x: x[2]['정밀도']))
Item_param_50
# Out:
# 12 개 추천
# 최대 정밀도 [450, '개의 유사도를 반영할 때', {'정밀도': 0.0458}]
# [[50, '개의 유사도를 반영할 때', {'정밀도': 0.0367}],
#  [100, '개의 유사도를 반영할 때', {'정밀도': 0.0325}],
#  [150, '개의 유사도를 반영할 때', {'정밀도': 0.0324}],
#  [200, '개의 유사도를 반영할 때', {'정밀도': 0.0347}],
#  [250, '개의 유사도를 반영할 때', {'정밀도': 0.037}],
#  [300, '개의 유사도를 반영할 때', {'정밀도': 0.0412}],
#  [350, '개의 유사도를 반영할 때', {'정밀도': 0.0441}],
#  [400, '개의 유사도를 반영할 때', {'정밀도': 0.0453}],
#  [450, '개의 유사도를 반영할 때', {'정밀도': 0.0458}],
#  [500, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [550, '개의 유사도를 반영할 때', {'정밀도': 0.0456}],
#  [600, '개의 유사도를 반영할 때', {'정밀도': 0.0456}],
#  [650, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [700, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [750, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [800, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [850, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [900, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [950, '개의 유사도를 반영할 때', {'정밀도': 0.0454}],
#  [1000, '개의 유사도를 반영할 때', {'정밀도': 0.0454}],
#  [1050, '개의 유사도를 반영할 때', {'정밀도': 0.0454}],
#  [1100, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [1150, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [1200, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [1250, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [1300, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [1350, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [1400, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [1450, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [1500, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [1550, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [1600, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [1650, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [1700, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [1750, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [1800, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [1850, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [1900, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [1950, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [2000, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [2050, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [2100, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [2150, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [2200, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [2250, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [2300, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [2350, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [2400, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [2450, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [2500, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [2550, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [2600, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [2650, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [2700, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [2750, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [2800, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [2850, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [2900, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [2950, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [3000, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [3050, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [3100, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [3150, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [3200, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [3250, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [3300, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [3350, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [3400, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [3450, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [3500, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [3550, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [3600, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [3650, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [3700, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [3750, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [3800, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [3850, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [3900, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [3950, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [4000, '개의 유사도를 반영할 때', {'정밀도': 0.0455}]]

# %%
x = [entry[0] for entry in Item_param_50]
y = [entry[2]['정밀도'] for entry in Item_param_50]

# 꺾은선 그래프 그리기
plt.plot(x, y, marker='o')

plt.title('50씩 증가시킬 때 정밀도 변화(아이템기반)')
plt.xlabel('유사도 수')
plt.ylabel('정밀도')

# 그래프 표시
plt.grid(True)
plt.show()

print('아이템기반 최대 정밀도')
print(x[np.argsort(y)[-1]],'개의 유사도를 반영할 때 정밀도:',max(y))
# Out:
# 아이템기반 최대 정밀도
# 450 개의 유사도를 반영할 때 정밀도: 0.0458

# %% [markdown]
# ### 400~500개

# %%
Item_param = []

print(recomm_n,'개 추천')
for i in range(400,501):
    sim = get_topsim(sim_Des, top_n= i)
    pred = pivot_CS.values.dot(sim.values) / np.array([np.abs(sim.values).sum(axis=1)])
    pred = pd.DataFrame(pred, index=pivot_CS.index, columns=pivot_CS.columns)
    result = recomm_model(pred, recomm_n=recomm_n)
    Item_param.append([i,'개의 유사도를 반영할 때',result[3]])
    
print('최대 유사도',max(Item_param, key=lambda x: x[2]['정밀도']))
Item_param
# Out:
# 12 개 추천
# 최대 유사도 [431, '개의 유사도를 반영할 때', {'정밀도': 0.0459}]
# [[400, '개의 유사도를 반영할 때', {'정밀도': 0.0453}],
#  [401, '개의 유사도를 반영할 때', {'정밀도': 0.0453}],
#  [402, '개의 유사도를 반영할 때', {'정밀도': 0.0454}],
#  [403, '개의 유사도를 반영할 때', {'정밀도': 0.0453}],
#  [404, '개의 유사도를 반영할 때', {'정밀도': 0.0452}],
#  [405, '개의 유사도를 반영할 때', {'정밀도': 0.0453}],
#  [406, '개의 유사도를 반영할 때', {'정밀도': 0.0453}],
#  [407, '개의 유사도를 반영할 때', {'정밀도': 0.0453}],
#  [408, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [409, '개의 유사도를 반영할 때', {'정밀도': 0.0454}],
#  [410, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [411, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [412, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [413, '개의 유사도를 반영할 때', {'정밀도': 0.0456}],
#  [414, '개의 유사도를 반영할 때', {'정밀도': 0.0457}],
#  [415, '개의 유사도를 반영할 때', {'정밀도': 0.0457}],
#  [416, '개의 유사도를 반영할 때', {'정밀도': 0.0456}],
#  [417, '개의 유사도를 반영할 때', {'정밀도': 0.0456}],
#  [418, '개의 유사도를 반영할 때', {'정밀도': 0.0456}],
#  [419, '개의 유사도를 반영할 때', {'정밀도': 0.0457}],
#  [420, '개의 유사도를 반영할 때', {'정밀도': 0.0457}],
#  [421, '개의 유사도를 반영할 때', {'정밀도': 0.0458}],
#  [422, '개의 유사도를 반영할 때', {'정밀도': 0.0458}],
#  [423, '개의 유사도를 반영할 때', {'정밀도': 0.0458}],
#  [424, '개의 유사도를 반영할 때', {'정밀도': 0.0458}],
#  [425, '개의 유사도를 반영할 때', {'정밀도': 0.0457}],
#  [426, '개의 유사도를 반영할 때', {'정밀도': 0.0457}],
#  [427, '개의 유사도를 반영할 때', {'정밀도': 0.0458}],
#  [428, '개의 유사도를 반영할 때', {'정밀도': 0.0457}],
#  [429, '개의 유사도를 반영할 때', {'정밀도': 0.0458}],
#  [430, '개의 유사도를 반영할 때', {'정밀도': 0.0457}],
#  [431, '개의 유사도를 반영할 때', {'정밀도': 0.0459}],
#  [432, '개의 유사도를 반영할 때', {'정밀도': 0.0458}],
#  [433, '개의 유사도를 반영할 때', {'정밀도': 0.0459}],
#  [434, '개의 유사도를 반영할 때', {'정밀도': 0.0459}],
#  [435, '개의 유사도를 반영할 때', {'정밀도': 0.0459}],
#  [436, '개의 유사도를 반영할 때', {'정밀도': 0.0459}],
#  [437, '개의 유사도를 반영할 때', {'정밀도': 0.0459}],
#  [438, '개의 유사도를 반영할 때', {'정밀도': 0.0459}],
#  [439, '개의 유사도를 반영할 때', {'정밀도': 0.0458}],
#  [440, '개의 유사도를 반영할 때', {'정밀도': 0.0458}],
#  [441, '개의 유사도를 반영할 때', {'정밀도': 0.0459}],
#  [442, '개의 유사도를 반영할 때', {'정밀도': 0.0458}],
#  [443, '개의 유사도를 반영할 때', {'정밀도': 0.0459}],
#  [444, '개의 유사도를 반영할 때', {'정밀도': 0.0459}],
#  [445, '개의 유사도를 반영할 때', {'정밀도': 0.0459}],
#  [446, '개의 유사도를 반영할 때', {'정밀도': 0.0459}],
#  [447, '개의 유사도를 반영할 때', {'정밀도': 0.0459}],
#  [448, '개의 유사도를 반영할 때', {'정밀도': 0.0459}],
#  [449, '개의 유사도를 반영할 때', {'정밀도': 0.0458}],
#  [450, '개의 유사도를 반영할 때', {'정밀도': 0.0458}],
#  [451, '개의 유사도를 반영할 때', {'정밀도': 0.0458}],
#  [452, '개의 유사도를 반영할 때', {'정밀도': 0.0457}],
#  [453, '개의 유사도를 반영할 때', {'정밀도': 0.0457}],
#  [454, '개의 유사도를 반영할 때', {'정밀도': 0.0457}],
#  [455, '개의 유사도를 반영할 때', {'정밀도': 0.0457}],
#  [456, '개의 유사도를 반영할 때', {'정밀도': 0.0458}],
#  [457, '개의 유사도를 반영할 때', {'정밀도': 0.0457}],
#  [458, '개의 유사도를 반영할 때', {'정밀도': 0.0457}],
#  [459, '개의 유사도를 반영할 때', {'정밀도': 0.0457}],
#  [460, '개의 유사도를 반영할 때', {'정밀도': 0.0457}],
#  [461, '개의 유사도를 반영할 때', {'정밀도': 0.0457}],
#  [462, '개의 유사도를 반영할 때', {'정밀도': 0.0456}],
#  [463, '개의 유사도를 반영할 때', {'정밀도': 0.0457}],
#  [464, '개의 유사도를 반영할 때', {'정밀도': 0.0457}],
#  [465, '개의 유사도를 반영할 때', {'정밀도': 0.0457}],
#  [466, '개의 유사도를 반영할 때', {'정밀도': 0.0456}],
#  [467, '개의 유사도를 반영할 때', {'정밀도': 0.0456}],
#  [468, '개의 유사도를 반영할 때', {'정밀도': 0.0456}],
#  [469, '개의 유사도를 반영할 때', {'정밀도': 0.0457}],
#  [470, '개의 유사도를 반영할 때', {'정밀도': 0.0456}],
#  [471, '개의 유사도를 반영할 때', {'정밀도': 0.0456}],
#  [472, '개의 유사도를 반영할 때', {'정밀도': 0.0456}],
#  [473, '개의 유사도를 반영할 때', {'정밀도': 0.0456}],
#  [474, '개의 유사도를 반영할 때', {'정밀도': 0.0456}],
#  [475, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [476, '개의 유사도를 반영할 때', {'정밀도': 0.0456}],
#  [477, '개의 유사도를 반영할 때', {'정밀도': 0.0456}],
#  [478, '개의 유사도를 반영할 때', {'정밀도': 0.0456}],
#  [479, '개의 유사도를 반영할 때', {'정밀도': 0.0456}],
#  [480, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [481, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [482, '개의 유사도를 반영할 때', {'정밀도': 0.0456}],
#  [483, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [484, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [485, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [486, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [487, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [488, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [489, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [490, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [491, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [492, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [493, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [494, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [495, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [496, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [497, '개의 유사도를 반영할 때', {'정밀도': 0.0455}],
#  [498, '개의 유사도를 반영할 때', {'정밀도': 0.0456}],
#  [499, '개의 유사도를 반영할 때', {'정밀도': 0.0456}],
#  [500, '개의 유사도를 반영할 때', {'정밀도': 0.0455}]]

# %%
x = [entry[0] for entry in Item_param]
y = [entry[2]['정밀도'] for entry in Item_param]

# 꺾은선 그래프 그리기
plt.plot(x, y, marker='o')

plt.title('400~500개의 유사도 반영시 정밀도 변화(아이템기반)')
plt.xlabel('유사도 수')
plt.ylabel('정밀도')

# 그래프 표시
plt.grid(True)
plt.show()

print('아이템기반 최대 정밀도')
print(x[np.argsort(y)[-1]],'개의 유사도를 반영할 때 정밀도:',max(y))
# Out:
# 아이템기반 최대 정밀도
# 436 개의 유사도를 반영할 때 정밀도: 0.0459

# %% [markdown]
# ## 종합모델
# - 주문 유사도 417개 반영
# - 고객 유사도 396개 반영
# - 아이템 유사도 436개 반영

# %%
pred_IS = predict_count(pivot_IS, get_topsim(sim_Inv, top_n = 417), IS = True)
pred_CS = predict_count(pivot_CS, get_topsim(sim_Cust, top_n = 396))

topsim_Des = get_topsim(sim_Des, top_n= 436)
pred_Des = pivot_CS.values.dot(topsim_Des.values) / np.array([np.abs(topsim_Des.values).sum(axis=1)])
pred_Des = pd.DataFrame(pred_Des, index=pivot_CS.index, columns=pivot_CS.columns)

# %%
print(recomm_model(pred_IS, recomm_n = recomm_n)[3])
print(recomm_model(pred_CS, recomm_n = recomm_n)[3])
print(recomm_model(pred_Des, recomm_n = recomm_n)[3])
# Out:
# {'정밀도': 0.1179}
# {'정밀도': 0.0764}
# {'정밀도': 0.0459}

# %%
total_param = [] 

# 첫 번째 숫자 선택
for num1 in range(101): #2601번 실행
    # 두 번째 숫자 선택
    for num2 in range(num1 + 1):
        # 세 번째 숫자는 첫 번째와 두 번째 숫자를 뺀 나머지
        num3 = 100 - num1 - num2
        # 세 번째 숫자가 음수가 되면 다음 순서로 넘어감
        if num3 < 0:
            continue

        num_1 = num1/100
        num_2 = num2/100
        num_3 = num3/100

        precision = recomm_model((num_1*pred_IS + num_2*pred_CS + num_3*pred_Des), recomm_n = recomm_n)[3]
        total_param.append(['가중치 비율',[num_1, num_2, num_3], precision])

        print('가중치 비율',[num_1, num_2, num_3], precision)
        
print('\n 최대 정밀도:', max(total_param, key=lambda x: x[2]['정밀도']))
# Out:
# 가중치 비율 [0.0, 0.0, 1.0] {'정밀도': 0.0459}
# 가중치 비율 [0.01, 0.0, 0.99] {'정밀도': 0.0466}
# 가중치 비율 [0.01, 0.01, 0.98] {'정밀도': 0.0471}
# 가중치 비율 [0.02, 0.0, 0.98] {'정밀도': 0.0474}
# 가중치 비율 [0.02, 0.01, 0.97] {'정밀도': 0.0476}
# 가중치 비율 [0.02, 0.02, 0.96] {'정밀도': 0.0481}
# 가중치 비율 [0.03, 0.0, 0.97] {'정밀도': 0.0479}
# 가중치 비율 [0.03, 0.01, 0.96] {'정밀도': 0.0482}
# 가중치 비율 [0.03, 0.02, 0.95] {'정밀도': 0.0489}
# 가중치 비율 [0.03, 0.03, 0.94] {'정밀도': 0.0497}
# 가중치 비율 [0.04, 0.0, 0.96] {'정밀도': 0.0484}
# 가중치 비율 [0.04, 0.01, 0.95] {'정밀도': 0.049}
# 가중치 비율 [0.04, 0.02, 0.94] {'정밀도': 0.0498}
# 가중치 비율 [0.04, 0.03, 0.93] {'정밀도': 0.0504}
# 가중치 비율 [0.04, 0.04, 0.92] {'정밀도': 0.0512}
# 가중치 비율 [0.05, 0.0, 0.95] {'정밀도': 0.0491}
# 가중치 비율 [0.05, 0.01, 0.94] {'정밀도': 0.0497}
# 가중치 비율 [0.05, 0.02, 0.93] {'정밀도': 0.0503}
# 가중치 비율 [0.05, 0.03, 0.92] {'정밀도': 0.051}
# 가중치 비율 [0.05, 0.04, 0.91] {'정밀도': 0.0517}
# 가중치 비율 [0.05, 0.05, 0.9] {'정밀도': 0.0524}
# 가중치 비율 [0.06, 0.0, 0.94] {'정밀도': 0.0499}
# 가중치 비율 [0.06, 0.01, 0.93] {'정밀도': 0.0503}
# 가중치 비율 [0.06, 0.02, 0.92] {'정밀도': 0.0511}
# 가중치 비율 [0.06, 0.03, 0.91] {'정밀도': 0.0519}
# 가중치 비율 [0.06, 0.04, 0.9] {'정밀도': 0.0526}
# 가중치 비율 [0.06, 0.05, 0.89] {'정밀도': 0.0531}
# 가중치 비율 [0.06, 0.06, 0.88] {'정밀도': 0.0535}
# 가중치 비율 [0.07, 0.0, 0.93] {'정밀도': 0.0508}
# 가중치 비율 [0.07, 0.01, 0.92] {'정밀도': 0.0513}
# 가중치 비율 [0.07, 0.02, 0.91] {'정밀도': 0.052}
# 가중치 비율 [0.07, 0.03, 0.9] {'정밀도': 0.0525}
# 가중치 비율 [0.07, 0.04, 0.89] {'정밀도': 0.0531}
# 가중치 비율 [0.07, 0.05, 0.88] {'정밀도': 0.0536}
# 가중치 비율 [0.07, 0.06, 0.87] {'정밀도': 0.0537}
# 가중치 비율 [0.07, 0.07, 0.86] {'정밀도': 0.054}
# 가중치 비율 [0.08, 0.0, 0.92] {'정밀도': 0.0514}
# 가중치 비율 [0.08, 0.01, 0.91] {'정밀도': 0.0519}
# 가중치 비율 [0.08, 0.02, 0.9] {'정밀도': 0.0525}
# 가중치 비율 [0.08, 0.03, 0.89] {'정밀도': 0.0531}
# 가중치 비율 [0.08, 0.04, 0.88] {'정밀도': 0.0535}
# 가중치 비율 [0.08, 0.05, 0.87] {'정밀도': 0.054}
# 가중치 비율 [0.08, 0.06, 0.86] {'정밀도': 0.0543}
# 가중치 비율 [0.08, 0.07, 0.85] {'정밀도': 0.0547}
# 가중치 비율 [0.08, 0.08, 0.84] {'정밀도': 0.0557}
# 가중치 비율 [0.09, 0.0, 0.91] {'정밀도': 0.0517}
# 가중치 비율 [0.09, 0.01, 0.9] {'정밀도': 0.0523}
# 가중치 비율 [0.09, 0.02, 0.89] {'정밀도': 0.053}
# 가중치 비율 [0.09, 0.03, 0.88] {'정밀도': 0.0536}
# 가중치 비율 [0.09, 0.04, 0.87] {'정밀도': 0.0544}
# 가중치 비율 [0.09, 0.05, 0.86] {'정밀도': 0.055}
# 가중치 비율 [0.09, 0.06, 0.85] {'정밀도': 0.0556}
# 가중치 비율 [0.09, 0.07, 0.84] {'정밀도': 0.0559}
# 가중치 비율 [0.09, 0.08, 0.83] {'정밀도': 0.0563}
# 가중치 비율 [0.09, 0.09, 0.82] {'정밀도': 0.0569}
# 가중치 비율 [0.1, 0.0, 0.9] {'정밀도': 0.0523}
# 가중치 비율 [0.1, 0.01, 0.89] {'정밀도': 0.0529}
# 가중치 비율 [0.1, 0.02, 0.88] {'정밀도': 0.0539}
# 가중치 비율 [0.1, 0.03, 0.87] {'정밀도': 0.0546}
# 가중치 비율 [0.1, 0.04, 0.86] {'정밀도': 0.0552}
# 가중치 비율 [0.1, 0.05, 0.85] {'정밀도': 0.0558}
# 가중치 비율 [0.1, 0.06, 0.84] {'정밀도': 0.0562}
# 가중치 비율 [0.1, 0.07, 0.83] {'정밀도': 0.0563}
# 가중치 비율 [0.1, 0.08, 0.82] {'정밀도': 0.0569}
# 가중치 비율 [0.1, 0.09, 0.81] {'정밀도': 0.0574}
# 가중치 비율 [0.1, 0.1, 0.8] {'정밀도': 0.0582}
# 가중치 비율 [0.11, 0.0, 0.89] {'정밀도': 0.053}
# 가중치 비율 [0.11, 0.01, 0.88] {'정밀도': 0.0538}
# 가중치 비율 [0.11, 0.02, 0.87] {'정밀도': 0.0547}
# 가중치 비율 [0.11, 0.03, 0.86] {'정밀도': 0.0553}
# 가중치 비율 [0.11, 0.04, 0.85] {'정밀도': 0.0558}
# 가중치 비율 [0.11, 0.05, 0.84] {'정밀도': 0.0565}
# 가중치 비율 [0.11, 0.06, 0.83] {'정밀도': 0.0568}
# 가중치 비율 [0.11, 0.07, 0.82] {'정밀도': 0.0573}
# 가중치 비율 [0.11, 0.08, 0.81] {'정밀도': 0.0578}
# 가중치 비율 [0.11, 0.09, 0.8] {'정밀도': 0.0585}
# 가중치 비율 [0.11, 0.1, 0.79] {'정밀도': 0.0591}
# 가중치 비율 [0.11, 0.11, 0.78] {'정밀도': 0.0602}
# 가중치 비율 [0.12, 0.0, 0.88] {'정밀도': 0.0541}
# 가중치 비율 [0.12, 0.01, 0.87] {'정밀도': 0.0548}
# 가중치 비율 [0.12, 0.02, 0.86] {'정밀도': 0.0556}
# 가중치 비율 [0.12, 0.03, 0.85] {'정밀도': 0.0562}
# 가중치 비율 [0.12, 0.04, 0.84] {'정밀도': 0.0567}
# 가중치 비율 [0.12, 0.05, 0.83] {'정밀도': 0.0573}
# 가중치 비율 [0.12, 0.06, 0.82] {'정밀도': 0.0576}
# 가중치 비율 [0.12, 0.07, 0.81] {'정밀도': 0.0581}
# 가중치 비율 [0.12, 0.08, 0.8] {'정밀도': 0.0586}
# 가중치 비율 [0.12, 0.09, 0.79] {'정밀도': 0.0594}
# 가중치 비율 [0.12, 0.1, 0.78] {'정밀도': 0.06}
# 가중치 비율 [0.12, 0.11, 0.77] {'정밀도': 0.061}
# 가중치 비율 [0.12, 0.12, 0.76] {'정밀도': 0.0618}
# 가중치 비율 [0.13, 0.0, 0.87] {'정밀도': 0.055}
# 가중치 비율 [0.13, 0.01, 0.86] {'정밀도': 0.0556}
# 가중치 비율 [0.13, 0.02, 0.85] {'정밀도': 0.0562}
# 가중치 비율 [0.13, 0.03, 0.84] {'정밀도': 0.0567}
# 가중치 비율 [0.13, 0.04, 0.83] {'정밀도': 0.0572}
# 가중치 비율 [0.13, 0.05, 0.82] {'정밀도': 0.0578}
# 가중치 비율 [0.13, 0.06, 0.81] {'정밀도': 0.0583}
# 가중치 비율 [0.13, 0.07, 0.8] {'정밀도': 0.0592}
# 가중치 비율 [0.13, 0.08, 0.79] {'정밀도': 0.0599}
# 가중치 비율 [0.13, 0.09, 0.78] {'정밀도': 0.0604}
# 가중치 비율 [0.13, 0.1, 0.77] {'정밀도': 0.0611}
# 가중치 비율 [0.13, 0.11, 0.76] {'정밀도': 0.0619}
# 가중치 비율 [0.13, 0.12, 0.75] {'정밀도': 0.0631}
# 가중치 비율 [0.13, 0.13, 0.74] {'정밀도': 0.0639}
# 가중치 비율 [0.14, 0.0, 0.86] {'정밀도': 0.0556}
# 가중치 비율 [0.14, 0.01, 0.85] {'정밀도': 0.0562}
# 가중치 비율 [0.14, 0.02, 0.84] {'정밀도': 0.0568}
# 가중치 비율 [0.14, 0.03, 0.83] {'정밀도': 0.0574}
# 가중치 비율 [0.14, 0.04, 0.82] {'정밀도': 0.0583}
# 가중치 비율 [0.14, 0.05, 0.81] {'정밀도': 0.0589}
# 가중치 비율 [0.14, 0.06, 0.8] {'정밀도': 0.0596}
# 가중치 비율 [0.14, 0.07, 0.79] {'정밀도': 0.0601}
# 가중치 비율 [0.14, 0.08, 0.78] {'정밀도': 0.0609}
# 가중치 비율 [0.14, 0.09, 0.77] {'정밀도': 0.0615}
# 가중치 비율 [0.14, 0.1, 0.76] {'정밀도': 0.0623}
# 가중치 비율 [0.14, 0.11, 0.75] {'정밀도': 0.0636}
# 가중치 비율 [0.14, 0.12, 0.74] {'정밀도': 0.0643}
# 가중치 비율 [0.14, 0.13, 0.73] {'정밀도': 0.0648}
# 가중치 비율 [0.14, 0.14, 0.72] {'정밀도': 0.066}
# 가중치 비율 [0.15, 0.0, 0.85] {'정밀도': 0.0566}
# 가중치 비율 [0.15, 0.01, 0.84] {'정밀도': 0.0569}
# 가중치 비율 [0.15, 0.02, 0.83] {'정밀도': 0.0576}
# 가중치 비율 [0.15, 0.03, 0.82] {'정밀도': 0.0582}
# 가중치 비율 [0.15, 0.04, 0.81] {'정밀도': 0.0592}
# 가중치 비율 [0.15, 0.05, 0.8] {'정밀도': 0.0598}
# 가중치 비율 [0.15, 0.06, 0.79] {'정밀도': 0.0603}
# 가중치 비율 [0.15, 0.07, 0.78] {'정밀도': 0.0611}
# 가중치 비율 [0.15, 0.08, 0.77] {'정밀도': 0.0619}
# 가중치 비율 [0.15, 0.09, 0.76] {'정밀도': 0.0628}
# 가중치 비율 [0.15, 0.1, 0.75] {'정밀도': 0.0635}
# 가중치 비율 [0.15, 0.11, 0.74] {'정밀도': 0.0645}
# 가중치 비율 [0.15, 0.12, 0.73] {'정밀도': 0.0653}
# 가중치 비율 [0.15, 0.13, 0.72] {'정밀도': 0.0662}
# 가중치 비율 [0.15, 0.14, 0.71] {'정밀도': 0.0675}
# 가중치 비율 [0.15, 0.15, 0.7] {'정밀도': 0.0681}
# 가중치 비율 [0.16, 0.0, 0.84] {'정밀도': 0.0571}
# 가중치 비율 [0.16, 0.01, 0.83] {'정밀도': 0.0576}
# 가중치 비율 [0.16, 0.02, 0.82] {'정밀도': 0.0583}
# 가중치 비율 [0.16, 0.03, 0.81] {'정밀도': 0.0595}
# 가중치 비율 [0.16, 0.04, 0.8] {'정밀도': 0.0601}
# 가중치 비율 [0.16, 0.05, 0.79] {'정밀도': 0.0605}
# 가중치 비율 [0.16, 0.06, 0.78] {'정밀도': 0.0613}
# 가중치 비율 [0.16, 0.07, 0.77] {'정밀도': 0.0623}
# 가중치 비율 [0.16, 0.08, 0.76] {'정밀도': 0.0632}
# 가중치 비율 [0.16, 0.09, 0.75] {'정밀도': 0.0638}
# 가중치 비율 [0.16, 0.1, 0.74] {'정밀도': 0.0648}
# 가중치 비율 [0.16, 0.11, 0.73] {'정밀도': 0.0655}
# 가중치 비율 [0.16, 0.12, 0.72] {'정밀도': 0.0667}
# 가중치 비율 [0.16, 0.13, 0.71] {'정밀도': 0.0676}
# 가중치 비율 [0.16, 0.14, 0.7] {'정밀도': 0.0687}
# 가중치 비율 [0.16, 0.15, 0.69] {'정밀도': 0.0697}
# 가중치 비율 [0.16, 0.16, 0.68] {'정밀도': 0.0704}
# 가중치 비율 [0.17, 0.0, 0.83] {'정밀도': 0.0579}
# 가중치 비율 [0.17, 0.01, 0.82] {'정밀도': 0.0585}
# 가중치 비율 [0.17, 0.02, 0.81] {'정밀도': 0.0595}
# 가중치 비율 [0.17, 0.03, 0.8] {'정밀도': 0.0605}
# 가중치 비율 [0.17, 0.04, 0.79] {'정밀도': 0.0612}
# 가중치 비율 [0.17, 0.05, 0.78] {'정밀도': 0.0618}
# 가중치 비율 [0.17, 0.06, 0.77] {'정밀도': 0.0623}
# 가중치 비율 [0.17, 0.07, 0.76] {'정밀도': 0.0631}
# 가중치 비율 [0.17, 0.08, 0.75] {'정밀도': 0.064}
# 가중치 비율 [0.17, 0.09, 0.74] {'정밀도': 0.0649}
# 가중치 비율 [0.17, 0.1, 0.73] {'정밀도': 0.066}
# 가중치 비율 [0.17, 0.11, 0.72] {'정밀도': 0.067}
# 가중치 비율 [0.17, 0.12, 0.71] {'정밀도': 0.0682}
# 가중치 비율 [0.17, 0.13, 0.7] {'정밀도': 0.0688}
# 가중치 비율 [0.17, 0.14, 0.69] {'정밀도': 0.0698}
# 가중치 비율 [0.17, 0.15, 0.68] {'정밀도': 0.0706}
# 가중치 비율 [0.17, 0.16, 0.67] {'정밀도': 0.0717}
# 가중치 비율 [0.17, 0.17, 0.66] {'정밀도': 0.0729}
# 가중치 비율 [0.18, 0.0, 0.82] {'정밀도': 0.0588}
# 가중치 비율 [0.18, 0.01, 0.81] {'정밀도': 0.0597}
# 가중치 비율 [0.18, 0.02, 0.8] {'정밀도': 0.0604}
# 가중치 비율 [0.18, 0.03, 0.79] {'정밀도': 0.0613}
# 가중치 비율 [0.18, 0.04, 0.78] {'정밀도': 0.0621}
# 가중치 비율 [0.18, 0.05, 0.77] {'정밀도': 0.0627}
# 가중치 비율 [0.18, 0.06, 0.76] {'정밀도': 0.0632}
# 가중치 비율 [0.18, 0.07, 0.75] {'정밀도': 0.0642}
# 가중치 비율 [0.18, 0.08, 0.74] {'정밀도': 0.0651}
# 가중치 비율 [0.18, 0.09, 0.73] {'정밀도': 0.0661}
# 가중치 비율 [0.18, 0.1, 0.72] {'정밀도': 0.0672}
# 가중치 비율 [0.18, 0.11, 0.71] {'정밀도': 0.0682}
# 가중치 비율 [0.18, 0.12, 0.7] {'정밀도': 0.0689}
# 가중치 비율 [0.18, 0.13, 0.69] {'정밀도': 0.0695}
# 가중치 비율 [0.18, 0.14, 0.68] {'정밀도': 0.0706}
# 가중치 비율 [0.18, 0.15, 0.67] {'정밀도': 0.0718}
# 가중치 비율 [0.18, 0.16, 0.66] {'정밀도': 0.0731}
# 가중치 비율 [0.18, 0.17, 0.65] {'정밀도': 0.0743}
# 가중치 비율 [0.18, 0.18, 0.64] {'정밀도': 0.0759}
# 가중치 비율 [0.19, 0.0, 0.81] {'정밀도': 0.0596}
# 가중치 비율 [0.19, 0.01, 0.8] {'정밀도': 0.0608}
# 가중치 비율 [0.19, 0.02, 0.79] {'정밀도': 0.0615}
# 가중치 비율 [0.19, 0.03, 0.78] {'정밀도': 0.0621}
# 가중치 비율 [0.19, 0.04, 0.77] {'정밀도': 0.0629}
# 가중치 비율 [0.19, 0.05, 0.76] {'정밀도': 0.0635}
# 가중치 비율 [0.19, 0.06, 0.75] {'정밀도': 0.0642}
# 가중치 비율 [0.19, 0.07, 0.74] {'정밀도': 0.0653}
# 가중치 비율 [0.19, 0.08, 0.73] {'정밀도': 0.0663}
# 가중치 비율 [0.19, 0.09, 0.72] {'정밀도': 0.0673}
# 가중치 비율 [0.19, 0.1, 0.71] {'정밀도': 0.0682}
# 가중치 비율 [0.19, 0.11, 0.7] {'정밀도': 0.069}
# 가중치 비율 [0.19, 0.12, 0.69] {'정밀도': 0.0698}
# 가중치 비율 [0.19, 0.13, 0.68] {'정밀도': 0.0706}
# 가중치 비율 [0.19, 0.14, 0.67] {'정밀도': 0.0717}
# 가중치 비율 [0.19, 0.15, 0.66] {'정밀도': 0.0734}
# 가중치 비율 [0.19, 0.16, 0.65] {'정밀도': 0.0746}
# 가중치 비율 [0.19, 0.17, 0.64] {'정밀도': 0.0757}
# 가중치 비율 [0.19, 0.18, 0.63] {'정밀도': 0.0772}
# 가중치 비율 [0.19, 0.19, 0.62] {'정밀도': 0.0783}
# 가중치 비율 [0.2, 0.0, 0.8] {'정밀도': 0.0607}
# 가중치 비율 [0.2, 0.01, 0.79] {'정밀도': 0.0615}
# 가중치 비율 [0.2, 0.02, 0.78] {'정밀도': 0.0624}
# 가중치 비율 [0.2, 0.03, 0.77] {'정밀도': 0.0632}
# 가중치 비율 [0.2, 0.04, 0.76] {'정밀도': 0.0637}
# 가중치 비율 [0.2, 0.05, 0.75] {'정밀도': 0.0644}
# 가중치 비율 [0.2, 0.06, 0.74] {'정밀도': 0.0652}
# 가중치 비율 [0.2, 0.07, 0.73] {'정밀도': 0.0663}
# 가중치 비율 [0.2, 0.08, 0.72] {'정밀도': 0.0672}
# 가중치 비율 [0.2, 0.09, 0.71] {'정밀도': 0.0682}
# 가중치 비율 [0.2, 0.1, 0.7] {'정밀도': 0.0691}
# 가중치 비율 [0.2, 0.11, 0.69] {'정밀도': 0.0699}
# 가중치 비율 [0.2, 0.12, 0.68] {'정밀도': 0.0707}
# 가중치 비율 [0.2, 0.13, 0.67] {'정밀도': 0.0721}
# 가중치 비율 [0.2, 0.14, 0.66] {'정밀도': 0.0734}
# 가중치 비율 [0.2, 0.15, 0.65] {'정밀도': 0.0748}
# 가중치 비율 [0.2, 0.16, 0.64] {'정밀도': 0.0761}
# 가중치 비율 [0.2, 0.17, 0.63] {'정밀도': 0.0772}
# 가중치 비율 [0.2, 0.18, 0.62] {'정밀도': 0.0782}
# 가중치 비율 [0.2, 0.19, 0.61] {'정밀도': 0.0794}
# 가중치 비율 [0.2, 0.2, 0.6] {'정밀도': 0.0806}
# 가중치 비율 [0.21, 0.0, 0.79] {'정밀도': 0.0615}
# 가중치 비율 [0.21, 0.01, 0.78] {'정밀도': 0.0623}
# 가중치 비율 [0.21, 0.02, 0.77] {'정밀도': 0.0632}
# 가중치 비율 [0.21, 0.03, 0.76] {'정밀도': 0.064}
# 가중치 비율 [0.21, 0.04, 0.75] {'정밀도': 0.0649}
# 가중치 비율 [0.21, 0.05, 0.74] {'정밀도': 0.0654}
# 가중치 비율 [0.21, 0.06, 0.73] {'정밀도': 0.0663}
# 가중치 비율 [0.21, 0.07, 0.72] {'정밀도': 0.0672}
# 가중치 비율 [0.21, 0.08, 0.71] {'정밀도': 0.0681}
# 가중치 비율 [0.21, 0.09, 0.7] {'정밀도': 0.0691}
# 가중치 비율 [0.21, 0.1, 0.69] {'정밀도': 0.0702}
# 가중치 비율 [0.21, 0.11, 0.68] {'정밀도': 0.0712}
# 가중치 비율 [0.21, 0.12, 0.67] {'정밀도': 0.0721}
# 가중치 비율 [0.21, 0.13, 0.66] {'정밀도': 0.0735}
# 가중치 비율 [0.21, 0.14, 0.65] {'정밀도': 0.0753}
# 가중치 비율 [0.21, 0.15, 0.64] {'정밀도': 0.0763}
# 가중치 비율 [0.21, 0.16, 0.63] {'정밀도': 0.0772}
# 가중치 비율 [0.21, 0.17, 0.62] {'정밀도': 0.0785}
# 가중치 비율 [0.21, 0.18, 0.61] {'정밀도': 0.0794}
# 가중치 비율 [0.21, 0.19, 0.6] {'정밀도': 0.0806}
# 가중치 비율 [0.21, 0.2, 0.59] {'정밀도': 0.0818}
# 가중치 비율 [0.21, 0.21, 0.58] {'정밀도': 0.0833}
# 가중치 비율 [0.22, 0.0, 0.78] {'정밀도': 0.0624}
# 가중치 비율 [0.22, 0.01, 0.77] {'정밀도': 0.0632}
# 가중치 비율 [0.22, 0.02, 0.76] {'정밀도': 0.0639}
# 가중치 비율 [0.22, 0.03, 0.75] {'정밀도': 0.0651}
# 가중치 비율 [0.22, 0.04, 0.74] {'정밀도': 0.0658}
# 가중치 비율 [0.22, 0.05, 0.73] {'정밀도': 0.0665}
# 가중치 비율 [0.22, 0.06, 0.72] {'정밀도': 0.0673}
# 가중치 비율 [0.22, 0.07, 0.71] {'정밀도': 0.0686}
# 가중치 비율 [0.22, 0.08, 0.7] {'정밀도': 0.0697}
# 가중치 비율 [0.22, 0.09, 0.69] {'정밀도': 0.0706}
# 가중치 비율 [0.22, 0.1, 0.68] {'정밀도': 0.0714}
# 가중치 비율 [0.22, 0.11, 0.67] {'정밀도': 0.0724}
# 가중치 비율 [0.22, 0.12, 0.66] {'정밀도': 0.0737}
# 가중치 비율 [0.22, 0.13, 0.65] {'정밀도': 0.0751}
# 가중치 비율 [0.22, 0.14, 0.64] {'정밀도': 0.0761}
# 가중치 비율 [0.22, 0.15, 0.63] {'정밀도': 0.0774}
# 가중치 비율 [0.22, 0.16, 0.62] {'정밀도': 0.0781}
# 가중치 비율 [0.22, 0.17, 0.61] {'정밀도': 0.0794}
# 가중치 비율 [0.22, 0.18, 0.6] {'정밀도': 0.0807}
# 가중치 비율 [0.22, 0.19, 0.59] {'정밀도': 0.082}
# 가중치 비율 [0.22, 0.2, 0.58] {'정밀도': 0.0836}
# 가중치 비율 [0.22, 0.21, 0.57] {'정밀도': 0.0847}
# 가중치 비율 [0.22, 0.22, 0.56] {'정밀도': 0.0856}
# 가중치 비율 [0.23, 0.0, 0.77] {'정밀도': 0.0634}
# 가중치 비율 [0.23, 0.01, 0.76] {'정밀도': 0.0642}
# 가중치 비율 [0.23, 0.02, 0.75] {'정밀도': 0.0649}
# 가중치 비율 [0.23, 0.03, 0.74] {'정밀도': 0.0661}
# 가중치 비율 [0.23, 0.04, 0.73] {'정밀도': 0.0669}
# 가중치 비율 [0.23, 0.05, 0.72] {'정밀도': 0.0678}
# 가중치 비율 [0.23, 0.06, 0.71] {'정밀도': 0.0687}
# 가중치 비율 [0.23, 0.07, 0.7] {'정밀도': 0.0698}
# 가중치 비율 [0.23, 0.08, 0.69] {'정밀도': 0.0707}
# 가중치 비율 [0.23, 0.09, 0.68] {'정밀도': 0.0717}
# 가중치 비율 [0.23, 0.1, 0.67] {'정밀도': 0.0724}
# 가중치 비율 [0.23, 0.11, 0.66] {'정밀도': 0.0739}
# 가중치 비율 [0.23, 0.12, 0.65] {'정밀도': 0.0751}
# 가중치 비율 [0.23, 0.13, 0.64] {'정밀도': 0.0766}
# 가중치 비율 [0.23, 0.14, 0.63] {'정밀도': 0.077}
# 가중치 비율 [0.23, 0.15, 0.62] {'정밀도': 0.0782}
# 가중치 비율 [0.23, 0.16, 0.61] {'정밀도': 0.0793}
# 가중치 비율 [0.23, 0.17, 0.6] {'정밀도': 0.0811}
# 가중치 비율 [0.23, 0.18, 0.59] {'정밀도': 0.0821}
# 가중치 비율 [0.23, 0.19, 0.58] {'정밀도': 0.0836}
# 가중치 비율 [0.23, 0.2, 0.57] {'정밀도': 0.0847}
# 가중치 비율 [0.23, 0.21, 0.56] {'정밀도': 0.0863}
# 가중치 비율 [0.23, 0.22, 0.55] {'정밀도': 0.0869}
# 가중치 비율 [0.23, 0.23, 0.54] {'정밀도': 0.0877}
# 가중치 비율 [0.24, 0.0, 0.76] {'정밀도': 0.0644}
# 가중치 비율 [0.24, 0.01, 0.75] {'정밀도': 0.0653}
# 가중치 비율 [0.24, 0.02, 0.74] {'정밀도': 0.0664}
# 가중치 비율 [0.24, 0.03, 0.73] {'정밀도': 0.0674}
# 가중치 비율 [0.24, 0.04, 0.72] {'정밀도': 0.0681}
# 가중치 비율 [0.24, 0.05, 0.71] {'정밀도': 0.069}
# 가중치 비율 [0.24, 0.06, 0.7] {'정밀도': 0.0702}
# 가중치 비율 [0.24, 0.07, 0.69] {'정밀도': 0.0707}
# 가중치 비율 [0.24, 0.08, 0.68] {'정밀도': 0.0715}
# 가중치 비율 [0.24, 0.09, 0.67] {'정밀도': 0.0729}
# 가중치 비율 [0.24, 0.1, 0.66] {'정밀도': 0.0738}
# 가중치 비율 [0.24, 0.11, 0.65] {'정밀도': 0.075}
# 가중치 비율 [0.24, 0.12, 0.64] {'정밀도': 0.0768}
# 가중치 비율 [0.24, 0.13, 0.63] {'정밀도': 0.0772}
# 가중치 비율 [0.24, 0.14, 0.62] {'정밀도': 0.0783}
# 가중치 비율 [0.24, 0.15, 0.61] {'정밀도': 0.0795}
# 가중치 비율 [0.24, 0.16, 0.6] {'정밀도': 0.081}
# 가중치 비율 [0.24, 0.17, 0.59] {'정밀도': 0.0823}
# 가중치 비율 [0.24, 0.18, 0.58] {'정밀도': 0.0837}
# 가중치 비율 [0.24, 0.19, 0.57] {'정밀도': 0.0849}
# 가중치 비율 [0.24, 0.2, 0.56] {'정밀도': 0.086}
# 가중치 비율 [0.24, 0.21, 0.55] {'정밀도': 0.087}
# 가중치 비율 [0.24, 0.22, 0.54] {'정밀도': 0.0875}
# 가중치 비율 [0.24, 0.23, 0.53] {'정밀도': 0.0886}
# 가중치 비율 [0.24, 0.24, 0.52] {'정밀도': 0.0891}
# 가중치 비율 [0.25, 0.0, 0.75] {'정밀도': 0.0655}
# 가중치 비율 [0.25, 0.01, 0.74] {'정밀도': 0.0665}
# 가중치 비율 [0.25, 0.02, 0.73] {'정밀도': 0.0675}
# 가중치 비율 [0.25, 0.03, 0.72] {'정밀도': 0.0681}
# 가중치 비율 [0.25, 0.04, 0.71] {'정밀도': 0.0691}
# 가중치 비율 [0.25, 0.05, 0.7] {'정밀도': 0.07}
# 가중치 비율 [0.25, 0.06, 0.69] {'정밀도': 0.071}
# 가중치 비율 [0.25, 0.07, 0.68] {'정밀도': 0.0716}
# 가중치 비율 [0.25, 0.08, 0.67] {'정밀도': 0.0729}
# 가중치 비율 [0.25, 0.09, 0.66] {'정밀도': 0.0738}
# 가중치 비율 [0.25, 0.1, 0.65] {'정밀도': 0.075}
# 가중치 비율 [0.25, 0.11, 0.64] {'정밀도': 0.0767}
# 가중치 비율 [0.25, 0.12, 0.63] {'정밀도': 0.0773}
# 가중치 비율 [0.25, 0.13, 0.62] {'정밀도': 0.0785}
# 가중치 비율 [0.25, 0.14, 0.61] {'정밀도': 0.08}
# 가중치 비율 [0.25, 0.15, 0.6] {'정밀도': 0.0811}
# 가중치 비율 [0.25, 0.16, 0.59] {'정밀도': 0.0824}
# 가중치 비율 [0.25, 0.17, 0.58] {'정밀도': 0.0838}
# 가중치 비율 [0.25, 0.18, 0.57] {'정밀도': 0.085}
# 가중치 비율 [0.25, 0.19, 0.56] {'정밀도': 0.0859}
# 가중치 비율 [0.25, 0.2, 0.55] {'정밀도': 0.0871}
# 가중치 비율 [0.25, 0.21, 0.54] {'정밀도': 0.0879}
# 가중치 비율 [0.25, 0.22, 0.53] {'정밀도': 0.0883}
# 가중치 비율 [0.25, 0.23, 0.52] {'정밀도': 0.0892}
# 가중치 비율 [0.25, 0.24, 0.51] {'정밀도': 0.0904}
# 가중치 비율 [0.25, 0.25, 0.5] {'정밀도': 0.0912}
# 가중치 비율 [0.26, 0.0, 0.74] {'정밀도': 0.0665}
# 가중치 비율 [0.26, 0.01, 0.73] {'정밀도': 0.0672}
# 가중치 비율 [0.26, 0.02, 0.72] {'정밀도': 0.0681}
# 가중치 비율 [0.26, 0.03, 0.71] {'정밀도': 0.0693}
# 가중치 비율 [0.26, 0.04, 0.7] {'정밀도': 0.0703}
# 가중치 비율 [0.26, 0.05, 0.69] {'정밀도': 0.0712}
# 가중치 비율 [0.26, 0.06, 0.68] {'정밀도': 0.0718}
# 가중치 비율 [0.26, 0.07, 0.67] {'정밀도': 0.0727}
# 가중치 비율 [0.26, 0.08, 0.66] {'정밀도': 0.074}
# 가중치 비율 [0.26, 0.09, 0.65] {'정밀도': 0.0753}
# 가중치 비율 [0.26, 0.1, 0.64] {'정밀도': 0.0765}
# 가중치 비율 [0.26, 0.11, 0.63] {'정밀도': 0.0777}
# 가중치 비율 [0.26, 0.12, 0.62] {'정밀도': 0.0788}
# 가중치 비율 [0.26, 0.13, 0.61] {'정밀도': 0.0801}
# 가중치 비율 [0.26, 0.14, 0.6] {'정밀도': 0.0815}
# 가중치 비율 [0.26, 0.15, 0.59] {'정밀도': 0.0827}
# 가중치 비율 [0.26, 0.16, 0.58] {'정밀도': 0.0839}
# 가중치 비율 [0.26, 0.17, 0.57] {'정밀도': 0.085}
# 가중치 비율 [0.26, 0.18, 0.56] {'정밀도': 0.0862}
# 가중치 비율 [0.26, 0.19, 0.55] {'정밀도': 0.0869}
# 가중치 비율 [0.26, 0.2, 0.54] {'정밀도': 0.0883}
# 가중치 비율 [0.26, 0.21, 0.53] {'정밀도': 0.089}
# 가중치 비율 [0.26, 0.22, 0.52] {'정밀도': 0.0897}
# 가중치 비율 [0.26, 0.23, 0.51] {'정밀도': 0.0903}
# 가중치 비율 [0.26, 0.24, 0.5] {'정밀도': 0.0915}
# 가중치 비율 [0.26, 0.25, 0.49] {'정밀도': 0.0928}
# 가중치 비율 [0.26, 0.26, 0.48] {'정밀도': 0.094}
# 가중치 비율 [0.27, 0.0, 0.73] {'정밀도': 0.0672}
# 가중치 비율 [0.27, 0.01, 0.72] {'정밀도': 0.0682}
# 가중치 비율 [0.27, 0.02, 0.71] {'정밀도': 0.0692}
# 가중치 비율 [0.27, 0.03, 0.7] {'정밀도': 0.0702}
# 가중치 비율 [0.27, 0.04, 0.69] {'정밀도': 0.0712}
# 가중치 비율 [0.27, 0.05, 0.68] {'정밀도': 0.0723}
# 가중치 비율 [0.27, 0.06, 0.67] {'정밀도': 0.0731}
# 가중치 비율 [0.27, 0.07, 0.66] {'정밀도': 0.0739}
# 가중치 비율 [0.27, 0.08, 0.65] {'정밀도': 0.0752}
# 가중치 비율 [0.27, 0.09, 0.64] {'정밀도': 0.0764}
# 가중치 비율 [0.27, 0.1, 0.63] {'정밀도': 0.0778}
# 가중치 비율 [0.27, 0.11, 0.62] {'정밀도': 0.0789}
# 가중치 비율 [0.27, 0.12, 0.61] {'정밀도': 0.0802}
# 가중치 비율 [0.27, 0.13, 0.6] {'정밀도': 0.0814}
# 가중치 비율 [0.27, 0.14, 0.59] {'정밀도': 0.0827}
# 가중치 비율 [0.27, 0.15, 0.58] {'정밀도': 0.0839}
# 가중치 비율 [0.27, 0.16, 0.57] {'정밀도': 0.0849}
# 가중치 비율 [0.27, 0.17, 0.56] {'정밀도': 0.086}
# 가중치 비율 [0.27, 0.18, 0.55] {'정밀도': 0.0868}
# 가중치 비율 [0.27, 0.19, 0.54] {'정밀도': 0.0881}
# 가중치 비율 [0.27, 0.2, 0.53] {'정밀도': 0.0893}
# 가중치 비율 [0.27, 0.21, 0.52] {'정밀도': 0.0898}
# 가중치 비율 [0.27, 0.22, 0.51] {'정밀도': 0.0905}
# 가중치 비율 [0.27, 0.23, 0.5] {'정밀도': 0.0916}
# 가중치 비율 [0.27, 0.24, 0.49] {'정밀도': 0.0924}
# 가중치 비율 [0.27, 0.25, 0.48] {'정밀도': 0.0943}
# 가중치 비율 [0.27, 0.26, 0.47] {'정밀도': 0.0955}
# 가중치 비율 [0.27, 0.27, 0.46] {'정밀도': 0.0964}
# 가중치 비율 [0.28, 0.0, 0.72] {'정밀도': 0.0684}
# 가중치 비율 [0.28, 0.01, 0.71] {'정밀도': 0.0693}
# 가중치 비율 [0.28, 0.02, 0.7] {'정밀도': 0.0705}
# 가중치 비율 [0.28, 0.03, 0.69] {'정밀도': 0.0715}
# 가중치 비율 [0.28, 0.04, 0.68] {'정밀도': 0.0723}
# 가중치 비율 [0.28, 0.05, 0.67] {'정밀도': 0.0729}
# 가중치 비율 [0.28, 0.06, 0.66] {'정밀도': 0.074}
# 가중치 비율 [0.28, 0.07, 0.65] {'정밀도': 0.075}
# 가중치 비율 [0.28, 0.08, 0.64] {'정밀도': 0.0764}
# 가중치 비율 [0.28, 0.09, 0.63] {'정밀도': 0.0777}
# 가중치 비율 [0.28, 0.1, 0.62] {'정밀도': 0.079}
# 가중치 비율 [0.28, 0.11, 0.61] {'정밀도': 0.0796}
# 가중치 비율 [0.28, 0.12, 0.6] {'정밀도': 0.0814}
# 가중치 비율 [0.28, 0.13, 0.59] {'정밀도': 0.083}
# 가중치 비율 [0.28, 0.14, 0.58] {'정밀도': 0.0835}
# 가중치 비율 [0.28, 0.15, 0.57] {'정밀도': 0.085}
# 가중치 비율 [0.28, 0.16, 0.56] {'정밀도': 0.0862}
# 가중치 비율 [0.28, 0.17, 0.55] {'정밀도': 0.0873}
# 가중치 비율 [0.28, 0.18, 0.54] {'정밀도': 0.0879}
# 가중치 비율 [0.28, 0.19, 0.53] {'정밀도': 0.089}
# 가중치 비율 [0.28, 0.2, 0.52] {'정밀도': 0.0901}
# 가중치 비율 [0.28, 0.21, 0.51] {'정밀도': 0.0904}
# 가중치 비율 [0.28, 0.22, 0.5] {'정밀도': 0.0919}
# 가중치 비율 [0.28, 0.23, 0.49] {'정밀도': 0.0927}
# 가중치 비율 [0.28, 0.24, 0.48] {'정밀도': 0.0944}
# 가중치 비율 [0.28, 0.25, 0.47] {'정밀도': 0.0953}
# 가중치 비율 [0.28, 0.26, 0.46] {'정밀도': 0.0967}
# 가중치 비율 [0.28, 0.27, 0.45] {'정밀도': 0.0975}
# 가중치 비율 [0.28, 0.28, 0.44] {'정밀도': 0.0983}
# 가중치 비율 [0.29, 0.0, 0.71] {'정밀도': 0.0691}
# 가중치 비율 [0.29, 0.01, 0.7] {'정밀도': 0.0704}
# 가중치 비율 [0.29, 0.02, 0.69] {'정밀도': 0.0714}
# 가중치 비율 [0.29, 0.03, 0.68] {'정밀도': 0.0724}
# 가중치 비율 [0.29, 0.04, 0.67] {'정밀도': 0.0731}
# 가중치 비율 [0.29, 0.05, 0.66] {'정밀도': 0.0739}
# 가중치 비율 [0.29, 0.06, 0.65] {'정밀도': 0.0751}
# 가중치 비율 [0.29, 0.07, 0.64] {'정밀도': 0.0761}
# 가중치 비율 [0.29, 0.08, 0.63] {'정밀도': 0.0773}
# 가중치 비율 [0.29, 0.09, 0.62] {'정밀도': 0.0789}
# 가중치 비율 [0.29, 0.1, 0.61] {'정밀도': 0.08}
# 가중치 비율 [0.29, 0.11, 0.6] {'정밀도': 0.0814}
# 가중치 비율 [0.29, 0.12, 0.59] {'정밀도': 0.0827}
# 가중치 비율 [0.29, 0.13, 0.58] {'정밀도': 0.0835}
# 가중치 비율 [0.29, 0.14, 0.57] {'정밀도': 0.085}
# 가중치 비율 [0.29, 0.15, 0.56] {'정밀도': 0.0862}
# 가중치 비율 [0.29, 0.16, 0.55] {'정밀도': 0.0873}
# 가중치 비율 [0.29, 0.17, 0.54] {'정밀도': 0.0883}
# 가중치 비율 [0.29, 0.18, 0.53] {'정밀도': 0.0891}
# 가중치 비율 [0.29, 0.19, 0.52] {'정밀도': 0.0899}
# 가중치 비율 [0.29, 0.2, 0.51] {'정밀도': 0.0907}
# 가중치 비율 [0.29, 0.21, 0.5] {'정밀도': 0.0924}
# 가중치 비율 [0.29, 0.22, 0.49] {'정밀도': 0.0931}
# 가중치 비율 [0.29, 0.23, 0.48] {'정밀도': 0.0942}
# 가중치 비율 [0.29, 0.24, 0.47] {'정밀도': 0.0952}
# 가중치 비율 [0.29, 0.25, 0.46] {'정밀도': 0.0965}
# 가중치 비율 [0.29, 0.26, 0.45] {'정밀도': 0.0976}
# 가중치 비율 [0.29, 0.27, 0.44] {'정밀도': 0.0984}
# 가중치 비율 [0.29, 0.28, 0.43] {'정밀도': 0.099}
# 가중치 비율 [0.29, 0.29, 0.42] {'정밀도': 0.0998}
# 가중치 비율 [0.3, 0.0, 0.7] {'정밀도': 0.0704}
# 가중치 비율 [0.3, 0.01, 0.69] {'정밀도': 0.0713}
# 가중치 비율 [0.3, 0.02, 0.68] {'정밀도': 0.0726}
# 가중치 비율 [0.3, 0.03, 0.67] {'정밀도': 0.0736}
# 가중치 비율 [0.3, 0.04, 0.66] {'정밀도': 0.0741}
# 가중치 비율 [0.3, 0.05, 0.65] {'정밀도': 0.075}
# 가중치 비율 [0.3, 0.06, 0.64] {'정밀도': 0.0762}
# 가중치 비율 [0.3, 0.07, 0.63] {'정밀도': 0.0771}
# 가중치 비율 [0.3, 0.08, 0.62] {'정밀도': 0.0784}
# 가중치 비율 [0.3, 0.09, 0.61] {'정밀도': 0.0801}
# 가중치 비율 [0.3, 0.1, 0.6] {'정밀도': 0.0812}
# 가중치 비율 [0.3, 0.11, 0.59] {'정밀도': 0.0826}
# 가중치 비율 [0.3, 0.12, 0.58] {'정밀도': 0.0834}
# 가중치 비율 [0.3, 0.13, 0.57] {'정밀도': 0.0847}
# 가중치 비율 [0.3, 0.14, 0.56] {'정밀도': 0.086}
# 가중치 비율 [0.3, 0.15, 0.55] {'정밀도': 0.0872}
# 가중치 비율 [0.3, 0.16, 0.54] {'정밀도': 0.0883}
# 가중치 비율 [0.3, 0.17, 0.53] {'정밀도': 0.089}
# 가중치 비율 [0.3, 0.18, 0.52] {'정밀도': 0.09}
# 가중치 비율 [0.3, 0.19, 0.51] {'정밀도': 0.091}
# 가중치 비율 [0.3, 0.2, 0.5] {'정밀도': 0.0921}
# 가중치 비율 [0.3, 0.21, 0.49] {'정밀도': 0.0932}
# 가중치 비율 [0.3, 0.22, 0.48] {'정밀도': 0.0944}
# 가중치 비율 [0.3, 0.23, 0.47] {'정밀도': 0.0954}
# 가중치 비율 [0.3, 0.24, 0.46] {'정밀도': 0.0964}
# 가중치 비율 [0.3, 0.25, 0.45] {'정밀도': 0.0978}
# 가중치 비율 [0.3, 0.26, 0.44] {'정밀도': 0.0984}
# 가중치 비율 [0.3, 0.27, 0.43] {'정밀도': 0.0997}
# 가중치 비율 [0.3, 0.28, 0.42] {'정밀도': 0.1002}
# 가중치 비율 [0.3, 0.29, 0.41] {'정밀도': 0.1003}
# 가중치 비율 [0.3, 0.3, 0.4] {'정밀도': 0.1008}
# 가중치 비율 [0.31, 0.0, 0.69] {'정밀도': 0.0711}
# 가중치 비율 [0.31, 0.01, 0.68] {'정밀도': 0.0723}
# 가중치 비율 [0.31, 0.02, 0.67] {'정밀도': 0.0735}
# 가중치 비율 [0.31, 0.03, 0.66] {'정밀도': 0.0747}
# 가중치 비율 [0.31, 0.04, 0.65] {'정밀도': 0.0753}
# 가중치 비율 [0.31, 0.05, 0.64] {'정밀도': 0.0758}
# 가중치 비율 [0.31, 0.06, 0.63] {'정밀도': 0.0772}
# 가중치 비율 [0.31, 0.07, 0.62] {'정밀도': 0.0783}
# 가중치 비율 [0.31, 0.08, 0.61] {'정밀도': 0.0796}
# 가중치 비율 [0.31, 0.09, 0.6] {'정밀도': 0.0813}
# 가중치 비율 [0.31, 0.1, 0.59] {'정밀도': 0.0825}
# 가중치 비율 [0.31, 0.11, 0.58] {'정밀도': 0.0835}
# 가중치 비율 [0.31, 0.12, 0.57] {'정밀도': 0.0845}
# 가중치 비율 [0.31, 0.13, 0.56] {'정밀도': 0.0861}
# 가중치 비율 [0.31, 0.14, 0.55] {'정밀도': 0.0872}
# 가중치 비율 [0.31, 0.15, 0.54] {'정밀도': 0.0882}
# 가중치 비율 [0.31, 0.16, 0.53] {'정밀도': 0.0891}
# 가중치 비율 [0.31, 0.17, 0.52] {'정밀도': 0.0901}
# 가중치 비율 [0.31, 0.18, 0.51] {'정밀도': 0.0911}
# 가중치 비율 [0.31, 0.19, 0.5] {'정밀도': 0.0926}
# 가중치 비율 [0.31, 0.2, 0.49] {'정밀도': 0.0935}
# 가중치 비율 [0.31, 0.21, 0.48] {'정밀도': 0.0944}
# 가중치 비율 [0.31, 0.22, 0.47] {'정밀도': 0.0955}
# 가중치 비율 [0.31, 0.23, 0.46] {'정밀도': 0.0964}
# 가중치 비율 [0.31, 0.24, 0.45] {'정밀도': 0.0975}
# 가중치 비율 [0.31, 0.25, 0.44] {'정밀도': 0.0986}
# 가중치 비율 [0.31, 0.26, 0.43] {'정밀도': 0.1}
# 가중치 비율 [0.31, 0.27, 0.42] {'정밀도': 0.1004}
# 가중치 비율 [0.31, 0.28, 0.41] {'정밀도': 0.1008}
# 가중치 비율 [0.31, 0.29, 0.4] {'정밀도': 0.1011}
# 가중치 비율 [0.31, 0.3, 0.39] {'정밀도': 0.1016}
# 가중치 비율 [0.31, 0.31, 0.38] {'정밀도': 0.1026}
# 가중치 비율 [0.32, 0.0, 0.68] {'정밀도': 0.0725}
# 가중치 비율 [0.32, 0.01, 0.67] {'정밀도': 0.0737}
# 가중치 비율 [0.32, 0.02, 0.66] {'정밀도': 0.0748}
# 가중치 비율 [0.32, 0.03, 0.65] {'정밀도': 0.0754}
# 가중치 비율 [0.32, 0.04, 0.64] {'정밀도': 0.0759}
# 가중치 비율 [0.32, 0.05, 0.63] {'정밀도': 0.0771}
# 가중치 비율 [0.32, 0.06, 0.62] {'정밀도': 0.0783}
# 가중치 비율 [0.32, 0.07, 0.61] {'정밀도': 0.0797}
# 가중치 비율 [0.32, 0.08, 0.6] {'정밀도': 0.0812}
# 가중치 비율 [0.32, 0.09, 0.59] {'정밀도': 0.0826}
# 가중치 비율 [0.32, 0.1, 0.58] {'정밀도': 0.0835}
# 가중치 비율 [0.32, 0.11, 0.57] {'정밀도': 0.0846}
# 가중치 비율 [0.32, 0.12, 0.56] {'정밀도': 0.086}
# 가중치 비율 [0.32, 0.13, 0.55] {'정밀도': 0.0871}
# 가중치 비율 [0.32, 0.14, 0.54] {'정밀도': 0.0884}
# 가중치 비율 [0.32, 0.15, 0.53] {'정밀도': 0.0895}
# 가중치 비율 [0.32, 0.16, 0.52] {'정밀도': 0.0905}
# 가중치 비율 [0.32, 0.17, 0.51] {'정밀도': 0.0914}
# 가중치 비율 [0.32, 0.18, 0.5] {'정밀도': 0.0927}
# 가중치 비율 [0.32, 0.19, 0.49] {'정밀도': 0.0936}
# 가중치 비율 [0.32, 0.2, 0.48] {'정밀도': 0.0948}
# 가중치 비율 [0.32, 0.21, 0.47] {'정밀도': 0.0954}
# 가중치 비율 [0.32, 0.22, 0.46] {'정밀도': 0.0961}
# 가중치 비율 [0.32, 0.23, 0.45] {'정밀도': 0.0971}
# 가중치 비율 [0.32, 0.24, 0.44] {'정밀도': 0.0987}
# 가중치 비율 [0.32, 0.25, 0.43] {'정밀도': 0.0999}
# 가중치 비율 [0.32, 0.26, 0.42] {'정밀도': 0.1005}
# 가중치 비율 [0.32, 0.27, 0.41] {'정밀도': 0.1012}
# 가중치 비율 [0.32, 0.28, 0.4] {'정밀도': 0.1016}
# 가중치 비율 [0.32, 0.29, 0.39] {'정밀도': 0.1019}
# 가중치 비율 [0.32, 0.3, 0.38] {'정밀도': 0.1026}
# 가중치 비율 [0.32, 0.31, 0.37] {'정밀도': 0.1032}
# 가중치 비율 [0.32, 0.32, 0.36] {'정밀도': 0.1034}
# 가중치 비율 [0.33, 0.0, 0.67] {'정밀도': 0.0736}
# 가중치 비율 [0.33, 0.01, 0.66] {'정밀도': 0.0746}
# 가중치 비율 [0.33, 0.02, 0.65] {'정밀도': 0.0756}
# 가중치 비율 [0.33, 0.03, 0.64] {'정밀도': 0.0763}
# 가중치 비율 [0.33, 0.04, 0.63] {'정밀도': 0.077}
# 가중치 비율 [0.33, 0.05, 0.62] {'정밀도': 0.0783}
# 가중치 비율 [0.33, 0.06, 0.61] {'정밀도': 0.0794}
# 가중치 비율 [0.33, 0.07, 0.6] {'정밀도': 0.0805}
# 가중치 비율 [0.33, 0.08, 0.59] {'정밀도': 0.0823}
# 가중치 비율 [0.33, 0.09, 0.58] {'정밀도': 0.0834}
# 가중치 비율 [0.33, 0.1, 0.57] {'정밀도': 0.0845}
# 가중치 비율 [0.33, 0.11, 0.56] {'정밀도': 0.086}
# 가중치 비율 [0.33, 0.12, 0.55] {'정밀도': 0.0872}
# 가중치 비율 [0.33, 0.13, 0.54] {'정밀도': 0.0883}
# 가중치 비율 [0.33, 0.14, 0.53] {'정밀도': 0.0895}
# 가중치 비율 [0.33, 0.15, 0.52] {'정밀도': 0.0907}
# 가중치 비율 [0.33, 0.16, 0.51] {'정밀도': 0.0917}
# 가중치 비율 [0.33, 0.17, 0.5] {'정밀도': 0.0922}
# 가중치 비율 [0.33, 0.18, 0.49] {'정밀도': 0.0936}
# 가중치 비율 [0.33, 0.19, 0.48] {'정밀도': 0.0949}
# 가중치 비율 [0.33, 0.2, 0.47] {'정밀도': 0.0956}
# 가중치 비율 [0.33, 0.21, 0.46] {'정밀도': 0.0964}
# 가중치 비율 [0.33, 0.22, 0.45] {'정밀도': 0.0978}
# 가중치 비율 [0.33, 0.23, 0.44] {'정밀도': 0.0987}
# 가중치 비율 [0.33, 0.24, 0.43] {'정밀도': 0.0998}
# 가중치 비율 [0.33, 0.25, 0.42] {'정밀도': 0.1006}
# 가중치 비율 [0.33, 0.26, 0.41] {'정밀도': 0.1009}
# 가중치 비율 [0.33, 0.27, 0.4] {'정밀도': 0.1016}
# 가중치 비율 [0.33, 0.28, 0.39] {'정밀도': 0.1024}
# 가중치 비율 [0.33, 0.29, 0.38] {'정밀도': 0.103}
# 가중치 비율 [0.33, 0.3, 0.37] {'정밀도': 0.1035}
# 가중치 비율 [0.33, 0.31, 0.36] {'정밀도': 0.104}
# 가중치 비율 [0.33, 0.32, 0.35] {'정밀도': 0.1043}
# 가중치 비율 [0.33, 0.33, 0.34] {'정밀도': 0.1047}
# 가중치 비율 [0.34, 0.0, 0.66] {'정밀도': 0.0743}
# 가중치 비율 [0.34, 0.01, 0.65] {'정밀도': 0.0753}
# 가중치 비율 [0.34, 0.02, 0.64] {'정밀도': 0.0763}
# 가중치 비율 [0.34, 0.03, 0.63] {'정밀도': 0.0772}
# 가중치 비율 [0.34, 0.04, 0.62] {'정밀도': 0.0784}
# 가중치 비율 [0.34, 0.05, 0.61] {'정밀도': 0.0794}
# 가중치 비율 [0.34, 0.06, 0.6] {'정밀도': 0.0806}
# 가중치 비율 [0.34, 0.07, 0.59] {'정밀도': 0.0819}
# 가중치 비율 [0.34, 0.08, 0.58] {'정밀도': 0.0837}
# 가중치 비율 [0.34, 0.09, 0.57] {'정밀도': 0.0847}
# 가중치 비율 [0.34, 0.1, 0.56] {'정밀도': 0.0862}
# 가중치 비율 [0.34, 0.11, 0.55] {'정밀도': 0.087}
# 가중치 비율 [0.34, 0.12, 0.54] {'정밀도': 0.0879}
# 가중치 비율 [0.34, 0.13, 0.53] {'정밀도': 0.0893}
# 가중치 비율 [0.34, 0.14, 0.52] {'정밀도': 0.0907}
# 가중치 비율 [0.34, 0.15, 0.51] {'정밀도': 0.0917}
# 가중치 비율 [0.34, 0.16, 0.5] {'정밀도': 0.0927}
# 가중치 비율 [0.34, 0.17, 0.49] {'정밀도': 0.0936}
# 가중치 비율 [0.34, 0.18, 0.48] {'정밀도': 0.0948}
# 가중치 비율 [0.34, 0.19, 0.47] {'정밀도': 0.0958}
# 가중치 비율 [0.34, 0.2, 0.46] {'정밀도': 0.0968}
# 가중치 비율 [0.34, 0.21, 0.45] {'정밀도': 0.0979}
# 가중치 비율 [0.34, 0.22, 0.44] {'정밀도': 0.0989}
# 가중치 비율 [0.34, 0.23, 0.43] {'정밀도': 0.0997}
# 가중치 비율 [0.34, 0.24, 0.42] {'정밀도': 0.1003}
# 가중치 비율 [0.34, 0.25, 0.41] {'정밀도': 0.1009}
# 가중치 비율 [0.34, 0.26, 0.4] {'정밀도': 0.1017}
# 가중치 비율 [0.34, 0.27, 0.39] {'정밀도': 0.1028}
# 가중치 비율 [0.34, 0.28, 0.38] {'정밀도': 0.1036}
# 가중치 비율 [0.34, 0.29, 0.37] {'정밀도': 0.1041}
# 가중치 비율 [0.34, 0.3, 0.36] {'정밀도': 0.1044}
# 가중치 비율 [0.34, 0.31, 0.35] {'정밀도': 0.1048}
# 가중치 비율 [0.34, 0.32, 0.34] {'정밀도': 0.1052}
# 가중치 비율 [0.34, 0.33, 0.33] {'정밀도': 0.1054}
# 가중치 비율 [0.34, 0.34, 0.32] {'정밀도': 0.1057}
# 가중치 비율 [0.35, 0.0, 0.65] {'정밀도': 0.0753}
# 가중치 비율 [0.35, 0.01, 0.64] {'정밀도': 0.0761}
# 가중치 비율 [0.35, 0.02, 0.63] {'정밀도': 0.0776}
# 가중치 비율 [0.35, 0.03, 0.62] {'정밀도': 0.0783}
# 가중치 비율 [0.35, 0.04, 0.61] {'정밀도': 0.0792}
# 가중치 비율 [0.35, 0.05, 0.6] {'정밀도': 0.0807}
# 가중치 비율 [0.35, 0.06, 0.59] {'정밀도': 0.0817}
# 가중치 비율 [0.35, 0.07, 0.58] {'정밀도': 0.0835}
# 가중치 비율 [0.35, 0.08, 0.57] {'정밀도': 0.0845}
# 가중치 비율 [0.35, 0.09, 0.56] {'정밀도': 0.086}
# 가중치 비율 [0.35, 0.1, 0.55] {'정밀도': 0.0871}
# 가중치 비율 [0.35, 0.11, 0.54] {'정밀도': 0.0879}
# 가중치 비율 [0.35, 0.12, 0.53] {'정밀도': 0.0888}
# 가중치 비율 [0.35, 0.13, 0.52] {'정밀도': 0.0906}
# 가중치 비율 [0.35, 0.14, 0.51] {'정밀도': 0.0916}
# 가중치 비율 [0.35, 0.15, 0.5] {'정밀도': 0.0929}
# 가중치 비율 [0.35, 0.16, 0.49] {'정밀도': 0.0938}
# 가중치 비율 [0.35, 0.17, 0.48] {'정밀도': 0.0948}
# 가중치 비율 [0.35, 0.18, 0.47] {'정밀도': 0.0958}
# 가중치 비율 [0.35, 0.19, 0.46] {'정밀도': 0.0969}
# 가중치 비율 [0.35, 0.2, 0.45] {'정밀도': 0.098}
# 가중치 비율 [0.35, 0.21, 0.44] {'정밀도': 0.099}
# 가중치 비율 [0.35, 0.22, 0.43] {'정밀도': 0.0998}
# 가중치 비율 [0.35, 0.23, 0.42] {'정밀도': 0.1003}
# 가중치 비율 [0.35, 0.24, 0.41] {'정밀도': 0.101}
# 가중치 비율 [0.35, 0.25, 0.4] {'정밀도': 0.1021}
# 가중치 비율 [0.35, 0.26, 0.39] {'정밀도': 0.1028}
# 가중치 비율 [0.35, 0.27, 0.38] {'정밀도': 0.1033}
# 가중치 비율 [0.35, 0.28, 0.37] {'정밀도': 0.104}
# 가중치 비율 [0.35, 0.29, 0.36] {'정밀도': 0.105}
# 가중치 비율 [0.35, 0.3, 0.35] {'정밀도': 0.1053}
# 가중치 비율 [0.35, 0.31, 0.34] {'정밀도': 0.1059}
# 가중치 비율 [0.35, 0.32, 0.33] {'정밀도': 0.1058}
# 가중치 비율 [0.35, 0.33, 0.32] {'정밀도': 0.1059}
# 가중치 비율 [0.35, 0.34, 0.31] {'정밀도': 0.1063}
# 가중치 비율 [0.35, 0.35, 0.3] {'정밀도': 0.1065}
# 가중치 비율 [0.36, 0.0, 0.64] {'정밀도': 0.0763}
# 가중치 비율 [0.36, 0.01, 0.63] {'정밀도': 0.0774}
# 가중치 비율 [0.36, 0.02, 0.62] {'정밀도': 0.0787}
# 가중치 비율 [0.36, 0.03, 0.61] {'정밀도': 0.0796}
# 가중치 비율 [0.36, 0.04, 0.6] {'정밀도': 0.0805}
# 가중치 비율 [0.36, 0.05, 0.59] {'정밀도': 0.0817}
# 가중치 비율 [0.36, 0.06, 0.58] {'정밀도': 0.0832}
# 가중치 비율 [0.36, 0.07, 0.57] {'정밀도': 0.0846}
# 가중치 비율 [0.36, 0.08, 0.56] {'정밀도': 0.0859}
# 가중치 비율 [0.36, 0.09, 0.55] {'정밀도': 0.0872}
# 가중치 비율 [0.36, 0.1, 0.54] {'정밀도': 0.088}
# 가중치 비율 [0.36, 0.11, 0.53] {'정밀도': 0.0887}
# 가중치 비율 [0.36, 0.12, 0.52] {'정밀도': 0.0897}
# 가중치 비율 [0.36, 0.13, 0.51] {'정밀도': 0.0913}
# 가중치 비율 [0.36, 0.14, 0.5] {'정밀도': 0.0929}
# 가중치 비율 [0.36, 0.15, 0.49] {'정밀도': 0.094}
# 가중치 비율 [0.36, 0.16, 0.48] {'정밀도': 0.0951}
# 가중치 비율 [0.36, 0.17, 0.47] {'정밀도': 0.0964}
# 가중치 비율 [0.36, 0.18, 0.46] {'정밀도': 0.097}
# 가중치 비율 [0.36, 0.19, 0.45] {'정밀도': 0.0984}
# 가중치 비율 [0.36, 0.2, 0.44] {'정밀도': 0.0993}
# 가중치 비율 [0.36, 0.21, 0.43] {'정밀도': 0.0999}
# 가중치 비율 [0.36, 0.22, 0.42] {'정밀도': 0.1006}
# 가중치 비율 [0.36, 0.23, 0.41] {'정밀도': 0.1015}
# 가중치 비율 [0.36, 0.24, 0.4] {'정밀도': 0.1021}
# 가중치 비율 [0.36, 0.25, 0.39] {'정밀도': 0.1029}
# 가중치 비율 [0.36, 0.26, 0.38] {'정밀도': 0.1035}
# 가중치 비율 [0.36, 0.27, 0.37] {'정밀도': 0.1043}
# 가중치 비율 [0.36, 0.28, 0.36] {'정밀도': 0.1054}
# 가중치 비율 [0.36, 0.29, 0.35] {'정밀도': 0.1055}
# 가중치 비율 [0.36, 0.3, 0.34] {'정밀도': 0.1064}
# 가중치 비율 [0.36, 0.31, 0.33] {'정밀도': 0.1064}
# 가중치 비율 [0.36, 0.32, 0.32] {'정밀도': 0.1067}
# 가중치 비율 [0.36, 0.33, 0.31] {'정밀도': 0.1064}
# 가중치 비율 [0.36, 0.34, 0.3] {'정밀도': 0.1067}
# 가중치 비율 [0.36, 0.35, 0.29] {'정밀도': 0.107}
# 가중치 비율 [0.36, 0.36, 0.28] {'정밀도': 0.1075}
# 가중치 비율 [0.37, 0.0, 0.63] {'정밀도': 0.0774}
# 가중치 비율 [0.37, 0.01, 0.62] {'정밀도': 0.0783}
# 가중치 비율 [0.37, 0.02, 0.61] {'정밀도': 0.08}
# 가중치 비율 [0.37, 0.03, 0.6] {'정밀도': 0.0807}
# 가중치 비율 [0.37, 0.04, 0.59] {'정밀도': 0.0819}
# 가중치 비율 [0.37, 0.05, 0.58] {'정밀도': 0.083}
# 가중치 비율 [0.37, 0.06, 0.57] {'정밀도': 0.0844}
# 가중치 비율 [0.37, 0.07, 0.56] {'정밀도': 0.0855}
# 가중치 비율 [0.37, 0.08, 0.55] {'정밀도': 0.0875}
# 가중치 비율 [0.37, 0.09, 0.54] {'정밀도': 0.0883}
# 가중치 비율 [0.37, 0.1, 0.53] {'정밀도': 0.0886}
# 가중치 비율 [0.37, 0.11, 0.52] {'정밀도': 0.0897}
# 가중치 비율 [0.37, 0.12, 0.51] {'정밀도': 0.0915}
# 가중치 비율 [0.37, 0.13, 0.5] {'정밀도': 0.0928}
# 가중치 비율 [0.37, 0.14, 0.49] {'정밀도': 0.0938}
# 가중치 비율 [0.37, 0.15, 0.48] {'정밀도': 0.0954}
# 가중치 비율 [0.37, 0.16, 0.47] {'정밀도': 0.0966}
# 가중치 비율 [0.37, 0.17, 0.46] {'정밀도': 0.0972}
# 가중치 비율 [0.37, 0.18, 0.45] {'정밀도': 0.0984}
# 가중치 비율 [0.37, 0.19, 0.44] {'정밀도': 0.0992}
# 가중치 비율 [0.37, 0.2, 0.43] {'정밀도': 0.1004}
# 가중치 비율 [0.37, 0.21, 0.42] {'정밀도': 0.101}
# 가중치 비율 [0.37, 0.22, 0.41] {'정밀도': 0.1019}
# 가중치 비율 [0.37, 0.23, 0.4] {'정밀도': 0.1023}
# 가중치 비율 [0.37, 0.24, 0.39] {'정밀도': 0.1032}
# 가중치 비율 [0.37, 0.25, 0.38] {'정밀도': 0.1041}
# 가중치 비율 [0.37, 0.26, 0.37] {'정밀도': 0.1045}
# 가중치 비율 [0.37, 0.27, 0.36] {'정밀도': 0.1055}
# 가중치 비율 [0.37, 0.28, 0.35] {'정밀도': 0.1058}
# 가중치 비율 [0.37, 0.29, 0.34] {'정밀도': 0.1065}
# 가중치 비율 [0.37, 0.3, 0.33] {'정밀도': 0.1073}
# 가중치 비율 [0.37, 0.31, 0.32] {'정밀도': 0.1072}
# 가중치 비율 [0.37, 0.32, 0.31] {'정밀도': 0.107}
# 가중치 비율 [0.37, 0.33, 0.3] {'정밀도': 0.1073}
# 가중치 비율 [0.37, 0.34, 0.29] {'정밀도': 0.1073}
# 가중치 비율 [0.37, 0.35, 0.28] {'정밀도': 0.1073}
# 가중치 비율 [0.37, 0.36, 0.27] {'정밀도': 0.1076}
# 가중치 비율 [0.37, 0.37, 0.26] {'정밀도': 0.1071}
# 가중치 비율 [0.38, 0.0, 0.62] {'정밀도': 0.0786}
# 가중치 비율 [0.38, 0.01, 0.61] {'정밀도': 0.0795}
# 가중치 비율 [0.38, 0.02, 0.6] {'정밀도': 0.0807}
# 가중치 비율 [0.38, 0.03, 0.59] {'정밀도': 0.0815}
# 가중치 비율 [0.38, 0.04, 0.58] {'정밀도': 0.0828}
# 가중치 비율 [0.38, 0.05, 0.57] {'정밀도': 0.0842}
# 가중치 비율 [0.38, 0.06, 0.56] {'정밀도': 0.0858}
# 가중치 비율 [0.38, 0.07, 0.55] {'정밀도': 0.0871}
# 가중치 비율 [0.38, 0.08, 0.54] {'정밀도': 0.0883}
# 가중치 비율 [0.38, 0.09, 0.53] {'정밀도': 0.0888}
# 가중치 비율 [0.38, 0.1, 0.52] {'정밀도': 0.0897}
# 가중치 비율 [0.38, 0.11, 0.51] {'정밀도': 0.0914}
# 가중치 비율 [0.38, 0.12, 0.5] {'정밀도': 0.0928}
# 가중치 비율 [0.38, 0.13, 0.49] {'정밀도': 0.094}
# 가중치 비율 [0.38, 0.14, 0.48] {'정밀도': 0.0953}
# 가중치 비율 [0.38, 0.15, 0.47] {'정밀도': 0.0964}
# 가중치 비율 [0.38, 0.16, 0.46] {'정밀도': 0.0976}
# 가중치 비율 [0.38, 0.17, 0.45] {'정밀도': 0.0984}
# 가중치 비율 [0.38, 0.18, 0.44] {'정밀도': 0.0997}
# 가중치 비율 [0.38, 0.19, 0.43] {'정밀도': 0.1002}
# 가중치 비율 [0.38, 0.2, 0.42] {'정밀도': 0.1018}
# 가중치 비율 [0.38, 0.21, 0.41] {'정밀도': 0.1021}
# 가중치 비율 [0.38, 0.22, 0.4] {'정밀도': 0.1027}
# 가중치 비율 [0.38, 0.23, 0.39] {'정밀도': 0.1036}
# 가중치 비율 [0.38, 0.24, 0.38] {'정밀도': 0.1042}
# 가중치 비율 [0.38, 0.25, 0.37] {'정밀도': 0.105}
# 가중치 비율 [0.38, 0.26, 0.36] {'정밀도': 0.1058}
# 가중치 비율 [0.38, 0.27, 0.35] {'정밀도': 0.1061}
# 가중치 비율 [0.38, 0.28, 0.34] {'정밀도': 0.1066}
# 가중치 비율 [0.38, 0.29, 0.33] {'정밀도': 0.107}
# 가중치 비율 [0.38, 0.3, 0.32] {'정밀도': 0.107}
# 가중치 비율 [0.38, 0.31, 0.31] {'정밀도': 0.1077}
# 가중치 비율 [0.38, 0.32, 0.3] {'정밀도': 0.1076}
# 가중치 비율 [0.38, 0.33, 0.29] {'정밀도': 0.108}
# 가중치 비율 [0.38, 0.34, 0.28] {'정밀도': 0.1077}
# 가중치 비율 [0.38, 0.35, 0.27] {'정밀도': 0.1079}
# 가중치 비율 [0.38, 0.36, 0.26] {'정밀도': 0.1077}
# 가중치 비율 [0.38, 0.37, 0.25] {'정밀도': 0.1072}
# 가중치 비율 [0.38, 0.38, 0.24] {'정밀도': 0.1064}
# 가중치 비율 [0.39, 0.0, 0.61] {'정밀도': 0.0797}
# 가중치 비율 [0.39, 0.01, 0.6] {'정밀도': 0.0803}
# 가중치 비율 [0.39, 0.02, 0.59] {'정밀도': 0.0817}
# 가중치 비율 [0.39, 0.03, 0.58] {'정밀도': 0.0827}
# 가중치 비율 [0.39, 0.04, 0.57] {'정밀도': 0.0842}
# 가중치 비율 [0.39, 0.05, 0.56] {'정밀도': 0.0855}
# 가중치 비율 [0.39, 0.06, 0.55] {'정밀도': 0.0864}
# 가중치 비율 [0.39, 0.07, 0.54] {'정밀도': 0.0881}
# 가중치 비율 [0.39, 0.08, 0.53] {'정밀도': 0.0885}
# 가중치 비율 [0.39, 0.09, 0.52] {'정밀도': 0.0901}
# 가중치 비율 [0.39, 0.1, 0.51] {'정밀도': 0.0914}
# 가중치 비율 [0.39, 0.11, 0.5] {'정밀도': 0.0926}
# 가중치 비율 [0.39, 0.12, 0.49] {'정밀도': 0.0939}
# 가중치 비율 [0.39, 0.13, 0.48] {'정밀도': 0.0954}
# 가중치 비율 [0.39, 0.14, 0.47] {'정밀도': 0.0963}
# 가중치 비율 [0.39, 0.15, 0.46] {'정밀도': 0.0978}
# 가중치 비율 [0.39, 0.16, 0.45] {'정밀도': 0.0988}
# 가중치 비율 [0.39, 0.17, 0.44] {'정밀도': 0.0997}
# 가중치 비율 [0.39, 0.18, 0.43] {'정밀도': 0.1007}
# 가중치 비율 [0.39, 0.19, 0.42] {'정밀도': 0.1016}
# 가중치 비율 [0.39, 0.2, 0.41] {'정밀도': 0.1025}
# 가중치 비율 [0.39, 0.21, 0.4] {'정밀도': 0.1032}
# 가중치 비율 [0.39, 0.22, 0.39] {'정밀도': 0.1043}
# 가중치 비율 [0.39, 0.23, 0.38] {'정밀도': 0.1048}
# 가중치 비율 [0.39, 0.24, 0.37] {'정밀도': 0.1052}
# 가중치 비율 [0.39, 0.25, 0.36] {'정밀도': 0.1058}
# 가중치 비율 [0.39, 0.26, 0.35] {'정밀도': 0.1066}
# 가중치 비율 [0.39, 0.27, 0.34] {'정밀도': 0.1066}
# 가중치 비율 [0.39, 0.28, 0.33] {'정밀도': 0.1072}
# 가중치 비율 [0.39, 0.29, 0.32] {'정밀도': 0.1074}
# 가중치 비율 [0.39, 0.3, 0.31] {'정밀도': 0.1075}
# 가중치 비율 [0.39, 0.31, 0.3] {'정밀도': 0.1079}
# 가중치 비율 [0.39, 0.32, 0.29] {'정밀도': 0.1084}
# 가중치 비율 [0.39, 0.33, 0.28] {'정밀도': 0.1081}
# 가중치 비율 [0.39, 0.34, 0.27] {'정밀도': 0.1085}
# 가중치 비율 [0.39, 0.35, 0.26] {'정밀도': 0.1082}
# 가중치 비율 [0.39, 0.36, 0.25] {'정밀도': 0.1079}
# 가중치 비율 [0.39, 0.37, 0.24] {'정밀도': 0.1074}
# 가중치 비율 [0.39, 0.38, 0.23] {'정밀도': 0.1066}
# 가중치 비율 [0.39, 0.39, 0.22] {'정밀도': 0.1062}
# 가중치 비율 [0.4, 0.0, 0.6] {'정밀도': 0.0803}
# 가중치 비율 [0.4, 0.01, 0.59] {'정밀도': 0.0814}
# 가중치 비율 [0.4, 0.02, 0.58] {'정밀도': 0.0826}
# 가중치 비율 [0.4, 0.03, 0.57] {'정밀도': 0.0839}
# 가중치 비율 [0.4, 0.04, 0.56] {'정밀도': 0.0851}
# 가중치 비율 [0.4, 0.05, 0.55] {'정밀도': 0.086}
# 가중치 비율 [0.4, 0.06, 0.54] {'정밀도': 0.0876}
# 가중치 비율 [0.4, 0.07, 0.53] {'정밀도': 0.0889}
# 가중치 비율 [0.4, 0.08, 0.52] {'정밀도': 0.0899}
# 가중치 비율 [0.4, 0.09, 0.51] {'정밀도': 0.0916}
# 가중치 비율 [0.4, 0.1, 0.5] {'정밀도': 0.0929}
# 가중치 비율 [0.4, 0.11, 0.49] {'정밀도': 0.0938}
# 가중치 비율 [0.4, 0.12, 0.48] {'정밀도': 0.0954}
# 가중치 비율 [0.4, 0.13, 0.47] {'정밀도': 0.0963}
# 가중치 비율 [0.4, 0.14, 0.46] {'정밀도': 0.0978}
# 가중치 비율 [0.4, 0.15, 0.45] {'정밀도': 0.099}
# 가중치 비율 [0.4, 0.16, 0.44] {'정밀도': 0.0999}
# 가중치 비율 [0.4, 0.17, 0.43] {'정밀도': 0.1011}
# 가중치 비율 [0.4, 0.18, 0.42] {'정밀도': 0.1018}
# 가중치 비율 [0.4, 0.19, 0.41] {'정밀도': 0.1031}
# 가중치 비율 [0.4, 0.2, 0.4] {'정밀도': 0.1041}
# 가중치 비율 [0.4, 0.21, 0.39] {'정밀도': 0.1044}
# 가중치 비율 [0.4, 0.22, 0.38] {'정밀도': 0.1052}
# 가중치 비율 [0.4, 0.23, 0.37] {'정밀도': 0.1059}
# 가중치 비율 [0.4, 0.24, 0.36] {'정밀도': 0.1064}
# 가중치 비율 [0.4, 0.25, 0.35] {'정밀도': 0.1065}
# 가중치 비율 [0.4, 0.26, 0.34] {'정밀도': 0.1066}
# 가중치 비율 [0.4, 0.27, 0.33] {'정밀도': 0.1072}
# 가중치 비율 [0.4, 0.28, 0.32] {'정밀도': 0.1076}
# 가중치 비율 [0.4, 0.29, 0.31] {'정밀도': 0.1078}
# 가중치 비율 [0.4, 0.3, 0.3] {'정밀도': 0.108}
# 가중치 비율 [0.4, 0.31, 0.29] {'정밀도': 0.1084}
# 가중치 비율 [0.4, 0.32, 0.28] {'정밀도': 0.1084}
# 가중치 비율 [0.4, 0.33, 0.27] {'정밀도': 0.1086}
# 가중치 비율 [0.4, 0.34, 0.26] {'정밀도': 0.1087}
# 가중치 비율 [0.4, 0.35, 0.25] {'정밀도': 0.1083}
# 가중치 비율 [0.4, 0.36, 0.24] {'정밀도': 0.1078}
# 가중치 비율 [0.4, 0.37, 0.23] {'정밀도': 0.1076}
# 가중치 비율 [0.4, 0.38, 0.22] {'정밀도': 0.1071}
# 가중치 비율 [0.4, 0.39, 0.21] {'정밀도': 0.1061}
# 가중치 비율 [0.4, 0.4, 0.2] {'정밀도': 0.1058}
# 가중치 비율 [0.41, 0.0, 0.59] {'정밀도': 0.0811}
# 가중치 비율 [0.41, 0.01, 0.58] {'정밀도': 0.0824}
# 가중치 비율 [0.41, 0.02, 0.57] {'정밀도': 0.0835}
# 가중치 비율 [0.41, 0.03, 0.56] {'정밀도': 0.0848}
# 가중치 비율 [0.41, 0.04, 0.55] {'정밀도': 0.0859}
# 가중치 비율 [0.41, 0.05, 0.54] {'정밀도': 0.0875}
# 가중치 비율 [0.41, 0.06, 0.53] {'정밀도': 0.0887}
# 가중치 비율 [0.41, 0.07, 0.52] {'정밀도': 0.0899}
# 가중치 비율 [0.41, 0.08, 0.51] {'정밀도': 0.0912}
# 가중치 비율 [0.41, 0.09, 0.5] {'정밀도': 0.093}
# 가중치 비율 [0.41, 0.1, 0.49] {'정밀도': 0.0941}
# 가중치 비율 [0.41, 0.11, 0.48] {'정밀도': 0.0952}
# 가중치 비율 [0.41, 0.12, 0.47] {'정밀도': 0.0964}
# 가중치 비율 [0.41, 0.13, 0.46] {'정밀도': 0.0977}
# 가중치 비율 [0.41, 0.14, 0.45] {'정밀도': 0.0991}
# 가중치 비율 [0.41, 0.15, 0.44] {'정밀도': 0.0998}
# 가중치 비율 [0.41, 0.16, 0.43] {'정밀도': 0.1012}
# 가중치 비율 [0.41, 0.17, 0.42] {'정밀도': 0.1021}
# 가중치 비율 [0.41, 0.18, 0.41] {'정밀도': 0.1036}
# 가중치 비율 [0.41, 0.19, 0.4] {'정밀도': 0.1045}
# 가중치 비율 [0.41, 0.2, 0.39] {'정밀도': 0.1048}
# 가중치 비율 [0.41, 0.21, 0.38] {'정밀도': 0.1056}
# 가중치 비율 [0.41, 0.22, 0.37] {'정밀도': 0.106}
# 가중치 비율 [0.41, 0.23, 0.36] {'정밀도': 0.1065}
# 가중치 비율 [0.41, 0.24, 0.35] {'정밀도': 0.1066}
# 가중치 비율 [0.41, 0.25, 0.34] {'정밀도': 0.107}
# 가중치 비율 [0.41, 0.26, 0.33] {'정밀도': 0.1072}
# 가중치 비율 [0.41, 0.27, 0.32] {'정밀도': 0.1081}
# 가중치 비율 [0.41, 0.28, 0.31] {'정밀도': 0.1083}
# 가중치 비율 [0.41, 0.29, 0.3] {'정밀도': 0.1081}
# 가중치 비율 [0.41, 0.3, 0.29] {'정밀도': 0.1085}
# 가중치 비율 [0.41, 0.31, 0.28] {'정밀도': 0.1086}
# 가중치 비율 [0.41, 0.32, 0.27] {'정밀도': 0.1087}
# 가중치 비율 [0.41, 0.33, 0.26] {'정밀도': 0.1086}
# 가중치 비율 [0.41, 0.34, 0.25] {'정밀도': 0.1087}
# 가중치 비율 [0.41, 0.35, 0.24] {'정밀도': 0.1085}
# 가중치 비율 [0.41, 0.36, 0.23] {'정밀도': 0.1081}
# 가중치 비율 [0.41, 0.37, 0.22] {'정밀도': 0.1074}
# 가중치 비율 [0.41, 0.38, 0.21] {'정밀도': 0.1068}
# 가중치 비율 [0.41, 0.39, 0.2] {'정밀도': 0.1064}
# 가중치 비율 [0.41, 0.4, 0.19] {'정밀도': 0.106}
# 가중치 비율 [0.41, 0.41, 0.18] {'정밀도': 0.1055}
# 가중치 비율 [0.42, 0.0, 0.58] {'정밀도': 0.0818}
# 가중치 비율 [0.42, 0.01, 0.57] {'정밀도': 0.0831}
# 가중치 비율 [0.42, 0.02, 0.56] {'정밀도': 0.0844}
# 가중치 비율 [0.42, 0.03, 0.55] {'정밀도': 0.0855}
# 가중치 비율 [0.42, 0.04, 0.54] {'정밀도': 0.0871}
# 가중치 비율 [0.42, 0.05, 0.53] {'정밀도': 0.0884}
# 가중치 비율 [0.42, 0.06, 0.52] {'정밀도': 0.0899}
# 가중치 비율 [0.42, 0.07, 0.51] {'정밀도': 0.091}
# 가중치 비율 [0.42, 0.08, 0.5] {'정밀도': 0.0929}
# 가중치 비율 [0.42, 0.09, 0.49] {'정밀도': 0.094}
# 가중치 비율 [0.42, 0.1, 0.48] {'정밀도': 0.0948}
# 가중치 비율 [0.42, 0.11, 0.47] {'정밀도': 0.0966}
# 가중치 비율 [0.42, 0.12, 0.46] {'정밀도': 0.0977}
# 가중치 비율 [0.42, 0.13, 0.45] {'정밀도': 0.0989}
# 가중치 비율 [0.42, 0.14, 0.44] {'정밀도': 0.0999}
# 가중치 비율 [0.42, 0.15, 0.43] {'정밀도': 0.1011}
# 가중치 비율 [0.42, 0.16, 0.42] {'정밀도': 0.1022}
# 가중치 비율 [0.42, 0.17, 0.41] {'정밀도': 0.1037}
# 가중치 비율 [0.42, 0.18, 0.4] {'정밀도': 0.1045}
# 가중치 비율 [0.42, 0.19, 0.39] {'정밀도': 0.1051}
# 가중치 비율 [0.42, 0.2, 0.38] {'정밀도': 0.1062}
# 가중치 비율 [0.42, 0.21, 0.37] {'정밀도': 0.1064}
# 가중치 비율 [0.42, 0.22, 0.36] {'정밀도': 0.1067}
# 가중치 비율 [0.42, 0.23, 0.35] {'정밀도': 0.107}
# 가중치 비율 [0.42, 0.24, 0.34] {'정밀도': 0.1075}
# 가중치 비율 [0.42, 0.25, 0.33] {'정밀도': 0.1076}
# 가중치 비율 [0.42, 0.26, 0.32] {'정밀도': 0.1079}
# 가중치 비율 [0.42, 0.27, 0.31] {'정밀도': 0.1087}
# 가중치 비율 [0.42, 0.28, 0.3] {'정밀도': 0.1088}
# 가중치 비율 [0.42, 0.29, 0.29] {'정밀도': 0.1087}
# 가중치 비율 [0.42, 0.3, 0.28] {'정밀도': 0.1092}
# 가중치 비율 [0.42, 0.31, 0.27] {'정밀도': 0.1089}
# 가중치 비율 [0.42, 0.32, 0.26] {'정밀도': 0.1088}
# 가중치 비율 [0.42, 0.33, 0.25] {'정밀도': 0.1091}
# 가중치 비율 [0.42, 0.34, 0.24] {'정밀도': 0.1088}
# 가중치 비율 [0.42, 0.35, 0.23] {'정밀도': 0.1082}
# 가중치 비율 [0.42, 0.36, 0.22] {'정밀도': 0.1081}
# 가중치 비율 [0.42, 0.37, 0.21] {'정밀도': 0.1072}
# 가중치 비율 [0.42, 0.38, 0.2] {'정밀도': 0.107}
# 가중치 비율 [0.42, 0.39, 0.19] {'정밀도': 0.1064}
# 가중치 비율 [0.42, 0.4, 0.18] {'정밀도': 0.1058}
# 가중치 비율 [0.42, 0.41, 0.17] {'정밀도': 0.1054}
# 가중치 비율 [0.42, 0.42, 0.16] {'정밀도': 0.105}
# 가중치 비율 [0.43, 0.0, 0.57] {'정밀도': 0.0827}
# 가중치 비율 [0.43, 0.01, 0.56] {'정밀도': 0.0843}
# 가중치 비율 [0.43, 0.02, 0.55] {'정밀도': 0.0857}
# 가중치 비율 [0.43, 0.03, 0.54] {'정밀도': 0.087}
# 가중치 비율 [0.43, 0.04, 0.53] {'정밀도': 0.0885}
# 가중치 비율 [0.43, 0.05, 0.52] {'정밀도': 0.0899}
# 가중치 비율 [0.43, 0.06, 0.51] {'정밀도': 0.0911}
# 가중치 비율 [0.43, 0.07, 0.5] {'정밀도': 0.0923}
# 가중치 비율 [0.43, 0.08, 0.49] {'정밀도': 0.0937}
# 가중치 비율 [0.43, 0.09, 0.48] {'정밀도': 0.0949}
# 가중치 비율 [0.43, 0.1, 0.47] {'정밀도': 0.096}
# 가중치 비율 [0.43, 0.11, 0.46] {'정밀도': 0.0975}
# 가중치 비율 [0.43, 0.12, 0.45] {'정밀도': 0.0985}
# 가중치 비율 [0.43, 0.13, 0.44] {'정밀도': 0.1}
# 가중치 비율 [0.43, 0.14, 0.43] {'정밀도': 0.1013}
# 가중치 비율 [0.43, 0.15, 0.42] {'정밀도': 0.1024}
# 가중치 비율 [0.43, 0.16, 0.41] {'정밀도': 0.1037}
# 가중치 비율 [0.43, 0.17, 0.4] {'정밀도': 0.1048}
# 가중치 비율 [0.43, 0.18, 0.39] {'정밀도': 0.1057}
# 가중치 비율 [0.43, 0.19, 0.38] {'정밀도': 0.1064}
# 가중치 비율 [0.43, 0.2, 0.37] {'정밀도': 0.1068}
# 가중치 비율 [0.43, 0.21, 0.36] {'정밀도': 0.1071}
# 가중치 비율 [0.43, 0.22, 0.35] {'정밀도': 0.1075}
# 가중치 비율 [0.43, 0.23, 0.34] {'정밀도': 0.1073}
# 가중치 비율 [0.43, 0.24, 0.33] {'정밀도': 0.1078}
# 가중치 비율 [0.43, 0.25, 0.32] {'정밀도': 0.1085}
# 가중치 비율 [0.43, 0.26, 0.31] {'정밀도': 0.1084}
# 가중치 비율 [0.43, 0.27, 0.3] {'정밀도': 0.1091}
# 가중치 비율 [0.43, 0.28, 0.29] {'정밀도': 0.1088}
# 가중치 비율 [0.43, 0.29, 0.28] {'정밀도': 0.1095}
# 가중치 비율 [0.43, 0.3, 0.27] {'정밀도': 0.1093}
# 가중치 비율 [0.43, 0.31, 0.26] {'정밀도': 0.109}
# 가중치 비율 [0.43, 0.32, 0.25] {'정밀도': 0.1089}
# 가중치 비율 [0.43, 0.33, 0.24] {'정밀도': 0.1088}
# 가중치 비율 [0.43, 0.34, 0.23] {'정밀도': 0.1087}
# 가중치 비율 [0.43, 0.35, 0.22] {'정밀도': 0.1084}
# 가중치 비율 [0.43, 0.36, 0.21] {'정밀도': 0.1076}
# 가중치 비율 [0.43, 0.37, 0.2] {'정밀도': 0.1076}
# 가중치 비율 [0.43, 0.38, 0.19] {'정밀도': 0.1069}
# 가중치 비율 [0.43, 0.39, 0.18] {'정밀도': 0.1065}
# 가중치 비율 [0.43, 0.4, 0.17] {'정밀도': 0.1062}
# 가중치 비율 [0.43, 0.41, 0.16] {'정밀도': 0.1052}
# 가중치 비율 [0.43, 0.42, 0.15] {'정밀도': 0.1049}
# 가중치 비율 [0.43, 0.43, 0.14] {'정밀도': 0.104}
# 가중치 비율 [0.44, 0.0, 0.56] {'정밀도': 0.0842}
# 가중치 비율 [0.44, 0.01, 0.55] {'정밀도': 0.0851}
# 가중치 비율 [0.44, 0.02, 0.54] {'정밀도': 0.0868}
# 가중치 비율 [0.44, 0.03, 0.53] {'정밀도': 0.0884}
# 가중치 비율 [0.44, 0.04, 0.52] {'정밀도': 0.0896}
# 가중치 비율 [0.44, 0.05, 0.51] {'정밀도': 0.091}
# 가중치 비율 [0.44, 0.06, 0.5] {'정밀도': 0.0919}
# 가중치 비율 [0.44, 0.07, 0.49] {'정밀도': 0.0936}
# 가중치 비율 [0.44, 0.08, 0.48] {'정밀도': 0.0948}
# 가중치 비율 [0.44, 0.09, 0.47] {'정밀도': 0.0959}
# 가중치 비율 [0.44, 0.1, 0.46] {'정밀도': 0.0973}
# 가중치 비율 [0.44, 0.11, 0.45] {'정밀도': 0.0985}
# 가중치 비율 [0.44, 0.12, 0.44] {'정밀도': 0.0996}
# 가중치 비율 [0.44, 0.13, 0.43] {'정밀도': 0.1012}
# 가중치 비율 [0.44, 0.14, 0.42] {'정밀도': 0.1022}
# 가중치 비율 [0.44, 0.15, 0.41] {'정밀도': 0.1038}
# 가중치 비율 [0.44, 0.16, 0.4] {'정밀도': 0.1048}
# 가중치 비율 [0.44, 0.17, 0.39] {'정밀도': 0.1058}
# 가중치 비율 [0.44, 0.18, 0.38] {'정밀도': 0.1066}
# 가중치 비율 [0.44, 0.19, 0.37] {'정밀도': 0.107}
# 가중치 비율 [0.44, 0.2, 0.36] {'정밀도': 0.1075}
# 가중치 비율 [0.44, 0.21, 0.35] {'정밀도': 0.1074}
# 가중치 비율 [0.44, 0.22, 0.34] {'정밀도': 0.1078}
# 가중치 비율 [0.44, 0.23, 0.33] {'정밀도': 0.108}
# 가중치 비율 [0.44, 0.24, 0.32] {'정밀도': 0.1086}
# 가중치 비율 [0.44, 0.25, 0.31] {'정밀도': 0.1089}
# 가중치 비율 [0.44, 0.26, 0.3] {'정밀도': 0.1093}
# 가중치 비율 [0.44, 0.27, 0.29] {'정밀도': 0.1092}
# 가중치 비율 [0.44, 0.28, 0.28] {'정밀도': 0.1096}
# 가중치 비율 [0.44, 0.29, 0.27] {'정밀도': 0.1096}
# 가중치 비율 [0.44, 0.3, 0.26] {'정밀도': 0.1094}
# 가중치 비율 [0.44, 0.31, 0.25] {'정밀도': 0.1092}
# 가중치 비율 [0.44, 0.32, 0.24] {'정밀도': 0.1092}
# 가중치 비율 [0.44, 0.33, 0.23] {'정밀도': 0.1091}
# 가중치 비율 [0.44, 0.34, 0.22] {'정밀도': 0.1088}
# 가중치 비율 [0.44, 0.35, 0.21] {'정밀도': 0.1085}
# 가중치 비율 [0.44, 0.36, 0.2] {'정밀도': 0.1078}
# 가중치 비율 [0.44, 0.37, 0.19] {'정밀도': 0.1073}
# 가중치 비율 [0.44, 0.38, 0.18] {'정밀도': 0.1069}
# 가중치 비율 [0.44, 0.39, 0.17] {'정밀도': 0.1066}
# 가중치 비율 [0.44, 0.4, 0.16] {'정밀도': 0.1061}
# 가중치 비율 [0.44, 0.41, 0.15] {'정밀도': 0.1053}
# 가중치 비율 [0.44, 0.42, 0.14] {'정밀도': 0.1048}
# 가중치 비율 [0.44, 0.43, 0.13] {'정밀도': 0.1039}
# 가중치 비율 [0.44, 0.44, 0.12] {'정밀도': 0.1031}
# 가중치 비율 [0.45, 0.0, 0.55] {'정밀도': 0.0853}
# 가중치 비율 [0.45, 0.01, 0.54] {'정밀도': 0.0864}
# 가중치 비율 [0.45, 0.02, 0.53] {'정밀도': 0.088}
# 가중치 비율 [0.45, 0.03, 0.52] {'정밀도': 0.0894}
# 가중치 비율 [0.45, 0.04, 0.51] {'정밀도': 0.0907}
# 가중치 비율 [0.45, 0.05, 0.5] {'정밀도': 0.0919}
# 가중치 비율 [0.45, 0.06, 0.49] {'정밀도': 0.0932}
# 가중치 비율 [0.45, 0.07, 0.48] {'정밀도': 0.0946}
# 가중치 비율 [0.45, 0.08, 0.47] {'정밀도': 0.0959}
# 가중치 비율 [0.45, 0.09, 0.46] {'정밀도': 0.0968}
# 가중치 비율 [0.45, 0.1, 0.45] {'정밀도': 0.098}
# 가중치 비율 [0.45, 0.11, 0.44] {'정밀도': 0.0996}
# 가중치 비율 [0.45, 0.12, 0.43] {'정밀도': 0.1012}
# 가중치 비율 [0.45, 0.13, 0.42] {'정밀도': 0.1026}
# 가중치 비율 [0.45, 0.14, 0.41] {'정밀도': 0.1035}
# 가중치 비율 [0.45, 0.15, 0.4] {'정밀도': 0.1048}
# 가중치 비율 [0.45, 0.16, 0.39] {'정밀도': 0.1056}
# 가중치 비율 [0.45, 0.17, 0.38] {'정밀도': 0.1068}
# 가중치 비율 [0.45, 0.18, 0.37] {'정밀도': 0.107}
# 가중치 비율 [0.45, 0.19, 0.36] {'정밀도': 0.1074}
# 가중치 비율 [0.45, 0.2, 0.35] {'정밀도': 0.1076}
# 가중치 비율 [0.45, 0.21, 0.34] {'정밀도': 0.108}
# 가중치 비율 [0.45, 0.22, 0.33] {'정밀도': 0.1086}
# 가중치 비율 [0.45, 0.23, 0.32] {'정밀도': 0.1086}
# 가중치 비율 [0.45, 0.24, 0.31] {'정밀도': 0.1094}
# 가중치 비율 [0.45, 0.25, 0.3] {'정밀도': 0.1092}
# 가중치 비율 [0.45, 0.26, 0.29] {'정밀도': 0.1095}
# 가중치 비율 [0.45, 0.27, 0.28] {'정밀도': 0.1096}
# 가중치 비율 [0.45, 0.28, 0.27] {'정밀도': 0.1101}
# 가중치 비율 [0.45, 0.29, 0.26] {'정밀도': 0.11}
# 가중치 비율 [0.45, 0.3, 0.25] {'정밀도': 0.1098}
# 가중치 비율 [0.45, 0.31, 0.24] {'정밀도': 0.1095}
# 가중치 비율 [0.45, 0.32, 0.23] {'정밀도': 0.1092}
# 가중치 비율 [0.45, 0.33, 0.22] {'정밀도': 0.109}
# 가중치 비율 [0.45, 0.34, 0.21] {'정밀도': 0.1084}
# 가중치 비율 [0.45, 0.35, 0.2] {'정밀도': 0.1085}
# 가중치 비율 [0.45, 0.36, 0.19] {'정밀도': 0.1076}
# 가중치 비율 [0.45, 0.37, 0.18] {'정밀도': 0.1074}
# 가중치 비율 [0.45, 0.38, 0.17] {'정밀도': 0.107}
# 가중치 비율 [0.45, 0.39, 0.16] {'정밀도': 0.1066}
# 가중치 비율 [0.45, 0.4, 0.15] {'정밀도': 0.1062}
# 가중치 비율 [0.45, 0.41, 0.14] {'정밀도': 0.1053}
# 가중치 비율 [0.45, 0.42, 0.13] {'정밀도': 0.1044}
# 가중치 비율 [0.45, 0.43, 0.12] {'정밀도': 0.1041}
# 가중치 비율 [0.45, 0.44, 0.11] {'정밀도': 0.1031}
# 가중치 비율 [0.45, 0.45, 0.1] {'정밀도': 0.1028}
# 가중치 비율 [0.46, 0.0, 0.54] {'정밀도': 0.0862}
# 가중치 비율 [0.46, 0.01, 0.53] {'정밀도': 0.0876}
# 가중치 비율 [0.46, 0.02, 0.52] {'정밀도': 0.089}
# 가중치 비율 [0.46, 0.03, 0.51] {'정밀도': 0.0905}
# 가중치 비율 [0.46, 0.04, 0.5] {'정밀도': 0.0917}
# 가중치 비율 [0.46, 0.05, 0.49] {'정밀도': 0.0933}
# 가중치 비율 [0.46, 0.06, 0.48] {'정밀도': 0.0945}
# 가중치 비율 [0.46, 0.07, 0.47] {'정밀도': 0.0957}
# 가중치 비율 [0.46, 0.08, 0.46] {'정밀도': 0.0968}
# 가중치 비율 [0.46, 0.09, 0.45] {'정밀도': 0.098}
# 가중치 비율 [0.46, 0.1, 0.44] {'정밀도': 0.0995}
# 가중치 비율 [0.46, 0.11, 0.43] {'정밀도': 0.101}
# 가중치 비율 [0.46, 0.12, 0.42] {'정밀도': 0.1029}
# 가중치 비율 [0.46, 0.13, 0.41] {'정밀도': 0.1035}
# 가중치 비율 [0.46, 0.14, 0.4] {'정밀도': 0.1046}
# 가중치 비율 [0.46, 0.15, 0.39] {'정밀도': 0.1058}
# 가중치 비율 [0.46, 0.16, 0.38] {'정밀도': 0.1068}
# 가중치 비율 [0.46, 0.17, 0.37] {'정밀도': 0.1073}
# 가중치 비율 [0.46, 0.18, 0.36] {'정밀도': 0.1074}
# 가중치 비율 [0.46, 0.19, 0.35] {'정밀도': 0.1079}
# 가중치 비율 [0.46, 0.2, 0.34] {'정밀도': 0.1079}
# 가중치 비율 [0.46, 0.21, 0.33] {'정밀도': 0.1086}
# 가중치 비율 [0.46, 0.22, 0.32] {'정밀도': 0.1094}
# 가중치 비율 [0.46, 0.23, 0.31] {'정밀도': 0.1094}
# 가중치 비율 [0.46, 0.24, 0.3] {'정밀도': 0.1097}
# 가중치 비율 [0.46, 0.25, 0.29] {'정밀도': 0.1097}
# 가중치 비율 [0.46, 0.26, 0.28] {'정밀도': 0.1099}
# 가중치 비율 [0.46, 0.27, 0.27] {'정밀도': 0.1104}
# 가중치 비율 [0.46, 0.28, 0.26] {'정밀도': 0.1105}
# 가중치 비율 [0.46, 0.29, 0.25] {'정밀도': 0.1104}
# 가중치 비율 [0.46, 0.3, 0.24] {'정밀도': 0.1097}
# 가중치 비율 [0.46, 0.31, 0.23] {'정밀도': 0.1096}
# 가중치 비율 [0.46, 0.32, 0.22] {'정밀도': 0.1092}
# 가중치 비율 [0.46, 0.33, 0.21] {'정밀도': 0.1087}
# 가중치 비율 [0.46, 0.34, 0.2] {'정밀도': 0.1084}
# 가중치 비율 [0.46, 0.35, 0.19] {'정밀도': 0.1084}
# 가중치 비율 [0.46, 0.36, 0.18] {'정밀도': 0.108}
# 가중치 비율 [0.46, 0.37, 0.17] {'정밀도': 0.1072}
# 가중치 비율 [0.46, 0.38, 0.16] {'정밀도': 0.1073}
# 가중치 비율 [0.46, 0.39, 0.15] {'정밀도': 0.1063}
# 가중치 비율 [0.46, 0.4, 0.14] {'정밀도': 0.106}
# 가중치 비율 [0.46, 0.41, 0.13] {'정밀도': 0.1053}
# 가중치 비율 [0.46, 0.42, 0.12] {'정밀도': 0.1044}
# 가중치 비율 [0.46, 0.43, 0.11] {'정밀도': 0.1037}
# 가중치 비율 [0.46, 0.44, 0.1] {'정밀도': 0.1028}
# 가중치 비율 [0.46, 0.45, 0.09] {'정밀도': 0.1022}
# 가중치 비율 [0.46, 0.46, 0.08] {'정밀도': 0.1016}
# 가중치 비율 [0.47, 0.0, 0.53] {'정밀도': 0.0873}
# 가중치 비율 [0.47, 0.01, 0.52] {'정밀도': 0.0887}
# 가중치 비율 [0.47, 0.02, 0.51] {'정밀도': 0.0902}
# 가중치 비율 [0.47, 0.03, 0.5] {'정밀도': 0.0914}
# 가중치 비율 [0.47, 0.04, 0.49] {'정밀도': 0.0931}
# 가중치 비율 [0.47, 0.05, 0.48] {'정밀도': 0.0943}
# 가중치 비율 [0.47, 0.06, 0.47] {'정밀도': 0.0955}
# 가중치 비율 [0.47, 0.07, 0.46] {'정밀도': 0.0967}
# 가중치 비율 [0.47, 0.08, 0.45] {'정밀도': 0.0979}
# 가중치 비율 [0.47, 0.09, 0.44] {'정밀도': 0.0994}
# 가중치 비율 [0.47, 0.1, 0.43] {'정밀도': 0.1008}
# 가중치 비율 [0.47, 0.11, 0.42] {'정밀도': 0.1026}
# 가중치 비율 [0.47, 0.12, 0.41] {'정밀도': 0.1037}
# 가중치 비율 [0.47, 0.13, 0.4] {'정밀도': 0.1047}
# 가중치 비율 [0.47, 0.14, 0.39] {'정밀도': 0.1057}
# 가중치 비율 [0.47, 0.15, 0.38] {'정밀도': 0.1068}
# 가중치 비율 [0.47, 0.16, 0.37] {'정밀도': 0.1077}
# 가중치 비율 [0.47, 0.17, 0.36] {'정밀도': 0.1081}
# 가중치 비율 [0.47, 0.18, 0.35] {'정밀도': 0.1082}
# 가중치 비율 [0.47, 0.19, 0.34] {'정밀도': 0.1087}
# 가중치 비율 [0.47, 0.2, 0.33] {'정밀도': 0.1087}
# 가중치 비율 [0.47, 0.21, 0.32] {'정밀도': 0.1093}
# 가중치 비율 [0.47, 0.22, 0.31] {'정밀도': 0.1098}
# 가중치 비율 [0.47, 0.23, 0.3] {'정밀도': 0.1098}
# 가중치 비율 [0.47, 0.24, 0.29] {'정밀도': 0.1099}
# 가중치 비율 [0.47, 0.25, 0.28] {'정밀도': 0.1105}
# ...
# 가중치 비율 [0.73, 0.23, 0.04] {'정밀도': 0.1116}
# 가중치 비율 [0.73, 0.24, 0.03] {'정밀도': 0.1109}
# 가중치 비율 [0.73, 0.25, 0.02] {'정밀도': 0.1103}
# 가중치 비율 [0.73, 0.26, 0.01] {'정밀도': 0.1096}
# 가중치 비율 [0.73, 0.27, 0.0] {'정밀도': 0.1087}
# 가중치 비율 [0.74, 0.0, 0.26] {'정밀도': 0.1142}
# 가중치 비율 [0.74, 0.01, 0.25] {'정밀도': 0.1152}
# 가중치 비율 [0.74, 0.02, 0.24] {'정밀도': 0.1153}
# 가중치 비율 [0.74, 0.03, 0.23] {'정밀도': 0.1159}
# 가중치 비율 [0.74, 0.04, 0.22] {'정밀도': 0.1166}
# 가중치 비율 [0.74, 0.05, 0.21] {'정밀도': 0.1168}
# 가중치 비율 [0.74, 0.06, 0.2] {'정밀도': 0.1172}
# 가중치 비율 [0.74, 0.07, 0.19] {'정밀도': 0.1178}
# 가중치 비율 [0.74, 0.08, 0.18] {'정밀도': 0.1177}
# 가중치 비율 [0.74, 0.09, 0.17] {'정밀도': 0.1176}
# 가중치 비율 [0.74, 0.1, 0.16] {'정밀도': 0.1175}
# 가중치 비율 [0.74, 0.11, 0.15] {'정밀도': 0.117}
# 가중치 비율 [0.74, 0.12, 0.14] {'정밀도': 0.1168}
# 가중치 비율 [0.74, 0.13, 0.13] {'정밀도': 0.1168}
# 가중치 비율 [0.74, 0.14, 0.12] {'정밀도': 0.1162}
# 가중치 비율 [0.74, 0.15, 0.11] {'정밀도': 0.1155}
# 가중치 비율 [0.74, 0.16, 0.1] {'정밀도': 0.1153}
# 가중치 비율 [0.74, 0.17, 0.09] {'정밀도': 0.115}
# 가중치 비율 [0.74, 0.18, 0.08] {'정밀도': 0.1143}
# 가중치 비율 [0.74, 0.19, 0.07] {'정밀도': 0.1136}
# 가중치 비율 [0.74, 0.2, 0.06] {'정밀도': 0.1131}
# 가중치 비율 [0.74, 0.21, 0.05] {'정밀도': 0.1124}
# 가중치 비율 [0.74, 0.22, 0.04] {'정밀도': 0.112}
# 가중치 비율 [0.74, 0.23, 0.03] {'정밀도': 0.1116}
# 가중치 비율 [0.74, 0.24, 0.02] {'정밀도': 0.111}
# 가중치 비율 [0.74, 0.25, 0.01] {'정밀도': 0.1101}
# 가중치 비율 [0.74, 0.26, 0.0] {'정밀도': 0.1092}
# 가중치 비율 [0.75, 0.0, 0.25] {'정밀도': 0.1148}
# 가중치 비율 [0.75, 0.01, 0.24] {'정밀도': 0.1156}
# 가중치 비율 [0.75, 0.02, 0.23] {'정밀도': 0.1157}
# 가중치 비율 [0.75, 0.03, 0.22] {'정밀도': 0.1164}
# 가중치 비율 [0.75, 0.04, 0.21] {'정밀도': 0.1169}
# 가중치 비율 [0.75, 0.05, 0.2] {'정밀도': 0.1171}
# 가중치 비율 [0.75, 0.06, 0.19] {'정밀도': 0.1179}
# 가중치 비율 [0.75, 0.07, 0.18] {'정밀도': 0.1181}
# 가중치 비율 [0.75, 0.08, 0.17] {'정밀도': 0.1181}
# 가중치 비율 [0.75, 0.09, 0.16] {'정밀도': 0.1178}
# 가중치 비율 [0.75, 0.1, 0.15] {'정밀도': 0.1174}
# 가중치 비율 [0.75, 0.11, 0.14] {'정밀도': 0.117}
# 가중치 비율 [0.75, 0.12, 0.13] {'정밀도': 0.1167}
# 가중치 비율 [0.75, 0.13, 0.12] {'정밀도': 0.1165}
# 가중치 비율 [0.75, 0.14, 0.11] {'정밀도': 0.116}
# 가중치 비율 [0.75, 0.15, 0.1] {'정밀도': 0.1154}
# 가중치 비율 [0.75, 0.16, 0.09] {'정밀도': 0.1153}
# 가중치 비율 [0.75, 0.17, 0.08] {'정밀도': 0.1147}
# 가중치 비율 [0.75, 0.18, 0.07] {'정밀도': 0.114}
# 가중치 비율 [0.75, 0.19, 0.06] {'정밀도': 0.1137}
# 가중치 비율 [0.75, 0.2, 0.05] {'정밀도': 0.1129}
# 가중치 비율 [0.75, 0.21, 0.04] {'정밀도': 0.1123}
# 가중치 비율 [0.75, 0.22, 0.03] {'정밀도': 0.112}
# 가중치 비율 [0.75, 0.23, 0.02] {'정밀도': 0.1113}
# 가중치 비율 [0.75, 0.24, 0.01] {'정밀도': 0.1106}
# 가중치 비율 [0.75, 0.25, 0.0] {'정밀도': 0.1096}
# 가중치 비율 [0.76, 0.0, 0.24] {'정밀도': 0.1155}
# 가중치 비율 [0.76, 0.01, 0.23] {'정밀도': 0.1159}
# 가중치 비율 [0.76, 0.02, 0.22] {'정밀도': 0.1163}
# 가중치 비율 [0.76, 0.03, 0.21] {'정밀도': 0.1168}
# 가중치 비율 [0.76, 0.04, 0.2] {'정밀도': 0.1171}
# 가중치 비율 [0.76, 0.05, 0.19] {'정밀도': 0.1176}
# 가중치 비율 [0.76, 0.06, 0.18] {'정밀도': 0.1183}
# 가중치 비율 [0.76, 0.07, 0.17] {'정밀도': 0.1184}
# 가중치 비율 [0.76, 0.08, 0.16] {'정밀도': 0.118}
# 가중치 비율 [0.76, 0.09, 0.15] {'정밀도': 0.1176}
# 가중치 비율 [0.76, 0.1, 0.14] {'정밀도': 0.1172}
# 가중치 비율 [0.76, 0.11, 0.13] {'정밀도': 0.1167}
# 가중치 비율 [0.76, 0.12, 0.12] {'정밀도': 0.1168}
# 가중치 비율 [0.76, 0.13, 0.11] {'정밀도': 0.1162}
# 가중치 비율 [0.76, 0.14, 0.1] {'정밀도': 0.1157}
# 가중치 비율 [0.76, 0.15, 0.09] {'정밀도': 0.1155}
# 가중치 비율 [0.76, 0.16, 0.08] {'정밀도': 0.1154}
# 가중치 비율 [0.76, 0.17, 0.07] {'정밀도': 0.1144}
# 가중치 비율 [0.76, 0.18, 0.06] {'정밀도': 0.1139}
# 가중치 비율 [0.76, 0.19, 0.05] {'정밀도': 0.1134}
# 가중치 비율 [0.76, 0.2, 0.04] {'정밀도': 0.1129}
# 가중치 비율 [0.76, 0.21, 0.03] {'정밀도': 0.1122}
# 가중치 비율 [0.76, 0.22, 0.02] {'정밀도': 0.1118}
# 가중치 비율 [0.76, 0.23, 0.01] {'정밀도': 0.1109}
# 가중치 비율 [0.76, 0.24, 0.0] {'정밀도': 0.1104}
# 가중치 비율 [0.77, 0.0, 0.23] {'정밀도': 0.1159}
# 가중치 비율 [0.77, 0.01, 0.22] {'정밀도': 0.1164}
# 가중치 비율 [0.77, 0.02, 0.21] {'정밀도': 0.1164}
# 가중치 비율 [0.77, 0.03, 0.2] {'정밀도': 0.1172}
# 가중치 비율 [0.77, 0.04, 0.19] {'정밀도': 0.1176}
# 가중치 비율 [0.77, 0.05, 0.18] {'정밀도': 0.1181}
# 가중치 비율 [0.77, 0.06, 0.17] {'정밀도': 0.1183}
# 가중치 비율 [0.77, 0.07, 0.16] {'정밀도': 0.118}
# 가중치 비율 [0.77, 0.08, 0.15] {'정밀도': 0.1179}
# 가중치 비율 [0.77, 0.09, 0.14] {'정밀도': 0.1177}
# 가중치 비율 [0.77, 0.1, 0.13] {'정밀도': 0.1167}
# 가중치 비율 [0.77, 0.11, 0.12] {'정밀도': 0.1167}
# 가중치 비율 [0.77, 0.12, 0.11] {'정밀도': 0.1166}
# 가중치 비율 [0.77, 0.13, 0.1] {'정밀도': 0.116}
# 가중치 비율 [0.77, 0.14, 0.09] {'정밀도': 0.1158}
# 가중치 비율 [0.77, 0.15, 0.08] {'정밀도': 0.1155}
# 가중치 비율 [0.77, 0.16, 0.07] {'정밀도': 0.1147}
# 가중치 비율 [0.77, 0.17, 0.06] {'정밀도': 0.1145}
# 가중치 비율 [0.77, 0.18, 0.05] {'정밀도': 0.1137}
# 가중치 비율 [0.77, 0.19, 0.04] {'정밀도': 0.1132}
# 가중치 비율 [0.77, 0.2, 0.03] {'정밀도': 0.1126}
# 가중치 비율 [0.77, 0.21, 0.02] {'정밀도': 0.112}
# 가중치 비율 [0.77, 0.22, 0.01] {'정밀도': 0.1117}
# 가중치 비율 [0.77, 0.23, 0.0] {'정밀도': 0.1107}
# 가중치 비율 [0.78, 0.0, 0.22] {'정밀도': 0.1164}
# 가중치 비율 [0.78, 0.01, 0.21] {'정밀도': 0.1169}
# 가중치 비율 [0.78, 0.02, 0.2] {'정밀도': 0.117}
# 가중치 비율 [0.78, 0.03, 0.19] {'정밀도': 0.1182}
# 가중치 비율 [0.78, 0.04, 0.18] {'정밀도': 0.1178}
# 가중치 비율 [0.78, 0.05, 0.17] {'정밀도': 0.1186}
# 가중치 비율 [0.78, 0.06, 0.16] {'정밀도': 0.1187}
# 가중치 비율 [0.78, 0.07, 0.15] {'정밀도': 0.1181}
# 가중치 비율 [0.78, 0.08, 0.14] {'정밀도': 0.1182}
# 가중치 비율 [0.78, 0.09, 0.13] {'정밀도': 0.1173}
# 가중치 비율 [0.78, 0.1, 0.12] {'정밀도': 0.1167}
# 가중치 비율 [0.78, 0.11, 0.11] {'정밀도': 0.1166}
# 가중치 비율 [0.78, 0.12, 0.1] {'정밀도': 0.1165}
# 가중치 비율 [0.78, 0.13, 0.09] {'정밀도': 0.1159}
# 가중치 비율 [0.78, 0.14, 0.08] {'정밀도': 0.1156}
# 가중치 비율 [0.78, 0.15, 0.07] {'정밀도': 0.115}
# 가중치 비율 [0.78, 0.16, 0.06] {'정밀도': 0.1148}
# 가중치 비율 [0.78, 0.17, 0.05] {'정밀도': 0.1142}
# 가중치 비율 [0.78, 0.18, 0.04] {'정밀도': 0.1136}
# 가중치 비율 [0.78, 0.19, 0.03] {'정밀도': 0.1129}
# 가중치 비율 [0.78, 0.2, 0.02] {'정밀도': 0.1123}
# 가중치 비율 [0.78, 0.21, 0.01] {'정밀도': 0.1118}
# 가중치 비율 [0.78, 0.22, 0.0] {'정밀도': 0.1113}
# 가중치 비율 [0.79, 0.0, 0.21] {'정밀도': 0.1168}
# 가중치 비율 [0.79, 0.01, 0.2] {'정밀도': 0.1176}
# 가중치 비율 [0.79, 0.02, 0.19] {'정밀도': 0.1176}
# 가중치 비율 [0.79, 0.03, 0.18] {'정밀도': 0.118}
# 가중치 비율 [0.79, 0.04, 0.17] {'정밀도': 0.1181}
# 가중치 비율 [0.79, 0.05, 0.16] {'정밀도': 0.1186}
# 가중치 비율 [0.79, 0.06, 0.15] {'정밀도': 0.1181}
# 가중치 비율 [0.79, 0.07, 0.14] {'정밀도': 0.1181}
# 가중치 비율 [0.79, 0.08, 0.13] {'정밀도': 0.1178}
# 가중치 비율 [0.79, 0.09, 0.12] {'정밀도': 0.1174}
# 가중치 비율 [0.79, 0.1, 0.11] {'정밀도': 0.1169}
# 가중치 비율 [0.79, 0.11, 0.1] {'정밀도': 0.1167}
# 가중치 비율 [0.79, 0.12, 0.09] {'정밀도': 0.1166}
# 가중치 비율 [0.79, 0.13, 0.08] {'정밀도': 0.1161}
# 가중치 비율 [0.79, 0.14, 0.07] {'정밀도': 0.1157}
# 가중치 비율 [0.79, 0.15, 0.06] {'정밀도': 0.1149}
# 가중치 비율 [0.79, 0.16, 0.05] {'정밀도': 0.1147}
# 가중치 비율 [0.79, 0.17, 0.04] {'정밀도': 0.1141}
# 가중치 비율 [0.79, 0.18, 0.03] {'정밀도': 0.1133}
# 가중치 비율 [0.79, 0.19, 0.02] {'정밀도': 0.1125}
# 가중치 비율 [0.79, 0.2, 0.01] {'정밀도': 0.1122}
# 가중치 비율 [0.79, 0.21, 0.0] {'정밀도': 0.1116}
# 가중치 비율 [0.8, 0.0, 0.2] {'정밀도': 0.1176}
# 가중치 비율 [0.8, 0.01, 0.19] {'정밀도': 0.1177}
# 가중치 비율 [0.8, 0.02, 0.18] {'정밀도': 0.118}
# 가중치 비율 [0.8, 0.03, 0.17] {'정밀도': 0.1181}
# 가중치 비율 [0.8, 0.04, 0.16] {'정밀도': 0.1184}
# 가중치 비율 [0.8, 0.05, 0.15] {'정밀도': 0.1186}
# 가중치 비율 [0.8, 0.06, 0.14] {'정밀도': 0.1184}
# 가중치 비율 [0.8, 0.07, 0.13] {'정밀도': 0.1184}
# 가중치 비율 [0.8, 0.08, 0.12] {'정밀도': 0.1179}
# 가중치 비율 [0.8, 0.09, 0.11] {'정밀도': 0.1171}
# 가중치 비율 [0.8, 0.1, 0.1] {'정밀도': 0.1169}
# 가중치 비율 [0.8, 0.11, 0.09] {'정밀도': 0.1169}
# 가중치 비율 [0.8, 0.12, 0.08] {'정밀도': 0.1164}
# 가중치 비율 [0.8, 0.13, 0.07] {'정밀도': 0.1161}
# 가중치 비율 [0.8, 0.14, 0.06] {'정밀도': 0.1148}
# 가중치 비율 [0.8, 0.15, 0.05] {'정밀도': 0.1149}
# 가중치 비율 [0.8, 0.16, 0.04] {'정밀도': 0.1146}
# 가중치 비율 [0.8, 0.17, 0.03] {'정밀도': 0.114}
# 가중치 비율 [0.8, 0.18, 0.02] {'정밀도': 0.1133}
# 가중치 비율 [0.8, 0.19, 0.01] {'정밀도': 0.1126}
# 가중치 비율 [0.8, 0.2, 0.0] {'정밀도': 0.112}
# 가중치 비율 [0.81, 0.0, 0.19] {'정밀도': 0.1183}
# 가중치 비율 [0.81, 0.01, 0.18] {'정밀도': 0.1181}
# 가중치 비율 [0.81, 0.02, 0.17] {'정밀도': 0.1181}
# 가중치 비율 [0.81, 0.03, 0.16] {'정밀도': 0.1185}
# 가중치 비율 [0.81, 0.04, 0.15] {'정밀도': 0.1185}
# 가중치 비율 [0.81, 0.05, 0.14] {'정밀도': 0.1188}
# 가중치 비율 [0.81, 0.06, 0.13] {'정밀도': 0.1182}
# 가중치 비율 [0.81, 0.07, 0.12] {'정밀도': 0.118}
# 가중치 비율 [0.81, 0.08, 0.11] {'정밀도': 0.1177}
# 가중치 비율 [0.81, 0.09, 0.1] {'정밀도': 0.117}
# 가중치 비율 [0.81, 0.1, 0.09] {'정밀도': 0.1169}
# 가중치 비율 [0.81, 0.11, 0.08] {'정밀도': 0.1168}
# 가중치 비율 [0.81, 0.12, 0.07] {'정밀도': 0.1163}
# 가중치 비율 [0.81, 0.13, 0.06] {'정밀도': 0.1155}
# 가중치 비율 [0.81, 0.14, 0.05] {'정밀도': 0.1148}
# 가중치 비율 [0.81, 0.15, 0.04] {'정밀도': 0.1147}
# 가중치 비율 [0.81, 0.16, 0.03] {'정밀도': 0.1145}
# 가중치 비율 [0.81, 0.17, 0.02] {'정밀도': 0.1138}
# 가중치 비율 [0.81, 0.18, 0.01] {'정밀도': 0.1129}
# 가중치 비율 [0.81, 0.19, 0.0] {'정밀도': 0.1126}
# 가중치 비율 [0.82, 0.0, 0.18] {'정밀도': 0.1184}
# 가중치 비율 [0.82, 0.01, 0.17] {'정밀도': 0.1183}
# 가중치 비율 [0.82, 0.02, 0.16] {'정밀도': 0.1181}
# 가중치 비율 [0.82, 0.03, 0.15] {'정밀도': 0.1184}
# 가중치 비율 [0.82, 0.04, 0.14] {'정밀도': 0.1188}
# 가중치 비율 [0.82, 0.05, 0.13] {'정밀도': 0.1188}
# 가중치 비율 [0.82, 0.06, 0.12] {'정밀도': 0.1182}
# 가중치 비율 [0.82, 0.07, 0.11] {'정밀도': 0.1178}
# 가중치 비율 [0.82, 0.08, 0.1] {'정밀도': 0.1174}
# 가중치 비율 [0.82, 0.09, 0.09] {'정밀도': 0.1173}
# 가중치 비율 [0.82, 0.1, 0.08] {'정밀도': 0.117}
# 가중치 비율 [0.82, 0.11, 0.07] {'정밀도': 0.1166}
# 가중치 비율 [0.82, 0.12, 0.06] {'정밀도': 0.116}
# 가중치 비율 [0.82, 0.13, 0.05] {'정밀도': 0.1151}
# 가중치 비율 [0.82, 0.14, 0.04] {'정밀도': 0.1146}
# 가중치 비율 [0.82, 0.15, 0.03] {'정밀도': 0.1148}
# 가중치 비율 [0.82, 0.16, 0.02] {'정밀도': 0.1142}
# 가중치 비율 [0.82, 0.17, 0.01] {'정밀도': 0.1136}
# 가중치 비율 [0.82, 0.18, 0.0] {'정밀도': 0.1129}
# 가중치 비율 [0.83, 0.0, 0.17] {'정밀도': 0.1187}
# 가중치 비율 [0.83, 0.01, 0.16] {'정밀도': 0.1182}
# 가중치 비율 [0.83, 0.02, 0.15] {'정밀도': 0.1187}
# 가중치 비율 [0.83, 0.03, 0.14] {'정밀도': 0.1189}
# 가중치 비율 [0.83, 0.04, 0.13] {'정밀도': 0.1189}
# 가중치 비율 [0.83, 0.05, 0.12] {'정밀도': 0.1187}
# 가중치 비율 [0.83, 0.06, 0.11] {'정밀도': 0.1177}
# 가중치 비율 [0.83, 0.07, 0.1] {'정밀도': 0.1179}
# 가중치 비율 [0.83, 0.08, 0.09] {'정밀도': 0.1172}
# 가중치 비율 [0.83, 0.09, 0.08] {'정밀도': 0.1171}
# 가중치 비율 [0.83, 0.1, 0.07] {'정밀도': 0.1165}
# 가중치 비율 [0.83, 0.11, 0.06] {'정밀도': 0.1164}
# 가중치 비율 [0.83, 0.12, 0.05] {'정밀도': 0.1156}
# 가중치 비율 [0.83, 0.13, 0.04] {'정밀도': 0.1151}
# 가중치 비율 [0.83, 0.14, 0.03] {'정밀도': 0.1147}
# 가중치 비율 [0.83, 0.15, 0.02] {'정밀도': 0.1145}
# 가중치 비율 [0.83, 0.16, 0.01] {'정밀도': 0.114}
# 가중치 비율 [0.83, 0.17, 0.0] {'정밀도': 0.1136}
# 가중치 비율 [0.84, 0.0, 0.16] {'정밀도': 0.1185}
# 가중치 비율 [0.84, 0.01, 0.15] {'정밀도': 0.1185}
# 가중치 비율 [0.84, 0.02, 0.14] {'정밀도': 0.1192}
# 가중치 비율 [0.84, 0.03, 0.13] {'정밀도': 0.1191}
# 가중치 비율 [0.84, 0.04, 0.12] {'정밀도': 0.1188}
# 가중치 비율 [0.84, 0.05, 0.11] {'정밀도': 0.1181}
# 가중치 비율 [0.84, 0.06, 0.1] {'정밀도': 0.1177}
# 가중치 비율 [0.84, 0.07, 0.09] {'정밀도': 0.1176}
# 가중치 비율 [0.84, 0.08, 0.08] {'정밀도': 0.117}
# 가중치 비율 [0.84, 0.09, 0.07] {'정밀도': 0.1166}
# 가중치 비율 [0.84, 0.1, 0.06] {'정밀도': 0.1162}
# 가중치 비율 [0.84, 0.11, 0.05] {'정밀도': 0.1158}
# 가중치 비율 [0.84, 0.12, 0.04] {'정밀도': 0.1152}
# 가중치 비율 [0.84, 0.13, 0.03] {'정밀도': 0.1152}
# 가중치 비율 [0.84, 0.14, 0.02] {'정밀도': 0.1145}
# 가중치 비율 [0.84, 0.15, 0.01] {'정밀도': 0.1142}
# 가중치 비율 [0.84, 0.16, 0.0] {'정밀도': 0.114}
# 가중치 비율 [0.85, 0.0, 0.15] {'정밀도': 0.1185}
# 가중치 비율 [0.85, 0.01, 0.14] {'정밀도': 0.1187}
# 가중치 비율 [0.85, 0.02, 0.13] {'정밀도': 0.1191}
# 가중치 비율 [0.85, 0.03, 0.12] {'정밀도': 0.1191}
# 가중치 비율 [0.85, 0.04, 0.11] {'정밀도': 0.1182}
# 가중치 비율 [0.85, 0.05, 0.1] {'정밀도': 0.1177}
# 가중치 비율 [0.85, 0.06, 0.09] {'정밀도': 0.1176}
# 가중치 비율 [0.85, 0.07, 0.08] {'정밀도': 0.1174}
# 가중치 비율 [0.85, 0.08, 0.07] {'정밀도': 0.1165}
# 가중치 비율 [0.85, 0.09, 0.06] {'정밀도': 0.1165}
# 가중치 비율 [0.85, 0.1, 0.05] {'정밀도': 0.1161}
# 가중치 비율 [0.85, 0.11, 0.04] {'정밀도': 0.1155}
# 가중치 비율 [0.85, 0.12, 0.03] {'정밀도': 0.1153}
# 가중치 비율 [0.85, 0.13, 0.02] {'정밀도': 0.1148}
# 가중치 비율 [0.85, 0.14, 0.01] {'정밀도': 0.1143}
# 가중치 비율 [0.85, 0.15, 0.0] {'정밀도': 0.1142}
# 가중치 비율 [0.86, 0.0, 0.14] {'정밀도': 0.119}
# 가중치 비율 [0.86, 0.01, 0.13] {'정밀도': 0.119}
# 가중치 비율 [0.86, 0.02, 0.12] {'정밀도': 0.1191}
# 가중치 비율 [0.86, 0.03, 0.11] {'정밀도': 0.119}
# 가중치 비율 [0.86, 0.04, 0.1] {'정밀도': 0.1181}
# 가중치 비율 [0.86, 0.05, 0.09] {'정밀도': 0.1178}
# 가중치 비율 [0.86, 0.06, 0.08] {'정밀도': 0.1175}
# 가중치 비율 [0.86, 0.07, 0.07] {'정밀도': 0.117}
# 가중치 비율 [0.86, 0.08, 0.06] {'정밀도': 0.1167}
# 가중치 비율 [0.86, 0.09, 0.05] {'정밀도': 0.1162}
# 가중치 비율 [0.86, 0.1, 0.04] {'정밀도': 0.1157}
# 가중치 비율 [0.86, 0.11, 0.03] {'정밀도': 0.1157}
# 가중치 비율 [0.86, 0.12, 0.02] {'정밀도': 0.1153}
# 가중치 비율 [0.86, 0.13, 0.01] {'정밀도': 0.1148}
# 가중치 비율 [0.86, 0.14, 0.0] {'정밀도': 0.114}
# 가중치 비율 [0.87, 0.0, 0.13] {'정밀도': 0.1187}
# 가중치 비율 [0.87, 0.01, 0.12] {'정밀도': 0.1192}
# 가중치 비율 [0.87, 0.02, 0.11] {'정밀도': 0.1193}
# 가중치 비율 [0.87, 0.03, 0.1] {'정밀도': 0.1187}
# 가중치 비율 [0.87, 0.04, 0.09] {'정밀도': 0.1178}
# 가중치 비율 [0.87, 0.05, 0.08] {'정밀도': 0.1174}
# 가중치 비율 [0.87, 0.06, 0.07] {'정밀도': 0.1171}
# 가중치 비율 [0.87, 0.07, 0.06] {'정밀도': 0.1164}
# 가중치 비율 [0.87, 0.08, 0.05] {'정밀도': 0.1164}
# 가중치 비율 [0.87, 0.09, 0.04] {'정밀도': 0.1161}
# 가중치 비율 [0.87, 0.1, 0.03] {'정밀도': 0.1156}
# 가중치 비율 [0.87, 0.11, 0.02] {'정밀도': 0.1156}
# 가중치 비율 [0.87, 0.12, 0.01] {'정밀도': 0.1152}
# 가중치 비율 [0.87, 0.13, 0.0] {'정밀도': 0.1146}
# 가중치 비율 [0.88, 0.0, 0.12] {'정밀도': 0.1194}
# 가중치 비율 [0.88, 0.01, 0.11] {'정밀도': 0.1191}
# 가중치 비율 [0.88, 0.02, 0.1] {'정밀도': 0.1186}
# 가중치 비율 [0.88, 0.03, 0.09] {'정밀도': 0.1183}
# 가중치 비율 [0.88, 0.04, 0.08] {'정밀도': 0.1176}
# 가중치 비율 [0.88, 0.05, 0.07] {'정밀도': 0.1174}
# 가중치 비율 [0.88, 0.06, 0.06] {'정밀도': 0.1168}
# 가중치 비율 [0.88, 0.07, 0.05] {'정밀도': 0.1164}
# 가중치 비율 [0.88, 0.08, 0.04] {'정밀도': 0.1163}
# 가중치 비율 [0.88, 0.09, 0.03] {'정밀도': 0.1157}
# 가중치 비율 [0.88, 0.1, 0.02] {'정밀도': 0.1158}
# 가중치 비율 [0.88, 0.11, 0.01] {'정밀도': 0.1153}
# 가중치 비율 [0.88, 0.12, 0.0] {'정밀도': 0.1149}
# 가중치 비율 [0.89, 0.0, 0.11] {'정밀도': 0.1193}
# 가중치 비율 [0.89, 0.01, 0.1] {'정밀도': 0.1188}
# 가중치 비율 [0.89, 0.02, 0.09] {'정밀도': 0.1186}
# 가중치 비율 [0.89, 0.03, 0.08] {'정밀도': 0.1182}
# 가중치 비율 [0.89, 0.04, 0.07] {'정밀도': 0.1173}
# 가중치 비율 [0.89, 0.05, 0.06] {'정밀도': 0.1172}
# 가중치 비율 [0.89, 0.06, 0.05] {'정밀도': 0.1168}
# 가중치 비율 [0.89, 0.07, 0.04] {'정밀도': 0.1164}
# 가중치 비율 [0.89, 0.08, 0.03] {'정밀도': 0.116}
# 가중치 비율 [0.89, 0.09, 0.02] {'정밀도': 0.116}
# 가중치 비율 [0.89, 0.1, 0.01] {'정밀도': 0.1155}
# 가중치 비율 [0.89, 0.11, 0.0] {'정밀도': 0.1152}
# 가중치 비율 [0.9, 0.0, 0.1] {'정밀도': 0.1192}
# 가중치 비율 [0.9, 0.01, 0.09] {'정밀도': 0.1184}
# 가중치 비율 [0.9, 0.02, 0.08] {'정밀도': 0.1183}
# 가중치 비율 [0.9, 0.03, 0.07] {'정밀도': 0.1178}
# 가중치 비율 [0.9, 0.04, 0.06] {'정밀도': 0.1172}
# 가중치 비율 [0.9, 0.05, 0.05] {'정밀도': 0.1171}
# 가중치 비율 [0.9, 0.06, 0.04] {'정밀도': 0.1165}
# 가중치 비율 [0.9, 0.07, 0.03] {'정밀도': 0.1162}
# 가중치 비율 [0.9, 0.08, 0.02] {'정밀도': 0.116}
# 가중치 비율 [0.9, 0.09, 0.01] {'정밀도': 0.1159}
# 가중치 비율 [0.9, 0.1, 0.0] {'정밀도': 0.1152}
# 가중치 비율 [0.91, 0.0, 0.09] {'정밀도': 0.1184}
# 가중치 비율 [0.91, 0.01, 0.08] {'정밀도': 0.1181}
# 가중치 비율 [0.91, 0.02, 0.07] {'정밀도': 0.1179}
# 가중치 비율 [0.91, 0.03, 0.06] {'정밀도': 0.1174}
# 가중치 비율 [0.91, 0.04, 0.05] {'정밀도': 0.1172}
# 가중치 비율 [0.91, 0.05, 0.04] {'정밀도': 0.1168}
# 가중치 비율 [0.91, 0.06, 0.03] {'정밀도': 0.1163}
# 가중치 비율 [0.91, 0.07, 0.02] {'정밀도': 0.1164}
# 가중치 비율 [0.91, 0.08, 0.01] {'정밀도': 0.1161}
# 가중치 비율 [0.91, 0.09, 0.0] {'정밀도': 0.1155}
# 가중치 비율 [0.92, 0.0, 0.08] {'정밀도': 0.1184}
# 가중치 비율 [0.92, 0.01, 0.07] {'정밀도': 0.118}
# 가중치 비율 [0.92, 0.02, 0.06] {'정밀도': 0.1179}
# 가중치 비율 [0.92, 0.03, 0.05] {'정밀도': 0.1175}
# 가중치 비율 [0.92, 0.04, 0.04] {'정밀도': 0.1168}
# 가중치 비율 [0.92, 0.05, 0.03] {'정밀도': 0.1166}
# 가중치 비율 [0.92, 0.06, 0.02] {'정밀도': 0.1164}
# 가중치 비율 [0.92, 0.07, 0.01] {'정밀도': 0.1162}
# 가중치 비율 [0.92, 0.08, 0.0] {'정밀도': 0.1161}
# 가중치 비율 [0.93, 0.0, 0.07] {'정밀도': 0.1184}
# 가중치 비율 [0.93, 0.01, 0.06] {'정밀도': 0.118}
# 가중치 비율 [0.93, 0.02, 0.05] {'정밀도': 0.1179}
# 가중치 비율 [0.93, 0.03, 0.04] {'정밀도': 0.1173}
# 가중치 비율 [0.93, 0.04, 0.03] {'정밀도': 0.1166}
# 가중치 비율 [0.93, 0.05, 0.02] {'정밀도': 0.1166}
# 가중치 비율 [0.93, 0.06, 0.01] {'정밀도': 0.1161}
# 가중치 비율 [0.93, 0.07, 0.0] {'정밀도': 0.1162}
# 가중치 비율 [0.94, 0.0, 0.06] {'정밀도': 0.1181}
# 가중치 비율 [0.94, 0.01, 0.05] {'정밀도': 0.1181}
# 가중치 비율 [0.94, 0.02, 0.04] {'정밀도': 0.1177}
# 가중치 비율 [0.94, 0.03, 0.03] {'정밀도': 0.1171}
# 가중치 비율 [0.94, 0.04, 0.02] {'정밀도': 0.1167}
# 가중치 비율 [0.94, 0.05, 0.01] {'정밀도': 0.1164}
# 가중치 비율 [0.94, 0.06, 0.0] {'정밀도': 0.1163}
# 가중치 비율 [0.95, 0.0, 0.05] {'정밀도': 0.118}
# 가중치 비율 [0.95, 0.01, 0.04] {'정밀도': 0.118}
# 가중치 비율 [0.95, 0.02, 0.03] {'정밀도': 0.1176}
# 가중치 비율 [0.95, 0.03, 0.02] {'정밀도': 0.117}
# 가중치 비율 [0.95, 0.04, 0.01] {'정밀도': 0.1167}
# 가중치 비율 [0.95, 0.05, 0.0] {'정밀도': 0.1164}
# 가중치 비율 [0.96, 0.0, 0.04] {'정밀도': 0.1177}
# 가중치 비율 [0.96, 0.01, 0.03] {'정밀도': 0.1179}
# 가중치 비율 [0.96, 0.02, 0.02] {'정밀도': 0.1175}
# 가중치 비율 [0.96, 0.03, 0.01] {'정밀도': 0.1169}
# 가중치 비율 [0.96, 0.04, 0.0] {'정밀도': 0.1165}
# 가중치 비율 [0.97, 0.0, 0.03] {'정밀도': 0.118}
# 가중치 비율 [0.97, 0.01, 0.02] {'정밀도': 0.1178}
# 가중치 비율 [0.97, 0.02, 0.01] {'정밀도': 0.1173}
# 가중치 비율 [0.97, 0.03, 0.0] {'정밀도': 0.1169}
# 가중치 비율 [0.98, 0.0, 0.02] {'정밀도': 0.1177}
# 가중치 비율 [0.98, 0.01, 0.01] {'정밀도': 0.1176}
# 가중치 비율 [0.98, 0.02, 0.0] {'정밀도': 0.1174}
# 가중치 비율 [0.99, 0.0, 0.01] {'정밀도': 0.1175}
# 가중치 비율 [0.99, 0.01, 0.0] {'정밀도': 0.1174}
# 가중치 비율 [1.0, 0.0, 0.0] {'정밀도': 0.1179}
#
#  최대 정밀도: ['가중치 비율', [0.88, 0.0, 0.12], {'정밀도': 0.1194}]

# %%
# with open('./data_model/total_param.json', 'w') as json_file:
#     json.dump(total_param, json_file)

# %%
x = range(len(total_param))
y = [entry[2]['정밀도'] for entry in total_param]

# 꺾은선 그래프 그리기
plt.plot(x, y, marker='.')

plt.title('종합 모델의 정밀도 변화')
plt.xlabel('')
plt.ylabel('정밀도')

# 그래프 표시
plt.grid(True)
plt.show()

print('최대 정밀도',max(y))
# Out:
# 최대 정밀도 0.1194

# %% [markdown]
# ## 최종 모델 결정
# - 주문 유사도 417개 반영
# - 고객 유사도 396개 반영
# - 아이템 유사도 436개 반영
# - 각각의 가중치 [0.88, 0.0, 0.12] 반영

# %%
pred_final = recomm_model((0.88*pred_IS + 0*pred_CS + 0.12*pred_Des), recomm_n = recomm_n)

# %% [markdown]
# ## 최종모델 검정

# %% [markdown]
# ### 인기제품 추천

# %%
#구매 수량 순, 구매 횟수 순 정렬
top_Quant_prod = train[['StockCode','Quantity']].groupby('StockCode').sum().sort_values(by='Quantity',ascending=False)
top_buy_prod = pd.DataFrame(train['StockCode'].value_counts())

# %%
top_buy_prod
# Out:
#            count
# StockCode
# 85123A      3046
# 85099B      1693
# 22423       1633
# 21212       1540
# 21232       1383
# ...          ...
# 90077          1
# 21838          1
# 20835          1
# 35950          1
# 90011A         1
#
# [4000 rows x 1 columns]

# %% [markdown]
# #### 이미 구매한 제품 제외, 인기도 순
# 확연히 낮은 정밀도를 보임을 알 수 있음

# %%
def popular_prod_eval(recomm_n = 10, popular_df = top_Quant_prod):
    total_conf_matrix = np.matrix([[0,0],[0,0]])
    shared_customers = set(train['CustomerID'].unique()).intersection(set(test['CustomerID'].unique())) 
    for CustomerID in shared_customers:
        #구매하지 않은 상품 추출
        Customer_info = pivot_CS.loc[CustomerID,]
        unbought_list = Customer_info[Customer_info==0].index

        #구매하지 않은 상품 중 상위 인기 recomm_n개 추천
        unbought_pop_df = popular_df[popular_df.index.isin(unbought_list)]
        recomm_prod = unbought_pop_df[:recomm_n].index

        #평가
        y_test = pd.Series(np.zeros(recomm_n))
        for index, value in enumerate(recomm_prod):
            if value in pivot_test.columns:
                y_test[index] = pivot_test.loc[CustomerID, value]
        y_pred = pd.Series(np.ones(len(recomm_prod)))
        conf_matrix = confusion_matrix(y_test, y_pred) # 혼동 행렬 계산
        if (conf_matrix[0,0] != 0):
            print('<전부 구매함>', f'\nCustomerID: {CustomerID}', f'\nprodcuct: {recomm_prod}')
            total_conf_matrix = total_conf_matrix + [[0,0],[0,conf_matrix[0,0]]]
        else:
            total_conf_matrix = total_conf_matrix + conf_matrix

    FP = total_conf_matrix[0,1]
    TP = total_conf_matrix[1,1]

    precision = np.round(TP / (TP + FP), 4) # 정밀도 계산

    evaluation = {'정밀도': precision}    
    return total_conf_matrix, evaluation

# %%
print(popular_prod_eval(recomm_n=recomm_n,popular_df=top_Quant_prod))
popular_prod_eval(recomm_n=recomm_n,popular_df=top_buy_prod)
# Out:
# (matrix([[    0, 30894],
#         [    0,  1602]], dtype=int64), {'정밀도': 0.0493})
# (matrix([[    0, 30286],
#          [    0,  2210]], dtype=int64),
#  {'정밀도': 0.068})

# %% [markdown]
# ### 최종모델의 추천 제품파악

# %%
recomm_final = pred_final[1]

def recomm_test(CustomerID):
    recomm_SC = recomm_final[recomm_final['CustomerID'] == CustomerID[0]]['recommend_products'].explode().tolist()
    recomm_Des = pairs_SD[pairs_SD.index.isin(recomm_SC)]
    recomm_Des.name = 'recomm_prod'
    
    bought_SC = train[train['CustomerID'] == CustomerID[0]]['StockCode'].unique()
    bought_Des = pairs_SD[pairs_SD.index.isin(bought_SC)]
    bought_Des.name = 'bought_prod'

    new_bought_SC = test[test['CustomerID'] == CustomerID[0]]['StockCode'].unique()
    new_bought_Des = pairs_SD[pairs_SD.index.isin(new_bought_SC)]
    new_bought_Des.name = 'new_bought_prod'

    bought_from_recomm = recomm_Des[recomm_Des.isin(new_bought_Des)]
    bought_from_recomm.name = 'bought_from_recomm'
    return recomm_Des, bought_Des, new_bought_Des, bought_from_recomm

# %%
import random

# random.seed(1004)
test_ID = random.sample(recomm_final['CustomerID'].tolist(), 1)
print('CustomerID:',test_ID,'\n')

model_test = recomm_test(test_ID) 

print(model_test[0],'\n') #추천제품
print(model_test[1],'\n') #기존 구매 제품
print(model_test[2],'\n') #최근 구매 제품
print(model_test[3]) #추천한 제품 중 구매한 제품
# Out:
# CustomerID: [13330]
#
# StockCode
# 20724               [RED SPOTTY CHARLOTTE BAG]
# 20725                   [LUNCH BAG RED SPOTTY]
# 20726                     [LUNCH BAG WOODLAND]
# 21930               [JUMBO STORAGE BAG SKULLS]
# 21977     [PACK OF 60 PINK PAISLEY CAKE CASES]
# 22384                [LUNCHBAG PINK RETROSPOT]
# 22411      [JUMBO SHOPPER VINTAGE RED PAISLEY]
# 22554       [PLASTERS IN TIN WOODLAND ANIMALS]
# 22568                  [FELTCRAFT CUSHION OWL]
# 85099B           [JUMBO BAG RED WHITE SPOTTY ]
# 85099C        [JUMBO  BAG BAROQUE BLACK WHITE]
# 85099F                  [JUMBO BAG STRAWBERRY]
# Name: recomm_prod, dtype: object
#
# StockCode
# 16156S                 [WRAP PINK FAIRY CAKES ]
# 16161U                  [WRAP,SUKI AND FRIENDS]
# 20727                 [LUNCH BAG  BLACK SKULL.]
# 20728                     [LUNCH BAG CARS BLUE]
# 20971        [PINK BLUE FELT CRAFT TRINKET BOX]
# 20972      [PINK CREAM FELT CRAFT TRINKET BOX ]
# 21212        [PACK OF 72 RETRO SPOT CAKE CASES]
# 21213             [PACK OF 72 SKULL CAKE CASES]
# 21231          [SWEETHEART CERAMIC TRINKET BOX]
# 21232          [STRAWBERRY CERAMIC TRINKET BOX]
# 21507               [ELEPHANT, BIRTHDAY CARD, ]
# 21509      [COWBOYS AND INDIANS BIRTHDAY CARD ]
# 21917         [SET 12 KIDS  WHITE CHALK STICKS]
# 21918        [SET 12 KIDS COLOUR  CHALK STICKS]
# 21931                  [JUMBO STORAGE BAG SUKI]
# 21935                      [SUKI  SHOULDER BAG]
# 21975          [PACK OF 60 DINOSAUR CAKE CASES]
# 21976          [PACK OF 60 MUSHROOM CAKE CASES]
# 22029                 [SPACE BOY BIRTHDAY CARD]
# 22045                     [SPACE BOY GIFT WRAP]
# 22138           [BAKING SET 9 PIECE RETROSPOT ]
# 22147              [FELTCRAFT BUTTERFLY HEARTS]
# 22149              [FELTCRAFT 6 FLOWER FRIENDS]
# 22355             [CHARLOTTE BAG , SUKI DESIGN]
# 22367            [CHILDS APRON SPACEBOY DESIGN]
# 22380                     [TOY TIDY SPACEBOY  ]
# 22381               [TOY TIDY PINK RETROSPOT  ]
# 22382               [LUNCHBAG SPACEBOY DESIGN ]
# 22383                  [LUNCHBAG SUKI  DESIGN ]
# 22385               [JUMBO BAG SPACEBOY DESIGN]
# 22386         [JUMBO BAG PINK WITH WHITE SPOTS]
# 22417          [PACK OF 60 SPACEBOY CAKE CASES]
# 22437           [SET OF 9 BLACK SKULL BALLOONS]
# 22439                      [6 ROCKET BALLOONS ]
# 22489          [PACK OF 12 TRADITIONAL CRAYONS]
# 22493               [PAINT YOUR OWN CANVAS SET]
# 22502              [PICNIC BASKET WICKER SMALL]
# 22526               [WHEELBARROW FOR CHILDREN ]
# 22551                [PLASTERS IN TIN SPACEBOY]
# 22553                  [PLASTERS IN TIN SKULLS]
# 22563                     [HAPPY STENCIL CRAFT]
# 22566     [FELTCRAFT HAIRBAND S/2, PINK/PURPLE]
# 22569             [FELTCRAFT CUSHION BUTTERFLY]
# 22570                [FELTCRAFT CUSHION RABBIT]
# 22586        [FELTCRAFT HAIRBAND PINK AND BLUE]
# 22617              [BAKING SET SPACEBOY DESIGN]
# 22629                     [SPACEBOY LUNCH BOX ]
# 22634          [CHILDS BREAKFAST SET SPACEBOY ]
# 22636      [CHILDS BREAKFAST SET CIRCUS PARADE]
# 22749       [FELTCRAFT PRINCESS CHARLOTTE DOLL]
# 47591D          [PINK FAIRY CAKE CHILD'S APRON]
# 84078A       [SET/4 WHITE RETRO STORAGE CUBES ]
# 84991             [60 TEATIME FAIRY CAKE CASES]
# Name: bought_prod, dtype: object
#
# StockCode
# 20728                  [LUNCH BAG CARS BLUE]
# 20992           [JAZZ HEARTS PURSE NOTEBOOK]
# 21242                    [RED SPOTTY PLATE ]
# 21365              [MIRRORED WALL ART STARS]
# 21369           [MIRRORED WALL ART SPLODGES]
# 21373         [MIRRORED WALL ART SNOWFLAKES]
# 21374             [MIRRORED WALL ART SKULLS]
# 21843                [RETRO SPOT CAKE STAND]
# 21929       [JUMBO BAG PINK VINTAGE PAISLEY]
# 21930             [JUMBO STORAGE BAG SKULLS]
# 21931               [JUMBO STORAGE BAG SUKI]
# 22139    [RETRO SPOT TEA SET CERAMIC 11 PC ]
# 22148               [EASTER CRAFT 4 CHICKS ]
# 22210           [WOOD STAMP SET BEST WISHES]
# 22211               [WOOD STAMP SET FLOWERS]
# 22382            [LUNCHBAG SPACEBOY DESIGN ]
# 22383               [LUNCHBAG SUKI  DESIGN ]
# 22384              [LUNCHBAG PINK RETROSPOT]
# 22385            [JUMBO BAG SPACEBOY DESIGN]
# 22386      [JUMBO BAG PINK WITH WHITE SPOTS]
# 22431           [WATERING CAN BLUE ELEPHANT]
# 22432              [WATERING CAN PINK BUNNY]
# 22433          [WATERING CAN GREEN DINOSAUR]
# 22467                    [GUMBALL COAT RACK]
# 22489       [PACK OF 12 TRADITIONAL CRAYONS]
# 22502           [PICNIC BASKET WICKER SMALL]
# 22553               [PLASTERS IN TIN SKULLS]
# 22554     [PLASTERS IN TIN WOODLAND ANIMALS]
# 22610             [PENS ASSORTED FUNNY FACE]
# 22629                  [SPACEBOY LUNCH BOX ]
# 84077    [WORLD WAR 2 GLIDERS ASSTD DESIGNS]
# Name: new_bought_prod, dtype: object
#
# StockCode
# 21930            [JUMBO STORAGE BAG SKULLS]
# 22384             [LUNCHBAG PINK RETROSPOT]
# 22554    [PLASTERS IN TIN WOODLAND ANIMALS]
# Name: bought_from_recomm, dtype: object

# %% [markdown]
# #### 13330 고객기준

# %%
pd.DataFrame(recomm_test([13330])[1]) #기존에 구매한 제품
# Out:
#                                      bought_prod
# StockCode
# 16156S                  [WRAP PINK FAIRY CAKES ]
# 16161U                   [WRAP,SUKI AND FRIENDS]
# 20727                  [LUNCH BAG  BLACK SKULL.]
# 20728                      [LUNCH BAG CARS BLUE]
# 20971         [PINK BLUE FELT CRAFT TRINKET BOX]
# 20972       [PINK CREAM FELT CRAFT TRINKET BOX ]
# 21212         [PACK OF 72 RETRO SPOT CAKE CASES]
# 21213              [PACK OF 72 SKULL CAKE CASES]
# 21231           [SWEETHEART CERAMIC TRINKET BOX]
# 21232           [STRAWBERRY CERAMIC TRINKET BOX]
# 21507                [ELEPHANT, BIRTHDAY CARD, ]
# 21509       [COWBOYS AND INDIANS BIRTHDAY CARD ]
# 21917          [SET 12 KIDS  WHITE CHALK STICKS]
# 21918         [SET 12 KIDS COLOUR  CHALK STICKS]
# 21931                   [JUMBO STORAGE BAG SUKI]
# 21935                       [SUKI  SHOULDER BAG]
# 21975           [PACK OF 60 DINOSAUR CAKE CASES]
# 21976           [PACK OF 60 MUSHROOM CAKE CASES]
# 22029                  [SPACE BOY BIRTHDAY CARD]
# 22045                      [SPACE BOY GIFT WRAP]
# 22138            [BAKING SET 9 PIECE RETROSPOT ]
# 22147               [FELTCRAFT BUTTERFLY HEARTS]
# 22149               [FELTCRAFT 6 FLOWER FRIENDS]
# 22355              [CHARLOTTE BAG , SUKI DESIGN]
# 22367             [CHILDS APRON SPACEBOY DESIGN]
# 22380                      [TOY TIDY SPACEBOY  ]
# 22381                [TOY TIDY PINK RETROSPOT  ]
# 22382                [LUNCHBAG SPACEBOY DESIGN ]
# 22383                   [LUNCHBAG SUKI  DESIGN ]
# 22385                [JUMBO BAG SPACEBOY DESIGN]
# 22386          [JUMBO BAG PINK WITH WHITE SPOTS]
# 22417           [PACK OF 60 SPACEBOY CAKE CASES]
# 22437            [SET OF 9 BLACK SKULL BALLOONS]
# 22439                       [6 ROCKET BALLOONS ]
# 22489           [PACK OF 12 TRADITIONAL CRAYONS]
# 22493                [PAINT YOUR OWN CANVAS SET]
# 22502               [PICNIC BASKET WICKER SMALL]
# 22526                [WHEELBARROW FOR CHILDREN ]
# 22551                 [PLASTERS IN TIN SPACEBOY]
# 22553                   [PLASTERS IN TIN SKULLS]
# 22563                      [HAPPY STENCIL CRAFT]
# 22566      [FELTCRAFT HAIRBAND S/2, PINK/PURPLE]
# 22569              [FELTCRAFT CUSHION BUTTERFLY]
# 22570                 [FELTCRAFT CUSHION RABBIT]
# 22586         [FELTCRAFT HAIRBAND PINK AND BLUE]
# 22617               [BAKING SET SPACEBOY DESIGN]
# 22629                      [SPACEBOY LUNCH BOX ]
# 22634           [CHILDS BREAKFAST SET SPACEBOY ]
# 22636       [CHILDS BREAKFAST SET CIRCUS PARADE]
# 22749        [FELTCRAFT PRINCESS CHARLOTTE DOLL]
# 47591D           [PINK FAIRY CAKE CHILD'S APRON]
# 84078A        [SET/4 WHITE RETRO STORAGE CUBES ]
# 84991              [60 TEATIME FAIRY CAKE CASES]

# %%
pairs_CI[pairs_CI.index == 13330] #13330 고객의 주문 => 498774을 임의로 선택
# Out:
# CustomerID
# 13330    [498774, 509396, 522048]
# Name: InvoiceNo, dtype: object

# %% [markdown]
# #### 498774 주문

# %%
tmp = sim_Inv[sim_Inv.index == 498774].values[0]
tmp2 = pd.Series(tmp,index=sim_Inv.index)
tmp2.sort_values()
# Out:
# InvoiceNo
# 489434    0.000000
# 518354    0.000000
# 518355    0.000000
# 518361    0.000000
# 518370    0.000000
#             ...
# 505316    0.385077
# 520703    0.391675
# 496772    0.410792
# 497242    0.553912
# 498774    1.000000
# Length: 18192, dtype: float64

# %%
display(train.loc[(train['InvoiceNo'] == 498774),['StockCode','Description']])
train.loc[(train['InvoiceNo'] == 497242),['StockCode','Description']]
# Out:
#       StockCode                      Description
# 58515     22367     CHILDS APRON SPACEBOY DESIGN
# 58516     22380              TOY TIDY SPACEBOY
# 58517     22381        TOY TIDY PINK RETROSPOT
# 58518     22382        LUNCHBAG SPACEBOY DESIGN
# 58519     22383           LUNCHBAG SUKI  DESIGN
# 58520     22384          LUNCHBAG PINK RETROSPOT
# 58521    47591D    PINK FAIRY CAKE CHILD'S APRON
# 58522     22385        JUMBO BAG SPACEBOY DESIGN
# 58523     22386  JUMBO BAG PINK WITH WHITE SPOTS
# 58524     82580              BATHROOM METAL SIGN
# 58525     20728              LUNCH BAG CARS BLUE

# %%
a = pivot_IS.loc[497242,pivot_IS.loc[497242]==1]
b = pivot_IS.loc[498774,pivot_IS.loc[498774]==1]
print(a,'\n')
print(b, '\n')
print(set(a.index)-set(b.index), '\n')
# Out:
# StockCode
# 20728     1.0
# 22367     1.0
# 22380     1.0
# 22381     1.0
# 22382     1.0
# 22383     1.0
# 22384     1.0
# 22385     1.0
# 22386     1.0
# 47591D    1.0
# 82580     1.0
# Name: 497242, dtype: float64
#
# StockCode
# 20728     1.0
# 20971     1.0
# 20972     1.0
# 21212     1.0
# 21213     1.0
# 21507     1.0
# 21509     1.0
# 21917     1.0
# 21931     1.0
# 22029     1.0
# 22138     1.0
# 22147     1.0
# 22149     1.0
# 22367     1.0
# 22380     1.0
# 22381     1.0
# 22382     1.0
# 22383     1.0
# 22385     1.0
# 22386     1.0
# 22417     1.0
# 47591D    1.0
# 84078A    1.0
# 84991     1.0
# Name: 498774, dtype: float64
#
# {'82580', '22384'}

# %%
Des_uniq[(Des_uniq.index == '82580')| (Des_uniq.index =='22384')]
# Out:
# 22384    LUNCHBAG PINK RETROSPOT
# 82580        BATHROOM METAL SIGN
# dtype: object
